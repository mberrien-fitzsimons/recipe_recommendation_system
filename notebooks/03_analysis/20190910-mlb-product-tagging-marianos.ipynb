# %% [markdown]
# # Tagging Products - Marianos Product Dataset

# %%
import argparse
import nltk
import pandas as pd
import pycrfsuite
import numpy as np
import re
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer

nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/markishab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
grocery_prices_marianos = pd.read_csv('../../data/02_intermediate/marianos_groceries_only.csv')

# %%
grocery_prices_marianos
# Out:
#                                           product main_price  \
# 0                        Green Onions (Scallions)      $0.99
# 1                                        Cilantro      $0.79
# 2                                 Italian Parsley      $0.99
# 3                 Roundy's Organic Fresh Rosemary      $2.50
# 4                    Roundy's Organic Fresh Thyme      $2.50
# ...                                           ...        ...
# 6237                          Organic Purple Kale      $1.79
# 6238                          Green Savoy Cabbage      $4.17
# 6239                             Cubanelle Pepper      $0.33
# 6240                               Belgian Endive      $2.84
# 6241  Marie's Garlic Parmesan Italian Vinaigrette      $4.49
#
#              prod_aile price_per_lb measure_words_main_price  \
# 0          Fresh Herbs          NaN                     each
# 1          Fresh Herbs          NaN                     each
# 2          Fresh Herbs          NaN                     each
# 3          Fresh Herbs          NaN                     each
# 4          Fresh Herbs          NaN                     each
# ...                ...          ...                      ...
# 6237  Fresh Vegetables          NaN                      NaN
# 6238  Fresh Vegetables      1.49/lb                     each
# 6239  Fresh Vegetables      3.29/lb                     each
# 6240  Fresh Vegetables      3.79/lb                     each
# 6241  Fresh Vegetables          NaN                     each
#
#      item_weight_count_vol date_collected     store  location
# 0                      NaN     2019-08-28  Marianos     60615
# 1                      NaN     2019-08-28  Marianos     60615
# 2                      NaN     2019-08-28  Marianos     60615
# 3               0.75 ounce     2019-08-28  Marianos     60615
# 4               0.75 ounce     2019-08-28  Marianos     60615
# ...                    ...            ...       ...       ...
# 6237                   NaN     2019-08-28  Marianos     60615
# 6238                   NaN     2019-08-28  Marianos     60615
# 6239                   NaN     2019-08-28  Marianos     60615
# 6240                   NaN     2019-08-28  Marianos     60615
# 6241         11.5 fl ounce     2019-08-28  Marianos     60615
#
# [6242 rows x 9 columns]

# %%
grocery_prices_marianos['product'].nunique()
# Out:
# 5851

# %%
products_list = list(grocery_prices_marianos['product'])

# %%
products_list_new = []
for i in products_list:
    word = i.replace("'", "")
    products_list_new.append(word.replace(".", ""))

# %%
# let's tokenize all the words and get rid of punctuation
tokenizer = RegexpTokenizer(r'(\d\/\d |\w+)')
token_sr = []
for product in products_list_new:
    token_sr.append(tokenizer.tokenize(product))

# %%
token_sr
# Out:
# [['Green', 'Onions', 'Scallions'],
#  ['Cilantro'],
#  ['Italian', 'Parsley'],
#  ['Roundys', 'Organic', 'Fresh', 'Rosemary'],
#  ['Roundys', 'Organic', 'Fresh', 'Thyme'],
#  ['Roundys', 'Mint'],
#  ['Basil'],
#  ['Dill'],
#  ['Roundys', 'Organics', 'Fresh', 'Dill'],
#  ['Gourmet', 'Garden', 'Ginger', 'Stir', 'in', 'Paste'],
#  ['Organic', 'Chives'],
#  ['Simple', 'Truth', 'Organic', 'Ithyme', 'Leaves'],
#  ['Organic', 'Curly', 'Parsley'],
#  ['Roundys', 'Organics', 'Sage'],
#  ['Roundys', 'Bay', 'Leaf'],
#  ['Bellino', 'Peeled', 'Garlic', 'Cloves'],
#  ['Gourmet', 'Garden', 'Lemongrass', 'Stir', 'in', 'Paste'],
#  ['Organic', 'Fennel', 'Bulb'],
#  ['Gourmet', 'Garden', 'Lightly', 'Dried', 'Parsley'],
#  ['Organic', 'Curly', 'Parsley', 'Bunch'],
#  ['McCormick', 'Thyme', 'Leaves'],
#  ['Roundys', 'Organics', 'Fresh', 'Parsley'],
#  ['Simple', 'Truth', 'Organic', 'Organic', 'Oregano', 'Leaves'],
#  ['Roundys', 'Ground', 'Ginger'],
#  ['Gourmet', 'Garden', 'Cilantro', 'Stir', 'in', 'Paste'],
#  ['Spice', 'Islands', 'Thyme'],
#  ['Ntwy', 'Dong', 'Quai', 'Root'],
#  ['Lemon', 'Basil', 'Package'],
#  ['Hersheys', 'Natural', 'Unsweetened', 'Cocoa'],
#  ['Arm', 'Hammer', 'Pure', 'Baking', 'Soda'],
#  ['Toll', 'House', 'Real', 'Semi', 'Sweet', 'Chocolate', 'Morsels'],
#  ['Libbys', 'Pumpkin', '100', 'Pure', 'LIBBYS', '100', 'Pure', 'Pumpkin'],
#  ['Kroger', 'Cocoa'],
#  ['Spice', 'Islands', 'Pure', 'Vanilla', 'Extract'],
#  ['Ghirardelli', 'Chocolate', 'Baking', 'Chips', '60', 'Cacao', 'Bittersweet'],
#  ['Stevia', 'in', 'the', 'Raw', 'Zero', 'Calorie', 'Sweetener'],
#  ['Splenda', 'No', 'Calorie', 'Sweetener', 'Packets'],
#  ['Carnation', 'Evaporated', 'Milk'],
#  ['King', 'Arthur', 'Flour', 'Unbleached', 'Flour', 'Bread'],
#  ['Toll', 'House', 'Dark', 'Chocolate', 'Morsels'],
#  ['King', 'Arthur', 'Flour', 'Unbleached', 'Flour', 'All', 'Purpose'],
#  ['Domino', 'Light', 'Brown', 'Sugar'],
#  ['Ghirardelli', 'Chocolate', 'Baking', 'Chips', 'Semi', 'Sweet', 'Chocolate'],
#  ['Sugar', 'In', 'The', 'Raw', 'Turbinado', 'Cane', 'Sugar'],
#  ['Domino', 'Premium', 'Pure', 'Cane', 'Granulated', 'Sugar'],
#  ['Simple', 'Truth', 'Organic', 'Madagascar', 'Vanilla', 'Extract'],
#  ['Granulated', 'No', 'Calorie', 'Sweetener'],
#  ['Gold', 'Medal', 'Flour', 'All', 'Purpose'],
#  ['McCormick', 'All', 'Natural', 'Pure', 'Vanilla', 'Extract'],
#  ['Kroger', 'Sliced', 'Almonds'],
#  ['Fleischmanns', 'ActiveDry', 'Yeast', 'Original'],
#  ['Florida',
#   'Crystals',
#   'Organic',
#   'Raw',
#   'Cane',
#   'Florida',
#   'Crystals',
#   'Organic',
#   'Raw',
#   'Cane',
#   'Sugar'],
#  ['Toll', 'House', 'Milk', 'Chocolate', 'Morsels'],
#  ['Libbys', 'Pumpkin', '100', 'Pure', 'LIBBYS', '100', 'Pure', 'Pumpkin'],
#  ['Ghirardelli', 'Chocolate', 'Premium', 'Baking', 'Cocoa', '100', 'Cocoa'],
#  ['Sweet',
#   'Leaf',
#   'Tea',
#   'Co',
#   'SweetLeaf',
#   'Natural',
#   'Stevia',
#   'Sweetener',
#   'Packets',
#   '70',
#   'CT'],
#  ['Kroger', 'Walnut', 'Pieces'],
#  ['Truvia', 'Natural', 'Sweetener'],
#  ['Keebler', 'Ready', 'Crust', 'Pie', 'Crust', 'Graham'],
#  ['Domino', 'Premium', 'Pure', 'Cane', 'Granulated', 'Sugar'],
#  ['Ghirardelli', 'Chocolate', 'Milk', 'Choc', 'Chips'],
#  ['Guittard', 'Candy', 'Chocolate', 'Extra', 'Dark', 'Bag'],
#  ['La', 'Lechera', 'Sweetened', 'Condensed', 'Milk'],
#  ['Domino',
#   'Confectioners',
#   'Pure',
#   'Cane',
#   '10',
#   'X',
#   'Powdered',
#   'Domino',
#   'Confectioners',
#   'Pure',
#   'Cane',
#   '10',
#   'X',
#   'Powdered',
#   'Sugar'],
#  ['Simple', 'Truth', 'Organic', 'Sugar'],
#  ['Duncan', 'Hines', 'Signature', 'Cake', 'Mix', 'Lemon', 'Supreme'],
#  ['Snack', 'Pack', 'Pudding', 'Banana', 'Cream', 'Pie'],
#  ['Diamond', 'Of', 'California', 'Pine', 'Nuts'],
#  ['Kroger', 'Walnut', 'Pieces'],
#  ['Gold', 'Medal', 'All', 'Purpose', 'Flour', 'Resealable', 'Bag'],
#  ['Clabber', 'Girl', 'Double', 'Acting', 'Baking', 'Powder'],
#  ['Equal', 'Original', '0', 'Calorie', 'Sweetener', 'Packets'],
#  ['Domino',
#   'Pure',
#   'Cane',
#   'Certified',
#   'Organic',
#   'Domino',
#   'Organic',
#   'Raw',
#   'Cane',
#   'Sugar'],
#  ['Kroger', 'Sweetener', 'No', 'Calorie'],
#  ['Kroger', 'Halves', 'Pecans'],
#  ['Pillsbury', 'Best', 'All', 'Purpose', 'Flour', 'Bleached', 'Enriched'],
#  ['Success', 'Boil', 'in', 'Bag', '100', 'Tri', 'Color', 'Quinoa'],
#  ['Carnation', 'Evaporated', 'Lowfat', '2', 'Mil'],
#  ['Bakers', 'Vanilla', 'Flavor'],
#  ['Domino', 'Dark', 'Brown', 'Sugar'],
#  ['Bakers',
#   'Real',
#   'Milk',
#   'Chocolate',
#   'Bakers',
#   'Real',
#   'Milk',
#   'Chocolate',
#   'Dipping',
#   'Chocolate'],
#  ['Domino',
#   'Quick',
#   'Dissolve',
#   'Superfine',
#   'Domino',
#   'Superfine',
#   'Pure',
#   'Cane',
#   'Sugar'],
#  ['Domino', 'Premium', 'Pure', 'Cane', 'Granulated', 'Sugar'],
#  ['Kroger', 'Pecan', 'Pieces'],
#  ['McCormick', 'Cinnamon', 'Sugar'],
#  ['Diamond', 'Of', 'California', 'Chopped', 'Macadamia', 'Nuts'],
#  ['Fleischmanns', 'RapidRise', 'Instant', 'Yeast'],
#  ['Kroger', 'Instant', 'Banana', 'Pudding', 'Pie', 'Filling'],
#  ['Hersheys', 'Kitchens', 'Special', 'Dark', 'Chocolate', 'Baking', 'Chips'],
#  ['Crystal', 'Granulated', 'Sugar'],
#  ['Eagle', 'Brand', 'Borden', 'Sweetened', 'Condensed', 'Milk'],
#  ['McCormick', 'Clear', 'Vanilla', 'Flavor'],
#  ['Wholesome', 'Organic', 'Turbinado', 'Raw', 'Cane', 'Sugar'],
#  ['Kraft', 'Marshmallows'],
#  ['Moly', 'Mcbutter', 'Butter', 'Flavor', 'Sprinkles'],
#  ['Kraft',
#   'Jet',
#   'Puffed',
#   'Miniature',
#   'Kraft',
#   'Jet',
#   'Puffed',
#   'Miniature',
#   'Marshmallows'],
#  ['Jell', 'O', 'Sugar', 'Free', 'Orange', 'Low', 'Calorie', 'Gelatin', 'Mix'],
#  ['Domino', 'Premium', 'Pure', 'Cane', 'Granulated', 'Sugar'],
#  ['Kraft', 'Jet', 'Puffed', 'Jumbo', 'Marshmallows'],
#  ['Jet',
#   'Puffed',
#   'FunMallows',
#   'Miniature',
#   'Marshmallows',
#   'Orange',
#   'Strawberry',
#   'Lemon',
#   'Lime'],
#  ['Kroger', 'Marshmallows'],
#  ['Gold', 'Medal', 'All', 'Purpose', 'Flour'],
#  ['Wilderness',
#   'Country',
#   'Cherry',
#   'Duncan',
#   'Hines',
#   'Wilderness',
#   'Country',
#   'Cherry',
#   'Pie',
#   'Filling',
#   'Topping'],
#  ['Kroger', 'Apriva', 'Zero', 'Calorie', 'Sweetener'],
#  ['Toll',
#   'House',
#   'Butterscotch',
#   'NESTLE',
#   'TOLL',
#   'HOUSE',
#   'Butterscotch',
#   'Morsels'],
#  ['Domino', 'Pourable', 'Light', 'Brown'],
#  ['Crisco', 'Butter', 'Flavor', 'All', 'Vegetable', 'Shortening'],
#  ['Hersheys', 'Kitchens', 'Milk', 'Chocolate', 'Baking', 'Chips'],
#  ['Crystal', 'Sugar', 'Powdered', 'Confectioners', 'Sugar'],
#  ['McCormick', 'Premium', 'Vanilla', 'Flavor'],
#  ['SweetN', 'Low', 'Zero', 'Calorie', 'Sweetener'],
#  ['Gold', 'Medal', 'Unbleached', 'All', 'Purpose', 'Flour'],
#  ['Kroger', 'Dry', 'Milk', 'Instant', 'Non', 'fat'],
#  ['McCormick', 'Maple', 'Extract', 'With', 'Other', 'Natural', 'Flavors'],
#  ['Jell', 'O', 'Jell', 'O', 'Lime', 'Sugar', 'Free', 'Gelatin', 'Mix'],
#  ['Pillsbury', 'Best', 'Bread', 'Flour', 'Enriched'],
#  ['Crystal', 'Sugar', 'Light', 'Brown', 'Sugar'],
#  ['McCormick', 'Coconut', 'Extract', 'With', 'Other', 'Natural', 'Flavors'],
#  ['Domino', 'Light', 'Brown', 'Sugar'],
#  ['Toll',
#   'House',
#   '62',
#   'Cacao',
#   'Bittersweet',
#   'Chocolate',
#   'NESTLE',
#   'TOLL',
#   'HOUSE',
#   '62',
#   'Cacao',
#   'Bittersweet',
#   'Chocolate',
#   'Morsels'],
#  ['Jell',
#   'O',
#   'Sugar',
#   'Free',
#   'Strawberry',
#   'Low',
#   'Calorie',
#   'Gelatin',
#   'Mix'],
#  ['Sweet',
#   'Leaf',
#   'Tea',
#   'Co',
#   'Sweet',
#   'Drops',
#   'Sweetener',
#   'Vanilla',
#   'Creme'],
#  ['Bobs', 'Red', 'Mill', 'Super', 'Fine', 'Almond', 'Flour'],
#  ['Bakers', 'Premium', 'Unsweetened', 'Chocolate', 'Baking', 'Bar'],
#  ['Jell', 'o', 'Jell', 'Oâ', 'Raspberry', 'Gelatin', 'Mix'],
#  ['Jell', 'O', 'Strawberry', 'Gelatin', 'Mix'],
#  ['Roundys', 'Walnut', 'Halves', 'Pieces'],
#  ['Private', 'Selection', 'Dark', 'Chocolate', 'Chunks'],
#  ['King',
#   'Arthur',
#   'Flour',
#   '100',
#   'Whole',
#   'Grain',
#   'Flour',
#   'Whole',
#   'Wheat'],
#  ['Wilderness', 'Original', 'Berry', 'Medley', 'Pie', 'Filling', 'Topping'],
#  ['Reeses', 'Peanut', 'Butter', 'Baking', 'Chips'],
#  ['Kroger', 'Ready', 'to', 'Eat', 'Chocolate', 'Pie', 'Crust'],
#  ['Bakers', 'Premium', 'Semi', 'Sweet', 'Chocolate', 'Baking', 'Bar'],
#  ['Kroger', 'Evaporated', 'Milk'],
#  ['Simple', 'Truth', 'Organic', 'Light', 'Brown', 'Sugar'],
#  ['Diamond', 'Of', 'California', 'Chopped', 'Pecans'],
#  ['Jell',
#   'O',
#   'Sugar',
#   'Free',
#   'Raspberry',
#   'Low',
#   'Calorie',
#   'Gelatin',
#   'Mix'],
#  ['McCormick', 'Red', 'Food', 'Color'],
#  ['Domino',
#   'Demerara',
#   'Raw',
#   'Cane',
#   'Sugar',
#   'Demerara',
#   'Raw',
#   'Cane',
#   'Sugar'],
#  ['Diamond', 'Of', 'California', 'Shelled', 'Walnuts'],
#  ['Jell', 'O', 'Grape', 'Gelatin', 'Dessert'],
#  ['Kroger', 'Unbleached', 'All', 'Purpose', 'Enriched', 'Flour'],
#  ['Kroger', 'Semisweet', 'Chocolate', 'Chips'],
#  ['Jell',
#   'O',
#   'Sugar',
#   'Free',
#   'Black',
#   'Cherry',
#   'Low',
#   'Calorie',
#   'Gelatin',
#   'Dessert',
#   'Mix'],
#  ['Quaker', 'Corn', 'Meal', 'White'],
#  ['Domino', 'Dark', 'Brown', 'Sugar'],
#  ['Crisco', 'All', 'Vegetable', 'Shortening'],
#  ['Kroger', 'Sweetened', 'Condensed', 'Milk'],
#  ['Carnation', 'Sweetened', 'CARNATION', 'Sweetened', 'Condensed', 'Milk'],
#  ['Simple', 'Truth', 'Organic', 'Unsweetened', 'Coconut', 'Flakes'],
#  ['Bakers',
#   'Angel',
#   'Flake',
#   'Sweetened',
#   'Bakers',
#   'Angel',
#   'Flake',
#   'Sweetened',
#   'Coconut'],
#  ['Kretschmer', 'Wheat', 'Germ', 'Original', 'Toasted'],
#  ['Diamond', 'Of', 'California', 'Chopped', 'Pecans'],
#  ['Wholesome', 'Sugar', 'Natural', 'Raw', 'Cane', 'Turbinado'],
#  ['Kroger',
#   'Instant',
#   'Sugar',
#   'Free',
#   'Vanilla',
#   'Pudding',
#   'Pie',
#   'Filling'],
#  ['Kroger', 'Pecan', 'Halves'],
#  ['Quaker', 'Yellow', 'Cornmeal'],
#  ['Droste', 'Cocoa'],
#  ['Kroger', 'Apriva', 'Zero', 'Calorie', 'Sweetener', 'With', 'Sucralose'],
#  ['Crisco', 'Shortening', 'All', 'Vegetable', 'Butter', 'Flavor'],
#  ['McCormick', 'Premium', 'Vanilla', 'Flavor'],
#  ['Toll', 'House', 'Premier', 'White', 'Morsels'],
#  ['Gold', 'Medal', 'White', 'Whole', 'Wheat', 'Flour'],
#  ['Honey',
#   'Maid',
#   'Graham',
#   'Nabisco',
#   'Honey',
#   'Maid',
#   'Graham',
#   'Cracker',
#   'Crumbs'],
#  ['McCormick', 'All', 'Natural', 'Pure', 'Vanilla', 'Extract'],
#  ['Domino',
#   'Confectioners',
#   '10',
#   'X',
#   'Powdered',
#   'Pure',
#   'Cane',
#   'with',
#   'Cornstarch',
#   'Sugar'],
#  ['Nabisco', 'Oreo', 'Pie', 'Crust'],
#  ['McCormick', 'Pure', 'Peppermint', 'Extract'],
#  ['Crystal', 'Sugar', 'Dark', 'Brown', 'Sugar'],
#  ['Ceresota', 'Flour', 'All', 'Purpose'],
#  ['Wholesome', 'Natural', 'Cane', 'Sugar'],
#  ['Kroger', 'All', 'Purpose', 'Enriched', 'Flour'],
#  ['Simple', 'Truth', 'Organic', 'Semi', 'Sweet', 'Chocolate', 'Chips'],
#  ['Fleischmanns', 'Bread', 'Machine', 'Instant', 'Yeast'],
#  ['Honey',
#   'Maid',
#   'Graham',
#   'Cracker',
#   'Nabisco',
#   'Honey',
#   'Maid',
#   'Graham',
#   'Cracker',
#   'Crust'],
#  ['Kroger', 'Vanilla', 'Candy', 'Coating'],
#  ['Splenda', 'Brown', 'Sugar', 'Blend'],
#  ['Crisco', 'All', 'Vegetable', 'Shortening', 'Baking', 'Sticks'],
#  ['King', 'Arthur', 'Flour', '100', 'Organic', 'All', 'Purpose', 'Flour'],
#  ['Kroger', 'Flour', 'All', 'Purpose'],
#  ['Swans', 'Down', 'Enriched', 'Bleached', 'Cake', 'Flour'],
#  ['Kroger', 'Zero', 'Calorie', 'Sweetener'],
#  ['Toll',
#   'House',
#   'Milk',
#   'Chocolate',
#   'NESTLE',
#   'TOLL',
#   'HOUSE',
#   'Milk',
#   'Chocolate',
#   'Morsels'],
#  ['Private', 'Selection', 'Sea', 'Salt', 'Caramel', 'Chocolate', 'Chunk'],
#  ['Kroger', 'Vanilla', 'Pudding', 'Pie', 'Filling'],
#  ['Kroger', 'Unsweetened', 'Coconut', 'Flakes'],
#  ['Kroger', 'Original', 'Pizza', 'Crust'],
#  ['Kroger', 'Sweetened', 'Coconut', 'Flakes'],
#  ['Keebler',
#   'Ready',
#   'Crust',
#   'Ready',
#   'Crust',
#   'Mini',
#   'Graham',
#   'Cracker',
#   'Pie',
#   'Crusts'],
#  ['Navitas',
#   'Organics',
#   'Freeze',
#   'dried',
#   'Acai',
#   'Powder',
#   'Amazon',
#   'Superfruit'],
#  ['Hersheys', 'Kitchens', 'Semi', 'Sweet', 'Chocolate', 'Baking', 'Chips'],
#  ['Duncan', 'Hines', 'Cake', 'Mix', 'Red', 'Velvet'],
#  ['Private', 'Selection', 'Smooth', 'White', 'Chocolate', 'Drops'],
#  ['Bakers',
#   'Bittersweet',
#   'Chocolate',
#   'Premium',
#   'Baker',
#   's',
#   'Bittersweet',
#   'Chocolate',
#   'Premium',
#   'Baking',
#   'Bar'],
#  ['McCormick', 'Imitation', 'Almond', 'Extract'],
#  ['C',
#   'H',
#   'Pure',
#   'Cane',
#   'Cubes',
#   'C',
#   'H',
#   'Pure',
#   'Cane',
#   'Sugar',
#   'Cubes'],
#  ['Bobs', 'Red', 'Mill', 'Flaxseed', 'Meal', 'Premium', 'Whole', 'Ground'],
#  ['Bakers', 'Premium', 'White', 'Chocolate', 'Baking', 'Bar'],
#  ['Jell', 'O', 'Lime', 'Gelatin', 'Dessert', 'Mix'],
#  ['Jell', 'O', 'Orange', 'Gelatin', 'Mix'],
#  ['Carnation',
#   'Fat',
#   'Free',
#   'CARNATION',
#   'Fat',
#   'Free',
#   'Evaporated',
#   'Milk'],
#  ['Jell', 'O', 'Sugar', 'Free', 'Lemon', 'Low', 'Calorie', 'Gelatin', 'Mix'],
#  ['Gold', 'Medal', 'Unbleached', 'All', 'Purpose', 'Flour'],
#  ['Gold', 'Medal', 'Wondra', 'Quick', 'Mixing', 'Flour'],
#  ['Crisco', 'All', 'Vegetable', 'Shortening'],
#  ['Kroger', 'Instant', 'Vanilla', 'Pudding', 'Pie', 'Filling'],
#  ['Gold', 'Medal', 'Unbleached', 'Bread', 'Flour'],
#  ['McCormick', 'Rum', 'Extract', 'With', 'Other', 'Natural', 'Flavors'],
#  ['Kroger', 'Extra', 'Peach', 'Pie', 'Filling'],
#  ['McCormick', 'Concentrated', 'Vanilla', 'Flavor'],
#  ['Kroger', 'Walnut', 'Halves', 'And', 'Pieces'],
#  ['Kroger', 'Pistachio', 'Pudding', 'Pie', 'Filling'],
#  ['Kroger', 'Mini', 'Marshmallows'],
#  ['Private', 'Selection', 'Semi', 'sweet', 'Chocolate', 'Drops'],
#  ['Saco', 'The', 'Saco', 'Pantry', 'Cultured', 'Buttermilk', 'Blend'],
#  ['McCormick', 'Pure', 'Mint', 'Extract'],
#  ['Solo', 'Pure', 'Almond', 'Paste'],
#  ['McCormick', 'Pure', 'Almond', 'Extract'],
#  ['Bobs', 'Red', 'Mill', 'Gluten', 'Free', 'Whole', 'Grain', 'Oat', 'Flour'],
#  ['SPLENDA',
#   'Naturals',
#   'Stevia',
#   'Sweetener',
#   'Packets',
#   'Sugar',
#   'free',
#   'No',
#   'Calorie',
#   'Sweetener',
#   'Made',
#   'With',
#   'Stevia',
#   'Leaf'],
#  ['Sweet', 'Leaf', 'Tea', 'Co', 'Stevia', 'Sweetener'],
#  ['Bobs',
#   'Red',
#   'Mill',
#   'Unbleached',
#   'White',
#   'All',
#   'Purpose',
#   'Organic',
#   'Flour'],
#  ['Heath', 'Milk', 'Chocolate', 'Toffee', 'Bits'],
#  ['Kroger', 'Flour', 'All', 'Purpose'],
#  ['Crisco', 'Baking', 'Stick'],
#  ['Kroger', 'Peanut', 'And', 'Pecan', 'Nut', 'Topping'],
#  ['Pillsbury', 'Best', 'Self', 'Rising', 'Flour'],
#  ['Wilderness',
#   'Blueberry',
#   'Duncan',
#   'Hines',
#   'Wilderness',
#   'Blueberry',
#   'Pie',
#   'Filling',
#   'Topping'],
#  ['Pillsbury', 'Best', 'Whole', 'Wheat', 'Flour'],
#  ['Bobs', 'Red', 'Mill', 'Organic', 'Cornmeal', 'Medium', 'Grind'],
#  ['McCormick', 'Pure', 'Orange', 'Extract'],
#  ['Bobs', 'Red', 'Mill', 'Brown', 'Rice', 'Flour'],
#  ['Wilderness',
#   'Apple',
#   'Duncan',
#   'Hines',
#   'Wilderness',
#   'Apple',
#   'Pie',
#   'Filling',
#   'Topping'],
#  ['McCormick', 'Banana', 'Extract', 'With', 'Other', 'Natural', 'Flavors'],
#  ['Jell', 'o', 'Jell', 'O', 'Lemon', 'Gelatin', 'Mix'],
#  ['Bobs', 'Red', 'Mill', 'No', '1', 'Durum', 'Wheat', 'Semolina', 'Flour'],
#  ['Gold', 'Medal', 'Whole', 'Wheat', 'Flour'],
#  ['Bobs', 'Red', 'Mill', 'Wheat', 'Germ'],
#  ['Hodgson', 'Mill', 'Premium', 'Naturally', 'White', 'Flour'],
#  ['Red',
#   'Star',
#   'Yeast',
#   'Quick',
#   'Rise',
#   'Yeast',
#   'for',
#   'Bread',
#   'Machines',
#   'Tradtional',
#   'Baking'],
#  ['Bella', 'Bread', 'Crumbs', 'Italian', 'Style', 'Tub'],
#  ['Crisco', 'Shortening', 'All', 'Vegetable', 'Butter'],
#  ['Kroger', 'Fast', 'Rise', 'Yeast'],
#  ['Kroger', 'Pork', 'Flavored', 'Stuffing', 'Mix'],
#  ['Clean', 'Clear', 'Zesty', 'Scrub', 'Lemon'],
#  ['Diamond', 'of', 'California', 'Walnuts', 'Shelled'],
#  ['Bobs', 'Red', 'Mill', 'Baking', 'Flour', '1', 'to', '1'],
#  ['Bobs', 'Red', 'Mill', 'Flour', 'Tapioca', 'Finely', 'Ground'],
#  ['Bobs', 'Red', 'Mill', 'All', 'Purpose', 'Baking', 'Flour'],
#  ['Simple',
#   'Truth',
#   'Organic',
#   'Semi',
#   'Sweet',
#   'Vegan',
#   'Chocolate',
#   'Chips'],
#  ['Carnation', 'Almond', 'Cooking', 'Milk'],
#  ['Grey', 'Poupon', 'Dijon', 'Mustard'],
#  ['Kraft', 'Miracle', 'Whip', 'Miracle', 'Whip'],
#  ['Hunts', 'Tomato', 'Sauce'],
#  ['Frenchs', 'Classic', 'Yellow', 'Mustard'],
#  ['Heinz', 'Tomato', 'Ketchup'],
#  ['Cholula', 'Hot', 'Sauce', 'Original'],
#  ['Kroger', 'Yellow', 'Mustard'],
#  ['Louisiana', 'Brand', 'The', 'Perfect', 'Hot', 'Sauce'],
#  ['Franks', 'RedHot', 'Original', 'Cayenne', 'Pepper', 'Hot', 'Sauce'],
#  ['Heinz', 'No', 'Sugar', 'Added', 'Tomato', 'Ketchup'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Tabasco', 'Pepper', 'Sauce'],
#  ['Dukes', 'Real', 'Mayonnaise'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Halo',
#   'Top',
#   'Dairy',
#   'Free',
#   'Frozen',
#   'Dessert',
#   'Sea',
#   'Salt',
#   'Caramel'],
#  ['Kraft', 'Mayo', 'Avocado', 'Oil', 'Reduced', 'Fat', 'Mayonnaise'],
#  ['Kraft',
#   'Specialty',
#   'Sauces',
#   'Chipotle',
#   'Aioli',
#   'Kraft',
#   'Chipotle',
#   'Aioli'],
#  ['G', 'Hughes', 'Sugar', 'Free', 'BBQ', 'Sauce', 'Hickory'],
#  ['Vlasic', 'Dill', 'Pickle', 'Relish'],
#  ['Simple', 'Truth', 'Organic', 'Tomato', 'Ketchup'],
#  ['Primal', 'Kitchen', 'Real', 'Mayonnaise', 'Made', 'With', 'Avocado', 'Oil'],
#  ['Kraft', 'Mayo', 'Olive', 'Oil', 'Reduced', 'Fat', 'Mayonnaise'],
#  ['Tabasco', 'Pepper', 'Sauce'],
#  ['Koops', 'Mustard', 'Deli', 'Spicy', 'Brown'],
#  ['Heinz', 'Simply', 'Tomato', 'Ketchup'],
#  ['Tabasco', 'Pepper', 'Sauce', 'Chipotle'],
#  ['Ort', 'Med', 'Taco', 'Sce'],
#  ['Heinz', 'Organic', 'Tomato', 'Ketchup'],
#  ['Kraft', 'Miracle', 'Whip', 'Original', 'Dressing'],
#  ['Louisiana', 'Brand', 'The', 'Perfect', 'Hot', 'Sauce'],
#  ['Follow', 'Your', 'Heart', 'Vegenaise', 'Original'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Tabasco', 'Green', 'Pepper', 'Sauce'],
#  ['Franks', 'RedHot', 'Original', 'Cayenne', 'Pepper', 'Hot', 'Sauce'],
#  ['Grey', 'Poupon', 'Harvest', 'Coarse', 'Ground', 'Mustard'],
#  ['Contadina',
#   'Pizza',
#   'Squeeze',
#   'Original',
#   'Contadina',
#   'Pizza',
#   'Squeeze',
#   'OrIginal',
#   'Pizza',
#   'Sauce'],
#  ['Cholula', 'Hot', 'Sauce', 'Original'],
#  ['Kraft',
#   'Barbecue',
#   'Sauce',
#   'Sweet',
#   'Brown',
#   'Sugar',
#   'Barbecue',
#   'Sauce',
#   'Kraft',
#   'Sweet',
#   'Brown',
#   'Sugar',
#   'Barbecue',
#   'Sauce',
#   'Dip'],
#  ['78', 'Red', 'Ketchup', 'Spicy'],
#  ['Marconi', 'Hot'],
#  ['Bearos', 'Original', 'Submarine', 'Dressing'],
#  ['Vlasic', 'Sweet', 'Pickle', 'Relish'],
#  ['Heinz', 'Yellow', 'Heinz', 'Yellow', 'Mustard'],
#  ['Tabasco', 'Pepper', 'Sauce', 'Original'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Alessi', 'Sun', 'Dried', 'Tomatoes'],
#  ['Heinz', 'Tomato', 'Ketchup'],
#  ['Manwich', 'Single', 'Serve', 'Bold', 'Sloppy', 'Joe', 'Sauce'],
#  ['Hellmanns', 'Mayonnaise', 'Dressing', 'With', 'Olive', 'Oil'],
#  ['Follow', 'Your', 'Heart', 'Vegenaise', 'Reduced', 'Fat'],
#  ['Plochmans', 'Mild', 'Yellow', 'Squeeze', 'Mustard'],
#  ['78', 'Red', 'All', 'Natural', 'Ketchup'],
#  ['Primal',
#   'Kitchen',
#   'Chipotle',
#   'Lime',
#   'Mayo',
#   'Made',
#   'With',
#   'Avocado',
#   'Oil'],
#  ['Cholula', 'Hot', 'Sauce', 'Green', 'Pepper'],
#  ['Grey', 'Poupon', 'Country', 'Dijon', 'Mustard'],
#  ['Sir', 'Kensingtons', 'Mayonnaise', 'Classic'],
#  ['Simple', 'Truth', 'Organic', 'Dijon', 'Mustard'],
#  ['Kikkoman', 'Sriracha', 'Mayo'],
#  ['Hellmanns', 'Mayonnaise', 'Dressing', 'With', 'Olive', 'Oil', 'Squeeze'],
#  ['Koops', 'Mustard', 'Stone', 'Ground', 'Flavor'],
#  ['Sir', 'Kensingtons', 'Ketchup', 'Classic'],
#  ['Hellmanns', 'Mayonnaise', 'Organic', 'Spicy', 'Chipotle'],
#  ['McCormick', 'Cinnamon', 'Sugar'],
#  ['Franks', 'RedHot', 'Original', 'Cayenne', 'Pepper', 'Hot', 'Sauce'],
#  ['Hellmanns', 'Mayonnaise', 'Light'],
#  ['Tapatio', 'Hot', 'Sauce'],
#  ['Kraft', 'Mayo', 'Olive', 'Oil', 'Kraft', 'Olive', 'Oil', 'Mayo'],
#  ['Sir', 'Kensingtons', 'Mayonnaise', 'Organic'],
#  ['Heinz', 'Chili', 'Sauce'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Maille', 'Mustard', 'Dijon', 'Originale'],
#  ['Kroger', 'Tartar', 'Sauce'],
#  ['Tabasco', 'Brand', 'Sriracha', 'Sauce'],
#  ['Heinz', 'Yellow', 'Heinz', 'Yellow', 'Mustard'],
#  ['Kraft', 'Mayo', 'Real'],
#  ['Cholula', 'Hot', 'Sauce', 'Chili', 'Garlic'],
#  ['Guldens', 'Spicy', 'Brown', 'Mustard'],
#  ['Lea', 'Perrins', 'The', 'Original', 'Worcestershire', 'Sauce'],
#  ['Cholula', 'Hot', 'Sauce', 'Chili', 'Lime'],
#  ['Sir', 'Kensingtons', 'Mayonnaise', 'Avocado', 'Oil'],
#  ['Kroger', 'Gravy', 'Mix'],
#  ['Hellmanns', 'Light', 'Mayonnaise', 'Squeeze'],
#  ['Heinz', 'Tomato', 'Ketchup'],
#  ['Tostitos', 'Roasted', 'Red', 'Pepper', 'Tortilla', 'Chips'],
#  ['Kroger', 'Mustard'],
#  ['House', 'of', 'Tsang', 'Classic', 'Stir', 'Fry', 'Sauce'],
#  ['Valentina', 'Mexican', 'Hot', 'Sauce', 'Extra', 'Hot'],
#  ['Koops', 'Mustard', 'Honey', 'Mustard'],
#  ['Heinz', 'Organic', 'Tomato', 'Ketchup'],
#  ['Koops', 'Mustard', 'Original', 'Yellow'],
#  ['Kraft', 'Specialty', 'Sauces', 'None', 'Kraft', 'Tartar', 'Sauce'],
#  ['Lea', 'Perrins', 'Worcestershire', 'Sauce'],
#  ['Tapatio', 'Tepatio', 'Hot', 'Sauce'],
#  ['Kraft',
#   'Miracle',
#   'Whip',
#   'Miracle',
#   'Whip',
#   'Kraft',
#   'Miracle',
#   'Whip',
#   'Dressing'],
#  ['Muchacha', 'Salsa', 'Medium'],
#  ['Hellmanns', 'Mayonnaise', 'Dressing', 'With', 'Olive', 'Oil', 'Squeeze'],
#  ['Vlasic', 'Homestyle', 'Sweet', 'Pickle', 'Relish'],
#  ['Franks', 'RedHot', 'Sweet', 'Chili', 'Sauce'],
#  ['Inglehoffer', 'Thick', 'n', 'Creamy', 'Horseradish'],
#  ['Kraft', 'Mayo', 'Real', 'Kraft', 'Real', 'Mayonnaise'],
#  ['Frenchs', 'Classic', 'Yellow', 'Mustard'],
#  ['Mina', 'Harissa', 'Harissa', 'Sauce', 'Moroccan', 'Red', 'Pepper', 'Mild'],
#  ['Hellmanns', 'Light', 'Mayonnaise', 'Squeeze'],
#  ['Kraft', 'Mayo', 'Real', 'Kraft', 'Real', 'Mayonnaise'],
#  ['Heinz', 'Simply', 'Tomato', 'Ketchup'],
#  ['Tabasco', 'Brand', 'Green', 'Jalapeño', 'Pepper', 'Sauce'],
#  ['Heinz', 'Sweet', 'Relish'],
#  ['Grey', 'Poupon', 'Dijon', 'Mustard'],
#  ['Kroger', 'Lite', 'Soy', 'Sauce'],
#  ['Cholula', 'Hot', 'Sauce', 'Chipotle'],
#  ['Crosse', 'Blackwell', 'Shrimp', 'Sauce', 'Zesty'],
#  ['Annies', 'Homegrown', 'Organic', 'Gluten', 'Free', 'Yellow', 'Mustard'],
#  ['Dellalpe', 'Relish', 'Hot', 'Giardiniera'],
#  ['Hellmanns', 'Tartar', 'Sauce'],
#  ['Sweet', 'Baby', 'Rays', 'Hawaiian', 'Style', 'Barbecue', 'Sauce'],
#  ['Frenchs', 'Classic', 'Yellow', 'Mustard'],
#  ['Hellmanns', 'Organic', 'Mayonnaise', 'Original'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Lee', 'Kum', 'Kee', 'Sriracha', 'Mayo'],
#  ['Ortega', 'Original', 'Thick', 'Smooth', 'Hot', 'Taco', 'Sauce'],
#  ['Frenchs', 'Honey', 'Dijon', 'Mustard', 'Squeeze', 'Bottle'],
#  ['Knorr',
#   'Pasta',
#   'Side',
#   'Dish',
#   'Roasted',
#   'Garlic',
#   'Pesto',
#   'With',
#   'Volanti',
#   'Pasta'],
#  ['Valentina', 'Red', 'Hot', 'Sauce'],
#  ['Kraft',
#   'Mayo',
#   'Olive',
#   'Oil',
#   'Reduced',
#   'Fat',
#   'Kraft',
#   'Olive',
#   'Oil',
#   'Reduced',
#   'Fat',
#   'Mayonnaise'],
#  ['Silver', 'Spring', 'Deli', 'Style', 'Mustard', 'Spicy', 'Brown'],
#  ['Kroger', 'Yellow', 'Mustard'],
#  ['Inglehoffer', 'Stone', 'Ground', 'Mustard'],
#  ['Crosse', 'Blackwell', 'Seafood', 'Cocktail', 'Sauce'],
#  ['Koops', 'Mustard', 'Horseradish'],
#  ['Koops', 'Mustard', 'Dijon'],
#  ['Follow', 'Your', 'Heart', 'Grapeseed', 'Oil', 'Vegenaise'],
#  ['Tabasco', 'Brand', 'Habanero', 'Pepper', 'Sauce'],
#  ['Vienna', 'Chicago', 'Style', 'Relish'],
#  ['Maille', 'Mustard', 'Honey', 'Dijon'],
#  ['Frenchs', 'Classic', 'Worcestershire', 'Sauce'],
#  ['Kroger', 'Original', 'Tomato', 'Ketchup'],
#  ['Heinz', '57', 'Sauce'],
#  ['Heinz', 'Sauce', 'Worcestershire'],
#  ['The', 'Ojai', 'Cook', 'Lemonaise'],
#  ['Yings', 'Yum', 'Yum', 'Sauce'],
#  ['Silver', 'Spring', 'Whole', 'Grain', 'Mustard', 'Old', 'Style'],
#  ['PF', 'Changs', 'Teriyaki', 'Sauce'],
#  ['Heinz', 'Spicy', 'Brown', 'Mustard'],
#  ['Heinz',
#   'Hawaii',
#   'Style',
#   'Sweet',
#   'Fruity',
#   'Heinz',
#   'Hawaii',
#   'Style',
#   'Sweet',
#   'Fruity',
#   'BBQ',
#   'Sauce'],
#  ['Heinz', 'Tomato', 'Ketchup'],
#  ['Sweet', 'Baby', 'Rays', 'Creamy', 'Buffalo', 'Wing', 'Dipping', 'Sauce'],
#  ['Texas', 'Pete', 'Hot', 'Sauce', 'Original'],
#  ['Simple', 'Truth', 'Organic', 'Original', 'Bbq', 'Sauce'],
#  ['Kraft', 'Miracle', 'Whip', 'Dressing', 'Light'],
#  ['Lawrys', 'Honey', 'Bourbon', 'Marinade'],
#  ['Heinz', 'Tomato', 'Heinz', 'Tomato', 'Ketchup'],
#  ['Hellmanns', 'Mayonnaise', 'Light'],
#  ['Heinz', 'Jalapeno', 'Tomato', 'Heinz', 'Jalapeno', 'Tomato', 'Ketchup'],
#  ['Kroger', 'Alfredo', 'Sauce'],
#  ['Bookbinders', 'Horseradish', 'Prepared'],
#  ['Grey', 'Poupon', 'Mild', 'Creamy', 'Dijon', 'Mustard'],
#  ['Pickapeppa', 'Sauce'],
#  ['Kraft',
#   'Mayo',
#   'Light',
#   'Mayo',
#   'Light',
#   'Kraft',
#   'Light',
#   'Mayo',
#   'Light',
#   'Mayonnaise'],
#  ['Silver', 'Springs', 'Horseradish', 'Sauce'],
#  ['Koops', 'Mustard', 'Dusseldorf', 'Bratwurst', 'Mustard'],
#  ['Kraft', 'Specialty', 'Sauces', 'Kraft', 'Sandwich', 'Spread'],
#  ['Grey', 'Poupon', 'Dijon', 'Mustard'],
#  ['Heinz', 'Tomato', 'Ketchup', '2'],
#  ['G',
#   'Hughes',
#   'Smokehouse',
#   'Ketchup',
#   'Sugar',
#   'Free',
#   'Original',
#   'Recipe'],
#  ['Kraft', 'Light', 'Kraft', 'Light', 'Mayo'],
#  ['Simple', 'Truth', 'Organic', 'Yellow', 'Mustard'],
#  ['Kikkoman',
#   'Korean',
#   'BBQ',
#   'Kikkoman',
#   'Korean',
#   'BBQ',
#   'Teriyaki',
#   'Sauce'],
#  ['Kraft', 'Miracle', 'Whip', 'Light'],
#  ['Hellmanns', 'Mayonnaise', 'Dressing', 'Low', 'Fat'],
#  ['Chung',
#   'Jung',
#   'One',
#   'Red',
#   'Pepper',
#   'Paste',
#   'Sunchang',
#   '3',
#   'Medium',
#   'Hot'],
#  ['Silver',
#   'Spring',
#   'Beern',
#   'Brat',
#   'Horseradish',
#   'Mustard',
#   'Goodn',
#   'Hot'],
#  ['McCormick',
#   'Golden',
#   'Dipt',
#   'Extra',
#   'Hot',
#   'Seafood',
#   'Cocktail',
#   'Sauce'],
#  ['Sir', 'Kensingtons', 'Mustard', 'Spicy', 'Brown'],
#  ['Hellmanns', 'Mayonnaise', 'Real'],
#  ['Plochmans', 'Mild', 'Yellow', 'Mustard'],
#  ['Kroger', 'Sweet', 'Sour', 'Sauce'],
#  ['Heinz', 'No', 'Salt', 'Added', 'Ketchup', 'Tomato'],
#  ['A1', 'Spicy', 'Chipotle', 'Sauce'],
#  ['Inglehoffer', 'Cream', 'Style', 'Horseradish'],
#  ['Hellmanns', 'Mayonnaise', 'Dressing', 'Canola', 'Cholesterol', 'Free'],
#  ['Kroger', 'Dijon', 'Mustard'],
#  ['Koops', 'Mustard', 'Arizona', 'Heat'],
#  ['Heinz', 'Original', 'Cocktail', 'Sauce'],
#  ['Open',
#   'Pit',
#   'Authentic',
#   'Hickory',
#   'Open',
#   'Pit',
#   'Hickory',
#   'Authentic',
#   'Barbecue',
#   'Sauce'],
#  ['Texas', 'Pete', 'Sriracha', 'CHA', 'Hot', 'Chile', 'Sauce'],
#  ['DeLallo', 'Sun', 'Dried', 'Tomato', 'Bruschetta'],
#  ['Hellmanns', 'Dijonnaise', 'Creamy', 'Dijon', 'Mustard'],
#  ['Kroger', 'Mustard', 'Honey'],
#  ['Frenchs', 'Honey', 'Mustard'],
#  ['Kroger', 'Cocktail', 'Sauce'],
#  ['Kraft', 'Sauce', 'Cocktail'],
#  ['Woebers', 'Horseradish', 'Sauce'],
#  ['Lea',
#   'Perrins',
#   'Reduced',
#   'Sodium',
#   'Lea',
#   'Perrins',
#   'Reduced',
#   'Sodium',
#   'Worcestershire',
#   'Sauce'],
#  ['Kroger', 'Taco', 'Sauce'],
#  ['DeLallo', 'Bruschetta', 'Artichoke'],
#  ['Heinz', 'Real', 'Heinz', 'Real', 'Mayonnaise'],
#  ['KA', 'ME', 'All', 'Natural', 'Duck', 'Sauce'],
#  ['Kroger', 'Horseradish', 'Sauce'],
#  ['Hidden', 'Valley', 'Ranch', 'Dressing', 'Cucumber'],
#  ['Private', 'Selection', 'Creamy', 'Horseradish', 'Sauce'],
#  ['Kraft', 'Miracle', 'Whip', 'Miracle', 'Whip', 'Dressing'],
#  ['Dukes', 'Real', 'Mayonnaise'],
#  ['Kraft', 'Miracle', 'Whip', 'Light', 'Light', 'Miracle', 'Whip'],
#  ['PF', 'Changs', 'Sesame', 'Sauce'],
#  ['Franks', 'RedHot', 'Xtra', 'Hot', 'Sauce'],
#  ['Private', 'Selection', 'Whole', 'Grain', 'Garlic', 'Mustard'],
#  ['Kroger', 'Mild', 'Taco', 'Sauce'],
#  ['McCormick', 'Mayonesa', 'Mayonnaise', 'With', 'Lime', 'Juice'],
#  ['Rufus', 'Teague', 'Whiskey', 'Maple', 'BBQ', 'Sauce'],
#  ['Koops', 'Mustard', 'Organic', 'Dijon'],
#  ['Simple', 'Truth', 'Organic', 'Stone', 'Ground', 'Mustard'],
#  ['Newmans', 'Own', 'Sweet', 'Spicy', 'Barbecue', 'Sauce'],
#  ['Valentina', 'Salsa', 'Picante', 'Extra', 'Hot'],
#  ['Kraft', 'Mayo', 'Real', 'Kraft', 'Real', 'Mayonnaise'],
#  ['Kraft', 'Tartar', 'Sauce', 'Natural', 'Lemon', 'Flavor', 'Herb'],
#  ['Frenchs', 'Dijon', 'Mustard', 'Squeeze', 'Bottle'],
#  ['Organicville', 'Organic', 'Ketchup'],
#  ['Kraft', 'Miracle', 'Whip', 'Dressing', 'With', 'Olive', 'Oil'],
#  ['Kroger', 'Lite', 'Soy', 'Sauce'],
#  ['Edmond', 'Fallot', 'Mustard', 'Dijon'],
#  ['Texas', 'Pete', 'Hotter', 'Texas', 'Pete', 'Hotter', 'Hot', 'Sauce'],
#  ['Private', 'Selection', 'Memphis', 'Barbecue', 'Sauce'],
#  ['Franks', 'RedHot', 'Original', 'Cayenne', 'Pepper', 'Sauce'],
#  ['Kroger', 'Tomato', 'Ketchup'],
#  ['Frenchs', 'Spicy', 'Brown', 'Deli', 'Mustard'],
#  ['Reese', 'Prepared', 'Horseradish'],
#  ['Kroger', 'Worcestershire', 'Sauce'],
#  ['Reese', 'Hollandaise', 'Sauce'],
#  ['Private', 'Selection', 'Coastal', 'Cocktail', 'Sauce'],
#  ['PF', 'Changs', 'Kung', 'Pao', 'Sauce'],
#  ['Private', 'Selection', 'French', 'Recipe', 'Dijon', 'Mustard'],
#  ['Sir', 'Kensingtons', 'Ketchup', 'Spicy'],
#  ['Red', 'Gold', 'Tomato', 'Red', 'Gold', 'Tomato', 'Ketchup'],
#  ['Yellowbird', 'Habanero', 'Condiment', 'Sauce'],
#  ['Kroger', 'Yellow', 'Mustard'],
#  ['Newmans', 'Own', 'Original', 'Barbecue', 'Sauce'],
#  ['Smart', 'Balance', 'Mayo', 'Light', 'Mayonnaise'],
#  ['Private', 'Selection', 'Carolina', 'Bbq', 'Sauce'],
#  ['Chung', 'Jung', 'One', 'Chili', 'Sauce', 'Korean', 'Gochujang'],
#  ['Private', 'Selection', 'Kansas', 'City', 'Barbecue', 'Sauce'],
#  ['Private', 'Selection', 'Texas', 'Barbecue', 'Sauce'],
#  ['Kikkoman', 'Gluten', 'Free', 'Sweet', 'Chili', 'Sauce'],
#  ['Edmond', 'Fallot', 'Mustard', 'Walnut', 'Dijon'],
#  ['Annies', 'Homegrown', 'Naturals', 'Organic', 'Horseradish', 'Mustard'],
#  ['Vitners', 'Potato', 'Chips', 'Sweet', 'N', 'Tangy', 'Bar', 'B', 'Q'],
#  ['Chi', 'chis', 'Sauces', 'Mild', 'Black', 'Bean', 'Corn', 'Salsa'],
#  ['Frenchs', 'Tomato', 'Ketchup'],
#  ['Nandos', 'Peri', 'Peri', 'Sauce', 'Hot'],
#  ['Maya', 'Kaimal', 'Spicy', 'Ketchup'],
#  ['Koops', 'Mustard', 'Organic', 'Stone', 'Ground'],
#  ['Alessi', 'Balsamic', 'Reduction', 'Traditional', 'Balsamic'],
#  ['Nandos', 'Peri', 'Peri', 'Sauce', 'Medium'],
#  ['Charboy', 'Hot', 'Spicy', 'Ketchup', 'Mild'],
#  ['Simple', 'Truth', 'Organic', 'Powdered', 'Sugar'],
#  ['True', 'Made', 'Foods', 'Lower', 'Sugar', 'Vegetable', 'Ketchup'],
#  ['Frenchs', 'Tomato', 'Ketchup'],
#  ['Vitners', 'Buffalo', 'Wing', 'Blue', 'Cheese', 'Ridgetts', 'Chips'],
#  ['El', 'Yucateco', 'Hot', 'Sauce', 'Chipotle'],
#  ['Simple', 'Truth', 'Organic', 'Bbq', 'Sauce'],
#  ['Country', 'Bobs', 'All', 'Purpose', 'Sauce'],
#  ['Rana', 'Alfredo', 'Rana', 'Alfredo', 'Sauce'],
#  ['Chosen', 'Foods', 'Avocado', 'Oil', 'Mayo', 'Wasabi'],
#  ['PF', 'Changs', 'Soy', 'Sauce', 'Lower', 'Sodium'],
#  ['Roundys', 'Sweet', 'Pickle', 'Relish'],
#  ['ricks', 'picks', 'Smokra', 'Pickled', 'Okra', 'with', 'Smoked', 'Paprika'],
#  ['Gaucho', 'Ranch', 'Chimichurri', 'Original'],
#  ['Koops', 'Mustard', 'Honey', 'Dijon'],
#  ['Lillies', 'Q', 'Ivory', 'Northern', 'Alabama', 'Style'],
#  ['McCormick', 'Seafood', 'Cocktail', 'Sauce'],
#  ['Mina',
#   'Harissa',
#   'Harissa',
#   'Sauce',
#   'Moroccan',
#   'Green',
#   'Pepper',
#   'Spicy'],
#  ['Kroger', 'Tomato', 'Ketchup'],
#  ['Kraft', 'Mayo', 'Fat', 'Free', 'Kraft', 'Free', 'Fat', 'Mayo'],
#  ['Urban', 'Accents', 'Simmer', 'Sauce', 'Taco', 'Jamaican', 'Jerk', 'Spicy'],
#  ['Manitoba',
#   'Harvest',
#   'Hemp',
#   'Foods',
#   'Hemp',
#   'Heart',
#   'Toppers',
#   'Hemp',
#   'Seed',
#   'Mix',
#   'Chipotle',
#   'Onion',
#   'Garlic'],
#  ['Dietz', 'Watson', 'Spicy', 'Brown', 'Mustard'],
#  ['Urban', 'Accents', 'Simmer', 'Sauce', 'Taco', 'Thai', 'Chili', 'Spicy'],
#  ['Heinz', 'Hot', 'Buffalo', 'Sauce', 'Cup'],
#  ['Chung', 'Jung', 'One', 'Ketchup', 'Sauce'],
#  ['Dietz', 'Watson', 'Mustard', 'Wassabi', 'Squeeze'],
#  ['Kraft', 'Miracle', 'Whip', 'Dressing', 'Original'],
#  ['Tassos', 'Bruschetta', 'Olivara'],
#  ['La', 'Preferida', 'Hot', 'Sauce', 'Louisiana', 'Style'],
#  ['Yings', 'Spicy', 'Kungpao', 'Sauce'],
#  ['La', 'Victoria', 'Red', 'Chile', 'Mild', 'Sauce'],
#  ['Budweiser', 'Wing', 'Sauce', 'Mild', 'Brewmaster', 's', 'Premium'],
#  ['Lee', 'Kum', 'Kee', 'Oyster', 'Flavored', 'Sauce'],
#  ['Louisiana', 'Cocktail', 'Sauce'],
#  ['La', 'Criolla', 'Seasoning', 'Adobo', 'with', 'Chipotle', 'Hot', 'Bottle'],
#  ['Saffron', 'Road', 'Simmer', 'Sauce', 'Thai', 'Mango'],
#  ['JL',
#   'Kraft',
#   'Smoky',
#   'Mesquite',
#   'JL',
#   'Kraft',
#   'Smoky',
#   'Mesquite',
#   'Marinade',
#   'In',
#   'a',
#   'Bag'],
#  ['Simple', 'Truth', 'Organic', 'Habanero', 'Hot', 'Sauce'],
#  ['Private',
#   'Selection',
#   'Hot',
#   'Hatch',
#   'Green',
#   'Chile',
#   'Culinary',
#   'Hot',
#   'Sauce'],
#  ['Simple', 'Truth', 'Organic', 'Tomato', 'Ketchup'],
#  ['Noble', 'Made', 'Sauce', 'Cooking', 'Dipping', 'Classic', 'BBQ'],
#  ['Hunts', 'Ketchup', 'Conventional'],
#  ['G',
#   'Hughes',
#   'Smokehouse',
#   'BBQ',
#   'Sauce',
#   'Sugar',
#   'Free',
#   'Sweet',
#   'Spicy'],
#  ['Hunts', 'Ketchup', 'Best', 'Ever'],
#  ['Kroger', 'Sriracha', 'Chili', 'Sauce'],
#  ['Prsl', 'Tomato', 'Basil', 'Sauce'],
#  ['Heinz', 'Mayochup', 'Sauce'],
#  ['Parsley', 'Marinara', 'Sauce'],
#  ['Private', 'Selection', 'Pineapple', 'Red', 'Pepper', 'Jelly'],
#  ['Vienna', 'Yellow', 'Mustard'],
#  ['Sir', 'Kensingtons', 'Mustard', 'Dijon'],
#  ['Ragu', 'Simply', 'Chunky', 'Marinara'],
#  ['Nandos', 'Peri', 'Peri', 'Sauce', 'Garlic', 'Medium'],
#  ['Private', 'Selection', 'Roasted', 'Garlic', 'Sauce'],
#  ['Ortega',
#   'Flavor',
#   'Craver',
#   'Chipotle',
#   'Ortega',
#   'Flavor',
#   'Craver',
#   'Chipotle',
#   'Taco',
#   'Sauce'],
#  ['Cracovia', 'Super', 'Extra', 'Hot', 'Mustard'],
#  ['Kroger', 'Sweet', 'Relish'],
#  ['Frontera', 'Avocado', 'Salsa'],
#  ['Louisiana', 'Hot', 'Sauce'],
#  ['Louisiana', 'Hot', 'Sauce', 'Sweet', 'Heat', 'with', 'Honey'],
#  ['Simply', 'Salsa'],
#  ['Simply', 'Salsa'],
#  ['Heinz', 'Real', 'Heinz', 'Real', 'Mayonnaise'],
#  ['Tessemaes', 'All', 'Natural', 'Goji', 'Pineapple', 'Juice'],
#  ['Roundys', 'Whole', 'Mustard'],
#  ['Pacific',
#   'Organic',
#   'Roasted',
#   'Red',
#   'Pepper',
#   'Tomato',
#   'Pacific',
#   'Foods',
#   'Organic',
#   'Roasted',
#   'Red',
#   'Pepper',
#   'Tomato',
#   'Soup'],
#  ['Maruchan', 'Chicken', 'Flavor', 'Ramen', 'Noodle', 'Soup'],
#  ['Progresso',
#   'Rich',
#   'and',
#   'Hearty',
#   'Chicken',
#   'and',
#   'Homestyle',
#   'Noodles',
#   'Soup'],
#  ['Simple', 'Truth', 'Organic', 'Chicken', 'Broth'],
#  ['Progresso', 'Soup', 'Vegetable', 'Classics', 'Vegetable', 'Soup'],
#  ['Campbells',
#   'Chunky',
#   'Campbells',
#   'Chunky',
#   'Soup',
#   'Creamy',
#   'Chicken',
#   'Dumplings'],
#  ['Progresso', 'Soup', 'Traditional', 'Chicken', 'Noodle', 'Soup'],
#  ['Lipton',
#   'Extra',
#   'Noodle',
#   'Soup',
#   'Mix',
#   'With',
#   'Real',
#   'Chicken',
#   'Flavor'],
#  ['Progresso', 'Traditional', 'Creamy', 'Tomato', 'With', 'Penne', 'Soup'],
#  ['Campbells', 'Chunky', 'Grilled', 'Chicken', 'Sausage', 'Gumbo'],
#  ['Progresso', 'Soup', 'Vegetable', 'Classics', 'Tomato', 'Basil', 'Soup'],
#  ['Progresso', 'Vegetable', 'Classics', 'Minestrone', 'Soup'],
#  ['Campbells', 'Healthy', 'Request', 'Homestyle', 'Chicken', 'Noodle', 'SOUP'],
#  ['Progresso', 'Traditional', 'Chicken', 'and', 'Wild', 'Rice', 'Soup'],
#  ['Progresso', 'Soup', 'Traditional'],
#  ['Swanson', 'Natural', 'Goodness', 'Natural', 'Goodness', 'Chicken', 'BROTH'],
#  ['Swansons', 'Chicken', 'BROTH'],
#  ['Campbells', 'Chunky', 'Classic', 'Chicken', 'Noodle', 'Soup'],
#  ['Campbells', 'Condensed', 'Tomato', 'Soup'],
#  ['Progresso', 'Vegetable', 'Classics', 'Garden', 'Vegetable', 'Soup'],
#  ['Amys', 'Organic', 'Soups', 'Vegetable', 'Barley', 'Low', 'Fat'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Creamy',
#   'Broccoli',
#   'Cheddar',
#   'Bisque'],
#  ['Campbells',
#   'Condensed',
#   'Campbells',
#   'Condensed',
#   'Disney',
#   'Princess',
#   'Soup'],
#  ['Progresso', 'Vegetable', 'Lentil', 'With', 'Roasted', 'Vegetables', 'Soup'],
#  ['Campbells', 'Chicken', 'Stars', 'Soup'],
#  ['Campbells', 'Creamy', 'Tomato', 'Soup', 'Microwavable', 'Bowl'],
#  ['Amys', 'Organic', 'Low', 'Sodium', 'Chunky', 'Tomato', 'Bisque', 'Soup'],
#  ['Progresso', 'Soup', 'Traditional', 'Italian', 'Style', 'Wedding', 'Soup'],
#  ['Progresso',
#   'Rich',
#   'and',
#   'Hearty',
#   'Beef',
#   'Pot',
#   'Roast',
#   'With',
#   'Country',
#   'Vegetables',
#   'Soup'],
#  ['Amys', 'Organic', 'Low', 'Fat', 'Black', 'Bean', 'Vegetable', 'Soup'],
#  ['Campbells', 'Chicken', 'Noodle', 'Soup'],
#  ['Pacific',
#   'Organic',
#   'Free',
#   'Range',
#   'Chicken',
#   'Pacific',
#   'Foods',
#   'Organic',
#   'Free',
#   'Range',
#   'Chicken',
#   'Broth'],
#  ['Simple', 'Truth', 'Organic', 'Chicken', 'Stock'],
#  ['Better', 'Than', 'Bouillon', 'Premium', 'Roasted', 'Chicken', 'Base'],
#  ['Campbells', 'Homestyle', 'Chicken', 'Noodle', 'SOUP'],
#  ['Progresso',
#   'Soup',
#   'Rich',
#   'Hearty',
#   'New',
#   'England',
#   'Clam',
#   'Chowder',
#   'Gluten',
#   'Free'],
#  ['Kroger', 'Reduced', 'Sodium', 'Chicken', 'Broth'],
#  ['Progresso', 'Light', 'Chicken', 'and', 'Dumpling', 'Soup'],
#  ['Campbells', 'Condensed', 'Marvel', 'Spiderman', 'Soup'],
#  ['Campbells', 'Chunky', 'Beef', 'with', 'Country', 'Vegetables', 'Soup'],
#  ['Chunky', 'Chicken', 'Tortilla', 'Soup'],
#  ['Amys', 'Organic', 'Soups', 'Fat', 'Free', 'Chunky', 'Vegetable'],
#  ['Simple', 'Truth', 'Organic', 'Chicken', 'Broth'],
#  ['Campbells', 'Chunky', 'Healthy', 'Request', 'Chicken', 'Noodle', 'Soup'],
#  ['Campbells', 'Chunky', 'Chunky', 'Chili', 'Mac'],
#  ['Kitchen', 'Basics', 'All', 'Natural', 'Unsalted', 'Chicken', 'Stock'],
#  ['Progresso', 'Traditional', 'Split', 'Pea', 'With', 'Ham', 'Soup'],
#  ['Campbells', 'Chicken', 'Noodle', 'Soup', 'Microwavable', 'Bowl'],
#  ['Pacific', 'Low', 'Sodium', 'Organic', 'Chicken', 'Broth'],
#  ['Progresso', 'Traditional', 'Chicken', 'and', 'Sausage', 'Gumbo', 'Soup'],
#  ['Campbells', 'Vegetarian', 'Vegetable', 'SOUP'],
#  ['Campbells', 'Chunky', 'Steak', 'Potato', 'Soup'],
#  ['Campbells',
#   'Condensed',
#   'Campbells',
#   'Condensed',
#   'Double',
#   'Noodle',
#   'Soup'],
#  ['Progresso', 'Soup', 'Traditional', 'Beef', 'Barley', 'Soup'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Kickin',
#   'Crab',
#   'Corn',
#   'Chowder'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Roasted',
#   'Chicken',
#   'Noodle',
#   'Soup',
#   'with',
#   'Herbs',
#   'White',
#   'Meat',
#   'Chicken'],
#  ['Simple', 'Truth', 'Organic', 'Fat', 'Free', 'Broth'],
#  ['Campbells', 'Chicken', 'Noodle', 'Condensed', 'Soup'],
#  ['Campbells', 'Chunky', 'Spicy', 'Chicken', 'Quesadilla', 'Soup'],
#  ['Progresso',
#   'Soup',
#   'Traditional',
#   'Chicken',
#   'Cheese',
#   'Enchilada',
#   'Flavor',
#   'Gluten',
#   'Free'],
#  ['Progresso', 'Traditional', 'Hearty', 'Chicken', 'and', 'Rotini', 'Soup'],
#  ['Kettle', 'Fire', 'Bone', 'Broth', 'Chicken'],
#  ['Progresso',
#   'Soup',
#   'Reduced',
#   'Sodium',
#   'Chicken',
#   'and',
#   'Wild',
#   'Rice',
#   'Soup'],
#  ['Amys',
#   'Organic',
#   'Soups',
#   'Lentil',
#   'Vegetable',
#   'Soup',
#   'Light',
#   'in',
#   'Sodium'],
#  ['Swansons', 'Unsalted', 'Chicken', 'Cooking', 'Stock'],
#  ['Progresso',
#   'Soup',
#   'Traditional',
#   'Chicken',
#   'Rice',
#   'with',
#   'Vegetables',
#   'Soup',
#   'Gluten',
#   'Free'],
#  ['Campbells',
#   'Soup',
#   'On',
#   'The',
#   'Go',
#   'Creamy',
#   'Tomato',
#   'Campbells',
#   'Soup',
#   'on',
#   'the',
#   'Go',
#   'Creamy',
#   'Tomato',
#   'Soup'],
#  ['Campbells', 'Condensed', 'Cream', 'of', 'Chicken', 'Soup'],
#  ['Campbells',
#   'Condensed',
#   'Campbells',
#   'Condensed',
#   'Healthy',
#   'Request',
#   'Chicken',
#   'Noodle',
#   'Soup'],
#  ['Wolfgang',
#   'Puck',
#   'Organic',
#   'Free',
#   'Range',
#   'Chicken',
#   'with',
#   'White',
#   'Wild',
#   'Rice',
#   'Soup'],
#  ['Progresso',
#   'Soup',
#   'Traditional',
#   'Creamy',
#   'Roasted',
#   'Chicken',
#   'with',
#   'Herb',
#   'Dumpling',
#   'Soup'],
#  ['Simply',
#   'Asia',
#   'Japanese',
#   'Inspired',
#   'Ramen',
#   'Soy',
#   'Ginger',
#   'Chicken',
#   'Broth'],
#  ['Swansons', 'Unsalted', 'Chicken', 'BROTH'],
#  ['Progresso', 'Rich', 'and', 'Hearty', 'Chicken', 'Corn', 'Chowder'],
#  ['Amys', 'Organic', 'Chili', 'Spicy'],
#  ['Amys', 'Organic', 'Soups', 'Split', 'Pea', 'Low', 'Fat'],
#  ['Campbells', 'Condensed', 'Cream', 'of', 'Mushroom', 'Soup'],
#  ['Amys', 'Organic', 'Medium', 'Chili', 'Soup'],
#  ['Progresso',
#   'Soup',
#   'Vegetable',
#   'Classics',
#   'Creamy',
#   'Mushroom',
#   'Soup',
#   'Gluten',
#   'Free'],
#  ['Campbells', 'Chunky', 'Chipotle', 'Chicken', 'Corn', 'Chowder'],
#  ['Campbells', 'Chunky', 'Pub', 'Style', 'Chicken', 'Pot', 'Pie', 'Soup'],
#  ['Kroger', 'Cream', 'Of', 'Mushroom', 'Condensed', 'Soup'],
#  ['Progresso',
#   'Vegetable',
#   'Classics',
#   'Vegetarian',
#   'Vegetable',
#   'With',
#   'Barley',
#   'Soup'],
#  ['Progresso', 'Vegetable', 'Classics', 'Hearty', 'Tomato', 'Soup'],
#  ['Amys', 'Low', 'Fat', 'Split', 'Pea', 'Soup'],
#  ['Campbells', 'Healthy', 'Request', 'Healthy', 'Request', 'Tomato', 'SOUP'],
#  ['Spaghettios',
#   'Campbells',
#   'SpaghettiOs',
#   'Disney',
#   'Princesses',
#   'Shaped',
#   'Pasta'],
#  ['Progresso',
#   'Traditional',
#   'Potato',
#   'Broccoli',
#   'and',
#   'Cheese',
#   'Chowder',
#   'Soup'],
#  ['Progresso',
#   'Soup',
#   'Rich',
#   'Hearty',
#   'Hearty',
#   'Chicken',
#   'Pot',
#   'Pie',
#   'Style',
#   'Soup'],
#  ['Progresso',
#   'Soup',
#   'Rich',
#   'Hearty',
#   'Loaded',
#   'Potato',
#   'with',
#   'Bacon',
#   'Soup'],
#  ['Pacific', 'Organic', 'Low', 'Sodium', 'Chicken', 'Broth'],
#  ['Goya', 'Black', 'Bean', 'Soup'],
#  ['Campbells', 'Chicken', 'with', 'Rice'],
#  ['Campbells', 'Chunky', 'Old', 'Fashioned', 'Vegetable', 'Beef', 'Soup'],
#  ['Swansons', 'Unsalted', 'Beef', 'Broth'],
#  ['Kitchen', 'Basics', 'All', 'Natural', 'Original', 'Chicken', 'Stock'],
#  ['Kettle', 'Fire', 'Bone', 'Broth', 'Beef'],
#  ['Campbells',
#   'Soup',
#   'On',
#   'The',
#   'Go',
#   'Chicken',
#   'Mini',
#   'Round',
#   'Noodles',
#   'SOUP'],
#  ['Amys', 'Organic', 'Lentil', 'Vegetable', 'Soup'],
#  ['Campbells', 'Chunky', 'Savory', 'Vegetable', 'Soup'],
#  ['Progresso', 'Traditional', 'Chicken', 'Tortilla', 'Soup'],
#  ['Progresso',
#   'Soup',
#   'Low',
#   'Fat',
#   'Light',
#   'Chicken',
#   'Pot',
#   'Pie',
#   'Style',
#   'Soup'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Tomato',
#   'Basil',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Tomato',
#   'Sweet',
#   'Basil',
#   'Bisque'],
#  ['Simple', 'Truth', 'Organic', 'Free', 'Range', 'Chicken', 'Bone', 'Broth'],
#  ['Campbells',
#   'Chunky',
#   'Healthy',
#   'Request',
#   'Grilled',
#   'Chicken',
#   'Sausage',
#   'Gumbo'],
#  ['Kroger', 'Vegetable', 'Broth'],
#  ['Campbells',
#   'Condensed',
#   'Beef',
#   'Broth',
#   'Campbells',
#   'Condensed',
#   'Beef',
#   'Broth'],
#  ['Pacific',
#   'Organic',
#   'Unsalted',
#   'Chicken',
#   'Pacific',
#   'Organic',
#   'Unsalted',
#   'Chicken',
#   'Bone',
#   'Broth'],
#  ['Pacific', 'Organic', 'Chicken', 'Broth'],
#  ['Amys', 'Hearty', 'Organic', 'Soups', 'Spanish', 'Rice', 'Red', 'Bean'],
#  ['Swansons', 'Vegetable', 'Broth'],
#  ['Campbells', 'Chunky', 'Hearty', 'Beef', 'Barley', 'Soup'],
#  ['Progresso',
#   'Reduced',
#   'Sodium',
#   'Southwest',
#   'Style',
#   'Black',
#   'Bean',
#   'and',
#   'Vegetable',
#   'Soup'],
#  ['Lipton', 'Soup', 'And', 'Dip', 'Mix', 'Onion', 'Flavor'],
#  ['Campbells', 'Chicken', 'Broth', 'SOUP'],
#  ['Progresso', 'Soup', 'Low', 'Fat', 'Light', 'Chicken', 'Noodle', 'Soup'],
#  ['Campbells', 'Well', 'Yes', 'Chicken', 'Noodle', 'Soup'],
#  ['Amys', 'Soups', 'Thai', 'Coconut', 'Tom', 'Kha', 'Phak'],
#  ['Kroger', 'Chicken', 'Broth'],
#  ['College',
#   'Inn',
#   '100',
#   'Natural',
#   'Chicken',
#   'College',
#   'Inn',
#   '100',
#   'Natural',
#   'Chicken',
#   'Broth'],
#  ['Campbells', 'Chunky', 'Creamy', 'Chicken', 'Noodle', 'Soup'],
#  ['Amys', 'Soups', 'Mushroom', 'Bisque', 'With', 'Porcini'],
#  ['Simple', 'Truth', 'Organic', 'Fat', 'Free', 'Vegetable', 'Stock'],
#  ['Amys', 'Soups', 'Low', 'Fat', 'No', 'Chicken', 'Noodle'],
#  ['Progresso',
#   'Vegetable',
#   'Classics',
#   'Tuscan',
#   'Style',
#   'White',
#   'Bean',
#   'Soup'],
#  ['Campbells',
#   '98',
#   'Fat',
#   'Free',
#   'Condensed',
#   'Cream',
#   'of',
#   'Chicken',
#   'Soup'],
#  ['Bear', 'Creek', 'Country', 'Kitchens', 'Minestrone', 'Soup', 'Mix'],
#  ['Pacific',
#   'Organic',
#   'Low',
#   'Sodium',
#   'Vegetable',
#   'Pacific',
#   'Organic',
#   'Low',
#   'Sodium',
#   'Vegetable',
#   'Broth'],
#  ['Progresso', 'Organic', 'Chicken', 'Noodle', 'Soup'],
#  ['Progresso',
#   'Soup',
#   'Reduced',
#   'Sodium',
#   'Roasted',
#   'Chicken',
#   'Noodle',
#   'Soup'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Tuscan',
#   'Style',
#   'Chicken',
#   'White',
#   'Bean',
#   'Soup',
#   'with',
#   'White',
#   'Meat',
#   'Chicken'],
#  ['Campbells',
#   'Chunky',
#   'Healthy',
#   'Request',
#   'Sirloin',
#   'Burger',
#   'with',
#   'Country',
#   'Vegetables',
#   'Soup'],
#  ['Campbells', 'Chunky', 'New', 'England', 'Clam', 'Chowder'],
#  ['Progresso',
#   'Light',
#   'Creamy',
#   'Potato',
#   'With',
#   'Bacon',
#   'and',
#   'Cheese',
#   'Soup'],
#  ['Amys', 'Organic', 'Soups', 'Low', 'Fat', 'Minestrone'],
#  ['Progresso',
#   'Soup',
#   'Low',
#   'Fat',
#   'Light',
#   'Savory',
#   'Vegetable',
#   'Barley',
#   'Soup'],
#  ['Wylers',
#   'Mrs',
#   'Grass',
#   'Soup',
#   'Mix',
#   'Noodles',
#   'Soup',
#   'with',
#   'Real',
#   'Chicken',
#   'Broth'],
#  ['Campbells',
#   'Chunky',
#   'Chicken',
#   'Broccoli',
#   'Cheese',
#   'with',
#   'Potato',
#   'Soup'],
#  ['Campbells',
#   'Healthy',
#   'Request',
#   'Healthy',
#   'Request',
#   'Chicken',
#   'with',
#   'Rice',
#   'SOUP'],
#  ['Progresso', 'Light', 'Chicken', 'Corn', 'Chowder', 'Soup'],
#  ['Pacific',
#   'Organic',
#   'Vegetable',
#   'Lentil',
#   'Roasted',
#   'Red',
#   'Pepper',
#   'Soup'],
#  ['Maruchan',
#   'Souper',
#   '6',
#   'Pack',
#   'Beef',
#   'Flavor',
#   'Ramen',
#   'Noodle',
#   'Soup'],
#  ['Campbells', 'Chunky', 'Chicken', 'Corn', 'Chowder', 'Soup'],
#  ['Progresso', 'Vegetable', 'Classics', 'Tomato', 'Rotini', 'Soup'],
#  ['Kroger', 'Cream', 'Of', 'Chicken', 'Condensed', 'Soup'],
#  ['Progresso', 'Vegetable', 'Classics', 'French', 'Onion', 'Soup'],
#  ['Progresso', 'Light', 'Chicken', 'and', 'Cheese', 'Enchilada', 'Soup'],
#  ['Swansons', 'Chicken', 'Broth'],
#  ['Swansons', 'Chicken', 'Cooking', 'Stock'],
#  ['Swanson',
#   'Natural',
#   'Goodness',
#   'Swanson',
#   'Natural',
#   'Goodness',
#   'Chicken',
#   'Broth'],
#  ['Campbells',
#   'Homestyle',
#   'Chicken',
#   'Noodle',
#   'Soup',
#   'Microwavable',
#   'Bowl'],
#  ['Campbells', 'Chunky', 'Savory', 'Pot', 'Roast', 'Soup'],
#  ['Campbells',
#   'Condensed',
#   'Family',
#   'Size',
#   'Cream',
#   'of',
#   'Chicken',
#   'Soup'],
#  ['Amys', 'Organic', 'Soups', 'Low', 'Fat', 'Cream', 'of', 'Tomato'],
#  ['Progresso',
#   'Soup',
#   'Traditional',
#   'Chicken',
#   'and',
#   'Herb',
#   'Dumplings',
#   'Soup'],
#  ['Pacific',
#   'Organic',
#   'Vegetable',
#   'Pacific',
#   'Organic',
#   'Vegetable',
#   'Broth'],
#  ['Campbells', 'Chunky', 'Minestrone', 'Soup', 'with', 'Italian', 'Sausage'],
#  ['Campbells', 'Homestyle', 'Chicken', 'Noodle', 'Soup'],
#  ['Campbells',
#   'Slow',
#   'Kettle',
#   'Campbells',
#   'Slow',
#   'Kettle',
#   'Style',
#   'Southwest',
#   'Style',
#   'Chicken',
#   'Chili',
#   'with',
#   'White',
#   'Meat',
#   'Chicken'],
#  ['Better', 'Than', 'Bouillon', 'Organic', 'Roasted', 'Chicken', 'Base'],
#  ['Campbells',
#   'Chunky',
#   'Hearty',
#   'Bean',
#   'and',
#   'Ham',
#   'with',
#   'Natural',
#   'Smoke',
#   'Flavor',
#   'Soup'],
#  ['Progresso',
#   'Light',
#   'Creamy',
#   'Roasted',
#   'Chicken',
#   'With',
#   'Herb',
#   'Dumpling',
#   'Soup'],
#  ['Progresso',
#   'Soup',
#   'Low',
#   'Fat',
#   'Light',
#   'New',
#   'England',
#   'Clam',
#   'Chowder',
#   'Gluten',
#   'Free'],
#  ['Progresso', 'Soup', 'Vegetable', 'Classics', 'Split', 'Pea', 'Soup'],
#  ['Campbells', 'Chicken', 'NoodleOs', 'SOUP'],
#  ['Swansons', 'Chicken', 'Broth'],
#  ['Campbells',
#   'Chunky',
#   'Jazzy',
#   'Jambalaya',
#   'with',
#   'Chicken',
#   'Sausage',
#   'Ham',
#   'Soup'],
#  ['Pacific', 'Organic', 'Poblano', 'Pepper', 'Corn', 'Chowder'],
#  ['Campbells',
#   'Soup',
#   'On',
#   'The',
#   'Go',
#   'Chicken',
#   'Star',
#   'Shaped',
#   'Pasta',
#   'SOUP'],
#  ['Amys', 'Organic', 'Soups', 'Chunky', 'Tomato', 'Bisque'],
#  ['Swansons', 'Low', 'Salt', 'Beef', 'Broth'],
#  ['Campbells',
#   'Chunky',
#   'Sirloin',
#   'Burger',
#   'with',
#   'Country',
#   'Vegetables',
#   'Soup'],
#  ['Lipton', 'Soup', 'Secrets', 'Noodle', 'Soup', 'Mix'],
#  ['Campbells', 'Slow', 'Cooker', 'Beef', 'Stew', 'Sauces'],
#  ['Campbells',
#   'Healthy',
#   'Request',
#   'Healthy',
#   'Request',
#   'Cream',
#   'of',
#   'Mushroom',
#   'SOUP'],
#  ['Swansons', 'Beef', 'BROTH'],
#  ['Progresso',
#   'Soup',
#   'Reduced',
#   'Sodium',
#   'Creamy',
#   'Tomato',
#   'Basil',
#   'Soup'],
#  ['Campbells',
#   'Chunky',
#   'Baked',
#   'Potato',
#   'with',
#   'Cheddar',
#   'Bacon',
#   'Bits',
#   'Soup'],
#  ['Campbells', 'Soup', 'On', 'The', 'Go', 'Classic', 'Tomato', 'SOUP'],
#  ['Campbells', 'Broccoli', 'Cheese', 'SOUP'],
#  ['Wylers',
#   'Chicken',
#   'Flavor',
#   'Instant',
#   'Wylers',
#   'Chicken',
#   'Flavor',
#   'Instant',
#   'Bouillon',
#   'Cubes'],
#  ['Progresso', 'Traditional', 'New', 'England', 'Clam', 'Chowder', 'Soup'],
#  ['Campbells',
#   '98',
#   'Fat',
#   'Free',
#   'Condensed',
#   'Cream',
#   'of',
#   'Mushroom',
#   'Soup'],
#  ['Progresso',
#   'Rich',
#   'and',
#   'Hearty',
#   'Minestrone',
#   'With',
#   'Italian',
#   'Sausage',
#   'Soup'],
#  ['Campbells', 'Tomato', 'SOUP'],
#  ['Campbells',
#   'Chunky',
#   'Healthy',
#   'Request',
#   'Roasted',
#   'Chicken',
#   'with',
#   'Country',
#   'Vegetables',
#   'Soup'],
#  ['Amys', 'Organic', 'Soups', 'Cream', 'Of', 'Mushroom'],
#  ['Campbells', 'Well', 'Yes', 'Mediterranean', 'Style', 'Wedding', 'Soup'],
#  ['Progresso', 'Reduced', 'Sodium', 'Hearty', 'Minestrone', 'Soup'],
#  ['Kroger', 'Chicken', 'Broth'],
#  ['Campbells',
#   'Chunky',
#   'Split',
#   'Pea',
#   'Ham',
#   'with',
#   'Natural',
#   'Smoke',
#   'Flavor',
#   'Soup'],
#  ['Shore', 'Lunch', 'Creamy', 'Wild', 'Rice', 'Soup', 'Mix'],
#  ['Panera', 'Bread', 'at', 'Home', 'Broccoli', 'Cheddar', 'Soup'],
#  ['Amys', 'Organic', 'Low', 'Fat', 'Medium', 'Black', 'Bean', 'Chili'],
#  ['Progresso', 'Light', 'Roasted', 'Chicken', 'and', 'Vegetable', 'Soup'],
#  ['Pacific', 'Organic', 'Soup', 'Vegetable', 'Quinoa', 'Soup'],
#  ['Campbells', 'Condensed', 'Vegetable', 'Soup'],
#  ['Pacific', 'Spicy', 'Black', 'Bean', 'Kale', 'Organic', 'Soup'],
#  ['Campbells', 'Condensed', 'Beef', 'Consomme'],
#  ['Campbells',
#   'Well',
#   'Yes',
#   'Roasted',
#   'Chicken',
#   'with',
#   'Wild',
#   'Rice',
#   'Soup',
#   'Campbells',
#   'Well',
#   'Yes',
#   'Roasted',
#   'Chicken',
#   'with',
#   'Wild',
#   'Rice',
#   'Soup'],
#  ['Bear',
#   'Creek',
#   'Country',
#   'Kitchens',
#   'Chicken',
#   'Noodle',
#   'Bear',
#   'Creek',
#   'Country',
#   'Kitchens',
#   'Chicken',
#   'Noodle',
#   'Soup',
#   'Mix'],
#  ['Sazon', 'Goya', 'Seasoning'],
#  ['Campbells',
#   'Chunky',
#   'Healthy',
#   'Request',
#   'Old',
#   'Fashioned',
#   'Vegetable',
#   'Beef',
#   'Soup'],
#  ['Campbells', 'Fiesta', 'Nacho', 'Cheese', 'SOUP'],
#  ['Pacific',
#   'Organic',
#   'Beef',
#   'Pacific',
#   'Foods',
#   'Organic',
#   'Beef',
#   'Broth'],
#  ['Campbells',
#   'Condensed',
#   'Family',
#   'Size',
#   'Cream',
#   'of',
#   'Mushroom',
#   'Soup'],
#  ['Better', 'Than', 'Bouillon', 'Superior', 'Touch', 'Beef', 'Base'],
#  ['Campbells', 'Chicken', 'Noodle', 'Soup'],
#  ['Pacific',
#   'Organic',
#   'Creamy',
#   'Cashew',
#   'Carrot',
#   'Ginger',
#   'Pacific',
#   'Organic',
#   'Creamy',
#   'Cashew',
#   'Carrot',
#   'Ginger',
#   'Soup'],
#  ['Pacific', 'Foods', 'Organic', 'Chicken', 'Noodle', 'Soup'],
#  ['Pacific', 'Organic', 'Mushroom', 'Pacific', 'Organic', 'Mushroom', 'Broth'],
#  ['Campbells', 'Cream', 'of', 'Mushroom', 'with', 'Roasted', 'Garlic', 'SOUP'],
#  ['Amys', 'Organic', 'Soups', 'Cream', 'of', 'Tomato', 'Low', 'Fat'],
#  ['Campbells', 'Sweet', 'Potato', 'Corn', 'Chowder', 'Soup'],
#  ['Campbells',
#   'Healthy',
#   'Request',
#   'Condensed',
#   'Cream',
#   'of',
#   'Chicken',
#   'Soup'],
#  ['Kitchen',
#   'Accomplice',
#   'Reduced',
#   'Sodium',
#   'Beef',
#   'Broth',
#   'Concentrate'],
#  ['Campbells',
#   'Condensed',
#   'Chicken',
#   'with',
#   'White',
#   'Wild',
#   'Rice',
#   'Soup'],
#  ['Pacific', 'Hearty', 'Split', 'Pea', 'Uncured', 'Ham', 'Soup'],
#  ['Progresso',
#   'Soup',
#   'Rich',
#   'Hearty',
#   'Savory',
#   'Beef',
#   'Barley',
#   'Vegetable',
#   'Soup'],
#  ['Kroger', 'Beef', 'Broth'],
#  ['Pacific',
#   'Organic',
#   'Cream',
#   'of',
#   'Mushroom',
#   'Condensed',
#   'Pacific',
#   'Foods',
#   'Organic',
#   'Cream',
#   'of',
#   'Mushroom',
#   'Condensed',
#   'Soup'],
#  ['Campbells',
#   'Chunky',
#   'Roasted',
#   'Beef',
#   'Tips',
#   'with',
#   'Vegetables',
#   'Soup'],
#  ['Wolfgang', 'Puck', 'Organic', 'Signature', 'Butternut', 'Squash', 'Soup'],
#  ['Campbells', 'Cream', 'of', 'Chicken', 'with', 'Herbs', 'SOUP'],
#  ['Campbells', '25', 'Less', 'Sodium', 'Cream', 'of', 'Mushroom', 'SOUP'],
#  ['Campbells', 'Vegetable', 'Beef', 'Condensed', 'Soup'],
#  ['Campbells', 'French', 'Onion', 'SOUP'],
#  ['Lipton', 'Soup', 'And', 'Dip', 'Mix', 'Savory', 'Herb', 'With', 'Garlic'],
#  ['Kroger', 'Classic', 'Cream', 'Of', 'Mushroom', 'Condensed', 'Soup'],
#  ['Swansons', 'Beef', 'Swanson', 'Beef', 'Stock'],
#  ['Swansons', 'Unsalted', 'Beef', 'BROTH'],
#  ['Wolfgang', 'Puck', 'Tomato', 'Basil', 'Bisque', 'Organic', 'Soup'],
#  ['Kitchen', 'Basics', 'Unsalted', 'Vegetable', 'Stock'],
#  ['Campbells', 'Cream', 'of', 'Celery', 'SOUP'],
#  ['Kroger', 'Fat', 'Free', 'Low', 'Sodium', 'Chicken', 'Broth'],
#  ['Campbells', 'Beef', 'Stroganoff', 'Sauces'],
#  ['Campbells',
#   'Chunky',
#   'Healthy',
#   'Request',
#   'New',
#   'England',
#   'Clam',
#   'Chowder'],
#  ['Lipton', 'Soup', 'And', 'Dip', 'Mix', 'Golden', 'Onion'],
#  ['Progresso', 'Light', 'Beef', 'Pot', 'Roast', 'Soup'],
#  ['Campbells', 'Well', 'Yes', 'Cajun', 'Red', 'Bean', 'Vegetable', 'Soup'],
#  ['Wolfgang', 'Puck', 'Organic', 'Signature', 'Tortilla', 'Soup'],
#  ['Campbells', 'Condensed', 'Cream', 'of', 'Mushroom', 'Soups'],
#  ['Knorr', 'Recipe', 'Mix', 'Vegetable'],
#  ['Progresso',
#   'Soup',
#   'Traditional',
#   'Manhattan',
#   'Clam',
#   'Chowder',
#   'Soup',
#   'Gluten',
#   'Free'],
#  ['Swansons',
#   'Organic',
#   'Free',
#   'Range',
#   'Chicken',
#   'Broth',
#   '32',
#   'oz',
#   'Carton'],
#  ['Swansons', 'Seafood', 'Cooking', 'Stock'],
#  ['Bear', 'Creek', 'Country', 'Kitchens', 'Soup', 'Mix', 'Creamy', 'Potato'],
#  ['Kroger', 'Cream', 'Of', 'Celery', 'Condensed', 'Soup'],
#  ['Better', 'Than', 'Bouillon', 'Organic', 'Beef', 'Base'],
#  ['BOU', 'Flavored', 'Bouillon', 'Cubes', 'Vegetables'],
#  ['Kroger',
#   'From',
#   'Our',
#   'Family',
#   'To',
#   'Yours',
#   'Tomato',
#   'Condensed',
#   'Soup'],
#  ['Alessi', 'Tuscan', 'White', 'Bean', 'Soup', 'Zuppa', 'Toscana'],
#  ['Campbells',
#   'Condensed',
#   'Campbells',
#   'Condensed',
#   'Cheddar',
#   'Cheese',
#   'Soup'],
#  ['Swanson', '50', 'Less', 'Sodium', 'Beef', 'Broth'],
#  ['Knorr', 'Homestyle', 'Stock', 'Chicken'],
#  ['Campbells', 'Spicy', 'BBQ', 'Seasoned', 'Chicken', 'with', 'Beans', 'Soup'],
#  ['Campbells', 'Chunky', 'Sausage', 'Pepper', 'Rigatoni', 'Soup'],
#  ['Kitchen', 'Basics', 'All', 'Natural', 'Original', 'Beef', 'Stock'],
#  ['Campbells', 'R', 'W', 'Minestrone', 'Soup'],
#  ['Manischewitz', 'Reduced', 'Sodium', 'Chicken', 'Broth'],
#  ['Pacific',
#   'Free',
#   'Range',
#   'Chicken',
#   'Pacific',
#   'Foods',
#   'Free',
#   'Range',
#   'Chicken',
#   'Broth'],
#  ['Kroger', 'Classic', 'Chicken', 'Noodle', 'Condensed', 'Soup'],
#  ['Campbells', 'Chicken', 'Gumbo', 'Condensed', 'Soup'],
#  ['Kitchen',
#   'Accomplice',
#   'Reduced',
#   'Sodium',
#   'Chicken',
#   'Broth',
#   'Concentrate'],
#  ['Kroger', 'Condensed', 'Soup', 'Bean', 'With', 'Bacon'],
#  ['Oceans', 'Halo', 'Broth', 'Miso'],
#  ['Kroger', 'Chicken', 'Rice', 'Soup'],
#  ['Campbells', 'Cream', 'of', 'Onion', 'SOUP'],
#  ['Campbells', 'Soup', 'On', 'The', 'Go', 'Creamy', 'Chicken', 'SOUP'],
#  ['Campbells', 'Cream', 'of', 'Chicken', 'Condensed', 'Soup'],
#  ['Kroger', 'Broth'],
#  ['Kroger', 'Vegetable', 'Beef', 'Condensed', 'Soup'],
#  ['Campbells', 'Condensed', 'Beefy', 'Mushroom', 'Soup'],
#  ['Idahoan',
#   'Premium',
#   'Steakhouse',
#   'Cheddar',
#   'Broccoli',
#   'Potato',
#   'Idahoan',
#   'Premium',
#   'Steakhouse',
#   'Cheddar',
#   'Broccoli',
#   'Potato',
#   'Soup'],
#  ['Lipton', 'Soup', 'And', 'Dip', 'Mix', 'Vegetable'],
#  ['Idahoan', 'Premium', 'Steakhouse', 'Creamy', 'Potato', 'Soup'],
#  ['Swanson', 'Clear', 'Beef', 'Broth'],
#  ['Wylers',
#   'Instant',
#   'Beef',
#   'Bouillon',
#   'Cubes',
#   'Wylers',
#   'Instant',
#   'Beef',
#   'Bouillon',
#   'Cubes'],
#  ['Pacific', 'Organic', 'Beef', 'Broth'],
#  ['Campbells', 'Healthy', 'Request', 'Tomato', 'SOUP'],
#  ['Campbells',
#   'Chunky',
#   'Fajita',
#   'Chicken',
#   'with',
#   'Rice',
#   'and',
#   'Beans',
#   'Soup'],
#  ['Amys', 'Soups', 'Organic', 'Carrot', 'Ginger'],
#  ['Campbells',
#   'Condensed',
#   '25',
#   'Less',
#   'Sodium',
#   'Chicken',
#   'Noodle',
#   'Soup'],
#  ['Lipton', 'Soup', 'And', 'Dip', 'Mix', 'Beefy', 'Onion', 'Flavor'],
#  ['Knorr', 'Recipe', 'Mix', 'French', 'Onion'],
#  ['Campbells', 'Golden', 'Mushroom', 'SOUP'],
#  ['Kroger', 'Cream', 'Of', 'Chicken', 'Condensed', 'Soup'],
#  ['Kroger', 'Reduced', 'Sodium', 'Beef', 'Broth'],
#  ['Knorr', 'Homestyle', 'Stock', 'Beef'],
#  ['Racconto', 'Orzo'],
#  ['Kroger', 'Bouillon', 'Cubes', 'Beef'],
#  ['Kroger', 'Vegetable', 'Broth'],
#  ['Kroger', 'Hearty', 'Roasted', 'Chicken', 'Noodle', 'Soup'],
#  ['Kroger', 'Cream', 'Of', 'Chicken', 'Condensed', 'Soup'],
#  ['Kroger', 'Beef', 'Stew'],
#  ['Lono', 'Life', 'Broth', 'Chicken', 'Bone', 'Savory'],
#  ['Kroger', 'Vegetable', 'Soup', 'Chunky'],
#  ['Campbells', 'Hearty', 'Tomato', 'with', 'Toasted', 'Barley', 'Soup'],
#  ['Kroger', 'Onion', 'Soup', 'Dip', 'Mix'],
#  ['Simple', 'Truth', 'Organic', 'Cream', 'Of', 'Chicken', 'Condensed', 'Soup'],
#  ['Campbells',
#   'Condensed',
#   'Family',
#   'Size',
#   'Homestyle',
#   'Chicken',
#   'Noodle',
#   'Soup'],
#  ['Kroger', 'Bouillon', 'Cubes', 'Chicken', 'Flavor'],
#  ['Campbells', 'New', 'England', 'Clam', 'Chowder', 'SOUP'],
#  ['Simply', 'Asia', 'Vietnamese', 'Inspired', 'Pho', 'Beef', 'Broth'],
#  ['Idahoan',
#   'Premium',
#   'Steakhouse',
#   'Loaded',
#   'Potato',
#   'Idahoan',
#   'Premium',
#   'Steakhouse',
#   'Loaded',
#   'Potato',
#   'Soup'],
#  ['BOU', 'Flavored', 'Bouillon', 'Cubes', 'Beef'],
#  ['Panera', 'Bread', 'at', 'Home', 'Chicken', 'Tortilla', 'Soup'],
#  ['Kroger', 'Beef', 'Flavored', 'Broth'],
#  ['Heinz', 'HomeStyle', 'Mushroom', 'Heinz', 'HomeStyle', 'Mushroom', 'Gravy'],
#  ['Campbells',
#   'Healthy',
#   'Request',
#   'Healthy',
#   'Request',
#   'Cream',
#   'of',
#   'Celery',
#   'SOUP'],
#  ['Kroger', 'Family', 'Size', 'Condensed', 'Tomato', 'Soup'],
#  ['Kroger', 'Chicken', 'Noodle', 'Condensed', 'Soup'],
#  ['Cuginos', 'Soup', 'Mix', 'Baked', 'Burgundy', 'French', 'Onion'],
#  ['Campbells', 'Vegetable', 'Beef', 'Soup', 'Microwavable', 'Bowl'],
#  ['Bear',
#   'Creek',
#   'Country',
#   'Kitchens',
#   'Soup',
#   'Mix',
#   'Cheddar',
#   'Broccoli'],
#  ['Heinz', 'Savory', 'Beef', 'Fat', 'Free', 'Gravy'],
#  ['Idahoan', 'Creamy', 'Potato', 'Soup', 'Mix'],
#  ['Campbells', 'Chicken', 'Gravy'],
#  ['Oceans', 'Halo', 'Broth', 'Thai', 'Coconut'],
#  ['Goya', 'Bouillon', 'Chicken', 'Flavored'],
#  ['Frontier', 'Soups', 'Stew', 'Mix', 'Chicken', 'Colorado', 'Campfire'],
#  ['Knorr', 'Granulated', 'Bouillon', 'Tomato', 'Chicken'],
#  ['Cuginos', 'Ridiculously', 'Delicious', 'Soup', 'Mix'],
#  ['Shore', 'Lunch', 'Classic', 'Chicken', 'Noodle', 'Soup'],
#  ['Manischewitz', 'Minestrone', 'Soup', 'Mix'],
#  ['Progresso', 'Rich', 'Hearty', 'Three', 'Cheese', 'Tortellini', 'Soup'],
#  ['Kroger', 'New', 'England', 'Style', 'Clam', 'Chowder'],
#  ['Kroger', 'Chicken', 'Dumpling', 'Soup'],
#  ['Kroger', 'Tomato', 'Soup'],
#  ['Amys', 'Organic', 'Low', 'Fat', 'Minestrone', 'Soup'],
#  ['Sto', 'Organic', 'Vegetable', 'Stock'],
#  ['Kroger', 'Cream', 'of', 'Chicken', 'Soup'],
#  ['Camp', 'Wy', 'Red', 'Beans', 'Vegetable', 'Soup'],
#  ['Pacific', 'Organic', 'Low', 'Sodium', 'Free', 'Range', 'Chicken', 'Broth'],
#  ['Pacific', 'Foods', 'Beef', 'Broth'],
#  ['Pacific',
#   'Organic',
#   'Beef',
#   'Pacific',
#   'Foods',
#   'Organic',
#   'Beef',
#   'Bone',
#   'Broth'],
#  ['Campbells',
#   'Condensed',
#   'Campbells',
#   'Condensed',
#   'Bean',
#   'with',
#   'Bacon',
#   'Soup',
#   '1125',
#   'oz'],
#  ['The', 'Kroger', 'Cream', 'of', 'Potato', 'Condensed', 'Soup'],
#  ['Kettle',
#   'Fire',
#   'Soup',
#   'with',
#   'Chicken',
#   'Bone',
#   'Broth',
#   'Butternut',
#   'Squash'],
#  ['Oceans', 'Halo', 'Pho', 'Broth'],
#  ['Campbells',
#   'Condensed',
#   'Healthy',
#   'Request',
#   'Bean',
#   'with',
#   'Bacon',
#   'Soup'],
#  ['Campbells',
#   'Soup',
#   'Well',
#   'Yes',
#   'Tomato',
#   'and',
#   'Sweet',
#   'Basil',
#   'Sipping',
#   'Soup'],
#  ['Progresso', 'Traditional', 'Butternut', 'Squash', 'Soup'],
#  ['Campbells',
#   'Soup',
#   'Well',
#   'Yes',
#   'Butternut',
#   'Squash',
#   'and',
#   'Sweet',
#   'Potato',
#   'Sipping',
#   'Soup'],
#  ['Annies',
#   'Homegrown',
#   'Organic',
#   'Creamy',
#   'Tomato',
#   'Bunny',
#   'Pasta',
#   'Soup'],
#  ['Progresso',
#   'Cheese',
#   'Tortellini',
#   'Garden',
#   'Vegetable',
#   'Tomato',
#   'Soup'],
#  ['Campbells', 'Condensed', 'Tomato', 'Bisque'],
#  ['Campbells', 'Condensed', 'Cream', 'of', 'Bacon', 'Soup'],
#  ['Swansons', 'Chicken', 'Bone', 'Broth'],
#  ['Progresso', 'Traditional', 'Broccoli', 'Cheese', 'Soup'],
#  ['Progresso', 'Light', 'Creamy', 'Chicken', 'Noodle', 'Soup'],
#  ['Campbells',
#   'Well',
#   'Yes',
#   'Lightly',
#   'Salted',
#   'Tomato',
#   'Basil',
#   'Bisque'],
#  ['Annies',
#   'Homegrown',
#   'Organic',
#   'Vegetable',
#   'Soup',
#   'with',
#   'Farm',
#   'Shaped',
#   'Pasta'],
#  ['Annies', 'Homegrown', 'Organic', 'Star', 'Pasta', 'Chicken', 'Soup'],
#  ['McCormick', 'Black', 'Pepper', 'Grinder'],
#  ['Kroger', '3', 'Pepper', 'Onion', 'Blend'],
#  ['Lipton',
#   'Extra',
#   'Noodle',
#   'Soup',
#   'Mix',
#   'With',
#   'Real',
#   'Chicken',
#   'Flavor'],
#  ['Kroger', 'Taco', 'Seasoning'],
#  ['McCormick', 'Mild', 'Taco', 'Seasoning', 'Mix'],
#  ['Morton', 'Salt', 'Kosher', 'Coarse', 'Bottle'],
#  ['McCormick', 'Sea', 'Salt', 'Grinder'],
#  ['Sazon', 'Goya', 'Seasoning', 'Coriander', 'Annatto'],
#  ['Mrs',
#   'Dash',
#   'Mrs',
#   'Dash',
#   'Salt',
#   'Free',
#   'Seasoning',
#   'Blend',
#   'Garlic',
#   'Herb'],
#  ['Lawrys', 'Economy', 'Size', 'Seasoned', 'Salt'],
#  ['McCormick', 'Garlic', 'Powder'],
#  ['Old', 'Bay', 'Seasoning'],
#  ['McCormick', 'Parsley', 'Flakes'],
#  ['Zatarains', 'New', 'Orleans', 'Style', 'Creole', 'Seasoning'],
#  ['McCormick', 'Minced', 'Onions'],
#  ['McCormick', 'Ground', 'White', 'Pepper'],
#  ['McCormick', 'Hot', 'Taco', 'Seasoning', 'Mix'],
#  ['McCormick', 'Paprika'],
#  ['McCormick', 'Himalayan', 'Pink', 'Salt', 'Grinder'],
#  ['Simple', 'Truth', 'Crushed', 'Red', 'Pepper'],
#  ['McCormick', 'Ground', 'Pepper', 'Black'],
#  ['Morton', 'Iodized', 'Sea', 'Salt', 'All', 'Purpose'],
#  ['Pepper'],
#  ['McCormick', '30', 'Less', 'Sodium', 'Taco', 'Seasoning', 'Mix'],
#  ['McCormick', 'Chili', 'Powder'],
#  ['Mrs', 'Dash', 'Original', 'Blend', 'Salt', 'Free', 'Seasoning', 'Blend'],
#  ['Morton', 'Iodized', 'Salt'],
#  ['Kroger', 'Pure', 'Vanilla', 'Extract'],
#  ['Bellino', 'Minced', 'Garlic'],
#  ['McCormick', 'Basil', 'Leaves'],
#  ['McCormick', 'Onion', 'Powder'],
#  ['Knorr', 'Rice', 'Side', 'Dish', 'Chicken', 'Broccoli'],
#  ['McCormick', 'Grill', 'Mates', 'Roasted', 'Garlic', 'Herb', 'Seasoning'],
#  ['Mrs',
#   'Dash',
#   'Southwest',
#   'Chipotle',
#   'Salt',
#   'Free',
#   'Seasoning',
#   'Blend'],
#  ['Mrs', 'Dash', 'Lemon', 'Pepper', 'Salt', 'Free', 'Seasoning', 'Blend'],
#  ['Goya', 'All', 'Purpose', 'Seasoning', 'with', 'Pepper'],
#  ['McCormick', 'Less', 'Sodium', 'Chili', 'Seasoning', 'Mix'],
#  ['McCormick', 'Garlic', 'Salt'],
#  ['Old', 'Bay', 'Shaker', 'Bottle', 'Seafood', 'Seasoning'],
#  ['McCormick', 'Peppercorn', 'Medley', 'Grinder'],
#  ['Simple', 'Truth', 'Organic', 'Ground', 'Chili', 'Powder'],
#  ['McCormick', 'Guacamole', 'Seasoning', 'Mix'],
#  ['Lawrys', 'Seasoned', 'Salt'],
#  ['Simple', 'Truth', 'Organic', 'Cayenne', 'Red', 'Pepper'],
#  ['McCormick',
#   'Slow',
#   'Cookers',
#   'Savory',
#   'Pot',
#   'Roast',
#   'Seasoning',
#   'Mix'],
#  ['Gourmet', 'Garden', 'Chili', 'Pepper', 'Stir', 'in', 'Paste'],
#  ['Tony', 'Chacheres', 'Creole', 'Seasoning', 'Original'],
#  ['McCormick', 'Perfect', 'Pinch', 'Vegetable', 'Seasoning'],
#  ['McCormick', 'Parsley', 'Flakes'],
#  ['Badia', 'Lemon', 'Pepper'],
#  ['Urban',
#   'Accents',
#   'Chicago',
#   'Steak',
#   'Chop',
#   'Cracked',
#   'Pepper',
#   'Garlic',
#   'Blend'],
#  ['Private', 'Selection', 'Whole', 'Black', 'Peppercorn', 'Grinder'],
#  ['Simple', 'Truth', 'Black', 'Chia', 'Seeds'],
#  ['McCormick', 'Gourmet', 'Organic', 'Ground', 'Saigon', 'Cinnamon'],
#  ['McCormick',
#   'Grill',
#   'Mates',
#   '25',
#   'Less',
#   'Sodium',
#   'Montreal',
#   'Steak',
#   'Seasoning'],
#  ['Morton', 'Sea', 'Salt', 'Grinder', 'Sea', 'Salt'],
#  ['McCormick', 'Crushed', 'Red', 'Pepper'],
#  ['McCormick',
#   'Himalayan',
#   'Pink',
#   'Salt',
#   'Black',
#   'Pepper',
#   'And',
#   'Garlic',
#   'All',
#   'Purpose',
#   'Seasoning'],
#  ['Bragg', 'Premium', 'Nutritional', 'Yeast', 'Seasoning'],
#  ['McCormick', 'Whole', 'Black', 'Pepper'],
#  ['Goya', 'Adobo', 'All', 'Purpose', 'Seasoning'],
#  ['Kroger', 'Pure', 'Ground', 'Black', 'Pepper'],
#  ['Simple', 'Truth', 'Nutmeg'],
#  ['McCormick', 'Grill', 'Mates', 'Spicy', 'Montreal', 'Steak', 'Seasoning'],
#  ['McCormick', 'Poultry', 'Seasoning'],
#  ['Kroger', 'Celery', 'Salt'],
#  ['Mrs', 'Dash', 'Onion', 'Herb', 'Salt', 'Free', 'Seasoning', 'Blend'],
#  ['McCormick', 'Gourmet', 'Organic', 'Onion', 'Powder'],
#  ['Roundys', 'Organics', 'Fresh', 'Oregano'],
#  ['McCormick', 'Garlic', 'Jalapeno', 'Seasoning'],
#  ['McCormick', 'Ground', 'Mustard'],
#  ['Hidden', 'Valley', 'Dips', 'Mix', 'Original', 'Ranch', '20', 'Ounces'],
#  ['McCormick', 'Italian', 'Blend', 'Herb', 'Grinder'],
#  ['McCormick', 'Ground', 'Cinnamon'],
#  ['McCormick', 'Bay', 'Leaves'],
#  ['Morton', 'Salt'],
#  ['Kroger', 'Iodized', 'Salt'],
#  ...]

# %%
crf_data  = []
for product in token_sr:
    pos = nltk.pos_tag(product)
    crf_data.append(pos)

# %%
len(products_list_new)
# Out:
# 6242

# %%
len(crf_data)
# Out:
# 6242

# %%
def word2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]

    # Common features for all words
    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'postag=' + postag
    ]

    # Features for words that are not
    # at the beginning of a document
    if i > 0:
        word1 = doc[i-1][0]
        postag1 = doc[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:postag=' + postag1
        ])
    else:
        # Indicate that it is the 'beginning of a document'
        features.append('BOS')

    # Features for words that are not
    # at the end of a document
    if i < len(doc)-1:
        word1 = doc[i+1][0]
        postag1 = doc[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:postag=' + postag1
        ])
    else:
        # Indicate that it is the 'end of a document'
        features.append('EOS')

    return features

# %%
# A function for extracting features in documents
def extract_features(doc):
    return [word2features(doc, i) for i in range(len(doc))]

# %%
X = [extract_features(doc) for doc in crf_data]

# %%
X
# Out:
# [[['bias',
#    'word.lower=green',
#    'word[-3:]=een',
#    'word[-2:]=en',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=onions',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=onions',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNP',
#    '-1:word.lower=green',
#    '-1:postag=JJ',
#    '+1:word.lower=scallions',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=scallions',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=onions',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=cilantro',
#    'word[-3:]=tro',
#    'word[-2:]=ro',
#    'postag=NN',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=italian',
#    'word[-3:]=ian',
#    'word[-2:]=an',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=parsley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=italian',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=fresh',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=rosemary',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=rosemary',
#    'word[-3:]=ary',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=fresh',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=thyme',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=thyme',
#    'word[-3:]=yme',
#    'word[-2:]=me',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=mint',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mint',
#    'word[-3:]=int',
#    'word[-2:]=nt',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=basil',
#    'word[-3:]=sil',
#    'word[-2:]=il',
#    'postag=NN',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=dill',
#    'word[-3:]=ill',
#    'word[-2:]=ll',
#    'postag=NN',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organics',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organics',
#    'word[-3:]=ics',
#    'word[-2:]=cs',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=fresh',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=organics',
#    '-1:postag=NNP',
#    '+1:word.lower=dill',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dill',
#    'word[-3:]=ill',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=gourmet',
#    'word[-3:]=met',
#    'word[-2:]=et',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=garden',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=gourmet',
#    '-1:postag=NNP',
#    '+1:word.lower=ginger',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ginger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=garden',
#    '-1:postag=NNP',
#    '+1:word.lower=stir',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=stir',
#    'word[-3:]=tir',
#    'word[-2:]=ir',
#    'postag=NNP',
#    '-1:word.lower=ginger',
#    '-1:postag=NNP',
#    '+1:word.lower=in',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=in',
#    'word[-3:]=in',
#    'word[-2:]=in',
#    'postag=IN',
#    '-1:word.lower=stir',
#    '-1:postag=NNP',
#    '+1:word.lower=paste',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=paste',
#    'word[-3:]=ste',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=in',
#    '-1:postag=IN',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=chives',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=chives',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=simple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=truth',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=truth',
#    'word[-3:]=uth',
#    'word[-2:]=th',
#    'postag=NNP',
#    '-1:word.lower=simple',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=truth',
#    '-1:postag=NNP',
#    '+1:word.lower=ithyme',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ithyme',
#    'word[-3:]=yme',
#    'word[-2:]=me',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=leaves',
#    '+1:postag=VBZ'],
#   ['bias',
#    'word.lower=leaves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=VBZ',
#    '-1:word.lower=ithyme',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=curly',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=curly',
#    'word[-3:]=rly',
#    'word[-2:]=ly',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=parsley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=curly',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organics',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organics',
#    'word[-3:]=ics',
#    'word[-2:]=cs',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=sage',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=sage',
#    'word[-3:]=age',
#    'word[-2:]=ge',
#    'postag=NN',
#    '-1:word.lower=organics',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=bay',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bay',
#    'word[-3:]=Bay',
#    'word[-2:]=ay',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=leaf',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=leaf',
#    'word[-3:]=eaf',
#    'word[-2:]=af',
#    'postag=NNP',
#    '-1:word.lower=bay',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=bellino',
#    'word[-3:]=ino',
#    'word[-2:]=no',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=peeled',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=peeled',
#    'word[-3:]=led',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=bellino',
#    '-1:postag=NNP',
#    '+1:word.lower=garlic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garlic',
#    'word[-3:]=lic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=peeled',
#    '-1:postag=NNP',
#    '+1:word.lower=cloves',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cloves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=garlic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=gourmet',
#    'word[-3:]=met',
#    'word[-2:]=et',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=garden',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=gourmet',
#    '-1:postag=NNP',
#    '+1:word.lower=lemongrass',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lemongrass',
#    'word[-3:]=ass',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=garden',
#    '-1:postag=NNP',
#    '+1:word.lower=stir',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=stir',
#    'word[-3:]=tir',
#    'word[-2:]=ir',
#    'postag=NNP',
#    '-1:word.lower=lemongrass',
#    '-1:postag=NNP',
#    '+1:word.lower=in',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=in',
#    'word[-3:]=in',
#    'word[-2:]=in',
#    'postag=IN',
#    '-1:word.lower=stir',
#    '-1:postag=NNP',
#    '+1:word.lower=paste',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=paste',
#    'word[-3:]=ste',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=in',
#    '-1:postag=IN',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=fennel',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fennel',
#    'word[-3:]=nel',
#    'word[-2:]=el',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=bulb',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bulb',
#    'word[-3:]=ulb',
#    'word[-2:]=lb',
#    'postag=NNP',
#    '-1:word.lower=fennel',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=gourmet',
#    'word[-3:]=met',
#    'word[-2:]=et',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=garden',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=gourmet',
#    '-1:postag=NNP',
#    '+1:word.lower=lightly',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lightly',
#    'word[-3:]=tly',
#    'word[-2:]=ly',
#    'postag=NNP',
#    '-1:word.lower=garden',
#    '-1:postag=NNP',
#    '+1:word.lower=dried',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dried',
#    'word[-3:]=ied',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=lightly',
#    '-1:postag=NNP',
#    '+1:word.lower=parsley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=dried',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=curly',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=curly',
#    'word[-3:]=rly',
#    'word[-2:]=ly',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=parsley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=curly',
#    '-1:postag=NNP',
#    '+1:word.lower=bunch',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bunch',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=parsley',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=thyme',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=thyme',
#    'word[-3:]=yme',
#    'word[-2:]=me',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=leaves',
#    '+1:postag=VBZ'],
#   ['bias',
#    'word.lower=leaves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=VBZ',
#    '-1:word.lower=thyme',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organics',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organics',
#    'word[-3:]=ics',
#    'word[-2:]=cs',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=fresh',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=organics',
#    '-1:postag=NNP',
#    '+1:word.lower=parsley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=simple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=truth',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=truth',
#    'word[-3:]=uth',
#    'word[-2:]=th',
#    'postag=NNP',
#    '-1:word.lower=simple',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=truth',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=oregano',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=oregano',
#    'word[-3:]=ano',
#    'word[-2:]=no',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=leaves',
#    '+1:postag=VBZ'],
#   ['bias',
#    'word.lower=leaves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=VBZ',
#    '-1:word.lower=oregano',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ground',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ground',
#    'word[-3:]=und',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=ginger',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ginger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=ground',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=gourmet',
#    'word[-3:]=met',
#    'word[-2:]=et',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=garden',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=gourmet',
#    '-1:postag=NNP',
#    '+1:word.lower=cilantro',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cilantro',
#    'word[-3:]=tro',
#    'word[-2:]=ro',
#    'postag=NNP',
#    '-1:word.lower=garden',
#    '-1:postag=NNP',
#    '+1:word.lower=stir',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=stir',
#    'word[-3:]=tir',
#    'word[-2:]=ir',
#    'postag=NNP',
#    '-1:word.lower=cilantro',
#    '-1:postag=NNP',
#    '+1:word.lower=in',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=in',
#    'word[-3:]=in',
#    'word[-2:]=in',
#    'postag=IN',
#    '-1:word.lower=stir',
#    '-1:postag=NNP',
#    '+1:word.lower=paste',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=paste',
#    'word[-3:]=ste',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=in',
#    '-1:postag=IN',
#    'EOS']],
#  [['bias',
#    'word.lower=spice',
#    'word[-3:]=ice',
#    'word[-2:]=ce',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=islands',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=islands',
#    'word[-3:]=nds',
#    'word[-2:]=ds',
#    'postag=NNP',
#    '-1:word.lower=spice',
#    '-1:postag=NNP',
#    '+1:word.lower=thyme',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=thyme',
#    'word[-3:]=yme',
#    'word[-2:]=me',
#    'postag=NNP',
#    '-1:word.lower=islands',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=ntwy',
#    'word[-3:]=twy',
#    'word[-2:]=wy',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=dong',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dong',
#    'word[-3:]=ong',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=ntwy',
#    '-1:postag=NNP',
#    '+1:word.lower=quai',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=quai',
#    'word[-3:]=uai',
#    'word[-2:]=ai',
#    'postag=NNP',
#    '-1:word.lower=dong',
#    '-1:postag=NNP',
#    '+1:word.lower=root',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=root',
#    'word[-3:]=oot',
#    'word[-2:]=ot',
#    'postag=NNP',
#    '-1:word.lower=quai',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=lemon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=basil',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=basil',
#    'word[-3:]=sil',
#    'word[-2:]=il',
#    'postag=NNP',
#    '-1:word.lower=lemon',
#    '-1:postag=NNP',
#    '+1:word.lower=package',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=package',
#    'word[-3:]=age',
#    'word[-2:]=ge',
#    'postag=NN',
#    '-1:word.lower=basil',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=hersheys',
#    'word[-3:]=eys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=hersheys',
#    '-1:postag=NNP',
#    '+1:word.lower=unsweetened',
#    '+1:postag=VBD'],
#   ['bias',
#    'word.lower=unsweetened',
#    'word[-3:]=ned',
#    'word[-2:]=ed',
#    'postag=VBD',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=cocoa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cocoa',
#    'word[-3:]=coa',
#    'word[-2:]=oa',
#    'postag=NNP',
#    '-1:word.lower=unsweetened',
#    '-1:postag=VBD',
#    'EOS']],
#  [['bias',
#    'word.lower=arm',
#    'word[-3:]=Arm',
#    'word[-2:]=rm',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=hammer',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=hammer',
#    'word[-3:]=mer',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=arm',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=hammer',
#    '-1:postag=NNP',
#    '+1:word.lower=baking',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baking',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=soda',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=soda',
#    'word[-3:]=oda',
#    'word[-2:]=da',
#    'postag=NNP',
#    '-1:word.lower=baking',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=toll',
#    'word[-3:]=oll',
#    'word[-2:]=ll',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=house',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=house',
#    'word[-3:]=use',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=toll',
#    '-1:postag=NNP',
#    '+1:word.lower=real',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=real',
#    'word[-3:]=eal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=house',
#    '-1:postag=NNP',
#    '+1:word.lower=semi',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=semi',
#    'word[-3:]=emi',
#    'word[-2:]=mi',
#    'postag=NNP',
#    '-1:word.lower=real',
#    '-1:postag=NNP',
#    '+1:word.lower=sweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=semi',
#    '-1:postag=NNP',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    '+1:word.lower=morsels',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=morsels',
#    'word[-3:]=els',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=libbys',
#    'word[-3:]=bys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pumpkin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pumpkin',
#    'word[-3:]=kin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=libbys',
#    '-1:postag=NNP',
#    '+1:word.lower=100',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=100',
#    'word[-3:]=100',
#    'word[-2:]=00',
#    'postag=CD',
#    '-1:word.lower=pumpkin',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=100',
#    '-1:postag=CD',
#    '+1:word.lower=libbys',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=libbys',
#    'word[-3:]=BYS',
#    'word[-2:]=YS',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=100',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=100',
#    'word[-3:]=100',
#    'word[-2:]=00',
#    'postag=CD',
#    '-1:word.lower=libbys',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=100',
#    '-1:postag=CD',
#    '+1:word.lower=pumpkin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pumpkin',
#    'word[-3:]=kin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=cocoa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cocoa',
#    'word[-3:]=coa',
#    'word[-2:]=oa',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=spice',
#    'word[-3:]=ice',
#    'word[-2:]=ce',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=islands',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=islands',
#    'word[-3:]=nds',
#    'word[-2:]=ds',
#    'postag=NNP',
#    '-1:word.lower=spice',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=islands',
#    '-1:postag=NNP',
#    '+1:word.lower=vanilla',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=vanilla',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=extract',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=extract',
#    'word[-3:]=act',
#    'word[-2:]=ct',
#    'postag=NNP',
#    '-1:word.lower=vanilla',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=ghirardelli',
#    'word[-3:]=lli',
#    'word[-2:]=li',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=ghirardelli',
#    '-1:postag=NNP',
#    '+1:word.lower=baking',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baking',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=chips',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chips',
#    'word[-3:]=ips',
#    'word[-2:]=ps',
#    'postag=NNP',
#    '-1:word.lower=baking',
#    '-1:postag=NNP',
#    '+1:word.lower=60',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=60',
#    'word[-3:]=60',
#    'word[-2:]=60',
#    'postag=CD',
#    '-1:word.lower=chips',
#    '-1:postag=NNP',
#    '+1:word.lower=cacao',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cacao',
#    'word[-3:]=cao',
#    'word[-2:]=ao',
#    'postag=NNP',
#    '-1:word.lower=60',
#    '-1:postag=CD',
#    '+1:word.lower=bittersweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bittersweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=cacao',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=stevia',
#    'word[-3:]=via',
#    'word[-2:]=ia',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=in',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=in',
#    'word[-3:]=in',
#    'word[-2:]=in',
#    'postag=IN',
#    '-1:word.lower=stevia',
#    '-1:postag=NNP',
#    '+1:word.lower=the',
#    '+1:postag=DT'],
#   ['bias',
#    'word.lower=the',
#    'word[-3:]=the',
#    'word[-2:]=he',
#    'postag=DT',
#    '-1:word.lower=in',
#    '-1:postag=IN',
#    '+1:word.lower=raw',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raw',
#    'word[-3:]=Raw',
#    'word[-2:]=aw',
#    'postag=NNP',
#    '-1:word.lower=the',
#    '-1:postag=DT',
#    '+1:word.lower=zero',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=zero',
#    'word[-3:]=ero',
#    'word[-2:]=ro',
#    'postag=NNP',
#    '-1:word.lower=raw',
#    '-1:postag=NNP',
#    '+1:word.lower=calorie',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=calorie',
#    'word[-3:]=rie',
#    'word[-2:]=ie',
#    'postag=NNP',
#    '-1:word.lower=zero',
#    '-1:postag=NNP',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=calorie',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=splenda',
#    'word[-3:]=nda',
#    'word[-2:]=da',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=no',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=no',
#    'word[-3:]=No',
#    'word[-2:]=No',
#    'postag=NNP',
#    '-1:word.lower=splenda',
#    '-1:postag=NNP',
#    '+1:word.lower=calorie',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=calorie',
#    'word[-3:]=rie',
#    'word[-2:]=ie',
#    'postag=NNP',
#    '-1:word.lower=no',
#    '-1:postag=NNP',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=calorie',
#    '-1:postag=NNP',
#    '+1:word.lower=packets',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=packets',
#    'word[-3:]=ets',
#    'word[-2:]=ts',
#    'postag=NNS',
#    '-1:word.lower=sweetener',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=carnation',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NN',
#    'BOS',
#    '+1:word.lower=evaporated',
#    '+1:postag=VBD'],
#   ['bias',
#    'word.lower=evaporated',
#    'word[-3:]=ted',
#    'word[-2:]=ed',
#    'postag=VBD',
#    '-1:word.lower=carnation',
#    '-1:postag=NN',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=evaporated',
#    '-1:postag=VBD',
#    'EOS']],
#  [['bias',
#    'word.lower=king',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    'BOS',
#    '+1:word.lower=arthur',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=arthur',
#    'word[-3:]=hur',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=king',
#    '-1:postag=VBG',
#    '+1:word.lower=flour',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flour',
#    'word[-3:]=our',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=arthur',
#    '-1:postag=NNP',
#    '+1:word.lower=unbleached',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=unbleached',
#    'word[-3:]=hed',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=flour',
#    '-1:postag=NNP',
#    '+1:word.lower=flour',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flour',
#    'word[-3:]=our',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=unbleached',
#    '-1:postag=NNP',
#    '+1:word.lower=bread',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bread',
#    'word[-3:]=ead',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=flour',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=toll',
#    'word[-3:]=oll',
#    'word[-2:]=ll',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=house',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=house',
#    'word[-3:]=use',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=toll',
#    '-1:postag=NNP',
#    '+1:word.lower=dark',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dark',
#    'word[-3:]=ark',
#    'word[-2:]=rk',
#    'postag=NNP',
#    '-1:word.lower=house',
#    '-1:postag=NNP',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=dark',
#    '-1:postag=NNP',
#    '+1:word.lower=morsels',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=morsels',
#    'word[-3:]=els',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=king',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    'BOS',
#    '+1:word.lower=arthur',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=arthur',
#    'word[-3:]=hur',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=king',
#    '-1:postag=VBG',
#    '+1:word.lower=flour',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flour',
#    'word[-3:]=our',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=arthur',
#    '-1:postag=NNP',
#    '+1:word.lower=unbleached',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=unbleached',
#    'word[-3:]=hed',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=flour',
#    '-1:postag=NNP',
#    '+1:word.lower=flour',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flour',
#    'word[-3:]=our',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=unbleached',
#    '-1:postag=NNP',
#    '+1:word.lower=all',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=flour',
#    '-1:postag=NNP',
#    '+1:word.lower=purpose',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=purpose',
#    'word[-3:]=ose',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=domino',
#    'word[-3:]=ino',
#    'word[-2:]=no',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=light',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=light',
#    'word[-3:]=ght',
#    'word[-2:]=ht',
#    'postag=NNP',
#    '-1:word.lower=domino',
#    '-1:postag=NNP',
#    '+1:word.lower=brown',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=brown',
#    'word[-3:]=own',
#    'word[-2:]=wn',
#    'postag=NNP',
#    '-1:word.lower=light',
#    '-1:postag=NNP',
#    '+1:word.lower=sugar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=brown',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=ghirardelli',
#    'word[-3:]=lli',
#    'word[-2:]=li',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=ghirardelli',
#    '-1:postag=NNP',
#    '+1:word.lower=baking',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baking',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=chips',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chips',
#    'word[-3:]=ips',
#    'word[-2:]=ps',
#    'postag=NNP',
#    '-1:word.lower=baking',
#    '-1:postag=NNP',
#    '+1:word.lower=semi',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=semi',
#    'word[-3:]=emi',
#    'word[-2:]=mi',
#    'postag=NNP',
#    '-1:word.lower=chips',
#    '-1:postag=NNP',
#    '+1:word.lower=sweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=semi',
#    '-1:postag=NNP',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NN',
#    'BOS',
#    '+1:word.lower=in',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=in',
#    'word[-3:]=In',
#    'word[-2:]=In',
#    'postag=IN',
#    '-1:word.lower=sugar',
#    '-1:postag=NN',
#    '+1:word.lower=the',
#    '+1:postag=DT'],
#   ['bias',
#    'word.lower=the',
#    'word[-3:]=The',
#    'word[-2:]=he',
#    'postag=DT',
#    '-1:word.lower=in',
#    '-1:postag=IN',
#    '+1:word.lower=raw',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raw',
#    'word[-3:]=Raw',
#    'word[-2:]=aw',
#    'postag=NNP',
#    '-1:word.lower=the',
#    '-1:postag=DT',
#    '+1:word.lower=turbinado',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=turbinado',
#    'word[-3:]=ado',
#    'word[-2:]=do',
#    'postag=NNP',
#    '-1:word.lower=raw',
#    '-1:postag=NNP',
#    '+1:word.lower=cane',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cane',
#    'word[-3:]=ane',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=turbinado',
#    '-1:postag=NNP',
#    '+1:word.lower=sugar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=cane',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=domino',
#    'word[-3:]=ino',
#    'word[-2:]=no',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=premium',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=premium',
#    'word[-3:]=ium',
#    'word[-2:]=um',
#    'postag=NNP',
#    '-1:word.lower=domino',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=premium',
#    '-1:postag=NNP',
#    '+1:word.lower=cane',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cane',
#    'word[-3:]=ane',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=granulated',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=granulated',
#    'word[-3:]=ted',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=cane',
#    '-1:postag=NNP',
#    '+1:word.lower=sugar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=granulated',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=simple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=truth',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=truth',
#    'word[-3:]=uth',
#    'word[-2:]=th',
#    'postag=NNP',
#    '-1:word.lower=simple',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=truth',
#    '-1:postag=NNP',
#    '+1:word.lower=madagascar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=madagascar',
#    'word[-3:]=car',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=vanilla',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=vanilla',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=madagascar',
#    '-1:postag=NNP',
#    '+1:word.lower=extract',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=extract',
#    'word[-3:]=act',
#    'word[-2:]=ct',
#    'postag=NNP',
#    '-1:word.lower=vanilla',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=granulated',
#    'word[-3:]=ted',
#    'word[-2:]=ed',
#    'postag=VBN',
#    'BOS',
#    '+1:word.lower=no',
#    '+1:postag=DT'],
#   ['bias',
#    'word.lower=no',
#    'word[-3:]=No',
#    'word[-2:]=No',
#    'postag=DT',
#    '-1:word.lower=granulated',
#    '-1:postag=VBN',
#    '+1:word.lower=calorie',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=calorie',
#    'word[-3:]=rie',
#    'word[-2:]=ie',
#    'postag=NNP',
#    '-1:word.lower=no',
#    '-1:postag=DT',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=calorie',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=gold',
#    'word[-3:]=old',
#    'word[-2:]=ld',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=medal',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=medal',
#    'word[-3:]=dal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=gold',
#    '-1:postag=NNP',
#    '+1:word.lower=flour',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flour',
#    'word[-3:]=our',
#    'word[-2:]=ur',
#    'postag=NNP',
#    '-1:word.lower=medal',
#    '-1:postag=NNP',
#    '+1:word.lower=all',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=flour',
#    '-1:postag=NNP',
#    '+1:word.lower=purpose',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=purpose',
#    'word[-3:]=ose',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=all',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=vanilla',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=vanilla',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=extract',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=extract',
#    'word[-3:]=act',
#    'word[-2:]=ct',
#    'postag=NNP',
#    '-1:word.lower=vanilla',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sliced',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sliced',
#    'word[-3:]=ced',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    '+1:word.lower=almonds',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almonds',
#    'word[-3:]=nds',
#    'word[-2:]=ds',
#    'postag=NNP',
#    '-1:word.lower=sliced',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=fleischmanns',
#    'word[-3:]=nns',
#    'word[-2:]=ns',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=activedry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=activedry',
#    'word[-3:]=Dry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=fleischmanns',
#    '-1:postag=NNP',
#    '+1:word.lower=yeast',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=yeast',
#    'word[-3:]=ast',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=activedry',
#    '-1:postag=NNP',
#    '+1:word.lower=original',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=yeast',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=florida',
#    'word[-3:]=ida',
#    'word[-2:]=da',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=crystals',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=crystals',
#    'word[-3:]=als',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=florida',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=crystals',
#    '-1:postag=NNP',
#    '+1:word.lower=raw',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raw',
#    'word[-3:]=Raw',
#    'word[-2:]=aw',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=cane',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cane',
#    'word[-3:]=ane',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=raw',
#    '-1:postag=NNP',
#    '+1:word.lower=florida',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=florida',
#    'word[-3:]=ida',
#    'word[-2:]=da',
#    'postag=NNP',
#    '-1:word.lower=cane',
#    '-1:postag=NNP',
#    '+1:word.lower=crystals',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=crystals',
#    'word[-3:]=als',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=florida',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=crystals',
#    '-1:postag=NNP',
#    '+1:word.lower=raw',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raw',
#    'word[-3:]=Raw',
#    'word[-2:]=aw',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=cane',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cane',
#    'word[-3:]=ane',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=raw',
#    '-1:postag=NNP',
#    '+1:word.lower=sugar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=cane',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=toll',
#    'word[-3:]=oll',
#    'word[-2:]=ll',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=house',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=house',
#    'word[-3:]=use',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=toll',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=house',
#    '-1:postag=NNP',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=milk',
#    '-1:postag=NNP',
#    '+1:word.lower=morsels',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=morsels',
#    'word[-3:]=els',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=libbys',
#    'word[-3:]=bys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pumpkin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pumpkin',
#    'word[-3:]=kin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=libbys',
#    '-1:postag=NNP',
#    '+1:word.lower=100',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=100',
#    'word[-3:]=100',
#    'word[-2:]=00',
#    'postag=CD',
#    '-1:word.lower=pumpkin',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=100',
#    '-1:postag=CD',
#    '+1:word.lower=libbys',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=libbys',
#    'word[-3:]=BYS',
#    'word[-2:]=YS',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=100',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=100',
#    'word[-3:]=100',
#    'word[-2:]=00',
#    'postag=CD',
#    '-1:word.lower=libbys',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=100',
#    '-1:postag=CD',
#    '+1:word.lower=pumpkin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pumpkin',
#    'word[-3:]=kin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=ghirardelli',
#    'word[-3:]=lli',
#    'word[-2:]=li',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=ghirardelli',
#    '-1:postag=NNP',
#    '+1:word.lower=premium',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=premium',
#    'word[-3:]=ium',
#    'word[-2:]=um',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=baking',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baking',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=premium',
#    '-1:postag=NNP',
#    '+1:word.lower=cocoa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cocoa',
#    'word[-3:]=coa',
#    'word[-2:]=oa',
#    'postag=NNP',
#    '-1:word.lower=baking',
#    '-1:postag=NNP',
#    '+1:word.lower=100',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=100',
#    'word[-3:]=100',
#    'word[-2:]=00',
#    'postag=CD',
#    '-1:word.lower=cocoa',
#    '-1:postag=NNP',
#    '+1:word.lower=cocoa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cocoa',
#    'word[-3:]=coa',
#    'word[-2:]=oa',
#    'postag=NNP',
#    '-1:word.lower=100',
#    '-1:postag=CD',
#    'EOS']],
#  [['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=leaf',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=leaf',
#    'word[-3:]=eaf',
#    'word[-2:]=af',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    '+1:word.lower=tea',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=tea',
#    'word[-3:]=Tea',
#    'word[-2:]=ea',
#    'postag=NNP',
#    '-1:word.lower=leaf',
#    '-1:postag=NNP',
#    '+1:word.lower=co',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=co',
#    'word[-3:]=Co',
#    'word[-2:]=Co',
#    'postag=NNP',
#    '-1:word.lower=tea',
#    '-1:postag=NNP',
#    '+1:word.lower=sweetleaf',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetleaf',
#    'word[-3:]=eaf',
#    'word[-2:]=af',
#    'postag=NNP',
#    '-1:word.lower=co',
#    '-1:postag=NNP',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=sweetleaf',
#    '-1:postag=NNP',
#    '+1:word.lower=stevia',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=stevia',
#    'word[-3:]=via',
#    'word[-2:]=ia',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=stevia',
#    '-1:postag=NNP',
#    '+1:word.lower=packets',
#    '+1:postag=VBZ'],
#   ['bias',
#    'word.lower=packets',
#    'word[-3:]=ets',
#    'word[-2:]=ts',
#    'postag=VBZ',
#    '-1:word.lower=sweetener',
#    '-1:postag=NNP',
#    '+1:word.lower=70',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=70',
#    'word[-3:]=70',
#    'word[-2:]=70',
#    'postag=CD',
#    '-1:word.lower=packets',
#    '-1:postag=VBZ',
#    '+1:word.lower=ct',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=ct',
#    'word[-3:]=CT',
#    'word[-2:]=CT',
#    'postag=NN',
#    '-1:word.lower=70',
#    '-1:postag=CD',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=walnut',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=walnut',
#    'word[-3:]=nut',
#    'word[-2:]=ut',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    '+1:word.lower=pieces',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=pieces',
#    'word[-3:]=ces',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=walnut',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=truvia',
#    'word[-3:]=via',
#    'word[-2:]=ia',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=truvia',
#    '-1:postag=NNP',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=keebler',
#    'word[-3:]=ler',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ready',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ready',
#    'word[-3:]=ady',
#    'word[-2:]=dy',
#    'postag=NNP',
#    '-1:word.lower=keebler',
#    '-1:postag=NNP',
#    '+1:word.lower=crust',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=crust',
#    'word[-3:]=ust',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=ready',
#    '-1:postag=NNP',
#    '+1:word.lower=pie',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pie',
#    'word[-3:]=Pie',
#    'word[-2:]=ie',
#    'postag=NNP',
#    '-1:word.lower=crust',
#    '-1:postag=NNP',
#    '+1:word.lower=crust',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=crust',
#    'word[-3:]=ust',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=pie',
#    '-1:postag=NNP',
#    '+1:word.lower=graham',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=graham',
#    'word[-3:]=ham',
#    'word[-2:]=am',
#    'postag=NNP',
#    '-1:word.lower=crust',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=domino',
#    'word[-3:]=ino',
#    'word[-2:]=no',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=premium',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=premium',
#    'word[-3:]=ium',
#    'word[-2:]=um',
#    'postag=NNP',
#    '-1:word.lower=domino',
#    '-1:postag=NNP',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=premium',
#    '-1:postag=NNP',
#    '+1:word.lower=cane',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cane',
#    'word[-3:]=ane',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=granulated',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=granulated',
#    'word[-3:]=ted',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=cane',
#    '-1:postag=NNP',
#    '+1:word.lower=sugar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sugar',
#    'word[-3:]=gar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=granulated',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=ghirardelli',
#    'word[-3:]=lli',
#    'word[-2:]=li',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=ghirardelli',
#    '-1:postag=NNP',
# ...
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=himalayan',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=himalayan',
#    'word[-3:]=yan',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=pink',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pink',
#    'word[-3:]=ink',
#    'word[-2:]=nk',
#    'postag=NNP',
#    '-1:word.lower=himalayan',
#    '-1:postag=NNP',
#    '+1:word.lower=salt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salt',
#    'word[-3:]=alt',
#    'word[-2:]=lt',
#    'postag=NNP',
#    '-1:word.lower=pink',
#    '-1:postag=NNP',
#    '+1:word.lower=black',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=black',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=salt',
#    '-1:postag=NNP',
#    '+1:word.lower=pepper',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pepper',
#    'word[-3:]=per',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=black',
#    '-1:postag=NNP',
#    '+1:word.lower=and',
#    '+1:postag=CC'],
#   ['bias',
#    'word.lower=and',
#    'word[-3:]=And',
#    'word[-2:]=nd',
#    'postag=CC',
#    '-1:word.lower=pepper',
#    '-1:postag=NNP',
#    '+1:word.lower=garlic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garlic',
#    'word[-3:]=lic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=and',
#    '-1:postag=CC',
#    '+1:word.lower=all',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=garlic',
#    '-1:postag=NNP',
#    '+1:word.lower=purpose',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=purpose',
#    'word[-3:]=ose',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=purpose',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=bragg',
#    'word[-3:]=agg',
#    'word[-2:]=gg',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=premium',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=premium',
#    'word[-3:]=ium',
#    'word[-2:]=um',
#    'postag=NNP',
#    '-1:word.lower=bragg',
#    '-1:postag=NNP',
#    '+1:word.lower=nutritional',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=nutritional',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=premium',
#    '-1:postag=NNP',
#    '+1:word.lower=yeast',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=yeast',
#    'word[-3:]=ast',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=nutritional',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=yeast',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=whole',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=whole',
#    'word[-3:]=ole',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=black',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=black',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=whole',
#    '-1:postag=NNP',
#    '+1:word.lower=pepper',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pepper',
#    'word[-3:]=per',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=black',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=goya',
#    'word[-3:]=oya',
#    'word[-2:]=ya',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=adobo',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=adobo',
#    'word[-3:]=obo',
#    'word[-2:]=bo',
#    'postag=NNP',
#    '-1:word.lower=goya',
#    '-1:postag=NNP',
#    '+1:word.lower=all',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=adobo',
#    '-1:postag=NNP',
#    '+1:word.lower=purpose',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=purpose',
#    'word[-3:]=ose',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=purpose',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pure',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pure',
#    'word[-3:]=ure',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    '+1:word.lower=ground',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ground',
#    'word[-3:]=und',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=pure',
#    '-1:postag=NNP',
#    '+1:word.lower=black',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=black',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=ground',
#    '-1:postag=NNP',
#    '+1:word.lower=pepper',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pepper',
#    'word[-3:]=per',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=black',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=simple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=truth',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=truth',
#    'word[-3:]=uth',
#    'word[-2:]=th',
#    'postag=NNP',
#    '-1:word.lower=simple',
#    '-1:postag=NNP',
#    '+1:word.lower=nutmeg',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=nutmeg',
#    'word[-3:]=meg',
#    'word[-2:]=eg',
#    'postag=NNP',
#    '-1:word.lower=truth',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=grill',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grill',
#    'word[-3:]=ill',
#    'word[-2:]=ll',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=mates',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mates',
#    'word[-3:]=tes',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=grill',
#    '-1:postag=NNP',
#    '+1:word.lower=spicy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spicy',
#    'word[-3:]=icy',
#    'word[-2:]=cy',
#    'postag=NNP',
#    '-1:word.lower=mates',
#    '-1:postag=NNP',
#    '+1:word.lower=montreal',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=montreal',
#    'word[-3:]=eal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=spicy',
#    '-1:postag=NNP',
#    '+1:word.lower=steak',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=steak',
#    'word[-3:]=eak',
#    'word[-2:]=ak',
#    'postag=NNP',
#    '-1:word.lower=montreal',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=VBG'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    '-1:word.lower=steak',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=poultry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=poultry',
#    'word[-3:]=try',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=VBG'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    '-1:word.lower=poultry',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=celery',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=celery',
#    'word[-3:]=ery',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    '+1:word.lower=salt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salt',
#    'word[-3:]=alt',
#    'word[-2:]=lt',
#    'postag=NNP',
#    '-1:word.lower=celery',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mrs',
#    'word[-3:]=Mrs',
#    'word[-2:]=rs',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=dash',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dash',
#    'word[-3:]=ash',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=mrs',
#    '-1:postag=NNP',
#    '+1:word.lower=onion',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=onion',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=dash',
#    '-1:postag=NNP',
#    '+1:word.lower=herb',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=herb',
#    'word[-3:]=erb',
#    'word[-2:]=rb',
#    'postag=NNP',
#    '-1:word.lower=onion',
#    '-1:postag=NNP',
#    '+1:word.lower=salt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salt',
#    'word[-3:]=alt',
#    'word[-2:]=lt',
#    'postag=NNP',
#    '-1:word.lower=herb',
#    '-1:postag=NNP',
#    '+1:word.lower=free',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=free',
#    'word[-3:]=ree',
#    'word[-2:]=ee',
#    'postag=NNP',
#    '-1:word.lower=salt',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=free',
#    '-1:postag=NNP',
#    '+1:word.lower=blend',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=blend',
#    'word[-3:]=end',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=seasoning',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=gourmet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=gourmet',
#    'word[-3:]=met',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=gourmet',
#    '-1:postag=NNP',
#    '+1:word.lower=onion',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=onion',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=powder',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=powder',
#    'word[-3:]=der',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=onion',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=roundys',
#    'word[-3:]=dys',
#    'word[-2:]=ys',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organics',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organics',
#    'word[-3:]=ics',
#    'word[-2:]=cs',
#    'postag=NNP',
#    '-1:word.lower=roundys',
#    '-1:postag=NNP',
#    '+1:word.lower=fresh',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=organics',
#    '-1:postag=NNP',
#    '+1:word.lower=oregano',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=oregano',
#    'word[-3:]=ano',
#    'word[-2:]=no',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=garlic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=garlic',
#    'word[-3:]=lic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=jalapeno',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=jalapeno',
#    'word[-3:]=eno',
#    'word[-2:]=no',
#    'postag=NNP',
#    '-1:word.lower=garlic',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=VBG'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    '-1:word.lower=jalapeno',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ground',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ground',
#    'word[-3:]=und',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=mustard',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mustard',
#    'word[-3:]=ard',
#    'word[-2:]=rd',
#    'postag=NNP',
#    '-1:word.lower=ground',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=hidden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=valley',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=valley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=hidden',
#    '-1:postag=NNP',
#    '+1:word.lower=dips',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dips',
#    'word[-3:]=ips',
#    'word[-2:]=ps',
#    'postag=NNP',
#    '-1:word.lower=valley',
#    '-1:postag=NNP',
#    '+1:word.lower=mix',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mix',
#    'word[-3:]=Mix',
#    'word[-2:]=ix',
#    'postag=NNP',
#    '-1:word.lower=dips',
#    '-1:postag=NNP',
#    '+1:word.lower=original',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=mix',
#    '-1:postag=NNP',
#    '+1:word.lower=ranch',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ranch',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=NNP',
#    '+1:word.lower=20',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=20',
#    'word[-3:]=20',
#    'word[-2:]=20',
#    'postag=CD',
#    '-1:word.lower=ranch',
#    '-1:postag=NNP',
#    '+1:word.lower=ounces',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=ounces',
#    'word[-3:]=ces',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=20',
#    '-1:postag=CD',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=italian',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=italian',
#    'word[-3:]=ian',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=blend',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=blend',
#    'word[-3:]=end',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=italian',
#    '-1:postag=NNP',
#    '+1:word.lower=herb',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=herb',
#    'word[-3:]=erb',
#    'word[-2:]=rb',
#    'postag=NNP',
#    '-1:word.lower=blend',
#    '-1:postag=NNP',
#    '+1:word.lower=grinder',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grinder',
#    'word[-3:]=der',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=herb',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ground',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ground',
#    'word[-3:]=und',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=cinnamon',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cinnamon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=ground',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mccormick',
#    'word[-3:]=ick',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=bay',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bay',
#    'word[-3:]=Bay',
#    'word[-2:]=ay',
#    'postag=NNP',
#    '-1:word.lower=mccormick',
#    '-1:postag=NNP',
#    '+1:word.lower=leaves',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=leaves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=bay',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=morton',
#    'word[-3:]=ton',
#    'word[-2:]=on',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=salt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salt',
#    'word[-3:]=alt',
#    'word[-2:]=lt',
#    'postag=NNP',
#    '-1:word.lower=morton',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kroger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=iodized',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=iodized',
#    'word[-3:]=zed',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=kroger',
#    '-1:postag=NNP',
#    '+1:word.lower=salt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salt',
#    'word[-3:]=alt',
#    'word[-2:]=lt',
#    'postag=NNP',
#    '-1:word.lower=iodized',
#    '-1:postag=NNP',
#    'EOS']],
#  ...]

# %%
tagger = pycrfsuite.Tagger()
tagger.open('../../data/04_models/crf_marianos_final.model')

# %%
y_pred = [tagger.tag(xseq) for xseq in X]

# %%
len(token_sr)
# Out:
# 6242

# %%
len(y_pred)
# Out:
# 6242

# %%
def product_tagger(product_sentence_tokens, product_label_sentence):
    pre = []
    food = []
    post = []

    for word, label in zip(product_sentence_tokens, product_label_sentence):
        if label == 'pre':
            pre.append(word.lower())
        if label == 'food':
            food.append(word.lower())
        if label == 'post':
            post.append(word.lower())
    return {'pre': " ".join(pre), 'food': " ".join(food), 'post': " ".join(post)}

# %%
def token_labels_to_dict(tokens, labels, titles):
    final_dict = {}
    for token, label, title in zip(tokens, labels, titles):
        prod = product_tagger(token, label)
        final_dict[str(title).lower()] = prod
    return final_dict

# %%
final_dict = token_labels_to_dict(token_sr, y_pred, products_list)

# %%
final_dict
# Out:
# {'green onions (scallions)': {'pre': 'green onions',
#   'food': 'scallions',
#   'post': ''},
#  'cilantro': {'pre': '', 'food': 'cilantro', 'post': ''},
#  'italian parsley': {'pre': 'italian', 'food': 'parsley', 'post': ''},
#  "roundy's organic fresh rosemary": {'pre': '',
#   'food': 'roundys',
#   'post': 'organic fresh rosemary'},
#  "roundy's organic fresh thyme": {'pre': 'roundys organic fresh',
#   'food': 'thyme',
#   'post': ''},
#  "roundy's mint": {'pre': 'roundys', 'food': 'mint', 'post': ''},
#  'basil': {'pre': '', 'food': 'basil', 'post': ''},
#  'dill': {'pre': '', 'food': 'dill', 'post': ''},
#  "roundy's organics fresh dill": {'pre': 'roundys organics fresh',
#   'food': 'dill',
#   'post': ''},
#  'gourmet garden™ ginger stir-in paste': {'pre': 'gourmet garden ginger stir in',
#   'food': 'paste',
#   'post': ''},
#  'organic chives': {'pre': 'organic', 'food': 'chives', 'post': ''},
#  'simple truth organic ithyme leaves': {'pre': 'simple truth organic',
#   'food': 'ithyme',
#   'post': 'leaves'},
#  'organic curly parsley': {'pre': 'organic curly',
#   'food': 'parsley',
#   'post': ''},
#  "roundy's organics sage": {'pre': 'roundys organics',
#   'food': 'sage',
#   'post': ''},
#  "roundy's bay leaf": {'pre': 'roundys bay', 'food': 'leaf', 'post': ''},
#  'bellino peeled garlic cloves': {'pre': 'bellino peeled',
#   'food': 'garlic',
#   'post': 'cloves'},
#  'gourmet garden™ lemongrass stir-in paste': {'pre': 'gourmet garden lemongrass stir in',
#   'food': 'paste',
#   'post': ''},
#  'organic fennel bulb': {'pre': 'organic', 'food': 'fennel', 'post': 'bulb'},
#  'gourmet garden™ lightly dried parsley': {'pre': 'gourmet garden lightly',
#   'food': 'dried parsley',
#   'post': ''},
#  'organic curly parsley bunch': {'pre': 'organic curly',
#   'food': 'parsley',
#   'post': 'bunch'},
#  'mccormick® thyme leaves': {'pre': 'mccormick',
#   'food': 'thyme',
#   'post': 'leaves'},
#  "roundy's organics fresh parsley": {'pre': 'roundys organics fresh',
#   'food': 'parsley',
#   'post': ''},
#  'simple truth organic organic oregano leaves': {'pre': 'simple truth organic organic',
#   'food': 'oregano',
#   'post': 'leaves'},
#  'roundys ground ginger': {'pre': 'roundys',
#   'food': 'ground ginger',
#   'post': ''},
#  'gourmet garden™ cilantro stir-in paste': {'pre': 'gourmet garden cilantro stir in',
#   'food': 'paste',
#   'post': ''},
#  'spice islands thyme': {'pre': 'spice islands', 'food': 'thyme', 'post': ''},
#  'ntwy dong quai root': {'pre': 'ntwy', 'food': 'dong', 'post': 'quai root'},
#  'lemon basil package': {'pre': '', 'food': 'lemon basil', 'post': 'package'},
#  "hershey's. natural unsweetened cocoa": {'pre': 'hersheys natural unsweetened',
#   'food': 'cocoa',
#   'post': ''},
#  'arm & hammer pure baking soda': {'pre': 'arm hammer pure',
#   'food': 'baking soda',
#   'post': ''},
#  'toll house real semi-sweet chocolate morsels': {'pre': 'toll house real semi sweet',
#   'food': 'chocolate',
#   'post': 'morsels'},
#  "libby's pumpkin 100% pure libby's 100% pure pumpkin": {'pre': 'libbys pumpkin 100 pure libbys 100 pure',
#   'food': 'pumpkin',
#   'post': ''},
#  'kroger cocoa': {'pre': 'kroger', 'food': 'cocoa', 'post': ''},
#  'spice islands pure vanilla extract': {'pre': 'spice islands',
#   'food': 'pure vanilla extract',
#   'post': ''},
#  'ghirardelli chocolate baking chips 60% cacao bittersweet': {'pre': 'ghirardelli chocolate',
#   'food': 'baking chips',
#   'post': '60 cacao bittersweet'},
#  'stevia in the raw zero calorie sweetener': {'pre': '',
#   'food': 'stevia',
#   'post': 'in the raw zero calorie sweetener'},
#  'splenda® no calorie sweetener, packets': {'pre': '',
#   'food': 'splenda',
#   'post': 'no calorie sweetener packets'},
#  'carnation evaporated milk': {'pre': 'carnation',
#   'food': 'evaporated milk',
#   'post': ''},
#  'king arthur flour unbleached flour bread': {'pre': 'king arthur flour unbleached',
#   'food': 'flour bread',
#   'post': ''},
#  'toll house dark chocolate morsels': {'pre': 'toll house',
#   'food': 'dark chocolate',
#   'post': 'morsels'},
#  'king arthur flour unbleached flour all-purpose': {'pre': 'king arthur flour unbleached',
#   'food': 'flour',
#   'post': 'all purpose'},
#  'domino light brown sugar': {'pre': 'domino',
#   'food': 'light brown sugar',
#   'post': ''},
#  'ghirardelli chocolate baking chips semi-sweet chocolate': {'pre': 'ghirardelli chocolate baking chips semi sweet',
#   'food': 'chocolate',
#   'post': ''},
#  'sugar in the raw turbinado cane sugar': {'pre': 'sugar in the raw turbinado cane',
#   'food': 'sugar',
#   'post': ''},
#  'domino premium pure cane granulated sugar': {'pre': 'domino premium pure cane granulated',
#   'food': 'sugar',
#   'post': ''},
#  'simple truth organic madagascar vanilla extract': {'pre': 'simple truth organic madagascar',
#   'food': 'vanilla extract',
#   'post': ''},
#  'granulated no calorie sweetener': {'pre': '',
#   'food': 'granulated no calorie sweetener',
#   'post': ''},
#  'gold medal flour all-purpose': {'pre': 'gold medal',
#   'food': 'flour',
#   'post': 'all purpose'},
#  'mccormick® all natural pure vanilla extract': {'pre': 'mccormick all natural pure',
#   'food': 'vanilla extract',
#   'post': ''},
#  'kroger sliced almonds': {'pre': 'kroger',
#   'food': 'sliced almonds',
#   'post': ''},
#  "fleischmann's activedry yeast original": {'pre': 'fleischmanns',
#   'food': 'activedry yeast',
#   'post': 'original'},
#  'florida crystals organic raw cane florida crystals organic raw cane sugar': {'pre': 'florida crystals organic raw cane florida crystals organic raw cane',
#   'food': 'sugar',
#   'post': ''},
#  'toll house milk chocolate morsels': {'pre': 'toll house',
#   'food': 'milk chocolate',
#   'post': 'morsels'},
#  'ghirardelli chocolate premium baking cocoa 100% cocoa': {'pre': 'ghirardelli chocolate premium',
#   'food': 'baking cocoa',
#   'post': '100 cocoa'},
#  'sweet leaf tea co sweetleaf natural stevia sweetener packets - 70 ct': {'pre': 'sweet leaf tea co sweetleaf natural',
#   'food': 'stevia',
#   'post': 'sweetener packets 70 ct'},
#  'kroger walnut pieces': {'pre': 'kroger', 'food': 'walnut', 'post': 'pieces'},
#  'truvia natural sweetener': {'pre': '',
#   'food': 'truvia',
#   'post': 'natural sweetener'},
#  'keebler ready crust pie crust graham': {'pre': 'keebler ready crust',
#   'food': 'pie crust',
#   'post': 'graham'},
#  'ghirardelli chocolate milk choc chips': {'pre': 'ghirardelli',
#   'food': 'chocolate milk',
#   'post': 'choc chips'},
#  'guittard candy, chocolate, extra dark, bag': {'pre': 'guittard candy',
#   'food': 'chocolate',
#   'post': 'extra dark bag'},
#  'la lechera sweetened condensed milk': {'pre': 'la lechera sweetened',
#   'food': 'condensed milk',
#   'post': ''},
#  'domino confectioners pure cane 10-x powdered domino confectioners pure cane 10-x powdered sugar': {'pre': 'domino confectioners pure cane 10 x powdered domino confectioners pure cane 10 x',
#   'food': 'powdered sugar',
#   'post': ''},
#  'simple truth organic sugar': {'pre': 'simple truth organic',
#   'food': 'sugar',
#   'post': ''},
#  'duncan hines signature cake mix lemon supreme': {'pre': 'duncan hines signature',
#   'food': 'cake mix',
#   'post': 'lemon supreme'},
#  'snack pack pudding banana cream pie': {'pre': 'snack pack',
#   'food': 'pudding',
#   'post': 'banana cream pie'},
#  'diamond of california® pine nuts': {'pre': 'diamond of california',
#   'food': 'pine nuts',
#   'post': ''},
#  'gold medal all-purpose flour resealable bag': {'pre': 'gold medal',
#   'food': 'all',
#   'post': 'purpose flour resealable bag'},
#  'clabber girl double acting baking powder': {'pre': 'clabber girl double acting',
#   'food': 'baking powder',
#   'post': ''},
#  'equal original 0 calorie sweetener packets': {'pre': '',
#   'food': 'equal',
#   'post': 'original 0 calorie sweetener packets'},
#  'domino pure cane certified organic domino organic raw cane sugar': {'pre': 'domino pure cane',
#   'food': 'certified',
#   'post': 'organic domino organic raw cane sugar'},
#  'kroger sweetener no calorie': {'pre': '',
#   'food': 'kroger sweetener no calorie',
#   'post': ''},
#  'kroger halves pecans': {'pre': 'kroger halves',
#   'food': 'pecans',
#   'post': ''},
#  'pillsbury best all purpose flour bleached enriched': {'pre': 'pillsbury best',
#   'food': 'all',
#   'post': 'purpose flour bleached enriched'},
#  'success boil-in-bag 100% tri-color quinoa': {'pre': 'success boil in bag 100 tri color',
#   'food': 'quinoa',
#   'post': ''},
#  'carnation evaporated lowfat 2% mil': {'pre': 'carnation evaporated lowfat 2',
#   'food': 'mil',
#   'post': ''},
#  "baker's® vanilla flavor": {'pre': 'bakers',
#   'food': 'vanilla flavor',
#   'post': ''},
#  'domino dark brown sugar': {'pre': 'domino dark',
#   'food': 'brown sugar',
#   'post': ''},
#  "baker's real milk chocolate baker's real milk chocolate dipping chocolate": {'pre': 'bakers',
#   'food': 'real milk chocolate bakers real milk chocolate dipping chocolate',
#   'post': ''},
#  'domino quick dissolve superfine domino superfine pure cane sugar': {'pre': 'domino quick dissolve superfine domino superfine pure cane',
#   'food': 'sugar',
#   'post': ''},
#  'kroger pecan pieces': {'pre': 'kroger', 'food': 'pecan', 'post': 'pieces'},
#  'mccormick® cinnamon sugar': {'pre': 'mccormick',
#   'food': 'cinnamon sugar',
#   'post': ''},
#  'diamond of california® chopped macadamia nuts': {'pre': 'diamond of california chopped',
#   'food': 'macadamia nuts',
#   'post': ''},
#  "fleischmann's rapidrise instant yeast": {'pre': 'fleischmanns rapidrise',
#   'food': 'instant yeast',
#   'post': ''},
#  'kroger instant banana pudding & pie filling': {'pre': 'kroger instant',
#   'food': 'banana pudding pie filling',
#   'post': ''},
#  "hershey's kitchens special dark chocolate baking chips": {'pre': 'hersheys kitchens special',
#   'food': 'dark chocolate baking chips',
#   'post': ''},
#  'crystal granulated sugar': {'pre': 'crystal granulated',
#   'food': 'sugar',
#   'post': ''},
#  'eagle brand borden sweetened condensed milk': {'pre': 'eagle brand borden sweetened',
#   'food': 'condensed milk',
#   'post': ''},
#  'mccormick® clear vanilla flavor': {'pre': 'mccormick clear',
#   'food': 'vanilla flavor',
#   'post': ''},
#  'wholesome organic turbinado raw cane sugar': {'pre': 'wholesome organic turbinado raw cane',
#   'food': 'sugar',
#   'post': ''},
#  'kraft marshmallows': {'pre': 'kraft', 'food': 'marshmallows', 'post': ''},
#  'moly mcbutter ® butter flavor sprinkles': {'pre': 'moly mcbutter',
#   'food': 'butter',
#   'post': 'flavor sprinkles'},
#  'kraft jet puffed miniature kraft jet-puffed miniature marshmallows': {'pre': 'kraft jet puffed miniature kraft jet puffed miniature',
#   'food': 'marshmallows',
#   'post': ''},
#  'jell-o sugar free orange low calorie gelatin mix': {'pre': 'jell o sugar free',
#   'food': 'orange',
#   'post': 'low calorie gelatin mix'},
#  'kraft jet-puffed jumbo marshmallows': {'pre': 'kraft jet puffed jumbo',
#   'food': 'marshmallows',
#   'post': ''},
#  'jet-puffed funmallows miniature marshmallows orange, strawberry, lemon & lime': {'pre': 'jet puffed funmallows miniature',
#   'food': 'marshmallows',
#   'post': 'orange strawberry lemon lime'},
#  'kroger marshmallows': {'pre': 'kroger', 'food': 'marshmallows', 'post': ''},
#  'gold medal all-purpose flour': {'pre': 'gold medal',
#   'food': 'all',
#   'post': 'purpose flour'},
#  'wilderness country cherry duncan hines wilderness country cherry pie filling & topping': {'pre': 'wilderness country cherry duncan hines wilderness country cherry',
#   'food': 'pie filling topping',
#   'post': ''},
#  'kroger apriva, zero calorie sweetener': {'pre': 'kroger apriva',
#   'food': 'zero calorie sweetener',
#   'post': ''},
#  'toll house butterscotch nestle toll house butterscotch morsels': {'pre': 'toll house butterscotch nestle toll house',
#   'food': 'butterscotch',
#   'post': 'morsels'},
#  'domino pourable light brown': {'pre': '',
#   'food': 'domino pourable light brown',
#   'post': ''},
#  'crisco butter flavor all‑vegetable shortening': {'pre': 'crisco butter flavor all',
#   'food': 'vegetable shortening',
#   'post': ''},
#  "hershey's kitchens milk chocolate baking chips": {'pre': 'hersheys kitchens',
#   'food': 'milk chocolate baking chips',
#   'post': ''},
#  'crystal sugar powdered confectioners sugar': {'pre': 'crystal sugar',
#   'food': 'powdered confectioners sugar',
#   'post': ''},
#  'mccormick® premium vanilla flavor': {'pre': 'mccormick premium',
#   'food': 'vanilla flavor',
#   'post': ''},
#  "sweet'n low zero calorie sweetener": {'pre': '',
#   'food': 'sweetn',
#   'post': 'low zero calorie sweetener'},
#  'gold medal unbleached all purpose flour': {'pre': 'gold medal unbleached',
#   'food': 'all',
#   'post': 'purpose flour'},
#  'kroger dry milk, instant non-fat': {'pre': 'kroger',
#   'food': 'dry milk',
#   'post': 'instant non fat'},
#  'mccormick® maple extract with other natural flavors': {'pre': 'mccormick',
#   'food': 'maple extract',
#   'post': 'with other natural flavors'},
#  'jell-o jell-o lime sugar free gelatin mix': {'pre': 'jell o jell o lime sugar free',
#   'food': 'gelatin',
#   'post': 'mix'},
#  'pillsbury best bread flour enriched': {'pre': 'pillsbury best',
#   'food': 'bread flour',
#   'post': 'enriched'},
#  'crystal sugar light brown sugar': {'pre': 'crystal sugar light',
#   'food': 'brown sugar',
#   'post': ''},
#  'mccormick® coconut extract with other natural flavors': {'pre': 'mccormick',
#   'food': 'coconut extract',
#   'post': 'with other natural flavors'},
#  'toll house 62% cacao bittersweet chocolate nestle toll house 62% cacao bittersweet chocolate morsels': {'pre': 'toll house 62 cacao bittersweet chocolate nestle toll house 62 cacao',
#   'food': 'bittersweet chocolate',
#   'post': 'morsels'},
#  'jell-o sugar free strawberry low calorie gelatin mix': {'pre': 'jell o sugar free',
#   'food': 'strawberry',
#   'post': 'low calorie gelatin mix'},
#  'sweet leaf tea co sweet drops sweetener vanilla creme': {'pre': 'sweet leaf tea co sweet drops sweetener vanilla',
#   'food': 'creme',
#   'post': ''},
#  "bob's red mill super-fine almond flour": {'pre': 'bobs red mill super fine',
#   'food': 'almond flour',
#   'post': ''},
#  "baker's premium unsweetened chocolate baking bar": {'pre': 'bakers premium unsweetened',
#   'food': 'chocolate baking bar',
#   'post': ''},
#  'jell-o jell oâ® raspberry gelatin mix': {'pre': 'jell o jell oâ raspberry',
#   'food': 'gelatin',
#   'post': 'mix'},
#  'jell-o strawberry gelatin mix': {'pre': 'jell o strawberry',
#   'food': 'gelatin',
#   'post': 'mix'},
#  "roundy's walnut halves & pieces": {'pre': 'roundys',
#   'food': 'walnut',
#   'post': 'halves pieces'},
#  'private selection dark chocolate chunks': {'pre': 'private selection',
#   'food': 'dark chocolate',
#   'post': 'chunks'},
#  'king arthur flour 100% whole grain flour whole wheat': {'pre': 'king arthur flour 100 whole grain',
#   'food': 'flour',
#   'post': 'whole wheat'},
#  'wilderness original berry medley pie filling & topping': {'pre': 'wilderness original berry medley',
#   'food': 'pie filling topping',
#   'post': ''},
#  "reese's peanut butter baking chips": {'pre': 'reeses',
#   'food': 'peanut butter baking chips',
#   'post': ''},
#  'kroger ready to eat chocolate pie crust': {'pre': 'kroger ready to eat chocolate',
#   'food': 'pie crust',
#   'post': ''},
#  "baker's premium semi sweet chocolate baking bar": {'pre': 'bakers premium semi sweet',
#   'food': 'chocolate baking bar',
#   'post': ''},
#  'kroger evaporated milk': {'pre': 'kroger',
#   'food': 'evaporated milk',
#   'post': ''},
#  'simple truth organic light brown sugar': {'pre': 'simple truth organic light',
#   'food': 'brown sugar',
#   'post': ''},
#  'diamond of california® chopped pecans': {'pre': 'diamond of california chopped',
#   'food': 'pecans',
#   'post': ''},
#  'jell-o sugar free raspberry low calorie gelatin mix': {'pre': 'jell o sugar free',
#   'food': 'raspberry',
#   'post': 'low calorie gelatin mix'},
#  'mccormick® red food color': {'pre': 'mccormick red food',
#   'food': 'color',
#   'post': ''},
#  'domino demerara raw cane sugar demerara raw cane sugar': {'pre': 'domino demerara raw cane sugar demerara raw cane',
#   'food': 'sugar',
#   'post': ''},
#  'diamond of california® shelled walnuts': {'pre': 'diamond of california shelled',
#   'food': 'walnuts',
#   'post': ''},
#  'jell-o grape gelatin dessert': {'pre': 'jell o',
#   'food': 'grape',
#   'post': 'gelatin dessert'},
#  'kroger unbleached all purpose enriched flour': {'pre': 'kroger unbleached',
#   'food': 'all purpose',
#   'post': 'enriched flour'},
#  'kroger semisweet chocolate chips': {'pre': 'kroger semisweet',
#   'food': 'chocolate chips',
#   'post': ''},
#  'jell-o sugar free black cherry low calorie gelatin dessert mix': {'pre': 'jell o sugar free',
#   'food': 'black',
#   'post': 'cherry low calorie gelatin dessert mix'},
#  'quaker corn meal white': {'pre': 'quaker',
#   'food': 'corn meal',
#   'post': 'white'},
#  'crisco all-vegetable shortening': {'pre': 'crisco all',
#   'food': 'vegetable shortening',
#   'post': ''},
#  'kroger sweetened condensed milk': {'pre': 'kroger sweetened',
#   'food': 'condensed milk',
#   'post': ''},
#  'carnation sweetened carnation sweetened condensed milk': {'pre': 'carnation sweetened carnation sweetened',
#   'food': 'condensed milk',
#   'post': ''},
#  'simple truth organic unsweetened coconut flakes': {'pre': 'simple truth organic unsweetened',
#   'food': 'coconut flakes',
#   'post': ''},
#  "baker's angel flake sweetened baker's angel flake sweetened coconut": {'pre': 'bakers',
#   'food': 'angel',
#   'post': 'flake sweetened bakers angel flake sweetened coconut'},
#  'kretschmer wheat germ original toasted': {'pre': 'kretschmer',
#   'food': 'wheat germ',
#   'post': 'original toasted'},
#  'wholesome sugar natural raw cane turbinado': {'pre': 'wholesome',
#   'food': 'sugar',
#   'post': 'natural raw cane turbinado'},
#  'kroger instant sugar free vanilla pudding & pie filling': {'pre': 'kroger instant sugar free',
#   'food': 'vanilla pudding pie filling',
#   'post': ''},
#  'kroger pecan halves': {'pre': 'kroger', 'food': 'pecan', 'post': 'halves'},
#  'quaker yellow cornmeal': {'pre': 'quaker yellow',
#   'food': 'cornmeal',
#   'post': ''},
#  'droste cocoa': {'pre': 'droste', 'food': 'cocoa', 'post': ''},
#  'kroger apriva zero calorie sweetener with sucralose': {'pre': 'kroger apriva',
#   'food': 'zero',
#   'post': 'calorie sweetener with sucralose'},
#  'crisco shortening, all-vegetable, butter flavor': {'pre': 'crisco',
#   'food': 'shortening',
#   'post': 'all vegetable butter flavor'},
#  'toll house premier white morsels': {'pre': 'toll house',
#   'food': 'premier',
#   'post': 'white morsels'},
#  'gold medal white whole wheat flour': {'pre': 'gold medal white whole',
#   'food': 'wheat flour',
#   'post': ''},
#  'honey maid graham nabisco honey maid graham cracker crumbs': {'pre': 'honey maid graham nabisco honey maid',
#   'food': 'graham cracker crumbs',
#   'post': ''},
#  'domino confectioners 10-x powdered pure cane with cornstarch sugar': {'pre': 'domino confectioners 10 x powdered pure cane with cornstarch',
#   'food': 'sugar',
#   'post': ''},
#  'nabisco oreo pie crust': {'pre': 'nabisco oreo',
#   'food': 'pie crust',
#   'post': ''},
#  'mccormick® pure peppermint extract': {'pre': 'mccormick pure',
#   'food': 'peppermint extract',
#   'post': ''},
#  'crystal sugar dark brown sugar': {'pre': 'crystal sugar dark',
#   'food': 'brown sugar',
#   'post': ''},
#  'ceresota flour all purpose': {'pre': 'ceresota',
#   'food': 'flour',
#   'post': 'all purpose'},
#  'wholesome natural cane sugar': {'pre': 'wholesome natural cane',
#   'food': 'sugar',
#   'post': ''},
#  'kroger all purpose enriched flour': {'pre': 'kroger',
#   'food': 'all purpose',
#   'post': 'enriched flour'},
#  'simple truth organic semi - sweet chocolate chips': {'pre': 'simple truth organic semi sweet',
#   'food': 'chocolate chips',
#   'post': ''},
#  "fleischmann's bread machine instant yeast": {'pre': 'fleischmanns bread machine',
#   'food': 'instant yeast',
#   'post': ''},
#  'honey maid graham cracker nabisco honey maid graham cracker crust': {'pre': 'honey maid graham cracker nabisco honey maid',
#   'food': 'graham cracker crust',
#   'post': ''},
#  'kroger vanilla candy coating': {'pre': 'kroger vanilla',
#   'food': 'candy coating',
#   'post': ''},
#  'splenda® brown sugar blend': {'pre': 'splenda',
#   'food': 'brown sugar',
#   'post': 'blend'},
#  'crisco all-vegetable shortening baking sticks': {'pre': 'crisco all',
#   'food': 'vegetable shortening',
#   'post': 'baking sticks'},
#  'king arthur flour 100% organic all-purpose flour': {'pre': 'king arthur',
#   'food': 'flour',
#   'post': '100 organic all purpose flour'},
#  'kroger flour all purpose': {'pre': 'kroger',
#   'food': 'flour',
#   'post': 'all purpose'},
#  'swans down enriched bleached cake flour': {'pre': 'swans down enriched bleached',
#   'food': 'cake flour',
#   'post': ''},
#  'kroger zero calorie sweetener': {'pre': 'kroger',
#   'food': 'zero calorie sweetener',
#   'post': ''},
#  'toll house milk chocolate nestle toll house milk chocolate morsels': {'pre': 'toll house milk chocolate nestle toll house',
#   'food': 'milk chocolate',
#   'post': 'morsels'},
#  'private selection sea salt caramel chocolate chunk': {'pre': 'private selection sea',
#   'food': 'salt',
#   'post': 'caramel chocolate chunk'},
#  'kroger vanilla pudding & pie filling': {'pre': 'kroger vanilla',
#   'food': 'pudding pie filling',
#   'post': ''},
#  'kroger unsweetened coconut flakes': {'pre': 'kroger unsweetened',
#   'food': 'coconut flakes',
#   'post': ''},
#  'kroger original pizza crust': {'pre': 'kroger original pizza',
#   'food': 'crust',
#   'post': ''},
#  'kroger sweetened coconut flakes': {'pre': 'kroger sweetened',
#   'food': 'coconut flakes',
#   'post': ''},
#  'keebler ready crust ready crust mini graham cracker pie crusts': {'pre': 'keebler ready crust ready crust mini graham cracker',
#   'food': 'pie crusts',
#   'post': ''},
#  'navitas organics freeze-dried acai powder, amazon superfruit': {'pre': 'navitas organics freeze',
#   'food': 'dried acai powder',
#   'post': 'amazon superfruit'},
#  "hershey's kitchens semi-sweet chocolate baking chips": {'pre': 'hersheys kitchens semi sweet',
#   'food': 'chocolate baking chips',
#   'post': ''},
#  'duncan hines cake mix red velvet': {'pre': 'duncan hines',
#   'food': 'cake mix',
#   'post': 'red velvet'},
#  'private selection smooth white chocolate drops': {'pre': 'private selection smooth white',
#   'food': 'chocolate',
#   'post': 'drops'},
#  "baker's bittersweet chocolate premium baker’s bittersweet chocolate premium baking bar": {'pre': 'bakers',
#   'food': 'bittersweet chocolate',
#   'post': 'premium baker s bittersweet chocolate premium baking bar'},
#  'mccormick® imitation almond extract': {'pre': 'mccormick imitation',
#   'food': 'almond extract',
#   'post': ''},
#  'c&h pure cane cubes c&h pure cane sugar cubes': {'pre': 'c h pure cane cubes c h pure cane',
#   'food': 'sugar cubes',
#   'post': ''},
#  'bobs red mill flaxseed meal, premium, whole ground': {'pre': 'bobs red mill',
#   'food': 'flaxseed meal',
#   'post': 'premium whole ground'},
#  "baker's premium white chocolate baking bar": {'pre': 'bakers premium white',
#   'food': 'chocolate baking bar',
#   'post': ''},
#  'jell-o lime gelatin dessert mix': {'pre': 'jell o lime',
#   'food': 'gelatin dessert',
#   'post': 'mix'},
#  'jell-o orange gelatin mix': {'pre': 'jell',
#   'food': 'o',
#   'post': 'orange gelatin mix'},
#  'carnation fat free carnation fat free evaporated milk': {'pre': 'carnation fat free carnation fat free',
#   'food': 'evaporated milk',
#   'post': ''},
#  'jell-o sugar free lemon low calorie gelatin mix': {'pre': 'jell o sugar free',
#   'food': 'lemon',
#   'post': 'low calorie gelatin mix'},
#  'gold medal wondra quick mixing flour': {'pre': 'gold medal wondra quick',
#   'food': 'mixing flour',
#   'post': ''},
#  'kroger instant vanilla pudding & pie filling': {'pre': 'kroger instant vanilla',
#   'food': 'pudding pie filling',
#   'post': ''},
#  'gold medal unbleached bread flour': {'pre': 'gold medal unbleached',
#   'food': 'bread flour',
#   'post': ''},
#  'mccormick® rum extract with other natural flavors': {'pre': 'mccormick',
#   'food': 'rum extract',
#   'post': 'with other natural flavors'},
#  'kroger extra peach pie filling': {'pre': 'kroger extra peach',
#   'food': 'pie filling',
#   'post': ''},
#  'mccormick® concentrated vanilla flavor': {'pre': 'mccormick concentrated',
#   'food': 'vanilla flavor',
#   'post': ''},
#  'kroger walnut halves and pieces': {'pre': 'kroger',
#   'food': 'walnut',
#   'post': 'halves and pieces'},
#  'kroger pistachio pudding/pie filling': {'pre': 'kroger pistachio',
#   'food': 'pudding pie filling',
#   'post': ''},
#  'kroger mini marshmallows': {'pre': 'kroger mini',
#   'food': 'marshmallows',
#   'post': ''},
#  'private selection semi-sweet chocolate drops': {'pre': 'private selection semi sweet',
#   'food': 'chocolate',
#   'post': 'drops'},
#  'saco the saco pantry cultured buttermilk blend': {'pre': 'saco the saco pantry cultured',
#   'food': 'buttermilk',
#   'post': 'blend'},
#  'mccormick® pure mint extract': {'pre': 'mccormick pure',
#   'food': 'mint extract',
#   'post': ''},
#  'solo pure almond paste': {'pre': 'solo pure',
#   'food': 'almond paste',
#   'post': ''},
#  'mccormick® pure almond extract': {'pre': 'mccormick pure',
#   'food': 'almond extract',
#   'post': ''},
#  "bob's red mill gluten free whole grain oat flour": {'pre': 'bobs red mill gluten free whole grain',
#   'food': 'oat flour',
#   'post': ''},
#  'splenda® naturals stevia sweetener packets | sugar-free, no-calorie sweetener made with stevia leaf': {'pre': 'splenda naturals',
#   'food': 'stevia',
#   'post': 'sweetener packets sugar free no calorie sweetener made with stevia leaf'},
#  'sweet leaf tea co stevia sweetener': {'pre': 'sweet leaf tea co',
#   'food': 'stevia',
#   'post': 'sweetener'},
#  "bob's red mill unbleached white all-purpose organic flour": {'pre': 'bobs red mill unbleached white',
#   'food': 'all',
#   'post': 'purpose organic flour'},
#  'heath milk chocolate toffee bits': {'pre': 'heath',
#   'food': 'milk chocolate',
#   'post': 'toffee bits'},
#  'crisco baking stick': {'pre': 'crisco', 'food': 'baking stick', 'post': ''},
#  'kroger peanut and pecan, nut topping': {'pre': 'kroger',
#   'food': 'peanut',
#   'post': 'and pecan nut topping'},
#  'pillsbury best self rising flour': {'pre': 'pillsbury best self',
#   'food': 'rising flour',
#   'post': ''},
#  'wilderness blueberry duncan hines wilderness blueberry pie filling & topping': {'pre': 'wilderness blueberry duncan hines wilderness blueberry',
#   'food': 'pie filling topping',
#   'post': ''},
#  'pillsbury best whole wheat flour': {'pre': 'pillsbury best whole',
#   'food': 'wheat flour',
#   'post': ''},
#  "bob's red mill organic cornmeal medium grind": {'pre': 'bobs red mill organic',
#   'food': 'cornmeal',
#   'post': 'medium grind'},
#  'mccormick® pure orange extract': {'pre': 'mccormick pure',
#   'food': 'orange extract',
#   'post': ''},
#  "bob's red mill brown rice flour": {'pre': 'bobs red mill',
#   'food': 'brown rice flour',
#   'post': ''},
#  'wilderness apple duncan hines wilderness apple pie filling & topping': {'pre': 'wilderness apple duncan hines wilderness',
#   'food': 'apple pie filling topping',
#   'post': ''},
#  'mccormick® banana extract with other natural flavors': {'pre': 'mccormick',
#   'food': 'banana extract',
#   'post': 'with other natural flavors'},
#  'jell-o jell o lemon gelatin mix': {'pre': 'jell o jell',
#   'food': 'o',
#   'post': 'lemon gelatin mix'},
#  "bob's red mill no. 1 durum wheat semolina flour": {'pre': 'bobs red mill no 1 durum wheat',
#   'food': 'semolina flour',
#   'post': ''},
#  'gold medal whole wheat flour': {'pre': 'gold medal whole',
#   'food': 'wheat flour',
#   'post': ''},
#  "bob's red mill wheat germ": {'pre': 'bobs red mill',
#   'food': 'wheat germ',
#   'post': ''},
#  'hodgson mill premium naturally white flour': {'pre': 'hodgson mill premium naturally white',
#   'food': 'flour',
#   'post': ''},
#  'red star yeast quick-rise yeast for bread machines & tradtional baking': {'pre': 'red star yeast quick rise yeast for',
#   'food': 'bread',
#   'post': 'machines tradtional baking'},
#  'bella bread crumbs, italian style, tub': {'pre': 'bella',
#   'food': 'bread crumbs',
#   'post': 'italian style tub'},
#  'crisco shortening all-vegetable butter': {'pre': 'crisco',
#   'food': 'shortening',
#   'post': 'all vegetable butter'},
#  'kroger fast rise yeast': {'pre': 'kroger fast rise',
#   'food': 'yeast',
#   'post': ''},
#  'kroger pork flavored stuffing mix': {'pre': 'kroger',
#   'food': 'pork flavored stuffing mix',
#   'post': ''},
#  'clean & clear zesty scrub lemon': {'pre': 'clean clear',
#   'food': 'zesty',
#   'post': 'scrub lemon'},
#  'diamond of california walnuts, shelled': {'pre': 'diamond of california',
#   'food': 'walnuts',
#   'post': 'shelled'},
#  'bobs red mill baking flour, 1 to 1': {'pre': 'bobs red mill baking',
#   'food': 'flour',
#   'post': '1 to 1'},
#  'bobs red mill flour, tapioca, finely ground': {'pre': 'bobs red mill flour',
#   'food': 'tapioca',
#   'post': 'finely ground'},
#  "bob's red mill all-purpose baking flour": {'pre': 'bobs red mill all',
#   'food': 'purpose baking flour',
#   'post': ''},
#  'simple truth organic semi-sweet vegan chocolate chips': {'pre': 'simple truth organic semi sweet vegan',
#   'food': 'chocolate chips',
#   'post': ''},
#  'carnation almond cooking milk': {'pre': 'carnation',
#   'food': 'almond cooking milk',
#   'post': ''},
#  'grey poupon dijon mustard': {'pre': 'grey poupon dijon',
#   'food': 'mustard',
#   'post': ''},
#  'kraft miracle whip miracle whip': {'pre': 'kraft miracle whip miracle',
#   'food': 'whip',
#   'post': ''},
#  "hunt's tomato sauce": {'pre': 'hunts', 'food': 'tomato sauce', 'post': ''},
#  "french's® classic yellow mustard": {'pre': 'frenchs classic yellow',
#   'food': 'mustard',
#   'post': ''},
#  'heinz tomato ketchup': {'pre': 'heinz tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'cholula hot sauce original': {'pre': 'cholula',
#   'food': 'hot sauce',
#   'post': 'original'},
#  'kroger yellow mustard': {'pre': 'kroger yellow',
#   'food': 'mustard',
#   'post': ''},
#  'louisiana brand the perfect hot sauce': {'pre': 'louisiana brand the perfect',
#   'food': 'hot sauce',
#   'post': ''},
#  "frank's® redhot® original cayenne pepper hot sauce": {'pre': 'franks redhot original cayenne pepper',
#   'food': 'hot sauce',
#   'post': ''},
#  'heinz no sugar added tomato ketchup': {'pre': 'heinz no sugar added tomato',
#   'food': 'ketchup',
#   'post': ''},
#  "hellmann's mayonnaise real": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'real'},
#  'tabasco pepper sauce': {'pre': '',
#   'food': 'tabasco',
#   'post': 'pepper sauce'},
#  "duke's real mayonnaise": {'pre': 'dukes real',
#   'food': 'mayonnaise',
#   'post': ''},
#  "hellmann's mayonnaise, real": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'real'},
#  'halo top dairy free frozen dessert sea salt caramel': {'pre': 'halo top dairy free',
#   'food': 'frozen dessert',
#   'post': 'sea salt caramel'},
#  'kraft mayo avocado oil reduced fat mayonnaise': {'pre': 'kraft mayo',
#   'food': 'avocado oil',
#   'post': 'reduced fat mayonnaise'},
#  'kraft specialty sauces chipotle aioli kraft chipotle aioli': {'pre': 'kraft specialty sauces chipotle aioli kraft chipotle',
#   'food': 'aioli',
#   'post': ''},
#  'g hughes sugar free bbq sauce hickory': {'pre': 'g hughes sugar free',
#   'food': 'bbq sauce',
#   'post': 'hickory'},
#  'vlasic dill pickle relish': {'pre': 'vlasic dill pickle',
#   'food': 'relish',
#   'post': ''},
#  'simple truth organic tomato ketchup': {'pre': 'simple truth organic tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'primal kitchen real mayonnaise made with avocado oil': {'pre': 'primal kitchen real',
#   'food': 'mayonnaise',
#   'post': 'made with avocado oil'},
#  'kraft mayo olive oil reduced fat mayonnaise': {'pre': 'kraft mayo olive oil reduced fat',
#   'food': 'mayonnaise',
#   'post': ''},
#  "koops' mustard deli spicy brown": {'pre': 'koops',
#   'food': 'mustard',
#   'post': 'deli spicy brown'},
#  'heinz simply tomato ketchup': {'pre': 'heinz simply tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'tabasco pepper sauce chipotle': {'pre': '',
#   'food': 'tabasco',
#   'post': 'pepper sauce chipotle'},
#  'ort med taco sce': {'pre': 'ort med taco', 'food': 'sce', 'post': ''},
#  'heinz organic tomato ketchup': {'pre': 'heinz organic tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'kraft miracle whip original dressing': {'pre': 'kraft miracle whip original',
#   'food': 'dressing',
#   'post': ''},
#  'follow your heart vegenaise original': {'pre': 'follow your heart',
#   'food': 'vegenaise',
#   'post': 'original'},
#  'tabasco green pepper sauce': {'pre': '',
#   'food': 'tabasco',
#   'post': 'green pepper sauce'},
#  'grey poupon harvest coarse ground mustard': {'pre': 'grey poupon harvest coarse ground',
#   'food': 'mustard',
#   'post': ''},
#  'contadina pizza squeeze original contadina pizza squeeze original pizza sauce': {'pre': 'contadina pizza squeeze original contadina pizza squeeze original',
#   'food': 'pizza sauce',
#   'post': ''},
#  'kraft barbecue sauce sweet brown sugar barbecue sauce kraft sweet brown sugar barbecue sauce & dip': {'pre': 'kraft',
#   'food': 'barbecue sauce',
#   'post': 'sweet brown sugar barbecue sauce kraft sweet brown sugar barbecue sauce dip'},
#  '78 red ketchup, spicy': {'pre': '78 red',
#   'food': 'ketchup',
#   'post': 'spicy'},
#  'marconi hot': {'pre': 'marconi', 'food': 'hot', 'post': ''},
#  "bearo's original submarine dressing": {'pre': 'bearos original',
#   'food': 'submarine dressing',
#   'post': ''},
#  'vlasic sweet pickle relish': {'pre': 'vlasic sweet pickle',
#   'food': 'relish',
#   'post': ''},
#  'heinz yellow heinz yellow mustard': {'pre': 'heinz yellow heinz yellow',
#   'food': 'mustard',
#   'post': ''},
#  'tabasco pepper sauce original': {'pre': '',
#   'food': 'tabasco',
#   'post': 'pepper sauce original'},
#  'alessi sun dried tomatoes': {'pre': 'alessi sun',
#   'food': 'dried tomatoes',
#   'post': ''},
#  'manwich single serve bold sloppy joe sauce': {'pre': 'manwich single serve bold',
#   'food': 'sloppy joe sauce',
#   'post': ''},
#  "hellmann's mayonnaise dressing with olive oil": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'dressing with olive oil'},
#  'follow your heart vegenaise reduced fat': {'pre': 'follow your heart',
#   'food': 'vegenaise',
#   'post': 'reduced fat'},
#  "plochman's mild yellow squeeze mustard": {'pre': 'plochmans mild yellow squeeze',
#   'food': 'mustard',
#   'post': ''},
#  '78 red all natural ketchup': {'pre': '78 red all natural',
#   'food': 'ketchup',
#   'post': ''},
#  'primal kitchen chipotle lime mayo made with avocado oil': {'pre': 'primal kitchen chipotle lime',
#   'food': 'mayo',
#   'post': 'made with avocado oil'},
#  'cholula hot sauce green pepper': {'pre': 'cholula',
#   'food': 'hot sauce',
#   'post': 'green pepper'},
#  'grey poupon country dijon mustard': {'pre': 'grey poupon country dijon',
#   'food': 'mustard',
#   'post': ''},
#  "sir kensington's mayonnaise classic": {'pre': 'sir kensingtons',
#   'food': 'mayonnaise',
#   'post': 'classic'},
#  'simple truth organic dijon mustard': {'pre': 'simple truth organic dijon',
#   'food': 'mustard',
#   'post': ''},
#  'kikkoman sriracha mayo': {'pre': 'kikkoman sriracha',
#   'food': 'mayo',
#   'post': ''},
#  "hellmann's mayonnaise dressing with olive oil squeeze": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'dressing with olive oil squeeze'},
#  "koops' mustard stone ground flavor": {'pre': 'koops',
#   'food': 'mustard',
#   'post': 'stone ground flavor'},
#  "sir kensington's ketchup classic": {'pre': 'sir kensingtons ketchup',
#   'food': 'classic',
#   'post': ''},
#  "hellmann's mayonnaise organic spicy chipotle": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'organic spicy chipotle'},
#  "hellmann's mayonnaise light": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'light'},
#  'tapatio hot sauce': {'pre': 'tapatio', 'food': 'hot sauce', 'post': ''},
#  'kraft mayo olive oil kraft olive oil mayo': {'pre': 'kraft mayo olive oil kraft olive oil',
#   'food': 'mayo',
#   'post': ''},
#  "sir kensington's mayonnaise organic": {'pre': 'sir kensingtons',
#   'food': 'mayonnaise',
#   'post': 'organic'},
#  'heinz chili sauce': {'pre': 'heinz', 'food': 'chili sauce', 'post': ''},
#  'maille mustard dijon originale': {'pre': 'maille',
#   'food': 'mustard',
#   'post': 'dijon originale'},
#  'kroger tartar sauce': {'pre': 'kroger', 'food': 'tartar sauce', 'post': ''},
#  'tabasco ® brand sriracha sauce': {'pre': '',
#   'food': 'tabasco',
#   'post': 'brand sriracha sauce'},
#  'kraft mayo real': {'pre': 'kraft mayo', 'food': 'real', 'post': ''},
#  'cholula hot sauce chili garlic': {'pre': 'cholula',
#   'food': 'hot',
#   'post': 'sauce chili garlic'},
#  "gulden's spicy brown mustard": {'pre': 'guldens spicy brown',
#   'food': 'mustard',
#   'post': ''},
#  'lea & perrins the original worcestershire sauce': {'pre': 'lea perrins',
#   'food': 'the',
#   'post': 'original worcestershire sauce'},
#  'cholula hot sauce chili lime': {'pre': 'cholula',
#   'food': 'hot',
#   'post': 'sauce chili lime'},
#  "sir kensington's mayonnaise avocado oil": {'pre': 'sir kensingtons mayonnaise',
#   'food': 'avocado oil',
#   'post': ''},
#  'kroger gravy mix': {'pre': 'kroger', 'food': 'gravy mix', 'post': ''},
#  "hellmann's light mayonnaise squeeze": {'pre': 'hellmanns light',
#   'food': 'mayonnaise',
#   'post': 'squeeze'},
#  'tostitos roasted red pepper tortilla chips': {'pre': 'tostitos roasted red pepper tortilla',
#   'food': 'chips',
#   'post': ''},
#  'kroger mustard': {'pre': 'kroger', 'food': 'mustard', 'post': ''},
#  'house of tsang classic stir-fry sauce': {'pre': 'house of tsang classic stir',
#   'food': 'fry sauce',
#   'post': ''},
#  'valentina mexican hot sauce extra hot': {'pre': '',
#   'food': 'valentina mexican',
#   'post': 'hot sauce extra hot'},
#  "koops' mustard honey mustard": {'pre': 'koops mustard honey',
#   'food': 'mustard',
#   'post': ''},
#  "koops' mustard original yellow": {'pre': 'koops',
#   'food': 'mustard',
#   'post': 'original yellow'},
#  'kraft specialty sauces none kraft tartar sauce': {'pre': 'kraft specialty sauces none kraft',
#   'food': 'tartar sauce',
#   'post': ''},
#  'lea & perrins worcestershire sauce': {'pre': 'lea perrins',
#   'food': 'worcestershire',
#   'post': 'sauce'},
#  'tapatio tepatio hot sauce': {'pre': 'tapatio tepatio',
#   'food': 'hot sauce',
#   'post': ''},
#  'kraft miracle whip miracle whip kraft miracle whip dressing': {'pre': 'kraft miracle whip miracle whip kraft miracle',
#   'food': 'whip dressing',
#   'post': ''},
#  'muchacha salsa medium': {'pre': 'muchacha',
#   'food': 'salsa',
#   'post': 'medium'},
#  'vlasic homestyle sweet pickle relish': {'pre': 'vlasic homestyle sweet pickle',
#   'food': 'relish',
#   'post': ''},
#  "frank's® redhot® sweet chili sauce": {'pre': 'franks redhot sweet',
#   'food': 'chili sauce',
#   'post': ''},
#  'inglehoffer thick-n-creamy horseradish': {'pre': 'inglehoffer thick n creamy',
#   'food': 'horseradish',
#   'post': ''},
#  'kraft mayo real kraft real mayonnaise': {'pre': 'kraft mayo real kraft real',
#   'food': 'mayonnaise',
#   'post': ''},
#  'mina harissa harissa sauce moroccan red pepper mild': {'pre': 'mina harissa',
#   'food': 'harissa sauce',
#   'post': 'moroccan red pepper mild'},
#  'tabasco ® brand green jalapeño pepper sauce': {'pre': '',
#   'food': 'tabasco',
#   'post': 'brand green jalapeño pepper sauce'},
#  'heinz sweet relish': {'pre': 'heinz sweet', 'food': 'relish', 'post': ''},
#  'kroger lite soy sauce': {'pre': 'kroger lite',
#   'food': 'soy sauce',
#   'post': ''},
#  'cholula hot sauce chipotle': {'pre': 'cholula',
#   'food': 'hot sauce',
#   'post': 'chipotle'},
#  'crosse & blackwell shrimp sauce zesty': {'pre': 'crosse blackwell',
#   'food': 'shrimp sauce',
#   'post': 'zesty'},
#  "annie's homegrown ® organic, gluten free, yellow mustard": {'pre': 'annies homegrown organic gluten free yellow',
#   'food': 'mustard',
#   'post': ''},
#  "dell'alpe relish, hot giardiniera": {'pre': 'dellalpe relish hot',
#   'food': 'giardiniera',
#   'post': ''},
#  "hellmann's tartar sauce": {'pre': 'hellmanns',
#   'food': 'tartar sauce',
#   'post': ''},
#  "sweet baby ray's hawaiian style barbecue sauce": {'pre': 'sweet',
#   'food': 'baby',
#   'post': 'rays hawaiian style barbecue sauce'},
#  "hellmann's organic mayonnaise original": {'pre': 'hellmanns organic',
#   'food': 'mayonnaise',
#   'post': 'original'},
#  'lee kum kee sriracha mayo': {'pre': 'lee kum kee sriracha',
#   'food': 'mayo',
#   'post': ''},
#  'ortega original thick & smooth hot taco sauce': {'pre': 'ortega original thick smooth hot',
#   'food': 'taco sauce',
#   'post': ''},
#  "french's® honey dijon mustard squeeze bottle": {'pre': 'frenchs honey dijon',
#   'food': 'mustard',
#   'post': 'squeeze bottle'},
#  'knorr pasta side dish roasted garlic pesto with volanti pasta': {'pre': 'knorr pasta side dish roasted garlic',
#   'food': 'pesto',
#   'post': 'with volanti pasta'},
#  'valentina red hot sauce': {'pre': 'valentina red',
#   'food': 'hot sauce',
#   'post': ''},
#  'kraft mayo olive oil reduced fat kraft olive oil reduced fat mayonnaise': {'pre': 'kraft mayo olive oil reduced fat kraft olive oil reduced fat',
#   'food': 'mayonnaise',
#   'post': ''},
#  'silver spring deli-style mustard spicy brown': {'pre': 'silver spring deli style',
#   'food': 'mustard',
#   'post': 'spicy brown'},
#  'inglehoffer stone ground mustard': {'pre': 'inglehoffer stone ground',
#   'food': 'mustard',
#   'post': ''},
#  'crosse & blackwell seafood cocktail sauce': {'pre': 'crosse blackwell seafood',
#   'food': 'cocktail sauce',
#   'post': ''},
#  "koops' mustard horseradish": {'pre': 'koops',
#   'food': 'mustard horseradish',
#   'post': ''},
#  "koops' mustard dijon": {'pre': 'koops', 'food': 'mustard', 'post': 'dijon'},
#  'follow your heart grapeseed oil vegenaise': {'pre': 'follow your heart',
#   'food': 'grapeseed',
#   'post': 'oil vegenaise'},
#  'tabasco ® brand habanero pepper sauce': {'pre': '',
#   'food': 'tabasco',
#   'post': 'brand habanero pepper sauce'},
#  'vienna chicago style relish': {'pre': 'vienna chicago style',
#   'food': 'relish',
#   'post': ''},
#  'maille mustard honey dijon': {'pre': 'maille',
#   'food': 'mustard',
#   'post': 'honey dijon'},
#  "french's® classic worcestershire sauce": {'pre': 'frenchs classic',
#   'food': 'worcestershire',
#   'post': 'sauce'},
#  'kroger original tomato ketchup': {'pre': 'kroger original tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'heinz 57 sauce': {'pre': 'heinz', 'food': '57 sauce', 'post': ''},
#  'heinz sauce worcestershire': {'pre': '',
#   'food': 'heinz sauce',
#   'post': 'worcestershire'},
#  'the ojai cook lemonaise': {'pre': 'the ojai cook',
#   'food': 'lemonaise',
#   'post': ''},
#  'yings yum yum sauce': {'pre': 'yings yum', 'food': 'yum sauce', 'post': ''},
#  'silver spring whole grain mustard old style': {'pre': 'silver spring whole grain',
#   'food': 'mustard',
#   'post': 'old style'},
#  "p.f. chang's teriyaki sauce": {'pre': 'pf changs',
#   'food': 'teriyaki sauce',
#   'post': ''},
#  'heinz spicy brown mustard': {'pre': 'heinz spicy brown',
#   'food': 'mustard',
#   'post': ''},
#  'heinz hawaii style sweet & fruity heinz hawaii style sweet & fruity bbq sauce': {'pre': 'heinz hawaii style sweet fruity heinz hawaii style sweet fruity',
#   'food': 'bbq sauce',
#   'post': ''},
#  "sweet baby ray's creamy buffalo wing dipping sauce": {'pre': 'sweet baby rays creamy buffalo wing',
#   'food': 'dipping sauce',
#   'post': ''},
#  'texas pete hot sauce original': {'pre': 'texas pete',
#   'food': 'hot sauce',
#   'post': 'original'},
#  'simple truth organic original bbq sauce': {'pre': 'simple truth organic original',
#   'food': 'bbq sauce',
#   'post': ''},
#  'kraft miracle whip dressing light': {'pre': 'kraft miracle whip dressing',
#   'food': 'light',
#   'post': ''},
#  "lawry's® honey bourbon marinade": {'pre': 'lawrys honey bourbon',
#   'food': 'marinade',
#   'post': ''},
#  'heinz tomato heinz tomato ketchup': {'pre': 'heinz tomato heinz tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'heinz jalapeno tomato heinz jalapeno tomato ketchup': {'pre': 'heinz jalapeno tomato heinz jalapeno tomato',
#   'food': 'ketchup',
#   'post': ''},
#  'kroger alfredo sauce': {'pre': 'kroger',
#   'food': 'alfredo sauce',
#   'post': ''},
#  "bookbinder's horseradish prepared": {'pre': 'bookbinders',
#   'food': 'horseradish',
#   'post': 'prepared'},
#  'grey poupon mild & creamy dijon mustard': {'pre': 'grey poupon mild creamy dijon',
#   'food': 'mustard',
#   'post': ''},
#  'pickapeppa sauce': {'pre': '', 'food': 'pickapeppa sauce', 'post': ''},
#  'kraft mayo light mayo light kraft light mayo light mayonnaise': {'pre': 'kraft mayo light mayo light kraft light mayo light',
#   'food': 'mayonnaise',
#   'post': ''},
#  'silver springs horseradish sauce': {'pre': '',
#   'food': 'silver',
#   'post': 'springs horseradish sauce'},
#  "koops' mustard dusseldorf bratwurst mustard": {'pre': 'koops mustard dusseldorf bratwurst',
#   'food': 'mustard',
#   'post': ''},
#  'kraft specialty sauces kraft sandwich spread': {'pre': 'kraft specialty sauces kraft sandwich',
#   'food': 'spread',
#   'post': ''},
#  'heinz tomato ketchup 2': {'pre': 'heinz tomato ketchup',
#   'food': '2',
#   'post': ''},
#  'g hughes smokehouse ketchup, sugar free, original recipe': {'pre': 'g hughes smokehouse ketchup',
#   'food': 'sugar',
#   'post': 'free original recipe'},
#  'kraft light kraft light mayo': {'pre': 'kraft light kraft light',
#   'food': 'mayo',
#   'post': ''},
#  'simple truth organic yellow mustard': {'pre': 'simple truth organic yellow',
#   'food': 'mustard',
#   'post': ''},
#  'kikkoman korean bbq kikkoman korean bbq teriyaki sauce': {'pre': 'kikkoman korean bbq kikkoman korean bbq',
#   'food': 'teriyaki sauce',
#   'post': ''},
#  'kraft miracle whip, light': {'pre': 'kraft miracle whip',
#   'food': 'light',
#   'post': ''},
#  "hellmann's mayonnaise dressing low fat": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'dressing low fat'},
#  'chung jung one red pepper paste, sunchang, 3 medium hot': {'pre': 'chung jung one red pepper paste sunchang 3 medium',
#   'food': 'hot',
#   'post': ''},
#  "silver spring beer'n brat horseradish mustard good'n hot": {'pre': '',
#   'food': 'silver',
#   'post': 'spring beern brat horseradish mustard goodn hot'},
#  'mccormick® golden dipt® extra hot seafood cocktail sauce': {'pre': 'mccormick golden dipt extra hot seafood',
#   'food': 'cocktail sauce',
#   'post': ''},
#  "sir kensington's mustard spicy brown": {'pre': 'sir kensingtons',
#   'food': 'mustard',
#   'post': 'spicy brown'},
#  "plochman's mild yellow mustard": {'pre': 'plochmans mild yellow',
#   'food': 'mustard',
#   'post': ''},
#  'kroger sweet & sour sauce': {'pre': 'kroger',
#   'food': 'sweet sour sauce',
#   'post': ''},
#  'heinz no salt added ketchup tomato': {'pre': 'heinz no salt added ketchup',
#   'food': 'tomato',
#   'post': ''},
#  'a.1. spicy chipotle sauce': {'pre': '',
#   'food': 'a1',
#   'post': 'spicy chipotle sauce'},
#  'inglehoffer cream style horseradish': {'pre': 'inglehoffer cream style',
#   'food': 'horseradish',
#   'post': ''},
#  "hellmann's mayonnaise dressing canola cholesterol free": {'pre': 'hellmanns',
#   'food': 'mayonnaise',
#   'post': 'dressing canola cholesterol free'},
#  'kroger dijon mustard': {'pre': 'kroger dijon',
#   'food': 'mustard',
#   'post': ''},
#  "koops' mustard arizona heat": {'pre': 'koops mustard arizona',
#   'food': 'heat',
#   'post': ''},
#  'heinz original cocktail sauce': {'pre': 'heinz original',
#   'food': 'cocktail sauce',
#   'post': ''},
#  'open pit authentic hickory open pit hickory authentic barbecue sauce': {'pre': 'open pit authentic hickory open pit hickory authentic',
#   'food': 'barbecue sauce',
#   'post': ''},
#  'texas pete sriracha cha! hot  chile sauce': {'pre': 'texas pete sriracha cha hot',
#   'food': 'chile sauce',
#   'post': ''},
#  'delallo sun dried tomato bruschetta': {'pre': 'delallo sun',
#   'food': 'dried',
#   'post': 'tomato bruschetta'},
#  "hellmann's dijonnaise creamy dijon mustard": {'pre': 'hellmanns dijonnaise creamy dijon',
#   'food': 'mustard',
#   'post': ''},
#  'kroger mustard honey': {'pre': 'kroger',
#   'food': 'mustard honey',
#   'post': ''},
#  "french's® honey mustard": {'pre': 'frenchs honey',
#   'food': 'mustard',
#   'post': ''},
#  'kroger cocktail sauce': {'pre': 'kroger',
#   'food': 'cocktail sauce',
#   'post': ''},
#  'kraft sauce cocktail': {'pre': '',
#   'food': 'kraft sauce',
#   'post': 'cocktail'},
#  "woeber's horseradish sauce": {'pre': 'woebers',
#   'food': 'horseradish',
#   'post': 'sauce'},
#  'lea & perrins reduced sodium lea & perrins reduced sodium worcestershire sauce': {'pre': 'lea perrins reduced sodium lea perrins reduced sodium',
#   'food': 'worcestershire',
#   'post': 'sauce'},
#  'kroger taco sauce': {'pre': 'kroger', 'food': 'taco sauce', 'post': ''},
#  'delallo bruschetta artichoke': {'pre': 'delallo',
#   'food': 'bruschetta',
#   'post': 'artichoke'},
# ...
#   'food': 'broccoli cheese soup',
#   'post': ''},
#  'progresso light creamy chicken noodle soup': {'pre': 'progresso light creamy',
#   'food': 'chicken noodle soup',
#   'post': ''},
#  "campbell's well yes! lightly salted tomato basil bisque": {'pre': 'campbells well yes lightly salted tomato',
#   'food': 'basil',
#   'post': 'bisque'},
#  "annie's homegrown organic vegetable soup with farm-shaped pasta": {'pre': 'annies homegrown organic',
#   'food': 'vegetable',
#   'post': 'soup with farm shaped pasta'},
#  "annie's homegrown organic star pasta & chicken soup": {'pre': 'annies homegrown organic star pasta',
#   'food': 'chicken soup',
#   'post': ''},
#  'mccormick® black pepper grinder': {'pre': '',
#   'food': 'mccormick black pepper grinder',
#   'post': ''},
#  'kroger 3 pepper & onion blend': {'pre': 'kroger',
#   'food': '3 pepper',
#   'post': 'onion blend'},
#  'kroger taco seasoning': {'pre': 'kroger',
#   'food': 'taco seasoning',
#   'post': ''},
#  'mccormick® mild taco seasoning mix': {'pre': 'mccormick mild',
#   'food': 'taco seasoning',
#   'post': 'mix'},
#  'morton salt, kosher, coarse, bottle': {'pre': 'morton',
#   'food': 'salt',
#   'post': 'kosher coarse bottle'},
#  'mccormick® sea salt grinder': {'pre': 'mccormick sea',
#   'food': 'salt grinder',
#   'post': ''},
#  'sazon goya seasoning, coriander & annatto': {'pre': 'sazon goya',
#   'food': 'seasoning',
#   'post': 'coriander annatto'},
#  'mrs. dash mrs. dash salt-free seasoning blend garlic & herb': {'pre': 'mrs dash mrs dash salt free',
#   'food': 'seasoning',
#   'post': 'blend garlic herb'},
#  "lawry's® economy size seasoned salt": {'pre': 'lawrys economy size seasoned',
#   'food': 'salt',
#   'post': ''},
#  'mccormick® garlic powder': {'pre': 'mccormick',
#   'food': 'garlic powder',
#   'post': ''},
#  'old bay® seasoning': {'pre': '', 'food': 'old bay seasoning', 'post': ''},
#  'mccormick® parsley flakes': {'pre': 'mccormick',
#   'food': 'parsley flakes',
#   'post': ''},
#  "zatarain's® new orleans style creole seasoning": {'pre': 'zatarains new orleans style',
#   'food': 'creole seasoning',
#   'post': ''},
#  'mccormick® minced onions': {'pre': 'mccormick',
#   'food': 'minced onions',
#   'post': ''},
#  'mccormick® ground white pepper': {'pre': 'mccormick ground',
#   'food': 'white pepper',
#   'post': ''},
#  'mccormick® hot taco seasoning mix': {'pre': 'mccormick hot',
#   'food': 'taco seasoning',
#   'post': 'mix'},
#  'mccormick® paprika': {'pre': '', 'food': 'mccormick paprika', 'post': ''},
#  'mccormick® himalayan pink salt grinder': {'pre': 'mccormick himalayan pink',
#   'food': 'salt grinder',
#   'post': ''},
#  'simple truth crushed red pepper': {'pre': 'simple truth',
#   'food': 'crushed red pepper',
#   'post': ''},
#  'mccormick® ground pepper black': {'pre': 'mccormick',
#   'food': 'ground pepper black',
#   'post': ''},
#  'morton iodized sea salt all-purpose': {'pre': 'morton iodized',
#   'food': 'sea salt',
#   'post': 'all purpose'},
#  'pepper': {'pre': '', 'food': 'pepper', 'post': ''},
#  'mccormick® 30% less sodium taco seasoning mix': {'pre': 'mccormick 30 less sodium',
#   'food': 'taco seasoning',
#   'post': 'mix'},
#  'mccormick® chili powder': {'pre': 'mccormick',
#   'food': 'chili powder',
#   'post': ''},
#  'mrs. dash original blend salt-free seasoning blend': {'pre': 'mrs',
#   'food': 'dash',
#   'post': 'original blend salt free seasoning blend'},
#  'morton iodized salt': {'pre': 'morton iodized', 'food': 'salt', 'post': ''},
#  'kroger pure vanilla extract': {'pre': 'kroger pure',
#   'food': 'vanilla extract',
#   'post': ''},
#  'bellino minced garlic': {'pre': 'bellino',
#   'food': 'minced garlic',
#   'post': ''},
#  'mccormick® basil leaves': {'pre': '',
#   'food': 'mccormick basil',
#   'post': 'leaves'},
#  'mccormick® onion powder': {'pre': '',
#   'food': 'mccormick onion powder',
#   'post': ''},
#  'knorr rice side dish chicken broccoli': {'pre': 'knorr rice side dish',
#   'food': 'chicken broccoli',
#   'post': ''},
#  'mccormick® grill mates® roasted garlic & herb seasoning': {'pre': 'mccormick grill mates roasted garlic',
#   'food': 'herb seasoning',
#   'post': ''},
#  'mrs. dash southwest chipotle salt-free seasoning blend': {'pre': 'mrs dash southwest chipotle salt free',
#   'food': 'seasoning',
#   'post': 'blend'},
#  'mrs. dash lemon pepper salt-free seasoning blend': {'pre': 'mrs dash',
#   'food': 'lemon',
#   'post': 'pepper salt free seasoning blend'},
#  'goya all purpose seasoning, with pepper': {'pre': 'goya',
#   'food': 'all',
#   'post': 'purpose seasoning with pepper'},
#  'mccormick® less sodium chili seasoning mix': {'pre': 'mccormick less sodium',
#   'food': 'chili',
#   'post': 'seasoning mix'},
#  'mccormick® garlic salt': {'pre': 'mccormick',
#   'food': 'garlic salt',
#   'post': ''},
#  'old bay® shaker bottle seafood seasoning': {'pre': '',
#   'food': 'old bay',
#   'post': 'shaker bottle seafood seasoning'},
#  'mccormick® peppercorn medley grinder': {'pre': 'mccormick',
#   'food': 'peppercorn medley grinder',
#   'post': ''},
#  'simple truth organic ground chili powder': {'pre': 'simple truth organic ground',
#   'food': 'chili powder',
#   'post': ''},
#  'mccormick® guacamole seasoning mix': {'pre': 'mccormick',
#   'food': 'guacamole seasoning',
#   'post': 'mix'},
#  "lawry's® seasoned salt": {'pre': 'lawrys seasoned',
#   'food': 'salt',
#   'post': ''},
#  'simple truth organic cayenne red pepper': {'pre': 'simple truth organic cayenne',
#   'food': 'red pepper',
#   'post': ''},
#  'mccormick® slow cookers savory pot roast seasoning mix': {'pre': 'mccormick slow cookers savory',
#   'food': 'pot roast seasoning',
#   'post': 'mix'},
#  'gourmet garden™ chili pepper stir-in paste': {'pre': 'gourmet garden',
#   'food': 'chili',
#   'post': 'pepper stir in paste'},
#  "tony chachere's creole seasoning original": {'pre': 'tony chacheres',
#   'food': 'creole seasoning',
#   'post': 'original'},
#  'mccormick® perfect pinch® vegetable seasoning': {'pre': 'mccormick perfect pinch',
#   'food': 'vegetable seasoning',
#   'post': ''},
#  'badia lemon pepper': {'pre': 'badia', 'food': 'lemon pepper', 'post': ''},
#  'urban accents chicago steak & chop cracked pepper & garlic blend': {'pre': 'urban',
#   'food': 'accents chicago steak chop cracked pepper garlic',
#   'post': 'blend'},
#  'private selection whole black peppercorn grinder': {'pre': 'private selection whole black',
#   'food': 'peppercorn grinder',
#   'post': ''},
#  'simple truth black chia seeds': {'pre': 'simple truth black',
#   'food': 'chia seeds',
#   'post': ''},
#  'mccormick gourmet™ organic ground saigon cinnamon': {'pre': 'mccormick gourmet organic ground saigon',
#   'food': 'cinnamon',
#   'post': ''},
#  'mccormick® grill mates® 25% less sodium montreal steak seasoning': {'pre': 'mccormick grill mates 25 less sodium',
#   'food': 'montreal steak seasoning',
#   'post': ''},
#  'morton sea salt grinder sea salt': {'pre': 'morton sea',
#   'food': 'salt grinder',
#   'post': 'sea salt'},
#  'mccormick® crushed red pepper': {'pre': 'mccormick',
#   'food': 'crushed red pepper',
#   'post': ''},
#  'mccormick® himalayan pink salt black pepper and garlic all purpose seasoning': {'pre': 'mccormick himalayan pink',
#   'food': 'salt black',
#   'post': 'pepper and garlic all purpose seasoning'},
#  'bragg premium nutritional yeast seasoning': {'pre': 'bragg premium nutritional',
#   'food': 'yeast seasoning',
#   'post': ''},
#  'mccormick® whole black pepper': {'pre': '',
#   'food': 'mccormick whole black pepper',
#   'post': ''},
#  'goya adobo all purpose seasoning': {'pre': 'goya adobo',
#   'food': 'all',
#   'post': 'purpose seasoning'},
#  'kroger pure ground black pepper': {'pre': 'kroger pure',
#   'food': 'ground black pepper',
#   'post': ''},
#  'simple truth nutmeg': {'pre': 'simple truth', 'food': 'nutmeg', 'post': ''},
#  'mccormick® grill mates® spicy montreal steak seasoning': {'pre': 'mccormick grill mates spicy',
#   'food': 'montreal steak seasoning',
#   'post': ''},
#  'mccormick® poultry seasoning': {'pre': 'mccormick',
#   'food': 'poultry seasoning',
#   'post': ''},
#  'kroger celery salt': {'pre': 'kroger', 'food': 'celery salt', 'post': ''},
#  'mrs. dash onion & herb salt-free seasoning blend': {'pre': 'mrs dash',
#   'food': 'onion',
#   'post': 'herb salt free seasoning blend'},
#  'mccormick gourmet™ organic onion powder': {'pre': 'mccormick gourmet organic',
#   'food': 'onion powder',
#   'post': ''},
#  "roundy's organics fresh oregano": {'pre': 'roundys organics fresh',
#   'food': 'oregano',
#   'post': ''},
#  'mccormick® garlic jalapeno seasoning': {'pre': 'mccormick',
#   'food': 'garlic jalapeno seasoning',
#   'post': ''},
#  'mccormick® ground mustard': {'pre': 'mccormick ground',
#   'food': 'mustard',
#   'post': ''},
#  'hidden valley dips mix, original ranch, 2.0 ounces': {'pre': 'hidden valley dips mix original ranch 20',
#   'food': 'ounces',
#   'post': ''},
#  'mccormick® italian blend herb grinder': {'pre': 'mccormick italian blend',
#   'food': 'herb grinder',
#   'post': ''},
#  'mccormick® ground cinnamon': {'pre': 'mccormick ground',
#   'food': 'cinnamon',
#   'post': ''},
#  'mccormick® bay leaves': {'pre': '',
#   'food': 'mccormick bay',
#   'post': 'leaves'},
#  'morton salt': {'pre': 'morton', 'food': 'salt', 'post': ''},
#  'kroger iodized salt': {'pre': 'kroger iodized', 'food': 'salt', 'post': ''},
#  'mccormick® grill mates® montreal chicken seasoning': {'pre': 'mccormick grill mates montreal',
#   'food': 'chicken seasoning',
#   'post': ''},
#  'simple truth organic ground coriander': {'pre': 'simple truth organic',
#   'food': 'ground coriander',
#   'post': ''},
#  "annie's homegrown macaroni & cheese, gluten free, shell pasta & creamy white cheddar": {'pre': 'annies homegrown macaroni cheese gluten free shell pasta creamy',
#   'food': 'white',
#   'post': 'cheddar'},
#  "lawry's® garlic salt": {'pre': 'lawrys', 'food': 'garlic salt', 'post': ''},
#  'mccormick gourmet™ organic italian seasoning': {'pre': 'mccormick gourmet organic',
#   'food': 'italian seasoning',
#   'post': ''},
#  'kroger cumin ground': {'pre': 'kroger', 'food': 'cumin', 'post': 'ground'},
#  'mccormick gourmet™ organic rosemary': {'pre': 'mccormick gourmet organic',
#   'food': 'rosemary',
#   'post': ''},
#  'mccormick® perfect pinch® garlic & herb salt free seasoning': {'pre': 'mccormick perfect pinch garlic herb salt free',
#   'food': 'seasoning',
#   'post': ''},
#  'mrs. dash table blend salt-free seasoning blend': {'pre': 'mrs dash',
#   'food': 'table',
#   'post': 'blend salt free seasoning blend'},
#  'badia star anise': {'pre': 'badia star', 'food': 'anise', 'post': ''},
#  'mccormick gourmet™ organic chili powder': {'pre': 'mccormick gourmet organic',
#   'food': 'chili powder',
#   'post': ''},
#  "redmond real real salt nature's first sea salt fine": {'pre': 'redmond real real salt natures first sea',
#   'food': 'salt',
#   'post': 'fine'},
#  'mccormick® mushroom gravy mix': {'pre': '',
#   'food': 'mccormick mushroom gravy mix',
#   'post': ''},
#  'mccormick® oregano leaves': {'pre': 'mccormick',
#   'food': 'oregano',
#   'post': 'leaves'},
#  'kitchen bouquet browning & seasoning sauce, 4 ounces': {'pre': 'kitchen bouquet',
#   'food': 'browning seasoning sauce',
#   'post': '4 ounces'},
#  'mccormick® smoked paprika': {'pre': 'mccormick',
#   'food': 'smoked paprika',
#   'post': ''},
#  'brightfarms delightfully sweet local basil': {'pre': 'brightfarms',
#   'food': 'delightfully',
#   'post': 'sweet local basil'},
#  'mccormick® ground ginger': {'pre': 'mccormick',
#   'food': 'ground ginger',
#   'post': ''},
#  'morton sea salt fine, jar': {'pre': 'morton sea',
#   'food': 'salt',
#   'post': 'fine jar'},
#  'mccormick® grill mates® brazilian steakhouse marinade': {'pre': 'mccormick grill mates brazilian steakhouse',
#   'food': 'marinade',
#   'post': ''},
#  'mccormick® hot mexican chili powder': {'pre': 'mccormick hot mexican',
#   'food': 'chili powder',
#   'post': ''},
#  'ortega fish taco seasoning mix': {'pre': 'ortega fish',
#   'food': 'taco seasoning',
#   'post': 'mix'},
#  'kroger free-flowing salt': {'pre': 'kroger free',
#   'food': 'flowing',
#   'post': 'salt'},
#  'kroger onion chopped': {'pre': 'kroger', 'food': 'onion', 'post': 'chopped'},
#  'mccormick® chopped onions': {'pre': '',
#   'food': 'mccormick',
#   'post': 'chopped onions'},
#  "lawry's® lemon pepper blend": {'pre': 'lawrys',
#   'food': 'lemon',
#   'post': 'pepper blend'},
#  'mccormick® dill weed': {'pre': 'mccormick', 'food': 'dill weed', 'post': ''},
#  'kroger black pepper pure ground': {'pre': 'kroger',
#   'food': 'black',
#   'post': 'pepper pure ground'},
#  'private selection ground cinnamon': {'pre': 'private selection',
#   'food': 'ground cinnamon',
#   'post': ''},
#  'mccormick® grill mates® smoky ranchero marinade': {'pre': 'mccormick grill mates smoky ranchero',
#   'food': 'marinade',
#   'post': ''},
#  'mccormick® california style garlic powder with parsley coarse grind blend': {'pre': 'mccormick california style',
#   'food': 'garlic powder',
#   'post': 'with parsley coarse grind blend'},
#  'mccormick® ground cumin': {'pre': 'mccormick',
#   'food': 'ground cumin',
#   'post': ''},
#  'mccormick® rubbed sage': {'pre': 'mccormick rubbed',
#   'food': 'sage',
#   'post': ''},
#  'mccormick® grill mates® brazilian steakhouse seasoning': {'pre': 'mccormick grill mates brazilian',
#   'food': 'steakhouse seasoning',
#   'post': ''},
#  'badia cinnamon sticks': {'pre': 'badia',
#   'food': 'cinnamon',
#   'post': 'sticks'},
#  'knorr savoury sauce alfredo sauce': {'pre': 'knorr savoury sauce',
#   'food': 'alfredo sauce',
#   'post': ''},
#  "lawry's® 25% less sodium seasoned salt": {'pre': 'lawrys 25 less sodium seasoned',
#   'food': 'salt',
#   'post': ''},
#  'spice islands turmeric': {'pre': 'spice islands',
#   'food': 'turmeric',
#   'post': ''},
#  'mccormick gourmet™ organic fennel seed': {'pre': 'mccormick gourmet organic',
#   'food': 'fennel seed',
#   'post': ''},
#  'good seasons zesty italian salad dressing & recipe mix 4': {'pre': 'good seasons',
#   'food': 'zesty italian salad dressing',
#   'post': 'recipe mix 4'},
#  'mccormick® garlic pepper seasoning grinder': {'pre': 'mccormick',
#   'food': 'garlic pepper seasoning grinder',
#   'post': ''},
#  'mccormick® grill mates® smokehouse maple seasoning': {'pre': 'mccormick grill mates smokehouse',
#   'food': 'maple seasoning',
#   'post': ''},
#  "colman's of norwich mustard powder": {'pre': 'colmans of norwich',
#   'food': 'mustard powder',
#   'post': ''},
#  'mrs. dash extra spicy salt-free seasoning blend': {'pre': 'mrs',
#   'food': 'dash',
#   'post': 'extra spicy salt free seasoning blend'},
#  "famous dave's rib rub seasoning": {'pre': 'famous',
#   'food': 'daves',
#   'post': 'rib rub seasoning'},
#  'mccormick gourmet™ organic smoked paprika': {'pre': 'mccormick gourmet organic',
#   'food': 'smoked paprika',
#   'post': ''},
#  'mccormick® celery salt': {'pre': 'mccormick',
#   'food': 'celery salt',
#   'post': ''},
#  'morton sea salt coarse, bottle': {'pre': 'morton sea',
#   'food': 'salt',
#   'post': 'coarse bottle'},
#  'mccormick® black peppercorn grinder': {'pre': 'mccormick black',
#   'food': 'peppercorn grinder',
#   'post': ''},
#  "lawry's® coarse ground with parsley garlic salt": {'pre': 'lawrys',
#   'food': 'coarse',
#   'post': 'ground with parsley garlic salt'},
#  "private selection za'atar blend": {'pre': 'private',
#   'food': 'selection',
#   'post': 'zaatar blend'},
#  'mccormick® chipotle chili pepper': {'pre': 'mccormick chipotle',
#   'food': 'chili',
#   'post': 'pepper'},
#  'mccormick® whole caraway seed': {'pre': 'mccormick whole',
#   'food': 'caraway seed',
#   'post': ''},
#  'slap ya mama cajun seasoning': {'pre': 'slap ya mama',
#   'food': 'cajun seasoning',
#   'post': ''},
#  'epic sea salt pepper venison bar': {'pre': 'epic sea',
#   'food': 'salt',
#   'post': 'pepper venison bar'},
#  'mccormick® ground turmeric': {'pre': 'mccormick',
#   'food': 'ground turmeric',
#   'post': ''},
#  'mccormick gourmet™ organic whole black peppercorns': {'pre': 'mccormick gourmet organic whole black',
#   'food': 'peppercorns',
#   'post': ''},
#  'goya adobo all purpose seasoning with cumin': {'pre': 'goya adobo',
#   'food': 'all',
#   'post': 'purpose seasoning with cumin'},
#  'mccormick® cilantro leaves': {'pre': 'mccormick cilantro',
#   'food': 'leaves',
#   'post': ''},
#  'mccormick gourmet™ organic ground thyme': {'pre': 'mccormick gourmet organic',
#   'food': 'ground thyme',
#   'post': ''},
#  ...}

# %%
def food_label_finder(token_list, label_list):
    pre = []
    food = []
    post = []

    for word, label in zip(token_list, label_list):
        if label == 'pre':
            pre.append(word.lower())
        if label == 'food':
            food.append(word.lower())
        if label == 'post':
            post.append(word.lower())
    return " ".join(food)

# %%
prod_list_new = []
for token, label in zip(token_sr, y_pred):
    prod_list_new.append(food_label_finder(token, label))

# %%
print(len(prod_list_new))
print(len(grocery_prices_marianos))
# Out:
# 6242
# 6242

# %%
prod_list_new
# Out:
# ['scallions',
#  'cilantro',
#  'parsley',
#  'roundys',
#  'thyme',
#  'mint',
#  'basil',
#  'dill',
#  'dill',
#  'paste',
#  'chives',
#  'ithyme',
#  'parsley',
#  'sage',
#  'leaf',
#  'garlic',
#  'paste',
#  'fennel',
#  'dried parsley',
#  'parsley',
#  'thyme',
#  'parsley',
#  'oregano',
#  'ground ginger',
#  'paste',
#  'thyme',
#  'dong',
#  'lemon basil',
#  'cocoa',
#  'baking soda',
#  'chocolate',
#  'pumpkin',
#  'cocoa',
#  'pure vanilla extract',
#  'baking chips',
#  'stevia',
#  'splenda',
#  'evaporated milk',
#  'flour bread',
#  'dark chocolate',
#  'flour',
#  'light brown sugar',
#  'chocolate',
#  'sugar',
#  'sugar',
#  'vanilla extract',
#  'granulated no calorie sweetener',
#  'flour',
#  'vanilla extract',
#  'sliced almonds',
#  'activedry yeast',
#  'sugar',
#  'milk chocolate',
#  'pumpkin',
#  'baking cocoa',
#  'stevia',
#  'walnut',
#  'truvia',
#  'pie crust',
#  'sugar',
#  'chocolate milk',
#  'chocolate',
#  'condensed milk',
#  'powdered sugar',
#  'sugar',
#  'cake mix',
#  'pudding',
#  'pine nuts',
#  'walnut',
#  'all',
#  'baking powder',
#  'equal',
#  'certified',
#  'kroger sweetener no calorie',
#  'pecans',
#  'all',
#  'quinoa',
#  'mil',
#  'vanilla flavor',
#  'brown sugar',
#  'real milk chocolate bakers real milk chocolate dipping chocolate',
#  'sugar',
#  'sugar',
#  'pecan',
#  'cinnamon sugar',
#  'macadamia nuts',
#  'instant yeast',
#  'banana pudding pie filling',
#  'dark chocolate baking chips',
#  'sugar',
#  'condensed milk',
#  'vanilla flavor',
#  'sugar',
#  'marshmallows',
#  'butter',
#  'marshmallows',
#  'orange',
#  'sugar',
#  'marshmallows',
#  'marshmallows',
#  'marshmallows',
#  'all',
#  'pie filling topping',
#  'zero calorie sweetener',
#  'butterscotch',
#  'domino pourable light brown',
#  'vegetable shortening',
#  'milk chocolate baking chips',
#  'powdered confectioners sugar',
#  'vanilla flavor',
#  'sweetn',
#  'all',
#  'dry milk',
#  'maple extract',
#  'gelatin',
#  'bread flour',
#  'brown sugar',
#  'coconut extract',
#  'light brown sugar',
#  'bittersweet chocolate',
#  'strawberry',
#  'creme',
#  'almond flour',
#  'chocolate baking bar',
#  'gelatin',
#  'gelatin',
#  'walnut',
#  'dark chocolate',
#  'flour',
#  'pie filling topping',
#  'peanut butter baking chips',
#  'pie crust',
#  'chocolate baking bar',
#  'evaporated milk',
#  'brown sugar',
#  'pecans',
#  'raspberry',
#  'color',
#  'sugar',
#  'walnuts',
#  'grape',
#  'all purpose',
#  'chocolate chips',
#  'black',
#  'corn meal',
#  'brown sugar',
#  'vegetable shortening',
#  'condensed milk',
#  'condensed milk',
#  'coconut flakes',
#  'angel',
#  'wheat germ',
#  'pecans',
#  'sugar',
#  'vanilla pudding pie filling',
#  'pecan',
#  'cornmeal',
#  'cocoa',
#  'zero',
#  'shortening',
#  'vanilla flavor',
#  'premier',
#  'wheat flour',
#  'graham cracker crumbs',
#  'vanilla extract',
#  'sugar',
#  'pie crust',
#  'peppermint extract',
#  'brown sugar',
#  'flour',
#  'sugar',
#  'all purpose',
#  'chocolate chips',
#  'instant yeast',
#  'graham cracker crust',
#  'candy coating',
#  'brown sugar',
#  'vegetable shortening',
#  'flour',
#  'flour',
#  'cake flour',
#  'zero calorie sweetener',
#  'milk chocolate',
#  'salt',
#  'pudding pie filling',
#  'coconut flakes',
#  'crust',
#  'coconut flakes',
#  'pie crusts',
#  'dried acai powder',
#  'chocolate baking chips',
#  'cake mix',
#  'chocolate',
#  'bittersweet chocolate',
#  'almond extract',
#  'sugar cubes',
#  'flaxseed meal',
#  'chocolate baking bar',
#  'gelatin dessert',
#  'o',
#  'evaporated milk',
#  'lemon',
#  'all',
#  'mixing flour',
#  'vegetable shortening',
#  'pudding pie filling',
#  'bread flour',
#  'rum extract',
#  'pie filling',
#  'vanilla flavor',
#  'walnut',
#  'pudding pie filling',
#  'marshmallows',
#  'chocolate',
#  'buttermilk',
#  'mint extract',
#  'almond paste',
#  'almond extract',
#  'oat flour',
#  'stevia',
#  'stevia',
#  'all',
#  'milk chocolate',
#  'flour',
#  'baking stick',
#  'peanut',
#  'rising flour',
#  'pie filling topping',
#  'wheat flour',
#  'cornmeal',
#  'orange extract',
#  'brown rice flour',
#  'apple pie filling topping',
#  'banana extract',
#  'o',
#  'semolina flour',
#  'wheat flour',
#  'wheat germ',
#  'flour',
#  'bread',
#  'bread crumbs',
#  'shortening',
#  'yeast',
#  'pork flavored stuffing mix',
#  'zesty',
#  'walnuts',
#  'flour',
#  'tapioca',
#  'purpose baking flour',
#  'chocolate chips',
#  'almond cooking milk',
#  'mustard',
#  'whip',
#  'tomato sauce',
#  'mustard',
#  'ketchup',
#  'hot sauce',
#  'mustard',
#  'hot sauce',
#  'hot sauce',
#  'ketchup',
#  'mayonnaise',
#  'tabasco',
#  'mayonnaise',
#  'mayonnaise',
#  'frozen dessert',
#  'avocado oil',
#  'aioli',
#  'bbq sauce',
#  'relish',
#  'ketchup',
#  'mayonnaise',
#  'mayonnaise',
#  'tabasco',
#  'mustard',
#  'ketchup',
#  'tabasco',
#  'sce',
#  'ketchup',
#  'dressing',
#  'hot sauce',
#  'vegenaise',
#  'mayonnaise',
#  'tabasco',
#  'hot sauce',
#  'mustard',
#  'pizza sauce',
#  'hot sauce',
#  'barbecue sauce',
#  'ketchup',
#  'hot',
#  'submarine dressing',
#  'relish',
#  'mustard',
#  'tabasco',
#  'mayonnaise',
#  'dried tomatoes',
#  'ketchup',
#  'sloppy joe sauce',
#  'mayonnaise',
#  'vegenaise',
#  'mustard',
#  'ketchup',
#  'mayo',
#  'hot sauce',
#  'mustard',
#  'mayonnaise',
#  'mustard',
#  'mayo',
#  'mayonnaise',
#  'mustard',
#  'classic',
#  'mayonnaise',
#  'cinnamon sugar',
#  'hot sauce',
#  'mayonnaise',
#  'hot sauce',
#  'mayo',
#  'mayonnaise',
#  'chili sauce',
#  'mayonnaise',
#  'mustard',
#  'tartar sauce',
#  'tabasco',
#  'mustard',
#  'real',
#  'hot',
#  'mustard',
#  'the',
#  'hot',
#  'avocado oil',
#  'gravy mix',
#  'mayonnaise',
#  'ketchup',
#  'chips',
#  'mustard',
#  'fry sauce',
#  'valentina mexican',
#  'mustard',
#  'ketchup',
#  'mustard',
#  'tartar sauce',
#  'worcestershire',
#  'hot sauce',
#  'whip dressing',
#  'salsa',
#  'mayonnaise',
#  'relish',
#  'chili sauce',
#  'horseradish',
#  'mayonnaise',
#  'mustard',
#  'harissa sauce',
#  'mayonnaise',
#  'mayonnaise',
#  'ketchup',
#  'tabasco',
#  'relish',
#  'mustard',
#  'soy sauce',
#  'hot sauce',
#  'shrimp sauce',
#  'mustard',
#  'giardiniera',
#  'tartar sauce',
#  'baby',
#  'mustard',
#  'mayonnaise',
#  'mayonnaise',
#  'mayo',
#  'taco sauce',
#  'mustard',
#  'pesto',
#  'hot sauce',
#  'mayonnaise',
#  'mustard',
#  'mustard',
#  'mustard',
#  'cocktail sauce',
#  'mustard horseradish',
#  'mustard',
#  'grapeseed',
#  'tabasco',
#  'relish',
#  'mustard',
#  'worcestershire',
#  'ketchup',
#  '57 sauce',
#  'heinz sauce',
#  'lemonaise',
#  'yum sauce',
#  'mustard',
#  'teriyaki sauce',
#  'mustard',
#  'bbq sauce',
#  'ketchup',
#  'dipping sauce',
#  'hot sauce',
#  'bbq sauce',
#  'light',
#  'marinade',
#  'ketchup',
#  'mayonnaise',
#  'ketchup',
#  'alfredo sauce',
#  'horseradish',
#  'mustard',
#  'pickapeppa sauce',
#  'mayonnaise',
#  'silver',
#  'mustard',
#  'spread',
#  'mustard',
#  '2',
#  'sugar',
#  'mayo',
#  'mustard',
#  'teriyaki sauce',
#  'light',
#  'mayonnaise',
#  'hot',
#  'silver',
#  'cocktail sauce',
#  'mustard',
#  'mayonnaise',
#  'mustard',
#  'sweet sour sauce',
#  'tomato',
#  'a1',
#  'horseradish',
#  'mayonnaise',
#  'mustard',
#  'heat',
#  'cocktail sauce',
#  'barbecue sauce',
#  'chile sauce',
#  'dried',
#  'mustard',
#  'mustard honey',
#  'mustard',
#  'cocktail sauce',
#  'kraft sauce',
#  'horseradish',
#  'worcestershire',
#  'taco sauce',
#  'bruschetta',
#  'mayonnaise',
#  'duck sauce',
#  'horseradish',
#  'ranch dressing',
#  'horseradish',
#  'whip dressing',
#  'mayonnaise',
#  'light miracle whip',
#  'sesame sauce',
#  'hot sauce',
#  'mustard',
#  'taco sauce',
#  'mayonesa',
#  'maple bbq sauce',
#  'mustard',
#  'mustard',
#  'own',
#  'salsa',
#  'mayonnaise',
#  'tartar sauce',
#  'mustard',
#  'ketchup',
#  'whip',
#  'soy sauce',
#  'mustard',
#  'hot sauce',
#  'barbecue sauce',
#  'cayenne pepper sauce',
#  'ketchup',
#  'mustard',
#  'prepared horseradish',
#  'worcestershire',
#  'hollandaise sauce',
#  'cocktail sauce',
#  'kung pao sauce',
#  'mustard',
#  'ketchup',
#  'ketchup',
#  'condiment sauce',
#  'mustard',
#  'barbecue sauce',
#  'mayonnaise',
#  'carolina bbq sauce',
#  'chili',
#  'barbecue sauce',
#  'barbecue sauce',
#  'sweet chili sauce',
#  'mustard walnut',
#  'annies',
#  'q',
#  'salsa',
#  'ketchup',
#  'peri sauce',
#  'ketchup',
#  'mustard',
#  'balsamic',
#  'peri sauce',
#  'mild',
#  'powdered sugar',
#  'ketchup',
#  'ketchup',
#  'chips',
#  'hot sauce',
#  'bbq sauce',
#  'bobs',
#  'alfredo sauce',
#  'wasabi',
#  'soy sauce',
#  'relish',
#  'ricks',
#  'chimichurri',
#  'mustard',
#  'lillies',
#  'cocktail sauce',
#  'harissa sauce',
#  'ketchup',
#  'fat mayo',
#  'accents simmer sauce',
#  'seed',
#  'mustard',
#  'accents simmer sauce',
#  'buffalo sauce',
#  'ketchup sauce',
#  'mustard',
#  'whip dressing',
#  'olivara',
#  'hot sauce',
#  'yings',
#  'mild sauce',
#  'wing sauce',
#  'flavored sauce',
#  'cocktail sauce',
#  'seasoning',
#  'road simmer sauce',
#  'a',
#  'hot sauce',
#  'hot sauce',
#  'ketchup',
#  'made sauce',
#  'ketchup',
#  'bbq sauce',
#  'ever',
#  'chili sauce',
#  'tomato basil sauce',
#  'mayochup sauce',
#  'marinara sauce',
#  'pineapple red pepper jelly',
#  'mustard',
#  'mustard',
#  'marinara',
#  'peri sauce garlic',
#  'garlic sauce',
#  'ortega',
#  'mustard',
#  'relish',
#  'salsa',
#  'hot sauce',
#  'hot sauce',
#  'salsa',
#  'salsa',
#  'mayonnaise',
#  'pineapple juice',
#  'mustard',
#  'tomato soup',
#  'chicken flavor ramen noodle soup',
#  'noodles soup',
#  'chicken broth',
#  'vegetable soup',
#  'chicken dumplings',
#  'chicken noodle soup',
#  'noodle soup',
#  'tomato',
#  'chicken sausage',
#  'tomato basil soup',
#  'minestrone soup',
#  'chicken noodle soup',
#  'chicken and wild rice soup',
#  'progresso soup',
#  'chicken broth',
#  'chicken broth',
#  'chicken noodle soup',
#  'tomato soup',
#  'vegetable soup',
#  'vegetable',
#  'broccoli',
#  'campbells',
#  'vegetable',
#  'chicken stars soup',
#  'tomato soup',
#  'bisque soup',
#  'wedding soup',
#  'vegetables soup',
#  'vegetable soup',
#  'chicken noodle soup',
#  'chicken broth',
#  'chicken stock',
#  'chicken base',
#  'chicken noodle soup',
#  'chowder',
#  'chicken broth',
#  'chicken and dumpling soup',
#  'marvel spiderman soup',
#  'beef',
#  'chicken tortilla soup',
#  'vegetable',
#  'chicken broth',
#  'chicken noodle soup',
#  'chili',
#  'chicken stock',
#  'split',
#  'chicken noodle soup',
#  'chicken broth',
#  'chicken and sausage',
#  'vegetable soup',
#  'chunky steak potato soup',
#  'double noodle soup',
#  'beef barley soup',
#  'kickin crab corn chowder',
#  'slow',
#  'broth',
#  'chicken noodle condensed soup',
#  'chicken quesadilla soup',
#  'chicken cheese enchilada',
#  'chicken and rotini soup',
#  'chicken',
#  'chicken and wild rice soup',
#  'vegetable soup',
#  'chicken cooking stock',
#  'chicken rice',
#  'tomato soup',
#  'chicken soup',
#  'chicken noodle soup',
#  'wolfgang',
#  'roasted',
#  'chicken broth',
#  'chicken broth',
#  'chicken corn chowder',
#  'chili',
#  'amys',
#  'cream of mushroom soup',
#  'chili soup',
#  'creamy mushroom soup',
#  'chicken corn chowder',
#  'chicken pot pie soup',
#  'condensed soup',
#  'vegetable',
#  'tomato soup',
#  'pea soup',
#  'tomato soup',
#  'princesses',
#  'broccoli and cheese chowder soup',
#  'pie style soup',
#  'bacon soup',
#  'chicken broth',
#  'bean soup',
#  'chicken with rice',
#  'vegetable beef soup',
#  'beef broth',
#  'chicken stock',
#  'beef',
#  'chicken mini',
#  'vegetable soup',
#  'vegetable soup',
#  'chicken tortilla soup',
#  'chicken pot pie style soup',
#  'tomato basil',
#  'bone broth',
#  'chicken sausage',
#  'vegetable broth',
#  'beef broth',
#  'bone broth',
#  'chicken broth',
#  'spanish rice',
#  'vegetable broth',
#  'beef barley soup',
#  'vegetable soup',
#  'onion flavor',
#  'chicken broth',
#  'chicken noodle soup',
#  'chicken noodle soup',
#  'phak',
#  'chicken broth',
#  'inn',
#  'chicken noodle soup',
#  'soups',
#  'vegetable stock',
#  'chicken noodle',
#  'bean soup',
#  'chicken soup',
#  'minestrone soup mix',
#  'vegetable broth',
#  'chicken noodle soup',
#  'chicken noodle soup',
#  'slow',
#  'vegetables soup',
#  'chowder',
#  'creamy potato with bacon and cheese soup',
#  'minestrone',
#  'vegetable barley soup',
#  'noodles',
#  'chicken broccoli cheese with potato soup',
#  'chicken with rice soup',
#  'chicken corn chowder soup',
#  'red pepper soup',
#  'noodle soup',
#  'chicken corn chowder soup',
#  'rotini soup',
#  'condensed soup',
#  'onion soup',
#  'chicken and cheese enchilada soup',
#  'chicken broth',
#  'chicken cooking stock',
#  'chicken broth',
#  'chicken noodle soup',
#  'pot roast soup',
#  'chicken soup',
#  'tomato',
#  'chicken and herb dumplings soup',
#  'vegetable broth',
#  'italian sausage',
#  'chicken noodle soup',
#  'chicken chili',
#  'chicken base',
#  'hearty',
#  'creamy',
#  'chowder',
#  'split pea soup',
#  'chicken noodleos soup',
#  'chicken broth',
#  'chicken sausage',
#  'corn chowder',
#  'campbells soup',
#  'tomato',
#  'beef broth',
#  'campbells',
#  'noodle soup mix',
#  'beef stew sauces',
#  'of mushroom soup',
#  'beef broth',
#  'tomato basil soup',
#  'baked potato',
#  'tomato soup',
#  'broccoli cheese soup',
#  'chicken flavor bouillon cubes',
#  'chowder soup',
#  'condensed cream of mushroom soup',
#  'italian sausage',
#  'tomato soup',
#  'chicken with country vegetables soup',
#  'of mushroom',
#  'wedding soup',
#  'minestrone soup',
#  'chicken broth',
#  'campbells',
#  'wild rice soup mix',
#  'bread',
#  'chili',
#  'chicken and vegetable soup',
#  'quinoa soup',
#  'vegetable soup',
#  'soup',
#  'beef consomme',
#  'yes',
#  'chicken noodle soup mix',
#  'seasoning',
#  'vegetable beef soup',
#  'nacho cheese soup',
#  'beef broth',
#  'cream of mushroom soup',
#  'beef base',
#  'chicken noodle soup',
#  'cashew carrot ginger soup',
#  'chicken noodle soup',
#  'mushroom broth',
#  'campbells',
#  'fat',
#  'corn chowder soup',
#  'chicken soup',
#  'beef broth',
#  'campbells',
#  'ham soup',
#  'beef barley vegetable soup',
#  'beef broth',
#  'condensed soup',
#  'vegetables soup',
#  'butternut squash soup',
#  'campbells',
#  'of mushroom soup',
#  'vegetable beef condensed soup',
#  'onion soup',
#  'lipton soup',
#  'condensed soup',
#  'beef swanson beef stock',
#  'beef broth',
#  'tomato basil',
#  'vegetable stock',
#  'celery soup',
#  'chicken broth',
#  'beef stroganoff sauces',
#  'chowder',
#  'onion',
#  'beef pot roast soup',
#  'vegetable soup',
#  'tortilla soup',
#  'campbells',
#  'vegetable',
#  'chowder soup',
#  'chicken broth',
#  'cooking stock',
#  'potato',
#  'condensed soup',
#  'beef base',
#  'bouillon cubes',
#  'condensed soup',
#  'toscana',
#  'campbells condensed cheddar cheese soup',
#  'beef broth',
#  'stock',
#  'campbells',
#  'sausage',
#  'beef stock',
#  'minestrone soup',
#  'chicken broth',
#  'chicken broth',
#  'chicken noodle condensed soup',
#  'chicken gumbo condensed soup',
#  'chicken broth',
#  'condensed soup',
#  'miso',
#  'chicken rice soup',
#  'of onion soup',
#  'chicken soup',
#  'condensed soup',
#  'broth',
#  'vegetable beef condensed soup',
#  'beefy mushroom soup',
#  'broccoli potato soup',
#  'vegetable',
#  'potato soup',
#  'beef broth',
#  'bouillon cubes',
#  'beef broth',
#  'tomato soup',
#  'chicken with rice and beans soup',
#  'carrot ginger',
#  'chicken noodle soup',
#  'onion flavor',
#  'onion',
#  'mushroom soup',
#  'condensed soup',
#  'beef broth',
#  'stock',
#  'orzo',
#  'bouillon cubes',
#  'vegetable broth',
#  'chicken noodle soup',
#  'condensed soup',
#  'beef stew',
#  'bone',
#  'vegetable soup chunky',
#  'barley soup',
#  'onion soup dip mix',
#  'condensed soup',
#  'chicken noodle soup',
#  'bouillon',
#  'chowder soup',
#  'beef broth',
#  'loaded potato soup',
#  'bouillon cubes',
#  'bread',
#  'beef flavored broth',
#  'mushroom gravy',
#  'celery soup',
#  'tomato soup',
#  'chicken noodle condensed soup',
#  'onion',
#  'vegetable beef soup',
#  'mix',
#  'gravy',
#  'potato soup mix',
#  'chicken gravy',
#  'coconut',
#  'chicken flavored',
#  'stew',
#  'chicken',
#  'delicious soup mix',
#  'chicken noodle soup',
#  'minestrone soup mix',
#  'tortellini soup',
#  'chowder',
#  'chicken dumpling soup',
#  'tomato soup',
#  'minestrone soup',
#  'vegetable stock',
#  'chicken soup',
#  'red beans vegetable soup',
#  'chicken broth',
#  'beef broth',
#  'bone broth',
#  'campbells',
#  'condensed soup',
#  'bone broth butternut squash',
#  'broth',
#  'bacon soup',
#  'sipping soup',
#  'butternut squash soup',
#  'butternut squash and sweet potato sipping soup',
#  'pasta soup',
#  'tomato soup',
#  'campbells',
#  'bacon soup',
#  'bone broth',
#  'broccoli cheese soup',
#  'chicken noodle soup',
#  'basil',
#  'vegetable',
#  'chicken soup',
#  'mccormick black pepper grinder',
#  '3 pepper',
#  'noodle soup',
#  'taco seasoning',
#  'taco seasoning',
#  'salt',
#  'salt grinder',
#  'seasoning',
#  'seasoning',
#  'salt',
#  'garlic powder',
#  'old bay seasoning',
#  'parsley flakes',
#  'creole seasoning',
#  'minced onions',
#  'white pepper',
#  'taco seasoning',
#  'mccormick paprika',
#  'salt grinder',
#  'crushed red pepper',
#  'ground pepper black',
#  'sea salt',
#  'pepper',
#  'taco seasoning',
#  'chili powder',
#  'dash',
#  'salt',
#  'vanilla extract',
#  'minced garlic',
#  'mccormick basil',
#  'mccormick onion powder',
#  'chicken broccoli',
#  'herb seasoning',
#  'seasoning',
#  'lemon',
#  'all',
#  'chili',
#  'garlic salt',
#  'old bay',
#  'peppercorn medley grinder',
#  'chili powder',
#  'guacamole seasoning',
#  'salt',
#  'red pepper',
#  'pot roast seasoning',
#  'chili',
#  'creole seasoning',
#  'vegetable seasoning',
#  'parsley flakes',
#  'lemon pepper',
#  'accents chicago steak chop cracked pepper garlic',
#  'peppercorn grinder',
#  'chia seeds',
#  'cinnamon',
#  'montreal steak seasoning',
#  'salt grinder',
#  'crushed red pepper',
#  'salt black',
#  'yeast seasoning',
#  'mccormick whole black pepper',
#  'all',
#  'ground black pepper',
#  'nutmeg',
#  'montreal steak seasoning',
#  'poultry seasoning',
#  'celery salt',
#  'onion',
#  'onion powder',
#  'oregano',
#  'garlic jalapeno seasoning',
#  'mustard',
#  'ounces',
#  'herb grinder',
#  'cinnamon',
#  'mccormick bay',
#  'salt',
#  'salt',
#  ...]

# %%
grocery_prices_marianos['product_new'] = prod_list_new

# %%
grocery_prices_marianos
# Out:
#                                           product main_price  \
# 0                        Green Onions (Scallions)      $0.99
# 1                                        Cilantro      $0.79
# 2                                 Italian Parsley      $0.99
# 3                 Roundy's Organic Fresh Rosemary      $2.50
# 4                    Roundy's Organic Fresh Thyme      $2.50
# ...                                           ...        ...
# 6237                          Organic Purple Kale      $1.79
# 6238                          Green Savoy Cabbage      $4.17
# 6239                             Cubanelle Pepper      $0.33
# 6240                               Belgian Endive      $2.84
# 6241  Marie's Garlic Parmesan Italian Vinaigrette      $4.49
#
#              prod_aile price_per_lb measure_words_main_price  \
# 0          Fresh Herbs          NaN                     each
# 1          Fresh Herbs          NaN                     each
# 2          Fresh Herbs          NaN                     each
# 3          Fresh Herbs          NaN                     each
# 4          Fresh Herbs          NaN                     each
# ...                ...          ...                      ...
# 6237  Fresh Vegetables          NaN                      NaN
# 6238  Fresh Vegetables      1.49/lb                     each
# 6239  Fresh Vegetables      3.29/lb                     each
# 6240  Fresh Vegetables      3.79/lb                     each
# 6241  Fresh Vegetables          NaN                     each
#
#      item_weight_count_vol date_collected     store  location  \
# 0                      NaN     2019-08-28  Marianos     60615
# 1                      NaN     2019-08-28  Marianos     60615
# 2                      NaN     2019-08-28  Marianos     60615
# 3               0.75 ounce     2019-08-28  Marianos     60615
# 4               0.75 ounce     2019-08-28  Marianos     60615
# ...                    ...            ...       ...       ...
# 6237                   NaN     2019-08-28  Marianos     60615
# 6238                   NaN     2019-08-28  Marianos     60615
# 6239                   NaN     2019-08-28  Marianos     60615
# 6240                   NaN     2019-08-28  Marianos     60615
# 6241         11.5 fl ounce     2019-08-28  Marianos     60615
#
#            product_new
# 0            scallions
# 1             cilantro
# 2              parsley
# 3              roundys
# 4                thyme
# ...                ...
# 6237       purple kale
# 6238           cabbage
# 6239  cubanelle pepper
# 6240            endive
# 6241       vinaigrette
#
# [6242 rows x 10 columns]

# %%
grocery_prices_marianos.to_csv('../../data/03_processed/grocery_prices_marianos_final.csv', index=False)
