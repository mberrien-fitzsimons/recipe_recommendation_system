# %% [markdown]
# # Tagging Products - Instacart Kaggle Dataset

# %%
import argparse
import nltk
import pandas as pd
import pycrfsuite
import numpy as np
import re
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer

nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/markishab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Read in Dataset and filter for only food

# %%
baskets = pd.read_csv('../../data/02_intermediate/baskets_spark.csv')
baskets.drop(columns=['Unnamed: 0'], inplace=True)

# %%
baskets.product_name.nunique()
# Out:
# 24495

# %%
baskets.head()
# Out:
#    order_id           product_name  user_id  all_ones
# 0         2     Organic Egg Whites   202279         1
# 1         2  Michigan Organic Kale   202279         1
# 2         2          Garlic Powder   202279         1
# 3         2         Coconut Butter   202279         1
# 4         2      Natural Sweetener   202279         1

# %% [markdown]
# ## Tagging Products through a CRF Model

# %%
products_list = list(baskets.product_name)

# %%
# let's tokenize all the words and get rid of punctuation
tokenizer = RegexpTokenizer(r'(\d\/\d |\w+)')
token_sr = []
for product in products_list:
    token_sr.append(tokenizer.tokenize(product))

# %%
token_sr
# Out:
# [['Organic', 'Egg', 'Whites'],
#  ['Michigan', 'Organic', 'Kale'],
#  ['Garlic', 'Powder'],
#  ['Coconut', 'Butter'],
#  ['Natural', 'Sweetener'],
#  ['Carrots'],
#  ['Original', 'Unflavored', 'Gelatine', 'Mix'],
#  ['All', 'Natural', 'No', 'Stir', 'Creamy', 'Almond', 'Butter'],
#  ['Classic', 'Blend', 'Cole', 'Slaw'],
#  ['Total', '2', 'with', 'Strawberry', 'Lowfat', 'Greek', 'Strained', 'Yogurt'],
#  ['Unsweetened', 'Almondmilk'],
#  ['Lemons'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Unsweetened', 'Chocolate', 'Almond', 'Breeze', 'Almond', 'Milk'],
#  ['Organic', 'Ginger', 'Root'],
#  ['Air', 'Chilled', 'Organic', 'Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Organic', 'Ezekiel', '49', 'Bread', 'Cinnamon', 'Raisin'],
#  ['Plain', 'Pre', 'Sliced', 'Bagels'],
#  ['Oats', 'Chocolate', 'Chewy', 'Bars'],
#  ['Kellogg', 's', 'Nutri', 'Grain', 'Apple', 'Cinnamon', 'Cereal'],
#  ['Nutri',
#   'Grain',
#   'Soft',
#   'Baked',
#   'Strawberry',
#   'Cereal',
#   'Breakfast',
#   'Bars'],
#  ['Kellogg', 's', 'Nutri', 'Grain', 'Blueberry', 'Cereal'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Just', 'Crisp', 'Parmesan'],
#  ['Fresh', 'Fruit', 'Salad'],
#  ['Organic', 'Raspberries'],
#  ['2', 'Reduced', 'Fat', 'Milk'],
#  ['Matzos', 'Thin', 'Tea'],
#  ['Boneless', 'Skinless', 'Chicken', 'Breast', 'Fillets'],
#  ['Mini', 'Original', 'Babybel', 'Cheese'],
#  ['Macaroni', 'And', 'Cheese'],
#  ['Clementines'],
#  ['Artichokes'],
#  ['Apricot', 'Preserves'],
#  ['American', 'Slices', 'Cheese'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Spaghetti', 'Pasta'],
#  ['Meyer', 'Lemon'],
#  ['Bag', 'of', 'Organic', 'Lemons'],
#  ['Pineapple', 'Chunks'],
#  ['Original', 'Hawaiian', 'Sweet', 'Rolls'],
#  ['Organic', 'Red', 'Radish', 'Bunch'],
#  ['Whole', 'White', 'Mushrooms'],
#  ['Baby', 'Spinach'],
#  ['Low',
#   'Fat',
#   'Kefir',
#   'Cultured',
#   'Milk',
#   'Smoothie',
#   'Lowfat',
#   'Probiotic',
#   'Blueberry'],
#  ['Natural', 'Applesauce', 'Snack', 'Go', 'Pouches'],
#  ['Green', 'Beans'],
#  ['Extra', 'Virgin', 'Olive', 'Oil'],
#  ['French', 'Baguettes', 'Take', 'Bake', 'Twin', 'Pack'],
#  ['Organic', 'Bread', 'with', '21', 'Whole', 'Grains'],
#  ['Vanilla', 'Almond', 'Breeze', 'Almond', 'Milk'],
#  ['Natural', 'Sharp', 'Cheddar', 'Sliced', 'Cheese'],
#  ['Fruit', 'Nutty', 'Almonds', 'Raisins', 'Cranberries', 'Pecans', 'Granola'],
#  ['Banana'],
#  ['Baby', 'Portabella', 'Mushrooms'],
#  ['Organic', 'Cilantro'],
#  ['Organic', 'Avocado'],
#  ['Yellow', 'Onions'],
#  ['Parsley', 'Italian', 'Flat', 'New', 'England', 'Grown'],
#  ['Organic', 'Strawberries'],
#  ['Organic', 'Black', 'Beans'],
#  ['Green', 'Beans'],
#  ['Organic', 'Half', 'Half'],
#  ['Boneless', 'Beef', 'Sirloin', 'Steak'],
#  ['Organic', 'Butterhead', 'Boston', 'Butter', 'Bibb', 'Lettuce'],
#  ['Organic', 'Sunchoke'],
#  ['Teriyaki', 'Pineapple', 'Chicken', 'Meatballs'],
#  ['Mango', 'Pineapple', 'Salsa'],
#  ['Traditional', 'Refried', 'Beans'],
#  ['Extra', 'Virgin', 'Olive', 'Oil'],
#  ['French', 'Vanilla', 'Coffee', 'Creamer'],
#  ['2', 'Milk'],
#  ['Cherubs', 'Heavenly', 'Salad', 'Tomatoes'],
#  ['Extra', 'Creamy', 'Dairy', 'Whipped', 'Topping'],
#  ['Cheddar', 'Cheese', 'Condensed', 'Soup'],
#  ['All', 'Natural', 'Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Combination', 'Pizza', 'Rolls'],
#  ['Chunky', 'Salsa', 'Medium'],
#  ['Salsa', 'Con', 'Queso', 'Medium', 'Dip'],
#  ['Philadelphia', 'Original', 'Cream', 'Cheese'],
#  ['Hampshire', '100', 'Natural', 'Sour', 'Cream'],
#  ['Organic', 'Whole', 'Milk'],
#  ['Organic', 'Mini', 'Homestyle', 'Waffles'],
#  ['Naturals', 'Chicken', 'Nuggets'],
#  ['Unprocessed', 'American', 'Singles', 'Colby', 'Style', 'Cheese'],
#  ['Organic', 'Mesa', 'Sunrise', 'Cereal'],
#  ['Total', 'Greek', 'Strained', 'Yogurt'],
#  ['Corn', 'Meal', 'Pizza', 'Crust'],
#  ['Sriracha', 'Chili', 'Sauce'],
#  ['Organic', 'Broccoli', 'Florets'],
#  ['Honeycrisp', 'Apple'],
#  ['Organic', 'Extra', 'Virgin', 'Olive', 'Oil'],
#  ['Pinto', 'Beans', 'No', 'Salt', 'Added'],
#  ['Red', 'Vine', 'Tomato'],
#  ['Apricots'],
#  ['Watermelon', 'Chunks'],
#  ['Organic', 'Fat', 'Free', 'Milk'],
#  ['Organic', 'Bosc', 'Pear'],
#  ['Organic', 'Raspberries'],
#  ['Ataulfo', 'Mango'],
#  ['Globe', 'Eggplant'],
#  ['Organic', 'Unsalted', 'Butter'],
#  ['Sesame', 'Oil', 'Pure'],
#  ['Frozen', 'Broccoli', 'Florets'],
#  ['Organic', 'Maple', 'Onion', 'Baked', 'Beans'],
#  ['Cilantro', 'Pesto'],
#  ['Raspberry', 'Preserves'],
#  ['Balsamic', 'Reduction', 'Traditional', 'Balsamic'],
#  ['Sweet', 'Corn', 'On', 'The', 'Cob'],
#  ['Organic', 'Hazelnut', 'Spread'],
#  ['Organic', 'Baby', 'Kale'],
#  ['Low', 'Sodium', 'Bacon'],
#  ['Asparagus'],
#  ['Organic', 'Avocado'],
#  ['Basil', 'Asiago', 'Pine', 'Nut', 'Pesto', 'Ravioli'],
#  ['Organic', 'Baby', 'Carrots'],
#  ['Unsweetened', 'Almondmilk'],
#  ['Organic', 'Whole', 'White', 'Mushrooms'],
#  ['Mini', 'Chocolate', 'Chip', 'Waffles'],
#  ['Sweet', 'Red', 'Grape', 'Tomatoes'],
#  ['Danimals', 'Swingin', 'Strawberry', 'Banana', 'Smoothie'],
#  ['Banana'],
#  ['Red', 'Delicious', 'Apple'],
#  ['Yuba', 'Tofu', 'Skin'],
#  ['Organic', 'Firm', 'Tofu'],
#  ['Frozen', 'Organic', 'Blueberries'],
#  ['Dairy', 'Free', 'Cheddar', 'Style', 'Wedges'],
#  ['2', 'Reduced', 'Fat', 'Milk'],
#  ['Butter', 'Top', 'White', 'Bread'],
#  ['Banana'],
#  ['Iceberg', 'Lettuce'],
#  ['Broccoli', 'Florets'],
#  ['Large', 'Grade', 'AA', 'Eggs'],
#  ['Provolone', 'Slices'],
#  ['Vine', 'Ripe', 'Tomatoes'],
#  ['Boneless', 'And', 'Skinless', 'Chicken', 'Breast'],
#  ['Deli',
#   'Fresh',
#   'Honey',
#   'Smoked',
#   'Turkey',
#   'Breast',
#   '98',
#   'Fat',
#   'Free',
#   'Gluten',
#   'Free'],
#  ['Presliced', 'Everything', 'Bagels'],
#  ['Cream', 'Cheese'],
#  ['Asparagus'],
#  ['Organic', 'Baby', 'Spinach', 'Salad'],
#  ['Red', 'Leaf', 'Lettuce'],
#  ['Potato', 'Yukon', 'Gold', 'Organic'],
#  ['White', 'Corn'],
#  ['Organic', 'Avocado'],
#  ['Gluten',
#   'Free',
#   'Supergrain',
#   'Pasta',
#   'Organic',
#   'Corn',
#   'Quinoa',
#   'Blend',
#   'Penne'],
#  ['Gluten', 'and', 'Dairy', 'Free', 'Sonoma', 'Veggie', 'Burger'],
#  ['Organic', 'Three', 'Grain', 'Tempeh'],
#  ['Lime'],
#  ['Organic', 'Red', 'Onion'],
#  ['Dairy', 'Free', 'Chive', 'Cream', 'Cheese'],
#  ['Healthy', 'Organic', 'Vinaigrette'],
#  ['Strawberry', 'Lemonade', 'Frozen', 'Pops'],
#  ['Mint', 'Chocolate', 'Cookie', 'Ice', 'Cream'],
#  ['Half', 'Baked', 'Ice', 'Cream'],
#  ['Steamfresh', 'Lightly', 'Sauced', 'Broccoli', 'With', 'Cheese', 'Sauce'],
#  ['Delights',
#   'Turkey',
#   'Sausage',
#   'Egg',
#   'Whites',
#   'Cheese',
#   'English',
#   'Muffin'],
#  ['Ultra', 'Thin', 'Sliced', 'Provolone', 'Cheese'],
#  ['Cheese', 'Shredded', 'Mozzarella', 'Reduced', 'Fat', '2'],
#  ['All', 'Whites', '100', 'Egg', 'Whites'],
#  ['Smok', 'Cured', 'Turkey', 'Bacon'],
#  ['Shredded', 'Hash', 'Browns'],
#  ['Craveables', 'Four', 'Cheese', 'Pizza'],
#  ['Macaroni', 'and', 'Cheese'],
#  ['Natural', 'Muenster', 'Cheese'],
#  ['Baby', 'Cut', 'Carrots'],
#  ['Organic', 'Unsweetened', 'Almond', 'Milk'],
#  ['Banana'],
#  ['Red', 'Grapefruit'],
#  ['Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Organic', 'Egg', 'Whites'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Berry', 'Medley'],
#  ['Organic', 'Avocado'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Low', 'Fat', 'Vanilla', 'Yogurt'],
#  ['Lemon', 'Hummus'],
#  ['Roasted', 'Red', 'Pepper', 'Hummus'],
#  ['Organic', 'Low', 'Sodium', 'Vegetable', 'Broth'],
#  ['Organic', 'Avocado'],
#  ['Carrots'],
#  ['Organic', 'Sour', 'Cream'],
#  ['Green', 'Bell', 'Pepper'],
#  ['Organic', 'No', 'Salt', 'Added', 'Diced', 'Tomatoes'],
#  ['No', 'Salt', 'Added', 'Black', 'Beans'],
#  ['Firm', 'Tofu'],
#  ['Organic', 'Eggplant'],
#  ['Organic', 'Marinara', 'Pasta', 'Sauce'],
#  ['Michigan', 'Organic', 'Kale'],
#  ['Organic', 'Bunch', 'Beets'],
#  ['Feta', 'Cheese', 'Crumbles'],
#  ['Pasta', 'Joy', 'Ready', 'Organic', 'Brown', 'Rice', 'Pasta', 'Penne'],
#  ['3', 'lb', 'Clementines'],
#  ['Organic', 'Whole', 'Strawberries'],
#  ['Organic', 'Mango', 'Chunks'],
#  ['Teriyaki', 'Veggie', 'Burgers'],
#  ['Organic', 'Tomato', 'Cluster'],
#  ['Coconut', 'Sugar', 'Pure', 'Unrefined'],
#  ['Almond', 'Meal', 'Flour'],
#  ['Salted', 'Butter'],
#  ['Cream', 'Cheese'],
#  ['Air', 'Chilled', 'Organic', 'Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Organic', 'D', 'Anjou', 'Pears'],
#  ['Cultured', 'Low', 'Fat', 'Buttermilk'],
#  ['Large', 'Lemon'],
#  ['Organic', 'Strawberry', 'Fruit', 'Spread'],
#  ['Large', 'Greenhouse', 'Tomato'],
#  ['Original', 'Semisoft', 'Cheese'],
#  ['Whole', 'Organic', 'Omega', '3', 'Milk'],
#  ['Organic', 'Heavy', 'Whipping', 'Cream'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['1', 'Lowfat', 'Milk'],
#  ['Organic',
#   'Whole',
#   'Milk',
#   'Strawberry',
#   'Beet',
#   'Berry',
#   'Yogurt',
#   'Pouch'],
#  ['Organic', 'Black', 'Plum'],
#  ['Organic', 'Red', 'Delicious', 'Apple'],
#  ['Raspberries'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Baby', 'Cucumbers'],
#  ['Sinfully', 'Sweet', 'Campari', 'Tomatoes'],
#  ['Mango', 'Chunks'],
#  ['Organic', 'Unsweetened', 'Soy', 'Milk', 'Beverage'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Organic', 'Cilantro'],
#  ['Seedless', 'Red', 'Grapes'],
#  ['Heirloom', 'Tomato'],
#  ['Organic', 'Whole', 'Grain', 'Sprouted', 'Quinoa'],
#  ['Uncured', 'No', 'Sugar', 'Hickory', 'Smoked', 'Bacon'],
#  ['Organic', 'Vidalia', 'Onion'],
#  ['Organic', 'Lactose', 'Free', '1', 'Lowfat', 'Milk'],
#  ['Lactose', 'Free', 'Grade', 'A', 'Low', 'Fat', 'Vanilla', 'Yogurt'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Broccoli', 'Florets'],
#  ['Organic', 'Bread', 'with', '21', 'Whole', 'Grains'],
#  ['Organic', 'Mixed', 'Vegetables'],
#  ['Cucumber', 'Kirby'],
#  ['Seedless', 'Red', 'Grapes'],
#  ['Clementines', 'Bag'],
#  ['Gluten', 'Free', 'Mushroom', 'Risotto', 'Bowl'],
#  ['Organic', 'Olive', 'Oil', 'Spray'],
#  ['Baby', 'Swiss', 'Slices', 'Cheese'],
#  ['Gourmet', 'Mochi', 'Ice', 'Cream', 'Vanilla', 'Bonbons'],
#  ['Original', 'Recipe', 'Rice', 'Pudding'],
#  ['Bunny', 'Luv', 'Organic', 'Carrots'],
#  ['Cranberry', 'Almond', 'Chicken', 'Salad'],
#  ['Organic', 'Garnet', 'Sweet', 'Potato', 'Yam'],
#  ['Yellow', 'Onions'],
#  ['Organic', 'Fuji', 'Apple'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Sliced', 'Genoa', 'Salami'],
#  ['Organic', '1', 'Low', 'Fat', 'Milk'],
#  ['Macaroni', 'Cheese'],
#  ['Chocolate', 'Milk', '1', 'Milkfat'],
#  ['Uncured', 'Genoa', 'Salami'],
#  ['All', 'Natural', 'Seasoned', 'Waffle', 'Cut', 'Fries'],
#  ['Unsweetened', 'Vanilla', 'Almond', 'Breeze'],
#  ['Pure', 'Irish', 'Butter'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Mozzarella',
#   'Light',
#   'Low',
#   'Moisture',
#   'Part',
#   'Skim',
#   'String',
#   'Cheese'],
#  ['White', 'Cheddar', 'Semisoft', 'Cheese'],
#  ['Lowfat', '2', 'Milkfat', 'Cottage', 'Cheese'],
#  ['Black', 'Seedless', 'Grapes'],
#  ['Sausage', 'Biscuit'],
#  ['Cereal'],
#  ['Breaded', 'Chicken', 'Breast', 'Tenders'],
#  ['Honey', 'Roasted', 'Turkey'],
#  ['Clover', 'Honey', 'Bear'],
#  ['French', 'Onion', 'Dip'],
#  ['Chicken', 'Pot', 'Pie'],
#  ['Eggo', 'Nutri', 'Grain', 'Blueberry', 'Waffles'],
#  ['Presliced', 'Everything', 'Bagels'],
#  ['Organic', 'Yams'],
#  ['Flour', 'Tortillas'],
#  ['Light', 'Sour', 'Cream'],
#  ['Simply', '100', 'Blueberry', 'Blended', 'Non', 'Fat', 'Greek', 'Yogurt'],
#  ['Simply', '100', 'Strawberry', 'Blended', 'Non', 'Fat', 'Greek', 'Yogurt'],
#  ['90', 'Calories', 'Low', 'Fat', 'Chocolate', 'Chunk', 'Granola', 'Bars'],
#  ['Reduced', 'Fat', 'Sliced', 'Provolone', 'Cheese'],
#  ['Deli', 'Select', 'Ultra', 'Thin', 'Honey', 'Ham'],
#  ['Cafe', 'Steamers', 'General', 'Tso', 's', 'Spicy', 'Chicken'],
#  ['Chicken', 'Marsala'],
#  ['100', 'Whole', 'Wheat', 'Bread'],
#  ['Original'],
#  ['Thick', 'N', 'Creamy', 'Macaroni', 'Cheese'],
#  ['Strawberries'],
#  ['Organic', 'Blueberries'],
#  ['Raspberries'],
#  ['Beef', 'Franks'],
#  ['Golden', 'Pineapple'],
#  ['Organic', 'Chicken', 'Bone', 'Broth'],
#  ['Yo', 'Baby', 'Organic', 'Whole', 'Milk', 'Banana', 'Mango', 'Yogurt'],
#  ['YoKids', 'Squeezers', 'Organic', 'Low', 'Fat', 'Yogurt', 'Strawberry'],
#  ['Low', 'Sodium', 'Beef', 'Broth'],
#  ['Organic', 'Unrefined', 'Toasted', 'Sesame', 'Oil'],
#  ['Gluten', 'Free', 'Chicken', 'Nuggets'],
#  ['Original', 'Barbeque', 'Sauce'],
#  ['Milk', 'Vitamin', 'D'],
#  ['Organic', 'Blueberry'],
#  ['Bananas'],
#  ['Original', 'Pure', 'Creamy', 'Almond', 'Milk'],
#  ['Pure', 'Granulated', 'Cane', 'Sugar'],
#  ['Mango', 'Yoghurt'],
#  ['Peach', 'Yoghurt'],
#  ['All', 'Natural', 'Gluten', 'Free', 'Probiotic', 'Pineapple', 'Yoghurt'],
#  ['Organic', 'Fresh', 'Basil'],
#  ['Shredded', 'Parmesan'],
#  ['French', 'Vanilla', 'Ice', 'Cream'],
#  ['Artesano', 'Style', 'Bread'],
#  ['Milk', 'Whole'],
#  ['Baby', 'Dynamic', 'Duo', 'Potatoes'],
#  ['Living', 'Potted', 'Rosemary'],
#  ['Yellow', 'Straightneck', 'Squash'],
#  ['Acorn', 'Squash'],
#  ['Organic', 'Extra', 'Virgin', 'Olive', 'Oil'],
#  ['Apple', 'Cider', 'Vinegar'],
#  ['Banana'],
#  ['Gala', 'Apples'],
#  ['Cucumber', 'Kirby'],
#  ['Cinnamon', 'Raisin', 'Granola'],
#  ['Banana'],
#  ['Organic', 'Gala', 'Apples'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Sprouted', 'Multi', 'Grain', 'Bread'],
#  ['Organic', 'Original', 'Tofu', 'Veggie', 'Burger'],
#  ['Sweet', 'Baguette'],
#  ['Organic', 'Grape', 'Tomatoes'],
#  ['Organic', 'Lemon'],
#  ['Yo', 'Baby', 'Organic', 'Whole', 'Milk', 'Banana', 'Mango', 'Yogurt'],
#  ['Organic', 'Traditional', 'Flour', 'Tortillas'],
#  ['Organic', 'Blueberries'],
#  ['Organic', 'Raw', 'Sharp', 'Cheddar', 'Cheese'],
#  ['Large', 'Lemon'],
#  ['Burrata'],
#  ['Instant', 'French', 'Vanilla', 'Pudding', 'Pie', 'Filling'],
#  ['Banana'],
#  ['Mixed', 'Berries', 'Wildly', 'Nutritious', 'Signature', 'Blends'],
#  ['Original', 'Whipped', 'Topping'],
#  ['Philadelphia', 'Original', 'Cream', 'Cheese'],
#  ['Sliced', 'Peaches'],
#  ['Unsalted', 'Butter'],
#  ['Semi', 'Sweet', 'Chocolate', 'Premium', 'Baking', 'Chips'],
#  ['Total', '2', 'Lowfat', 'Plain', 'Greek', 'Yogurt'],
#  ['Organic', 'Lemon'],
#  ['Organic', 'Raspberries'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Roasted', 'Mushroom', 'Pizza'],
#  ['Italian', 'Sausage', 'Pizza'],
#  ['Organic', 'Cucumber'],
#  ['Organic', 'Red', 'Onion'],
#  ['Spaghetti'],
#  ['Large', 'Alfresco', 'Eggs'],
#  ['Organic', 'Spinach', 'Bunch'],
#  ['Blood', 'Oranges'],
#  ['Organic', '21', 'Grain', 'Thin', 'Sliced', 'Bread'],
#  ['Organic', 'Butterhead', 'Boston', 'Butter', 'Bibb', 'Lettuce'],
#  ['Organic', 'Tomato', 'Cluster'],
#  ['Organic', 'Large', 'Green', 'Asparagus'],
#  ['Organic', 'Braeburn', 'Apple'],
#  ['Organic', 'Tomato', 'Paste'],
#  ['Shredded', 'Parmesan'],
#  ['Organic', 'Garlic'],
#  ['Large', 'Alfresco', 'Eggs'],
#  ['Blueberries'],
#  ['Buttermilk', 'Biscuits'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Coconut', 'Almond', 'Creamer', 'Blend'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Organic', 'Strawberries'],
#  ['Organic', 'Bartlett', 'Pear'],
#  ['Organic', 'Large', 'Extra', 'Fancy', 'Fuji', 'Apple'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Authentic', 'French', 'Brioche'],
#  ['Marinara', 'Sauce'],
#  ['Organic', 'Original', 'Hommus'],
#  ['Organic', 'D', 'Anjou', 'Pears'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Blackberries'],
#  ['Organic', 'Baby', 'Carrots'],
#  ['Organic', 'Australian', 'Style', 'Vanilla', 'Lowfat', 'Yogurt'],
#  ['Tomato', 'Sauce'],
#  ['Milk', 'Vitamin', 'D'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Gala', 'Apples'],
#  ['Organic', 'Raspberries'],
#  ['Organic', 'Honeydew'],
#  ['Organic', 'Green', 'Seedless', 'Grapes'],
#  ['Muffins', 'Mini', 'Flax', 'Chocolate', 'Brownie'],
#  ['Organic', 'Whole', 'Wheat', 'Bread'],
#  ['Organic', 'Shredded', 'Mild', 'Cheddar'],
#  ['Skim', 'Milk'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Diced', 'Tomatoes'],
#  ['Carrots'],
#  ['Organic', 'Roasted', 'Turkey', 'Breast'],
#  ['Organic', 'Spring', 'Mix', 'Salad'],
#  ['Organic', 'Baby', 'Carrots'],
#  ['Premium', 'Grapefruit', 'Large'],
#  ['Frozen', 'Organic', 'Blueberries'],
#  ['Dairy', 'Free', 'Unsweetened', 'Coconut', 'Milk'],
#  ['Original', 'Almondmilk'],
#  ['with', 'Crispy', 'Almonds', 'Cereal'],
#  ['Organic', 'Low', 'Fat', 'Milk'],
#  ['Half', 'And', 'Half', 'Cream'],
#  ['Non', 'Fat', 'Greek', 'Yogurt'],
#  ['0', 'Greek', 'Strained', 'Yogurt'],
#  ['Clementines'],
#  ['Tilapia', 'Filet'],
#  ['Organic', 'Lactose', 'Free', 'Whole', 'Milk'],
#  ['XL', 'Emerald', 'White', 'Seedless', 'Grapes'],
#  ['Limes'],
#  ['Organic', 'Avocado'],
#  ['No', 'Salt', 'Added', 'Black', 'Beans'],
#  ['Jalapeno', 'Peppers'],
#  ['Wild', 'Blend', 'Rice'],
#  ['Reduced', 'fat', 'Soft', 'Cream', 'Cheese'],
#  ['Garlic', 'Powder'],
#  ['Whole', 'Grain', 'Oatmeal', 'Bread'],
#  ['Steamfresh', 'Selects', 'Frozen', 'Broccoli', 'Cauliflower', 'Carrots'],
#  ['Steamfresh', 'Premium', 'Selects', 'Frozen', 'Whole', 'Green', 'Beans'],
#  ['Boneless', 'Skinless', 'Chicken', 'Breast'],
#  ['Turkey'],
#  ['Red', 'Bell', 'Pepper'],
#  ['Red', 'Potatoes'],
#  ['Half', 'And', 'Half', 'Ultra', 'Pasteurized'],
#  ['Smoothies', 'Strawberries', 'Wild'],
#  ['Organic', '1', 'Lowfat', 'Milk'],
#  ['Organic', '2', 'Reduced', 'Fat', 'Milk'],
#  ['Soy', 'Sauce'],
#  ['All', 'Natural', 'Marinara', 'Pasta', 'Sauce'],
#  ['Organic', 'Reduced', 'Fat', 'Milk'],
#  ['Roman', 'Raspberry', 'Sorbetto'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Plain', 'Greek', 'Yogurt'],
#  ['Maple', 'Glazed', 'Honey', 'Ham'],
#  ['Organic', 'Grade', 'A', 'Large', 'Brown', 'Eggs'],
#  ['Cherry', 'Garcia', 'Ice', 'Cream'],
#  ['Prosciutto'],
#  ['Gourmet', 'Tomato', 'Medley'],
#  ['Granny', 'Smith', 'Apples'],
#  ['Ginger', 'Dressing'],
#  ['Non', 'Fat', 'Greek', 'Yogurt'],
#  ['Blackberries'],
#  ['Organic', 'Whole', 'Milk'],
#  ['Chocolate', 'Peanut', 'Butter', 'Cup', 'Gelato'],
#  ['Carrot', 'Raisin', 'Flax', 'Muffins'],
#  ['Hass', 'Avocados'],
#  ['Organic', 'Romaine', 'Leaf'],
#  ['100', 'Whole', 'Wheat', 'Hot', 'Dog', 'Buns'],
#  ['Organic', 'Quinoa', 'Brown', 'Rice', 'With', 'Garlic'],
#  ['Organic', 'Greek', 'Whole', 'Milk', 'Blended', 'Vanilla', 'Bean', 'Yogurt'],
#  ['Boneless', 'Chicken', 'Breast'],
#  ['Tilapia', 'Filet'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Organic', 'Crushed', 'Fire', 'Roasted', 'Tomatoes'],
#  ['Organic', 'Lemon'],
#  ['Fresh', 'Ginger', 'Root'],
#  ['Organic', 'Cilantro'],
#  ['Limes'],
#  ['Organic', 'Fuji', 'Apple'],
#  ['Toasted', 'Coconut', 'Almondmilk', 'Blend'],
#  ['Forelle', 'Pears'],
#  ['Original', 'Traditional', 'Dijon', 'Mustard'],
#  ['Baby', 'Boomer', 'Fresh', 'Creamer', 'Potatoes'],
#  ['Vegan', 'Buttery', 'Sticks'],
#  ['Banana'],
#  ['Squeeze', 'Real', 'Mayonnaise'],
#  ['Organic', 'Unsalted', 'Butter'],
#  ['Organic', 'Homogenized', 'Whole', 'Milk'],
#  ['Bunny', 'Luv', 'Organic', 'Carrots'],
#  ['Olive', 'Bread'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Organic', 'Ginger', 'Root'],
#  ['Organic', 'Chicken', 'Bone', 'Broth'],
#  ['Organic', 'Low', 'Sodium', 'Chicken', 'Cooking', 'Stock'],
#  ['Original', 'Soy', 'Creamer'],
#  ['Liquid', 'Egg', 'Whites'],
#  ['Americone', 'Dream', 'Ice', 'Cream'],
#  ['Rosemary', 'Ham'],
#  ['Organic', 'Mayonnaise'],
#  ['Organic', 'Sunday', 'Bacon'],
#  ['Organic', 'Beefsteak', 'Tomato'],
#  ['Organic', 'Roma', 'Tomato'],
#  ['Organic', 'Plain', 'Greek', 'Whole', 'Milk', 'Yogurt'],
#  ['Mint', 'Chip'],
#  ['Organic', 'Short', 'Brown', 'Sprouted', 'Rice'],
#  ['Organic', 'Blueberries'],
#  ['Organic', 'Baby', 'Arugula'],
#  ['Hass', 'Avocados'],
#  ['Sinfully', 'Sweet', 'Campari', 'Tomatoes'],
#  ['Four', 'Cheese', 'Thin', 'Crust', 'Pizza'],
#  ['Dark', 'Chocolate', 'Covered', 'Banana'],
#  ['Grated', 'Parmesan', 'Cheese'],
#  ['Roasted', 'Red', 'Pepper', 'Hummus'],
#  ['Imported', 'Capote', 'Capers'],
#  ['Roasted', 'Garlic', 'Loaf'],
#  ['Seedless', 'Watermelon'],
#  ['Fresh', 'Sugar', 'Snap', 'Peas'],
#  ['Grape', 'Tomatoes'],
#  ['Mini', 'Sweet', 'Peppers'],
#  ['Organic', 'Gluten', 'Free', 'Maple', 'Buckwheat', 'Flakes'],
#  ['Organic', 'Vanilla', 'Soymilk'],
#  ['Red', 'Peppers'],
#  ['Yellow', 'Bell', 'Pepper'],
#  ['Apple', 'Honeycrisp', 'Organic'],
#  ['Red', 'Vine', 'Tomato'],
#  ['Large', 'Lemon'],
#  ['Orange', 'Bell', 'Pepper'],
#  ['Beyond', 'Beef', 'Beefy', 'Crumble'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Cucumber'],
#  ['California', 'Sourdough', 'Bread'],
#  ['Hummus', 'Hope', 'Original', 'Recipe'],
#  ['Seven', 'Grain', 'Crispy', 'Tenders'],
#  ['Organic', 'Tomato', 'Basil', 'Pasta', 'Sauce'],
#  ['Marinara', 'Pasta', 'Sauce'],
#  ['Organic', 'Extra', 'Large', 'Grade', 'AA', 'Brown', 'Eggs'],
#  ['Veggie', 'Burger', 'Quarter', 'Pound'],
#  ['Fat', 'Free', 'Skim', 'Milk'],
#  ['Fresh', 'Mozzarella', 'All', 'Natural', 'Sliced', 'Cheese'],
#  ['Roasted', 'Pine', 'Nut', 'Hummus'],
#  ['Strawberries'],
#  ['Whole', 'Milk'],
#  ['Bag', 'of', 'Oranges'],
#  ['Organic',
#   'Yokids',
#   'Lemonade',
#   'Blueberry',
#   'Variety',
#   'Pack',
#   'Yogurt',
#   'Squeezers',
#   'Tubes'],
#  ['Organic', 'Whole', 'Milk'],
#  ['Banana'],
#  ['Sour', 'Cream'],
#  ['Yellow', 'Bell', 'Pepper'],
#  ['Organic', 'Blackberries'],
#  ['Organic', 'Baby', 'Spinach', 'Salad'],
#  ['Sliced', 'Baby', 'Bella', 'Mushrooms'],
#  ['Unsweetened', 'Almondmilk'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Organic', 'Acorn', 'Squash'],
#  ['Canary', 'Melon'],
#  ['Organic', 'English', 'Cucumber'],
#  ['Organic', 'Strawberries'],
#  ['Organic', 'Kiwi'],
#  ['Fancy', 'Whole', 'Artichoke', 'Hearts'],
#  ['Brussels', 'Sprouts'],
#  ['Reduced', 'Fat', 'Milk', '2'],
#  ['Premium', 'Traditional', 'Homestyle', 'Cream', 'Style', 'Corn'],
#  ['Organic', 'Whole', 'Kernel', 'Sweet', 'Corn', 'No', 'Salt', 'Added'],
#  ['Mild', 'Diced', 'Green', 'Chiles'],
#  ['Organic', 'Beef', 'Uncured', 'Hot', 'Dogs'],
#  ['Strawberries'],
#  ['Organic', 'Gala', 'Apples'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Sunrise', 'Crunchy', 'Cinnamon', 'Cereal'],
#  ['Organic', 'Vanilla', 'Almond', 'Milk'],
#  ['Large', 'Pineapple', 'Chunks'],
#  ['Light', 'Lean', 'Sweet', 'Sour', 'Asian', 'Noodle', 'Pasta'],
#  ['Light', 'Lean', 'Black', 'Bean', 'and', 'Cheese', 'Enchilada'],
#  ['Light', 'and', 'Lean', '3', 'Cheese', 'Penne', 'Marinara'],
#  ['Raspberries'],
#  ['Cheese', 'Ravioli'],
#  ['Yellow', 'Onions'],
#  ['Original', 'BBQ', 'Sauce'],
#  ['Organic', 'Milk'],
#  ['Ancient', 'Grain', 'Blueberry', 'Hemp', 'Granola'],
#  ['Bunched', 'Cilantro'],
#  ['Organic', 'Mint'],
#  ['Mango', 'Coconut', 'Chia', 'Squeeze'],
#  ['Tomatoes', 'Crushed', 'Organic'],
#  ['Strawberries'],
#  ['Green', 'Seedless', 'Grapes'],
#  ['Red', 'Globe', 'Grapes'],
#  ['Mini', 'Marshmallows'],
#  ['Dha', 'Omega', '3', 'Vitamin', 'D', 'Milk'],
#  ['Organic', 'Whole', 'Grain', 'Wheat', 'English', 'Muffins'],
#  ['Strawberries'],
#  ['Lite', 'Salt'],
#  ['Chopped', 'Green', 'Chiles'],
#  ['Turkey', 'Store', 'Lean', 'Ground', 'Turkey'],
#  ['Leafy', 'Green', 'Romaine', 'Lettuce'],
#  ['Honey', 'Mustard', 'Dressing', 'Topping', 'Spread'],
#  ['Organic', 'Baby', 'Arugula'],
#  ['Half', 'And', 'Half'],
#  ['Large', 'Lemon'],
#  ['Organic', 'Strawberry', 'Smoothie'],
#  ['Total',
#   '2',
#   'All',
#   'Natural',
#   'Greek',
#   'Strained',
#   'Yogurt',
#   'with',
#   'Honey'],
#  ['Banana'],
#  ['Organic', 'Strawberries'],
#  ['Organic', 'Peeled', 'Whole', 'Baby', 'Carrots'],
#  ['Garlic', 'Hummus'],
#  ['Penne', 'Rigate', '41', 'Pasta'],
#  ['Organic', 'Avocado'],
#  ['Low', 'Fat', 'Vanilla', 'Yogurt'],
#  ['Smoked', 'Turkey', 'Breast', 'Slices'],
#  ['Organic', 'Grade', 'A', 'Large', 'Brown', 'Eggs'],
#  ['Original', 'Semisoft', 'Cheese'],
#  ['Mango', 'Chunks'],
#  ['Atlantic', 'Salmon', 'Fillets'],
#  ['Cucumber', 'Kirby'],
#  ['Baby', 'Seedless', 'Cucumbers'],
#  ['Asparation', 'Broccolini', 'Baby', 'Broccoli'],
#  ['Iceberg', 'Lettuce'],
#  ['Carrots'],
#  ['Organic', 'Lemon'],
#  ['Artichokes'],
#  ['Ataulfo', 'Mango'],
#  ['Organic', 'Baby', 'Carrots'],
#  ['Crescent', 'Rolls'],
#  ['Organic', 'Diced', 'Tomatoes'],
#  ['Organic', 'Tomato', 'Sauce'],
#  ['Organic', 'Whole', 'Peeled', 'Tomatoes'],
#  ['Organic', 'Celery'],
#  ['Organic', 'Shredded', 'Unsweetened', 'Coconut'],
#  ['Lightly', 'Breaded', 'Fish', 'Sticks'],
#  ['Smoked', 'Maple', 'Ham'],
#  ['Organic', 'Avocados'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Wild', 'Berry', 'Smoothie'],
#  ['Organic', 'Jasmine', 'Rice'],
#  ['Organic',
#   'Toaster',
#   'Pastries',
#   'Frosted',
#   'Lotta',
#   'Chocolotta',
#   '6',
#   'CT'],
#  ['Organic', 'Beef', 'Hot', 'Dogs'],
#  ['Coconut', 'Aminos', 'Teriyaki', 'Sauce'],
#  ['Buttermilk', 'Biscuits'],
#  ['Organic', 'Vanilla', 'Almond', 'Milk'],
#  ['Organic', 'Yellow', 'Mustard'],
#  ['Gluten', 'Free', 'Hamburger', 'Buns'],
#  ['Organic', 'Beefsteak', 'Tomato'],
#  ['Chopped', 'Onions'],
#  ['Medium', 'Salsa', 'Organica'],
#  ['Organic', 'Hass', 'Avocado', 'Bag'],
#  ['Organic', 'Kiwi'],
#  ['Organic', 'Strawberries'],
#  ['Banana'],
#  ['Organic', 'Blackberries'],
#  ['Organic', 'Half', 'Half'],
#  ['Organic', 'Turkey', 'Bacon'],
#  ['Taco', 'Seasoning', 'Mix', 'Original'],
#  ['Sweetened', 'Corn', 'Oat', 'Cereal'],
#  ['Crunchy', 'Taco', 'Shells'],
#  ['2', 'Reduced', 'Fat', 'Milk'],
#  ['French', 'Vanilla', 'Creamer'],
#  ['Pure', 'Natural', 'Sour', 'Cream'],
#  ['37', 'Less', 'Sodium', 'Soy', 'Sauce'],
#  ['Gala', 'Apples'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Roma', 'Tomato'],
#  ['Delifresh',
#   'Combos',
#   'The',
#   'Honey',
#   'Smoked',
#   'Turkey',
#   'Breast',
#   'Honey',
#   'Ham'],
#  ['Large', 'Alfresco', 'Eggs'],
#  ['Frozen', 'Organic', 'Wild', 'Blueberries'],
#  ['Purity', 'Farms', 'Ghee', 'Clarified', 'Butter'],
#  ['Wild', 'Sockeye', 'Salmon'],
#  ['Boneless', 'Skinless', 'Wild', 'Alaskan', 'Sockeye', 'Salmon'],
#  ['Organic', 'Whole', 'String', 'Cheese'],
#  ['Organic', 'Free', 'Range', 'Large', 'Grade', 'A', 'Brown', 'Eggs'],
#  ['Organic', 'Kiwi'],
#  ['Plain', 'Goat', 'Milk', 'Yogurt'],
#  ['Organic', 'Strawberries'],
#  ['Hickory', 'Smoked', 'Ham'],
#  ['Organic', 'Avocado'],
#  ['Organic', 'Muenster', 'Cheese'],
#  ['Cucumber', 'Kirby'],
#  ['Natural', 'Chicken', 'Maple', 'Breakfast', 'Sausage', 'Patty'],
#  ['Chicken', 'Maple', 'Breakfast', 'Sausage'],
#  ['YoKids', 'Squeezers', 'Organic', 'Low', 'Fat', 'Yogurt', 'Strawberry'],
#  ['Chocolate', 'Chip', 'Cookie', 'Dough', 'Ice', 'Cream'],
#  ['Organic', 'YoKids', 'Smoothie', 'Strawberry', 'Banana', 'Lowfat', 'Yogurt'],
#  ['Half', 'Baked', 'Ice', 'Cream'],
#  ['Bunny', 'Pasta', 'with', 'Yummy', 'Cheese', 'Macaroni', 'Cheese'],
#  ['Chicken', 'Apple', 'Sausage', 'Egg', 'White', 'Breakfast', 'Burrito'],
#  ['Icelandic', 'Style', 'Skyr', 'Blueberry', 'Non', 'fat', 'Yogurt'],
#  ['Organic',
#   'Yokids',
#   'Lemonade',
#   'Blueberry',
#   'Variety',
#   'Pack',
#   'Yogurt',
#   'Squeezers',
#   'Tubes'],
#  ['Uncured', 'Slow', 'Cooked', 'Ham'],
#  ['Peanut', 'Butter', 'Whole', 'Grain', 'Clusters'],
#  ['Condensed', 'Cream', 'of', 'Mushroom', 'Soup'],
#  ['No', 'Sugar', 'Added', 'Variety', 'Fruit', 'Bars'],
#  ['Bagel', 'Thins', 'Everything'],
#  ['Hazelnut', 'Spread', 'With', 'Skim', 'Milk', 'Cocoa'],
#  ['White', 'Distilled', 'Vinegar'],
#  ['YoKids', 'Blueberry', 'Strawberry', 'Vanilla', 'Yogurt'],
#  ['Hearty', 'Style', '100', 'Whole', 'Grain', 'Whole', 'Wheat', 'Bread'],
#  ['Uncured', 'Beef', 'Hot', 'Dogs'],
#  ['Fully', 'Cooked', 'Maple', 'Sausages', '10', 'Count'],
#  ['Cream', 'Cheese', 'Cream', 'Cheese', 'Spread'],
#  ['Tamari', 'Gluten', 'Free', 'Soy', 'Sauce', 'Reduced', 'Sodium'],
#  ['Vidalia', 'Onion', 'and', 'Cilantro', 'Dressing', 'Marinade'],
#  ['Mini', 'Cucumbers'],
#  ['Organic', 'Fresh', 'Carrot', 'Chips'],
#  ['Toasted', 'Coconut', 'Almondmilk', 'Blend'],
#  ['Organic', 'Baby', 'Arugula'],
#  ['Flat', 'Fillets', 'of', 'Anchovies'],
#  ['Organic', 'Whole', 'Wheat', 'Fusilli'],
#  ['Large', 'Lemon'],
#  ['Roma', 'Tomato'],
#  ['Natural', 'Black', 'Cherry', 'Gels', 'Gelatin', 'Free', 'Snacks'],
#  ['Organic', 'Raspberries'],
#  ['Organic', 'Romaine'],
#  ['Fresh', 'Cauliflower'],
#  ['Organic', 'Avocados', 'Hass', 'Variety'],
#  ['Thick', 'Chunky', 'Salsa'],
#  ['Kale', 'Greens'],
#  ['Brown', 'Rice', 'Pasta', 'Spirals'],
#  ['Oven', 'Roasted', 'Turkey'],
#  ['Total', '0', 'Raspberry', 'Yogurt'],
#  ['Organic', 'Blackberries'],
#  ['Watermelon', 'Chunks'],
#  ['Chocolate', 'Chip', 'Cookie', 'Dough', 'Ice', 'Cream'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Real', 'Aged', 'Cheddar', 'Macaroni', 'Cheese'],
#  ['YoKids', 'Squeezers', 'Organic', 'Low', 'Fat', 'Yogurt', 'Strawberry'],
#  ['Seedless', 'Red', 'Grapes'],
#  ['Organic', 'Fuji', 'Apple'],
#  ['Organic', 'AppleApple'],
#  ['Whole', 'Milk', 'With', 'Vitamin', 'D'],
#  ['Whole', 'Milk'],
#  ['Cage', 'Free', 'Large', 'White', 'Eggs'],
#  ['Whole', 'Milk'],
#  ['Extra', 'Large', 'Grade', 'A', 'Eggs'],
#  ['Original', 'Slices', 'Pepperoni'],
#  ['Original', 'Breakfast', 'Sausage', 'Links'],
#  ['Hot', 'Italian', 'Sausage'],
#  ['Chocolate', 'Chip', 'Cookie', 'Dough'],
#  ['Sesame', 'Topped', 'Hamburger', 'Buns'],
#  ['Natural', 'Muenster', 'Cheese'],
#  ['Unsweetened', 'Original', 'Almond', 'Breeze', 'Almond', 'Milk'],
#  ['Chocolate', 'Peanut', 'Butter', 'Ice', 'Cream'],
#  ['Red', 'Peppers'],
#  ['Macaroni', 'Cheese', 'Dinner', 'Original', 'Flavor'],
#  ['Rice', 'Sides', 'Chicken', 'Flavor'],
#  ['Penne', 'Pasta'],
#  ['Grands', 'Southern', 'Homestyle', 'Biscuit'],
#  ['Green', 'Bell', 'Pepper'],
#  ['Pasta', 'Sides', 'Butter', 'Flavor', 'Fettuccini'],
#  ['Rice', 'Sides', 'Chicken', 'Flavor', 'Broccoli'],
#  ['Organic', 'Seasoned', 'Yukon', 'Select', 'Potatoes', 'Hashed', 'Browns'],
#  ['Baby', 'Boomer', 'Fresh', 'Creamer', 'Potatoes'],
#  ['Pasta', 'Sides', 'Chicken', 'Flavor'],
#  ['Signature', 'Recipes', 'Vodka', 'Sauce', 'Pasta', 'Sauce'],
#  ['Pasta', 'Sauce', 'Original', 'Traditional'],
#  ['Mild', 'Diced', 'Tomatoes', 'Green', 'Chilies'],
#  ['Sweet', 'Onions'],
#  ['Shoestrings', 'French', 'Fried', 'Potatoes'],
#  ['Jalapeno', 'Peppers'],
#  ['Spicy', 'Brown', 'Mustard'],
#  ['Organic', 'Red', 'Chard', 'Greens'],
#  ['Organic', 'Cucumber'],
#  ['Organic', 'Lactose', 'Free', 'Whole', 'Milk'],
#  ['Creamy', 'Peanut', 'Butter'],
#  ['Organic', 'Fat', 'Free', 'Milk'],
#  ['Tomato', 'Ketchup'],
#  ['Thin', 'Sliced', 'American', 'Cheese'],
#  ['Watermelon', 'Chunks'],
#  ['Dressing', 'Marinade', 'Toasted', 'Sesame'],
#  ['Organic', 'Unsalted', 'Butter'],
#  ['Frozen', 'Organic', 'Strawberries'],
#  ['Mexican', 'Blend', 'Cheese'],
#  ['Traditional', 'Hearty', 'Chicken', 'and', 'Rotini', 'Soup'],
#  ['Rich', 'Hearty', 'Chicken', 'Homestyle', 'Noodles', 'Soup'],
#  ['Organic', 'Low', 'Sodium', 'Chunky', 'Tomato', 'Bisque', 'Soup'],
#  ['Organic', 'Blend', 'Me', 'Mixed', 'Vegetables'],
#  ['Organic', 'Light', 'in', 'Sodium', 'Lentil', 'Vegetable', 'Soup'],
#  ['Fresh', 'Donuts'],
#  ['Oven', 'Roasted', 'Turkey', 'Breast'],
#  ['Organic', 'Lemon'],
#  ['Organic', 'Unsweetened', 'Almond', 'Milk'],
#  ['Beef', 'Top', 'Round', 'Steak'],
#  ['Cotija'],
#  ['Organic', 'Red', 'Radish', 'Bunch'],
#  ['Banana'],
#  ['Organic', 'Iceberg', 'Lettuce'],
#  ['Red', 'Vine', 'Tomato'],
#  ['Jalapeno', 'Peppers'],
#  ['Strawberries'],
#  ['Roasted', 'Turkey'],
#  ['Air', 'Chilled', 'Organic', 'Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Cucumber', 'Kirby'],
#  ['Organic', 'Grade', 'A', 'Large', 'Brown', 'Eggs'],
#  ['Organic', 'Vanilla', 'Almond', 'Milk'],
#  ['Bread', 'Crumbs'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Organic', 'Nectarine'],
#  ['Russet', 'Potato'],
#  ['Baby', 'Swiss', 'Slices', 'Cheese'],
#  ['Total', '0', 'with', 'Honey', 'Nonfat', 'Greek', 'Strained', 'Yogurt'],
#  ['Homestyle', 'Ranch'],
#  ['Grade', 'A', 'Large', 'White', 'Eggs'],
#  ['American', 'Cheese', 'Slices', '12', 'Count'],
#  ['French', 'Vanilla', 'Sugar', 'Free', 'Liquid', 'Coffee', 'Creamer'],
#  ['Italian', 'Sausage', 'Pizza'],
#  ['Chicken', 'Parmesan'],
#  ['Cheese', 'Pizza', 'Snacks'],
#  ['Whole', 'Organic', 'Omega', '3', 'Milk'],
#  ['Asian', 'Salad', 'Kit'],
#  ['Vanilla', 'Soy', 'Milk'],
#  ['Marinara', 'Sauce'],
#  ['Frozen', 'Limeade', 'Concentrate'],
#  ['Original', 'New', 'Orleans', 'Style', 'Dirty', 'Rice', 'Mix'],
#  ['Cage', 'Free', 'Brown', 'Eggs', 'Large', 'Grade', 'A'],
#  ['Fresh', 'Cauliflower'],
#  ['Roasted', 'Turkey', 'Breast'],
#  ['Unsalted', 'Pure', 'Irish', 'Butter'],
#  ['Heavy', 'Whipping', 'Cream'],
#  ['Pure', 'Natural', 'Sour', 'Cream'],
#  ['Original', 'Hot', 'Sauce'],
#  ['Cream', 'Cheese'],
#  ['Organic', 'Promise', 'Berry', 'Fruitful', 'Cereal'],
#  ['Otria', 'Spinach', 'Artichoke', 'Greek', 'Yogurt', 'Veggie', 'Dip'],
#  ['Classico', 'Traditional', 'Pizza', 'Sauce'],
#  ['Light', 'Multi', 'Grain', 'English', 'Muffins'],
#  ['6', 'Cheese', 'Italian', 'Shredded', 'Cheese'],
#  ['Baby', 'Cucumbers'],
#  ['Rainbow', 'Bell', 'Peppers'],
#  ['Red', 'Seedless', 'Grapes'],
#  ['Fresh', 'Asparagus'],
#  ['Pizza', 'Dough'],
#  ['Tomato', 'Sauce'],
#  ['Organic', 'Premium', 'Tomato', 'Paste'],
#  ['Organic', 'Tomato', 'Sauce', 'No', 'Salt', 'Added'],
#  ['Red', 'Onion'],
#  ['Shredded', 'Mozzarella'],
#  ['Extra', 'Virgin', 'Olive', 'Oil'],
#  ['Pitted', 'Castelvetrano', 'Green', 'Olives'],
#  ['Berry', 'Medley'],
#  ['Organic', 'Blackberries'],
#  ['Organic', 'Fuji', 'Apple'],
#  ['Broccoli', 'Florets'],
#  ['Spinach'],
#  ['Organic', 'Mini', 'Peeled', 'Carrots'],
#  ['Light', 'Wisconsin', 'String', 'Cheese'],
#  ['Low', 'Fat', 'Cottage', 'Cheese'],
#  ['Shelled', 'Soybeans', 'Edamame'],
#  ['Cauliflower', 'Florets'],
#  ['Total', '0', 'Nonfat', 'Plain', 'Greek', 'Yogurt'],
#  ['Organic', 'Egg', 'Whites'],
#  ['Asparagus', 'Tips'],
#  ['Quick', 'Easy', 'Fresh', 'Green', 'Beans'],
#  ['Mini', 'Peppers'],
#  ['Pure', 'Cane', 'Cubes', 'Sugar'],
#  ['Original', 'Style', 'Yoghurt', 'Plain'],
#  ['Carrots'],
#  ['Organic', 'Sliced', 'Bella', 'Mushrooms'],
#  ['Organic', 'Broccoli'],
#  ['Organic', 'Whole', 'String', 'Cheese'],
#  ['Blackberry', 'Yogurt'],
#  ['The', 'Ultimate', 'Beefless', 'Burger'],
#  ['Lightly', 'Seasoned', 'Chick', 'n', 'Scallopini'],
#  ['Apple', 'Cinnamon', 'Instant', 'Oatmeal'],
#  ['Organic', 'Blackberries'],
#  ['Organic', 'Butternut', 'Squash'],
#  ['Light',
#   'and',
#   'Lean',
#   'Quinoa',
#   'Black',
#   'Beans',
#   'with',
#   'Butternut',
#   'Squash',
#   'and',
#   'Chard'],
#  ['Butternut', 'Squash', 'Ravioli'],
#  ['Organic', 'Gala', 'Apples'],
#  ['Organic', 'Cut', 'Green', 'Beans'],
#  ['Brussels', 'Sprouts'],
#  ['Rotini'],
#  ['Kale', 'Greens'],
#  ['Gluten', 'Free', 'Quiche', 'Pie', 'Crusts'],
#  ['White', 'Horseradish'],
#  ['Organic', 'Red', 'Radish', 'Bunch'],
#  ['Broccoli', 'Rabe'],
#  ['Curly', 'Parsley', 'Bunch'],
#  ['Organic', 'California', 'Style', 'Sprouted', 'Bread'],
#  ['Organic', 'Whole', 'String', 'Cheese'],
#  ['Original', 'Hummus'],
#  ['Organic', 'Extra', 'Large', 'Grade', 'AA', 'Brown', 'Eggs'],
#  ['Organic', 'Roasted', 'Turkey', 'Breast'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Half', 'Half'],
#  ['Organic', 'Peeled', 'Whole', 'Baby', 'Carrots'],
#  ['Organic', 'Small', 'Bunch', 'Celery'],
#  ['Medium', 'Cheddar', 'Cheese', 'Block'],
#  ['Organic', 'Bernie', 's', 'Farm', 'Macaroni', 'Cheese'],
#  ['Organic', 'Tomato', 'Basil', 'Pasta', 'Sauce'],
#  ['Shredded', 'Mozzarella'],
#  ['Frozen', 'Organic', 'Wild', 'Blueberries'],
#  ['Organic', 'Orzo'],
#  ['Organic', 'Pinto', 'Beans'],
#  ['Organic', 'Garbanzo', 'Beans', 'No', 'Salt', 'Added'],
#  ['Maple', 'Quinoa', 'Cluster', 'With', 'Chia', 'Seeds'],
#  ['Gluten', 'Free', 'Blueberry', 'Waffles'],
#  ['Organic', 'Whole', 'Wheat', 'Pie', '9', 'Shells', '2', 'ct'],
#  ['The', 'World', 's', 'Best', 'Veggie', 'Burger'],
#  ['Organic', 'Roasted', 'Sliced', 'Chicken', 'Breast'],
#  ['Organic', 'Milk'],
#  ['Whole', 'Milk', 'Plain', 'Yogurt'],
#  ['Low', 'Fat', 'Plain', 'Yogurt'],
#  ['Boneless', 'Skinless', 'Chicken', 'Breasts'],
#  ['Organic', 'Hass', 'Avocado'],
#  ['Apple', 'Blueberry', 'Granola'],
#  ['Strawberries'],
#  ['Blueberries'],
#  ['Chili', 'With', 'Beans'],
#  ['Natural', 'Bliss', 'Cinnamon', 'Cream', 'Coffee', 'Creamer'],
#  ['Star', 'Wars', 'Italian', 'Sweet', 'Creme', 'Creamer'],
#  ['Honey', 'Wheat', 'Bread'],
#  ['Natural', 'Classic', 'Pork', 'Breakfast', 'Sausage'],
#  ['7', 'Grain', 'Waffles'],
#  ['Organic', 'Beef', 'Uncured', 'Hot', 'Dogs'],
#  ['Uncured', 'Italian', 'Dry', 'Salami'],
#  ['Red', 'Peppers'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Baby', 'Carrots'],
#  ['Lacinato', 'Kale', 'Og'],
#  ['Organic', 'Penne', 'Rigate'],
#  ['Organic', 'White', 'Basmati', 'Rice'],
#  ['Organic', 'Dill'],
#  ['Bag', 'of', 'Organic', 'Bananas'],
#  ['Organic', 'Strawberry', 'Smoothie'],
#  ['Baby', 'Seedless', 'Cucumbers'],
#  ['85', 'Lean', 'Ground', 'Beef'],
#  ['Organic', 'Tomato', 'Cluster'],
#  ['Pomelo', 'Grapefruit', 'Aloe', 'Appeal'],
#  ['Organic', 'Bunch', 'Arugula'],
#  ['Tilapia', 'Filet'],
#  ['Organic', 'Whole', 'Milk'],
#  ['Hommus', 'Artichoke', 'Kalamata'],
#  ['Three', 'Cheese', 'Pizza', 'Shell'],
#  ['Wild', 'Skipjack', 'Light', 'Tuna'],
#  ['Banana'],
#  ['Unsweetened', 'Cashew', 'Milk'],
#  ['Radish'],
#  ['Nonfat', 'Icelandic', 'Style', 'Strawberry', 'Yogurt'],
#  ['Organic', 'Large', 'Extra', 'Fancy', 'Fuji', 'Apple'],
#  ['Organic', 'Tomato', 'Sauce'],
#  ['Garlic'],
#  ['Organic', 'Vidalia', 'Onion'],
#  ['Unsweetened', 'Coconut', 'Milk', 'Beverage'],
#  ['Organic', 'Lemon'],
#  ['Organic', 'Garlic'],
#  ['Organic', 'Cilantro'],
#  ['Organic', 'Italian', 'Parsley', 'Bunch'],
#  ['Organic', 'Dill'],
#  ['Organic', 'Zucchini'],
#  ['Yellow', 'Potato'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Kale'],
#  ['I', 'Heart', 'Baby', 'Kale'],
#  ['Organic', 'Grape', 'Tomatoes'],
#  ['Organic', 'Red', 'Radish', 'Bunch'],
#  ['Total', 'Greek', 'Strained', 'Yogurt'],
#  ['Organic', 'Saffron'],
#  ['Organic', 'Garbanzo', 'Beans'],
#  ['High', 'Heat', 'Canola', 'Spray', 'Oil'],
#  ['Parchment', 'Baking', 'Paper'],
#  ['Pita', 'Bread'],
#  ['Sprouted', 'Grain', 'Low', 'Sodium', 'Bread'],
#  ['Ezekiel', '4', '9', 'Sprouted', 'Whole', 'Grain', 'Cereal', 'Almond'],
#  ['Peanut', 'Butter', 'Creamy', 'With', 'Salt'],
#  ['Premium', 'Organic', 'Strawberry', 'Spread'],
#  ['Original', 'Pure', 'Creamy', 'Almond', 'Milk'],
#  ['Unsweetened', 'Vanilla', 'Almond', 'Milk'],
#  ['Hummus', 'Hope', 'Original', 'Recipe'],
#  ['Seitan', 'wheat', 'Strips'],
#  ['Chorizo', 'Seitan'],
#  ['Vegan', 'Chao', 'Creamy', 'Original', 'Cheese', 'Slices'],
#  ['Organic', 'Garnet', 'Sweet', 'Potato', 'Yam'],
#  ['Original', 'Enriched', 'Rice', 'Drink'],
#  ['Organic', 'Peeled', 'Whole', 'Baby', 'Carrots'],
#  ['Vitamin', 'D', 'Organic', 'Whole', 'Milk'],
#  ['All', 'Natural', 'Marinara', 'Sauce'],
#  ['Eggo', 'Homestyle', 'Waffles'],
#  ['Extra', 'Sharp', 'Cheddar', 'Cheese'],
#  ['Total', '2', 'All', 'Natural', 'Plain', 'Greek', 'Yogurt'],
#  ['Plain', 'Mini', 'Bagels'],
#  ['Organic', 'Sweet', 'Peas'],
#  ['Mini', 'Seedless', 'Cucumbers'],
#  ['Total', '0', 'Nonfat', 'Plain', 'Greek', 'Yogurt'],
#  ['Vanilla', 'Milk', 'Chocolate', 'Almond', 'Ice', 'Cream', 'Bars'],
#  ['Roasted', 'Sesame', 'Seaweed', 'Snacks'],
#  ['Vanilla', 'Milk', 'Chocolate', 'Ice', 'Cream', 'Bars'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Organic', 'Half', 'Baby', 'Spinach', 'Half', 'Baby', 'Arugula'],
#  ['Kosher', 'Dill', 'Halves', 'Pickles'],
#  ['Organic', 'Avocado'],
#  ['Organic', 'Grade', 'A', 'Free', 'Range', 'Large', 'Brown', 'Eggs'],
#  ['Organic', 'Cream', 'Cheese', 'Bar'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Cinnamon', 'Apple', 'Sauce'],
#  ['Baby', 'Back', 'Pork', 'Ribs'],
#  ['Organic', 'Frozen', 'Peas'],
#  ['Organic', 'Russet', 'Potato'],
#  ['Organic', 'Yellow', 'Onion'],
#  ['Organic', 'Baby', 'Spinach'],
#  ['Grated', 'Parmesan'],
#  ['Vegetable', 'Classics', 'Minestrone', 'Soup'],
#  ['Frozen', 'Organic', 'Peach', 'Slices'],
#  ['Black', 'Beans'],
#  ['Organic', 'Large', 'Grade', 'AA', 'Brown', 'Eggs'],
#  ['Chocolate', 'Chip', 'Granola'],
#  ['Crunchy', 'Oats', 'n', 'Honey', 'Granola'],
#  ['2', 'Reduced', 'Fat', 'Milk'],
#  ['Lactose', 'Free', '2', 'Milk'],
#  ['Whole', 'Vitamin', 'D', 'Milk'],
#  ['Fat', 'Free', 'Milk'],
#  ['Extra', 'Sharp', 'Cheddar', 'Cheese', 'Block'],
#  ['Red', 'Hot', 'Original', 'Cayenne', 'Pepper', 'Sauce'],
#  ['Original', 'Ranch', 'Salad', 'Dressing', 'Seasoning', 'Mix'],
#  ['Large', 'Lemon'],
#  ['Banana'],
#  ['Yellow', 'Onions'],
#  ['Organic', 'Red', 'Onion'],
#  ['Golden', 'Sweet', 'Potato'],
#  ['Organic', 'Honey'],
#  ['Super',
#   'Spinach',
#   'Baby',
#   'Spinach',
#   'Baby',
#   'Bok',
#   'Choy',
#   'Sweet',
#   'Baby',
#   'Kale'],
#  ['Honeycrisp', 'Apple'],
#  ...]

# %% [markdown]
# ### Feature Creation

# %%
crf_data  = []
for product in token_sr:
    pos = nltk.pos_tag(product)
    crf_data.append(pos)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0ddc3d11c8a3> in <module>
#       1 crf_data  = []
#       2 for product in token_sr:
# ----> 3     pos = nltk.pos_tag(product)
#       4     crf_data.append(pos)
#
# /usr/local/lib/python3.7/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     160     """
#     161     tagger = _get_tagger(lang)
# --> 162     return _pos_tag(tokens, tagset, tagger, lang)
#     163
#     164
#
# /usr/local/lib/python3.7/site-packages/nltk/tag/__init__.py in _pos_tag(tokens, tagset, tagger, lang)
#     117         )
#     118     else:
# --> 119         tagged_tokens = tagger.tag(tokens)
#     120         if tagset:  # Maps to the specified tagset.
#     121             if lang == 'eng':
#
# /usr/local/lib/python3.7/site-packages/nltk/tag/perceptron.py in tag(self, tokens, return_conf, use_tagdict)
#     178             if not tag:
#     179                 features = self._get_features(i, word, context, prev, prev2)
# --> 180                 tag, conf = self.model.predict(features, return_conf)
#     181             output.append((word, tag, conf) if return_conf == True else (word, tag))
#     182
#
# /usr/local/lib/python3.7/site-packages/nltk/tag/perceptron.py in predict(self, features, return_conf)
#      67             weights = self.weights[feat]
#      68             for label, weight in weights.items():
# ---> 69                 scores[label] += value * weight
#      70
#      71         # Do a secondary alphabetic sort, for stability
#
# KeyboardInterrupt:

# %%
len(products_list)
# Out:
# 24890363

# %%
len(crf_data)
# Out:
# 24890363

# %%
 def word2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]

    # Common features for all words
    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'postag=' + postag
    ]

    # Features for words that are not
    # at the beginning of a document
    if i > 0:
        word1 = doc[i-1][0]
        postag1 = doc[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:postag=' + postag1
        ])
    else:
        # Indicate that it is the 'beginning of a document'
        features.append('BOS')

    # Features for words that are not
    # at the end of a document
    if i < len(doc)-1:
        word1 = doc[i+1][0]
        postag1 = doc[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:postag=' + postag1
        ])
    else:
        # Indicate that it is the 'end of a document'
        features.append('EOS')

    return features

# %%
# A function for extracting features in documents
def extract_features(doc):
    return [word2features(doc, i) for i in range(len(doc))]

# %%
X = [extract_features(doc) for doc in crf_data]

# %%
X
# Out:
# [[['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=egg',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=egg',
#    'word[-3:]=Egg',
#    'word[-2:]=gg',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=whites',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=whites',
#    'word[-3:]=tes',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=egg',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=michigan',
#    'word[-3:]=gan',
#    'word[-2:]=an',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=michigan',
#    '-1:postag=NNP',
#    '+1:word.lower=kale',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=kale',
#    'word[-3:]=ale',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=garlic',
#    'word[-3:]=lic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=powder',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=powder',
#    'word[-3:]=der',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=garlic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=coconut',
#    'word[-3:]=nut',
#    'word[-2:]=ut',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=butter',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=butter',
#    'word[-3:]=ter',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=coconut',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sweetener',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweetener',
#    'word[-3:]=ner',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=carrots',
#    'word[-3:]=ots',
#    'word[-2:]=ts',
#    'postag=NNS',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=unflavored',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=unflavored',
#    'word[-3:]=red',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=JJ',
#    '+1:word.lower=gelatine',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=gelatine',
#    'word[-3:]=ine',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=unflavored',
#    '-1:postag=NNP',
#    '+1:word.lower=mix',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mix',
#    'word[-3:]=Mix',
#    'word[-2:]=ix',
#    'postag=NNP',
#    '-1:word.lower=gelatine',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=DT',
#    'BOS',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=DT',
#    '+1:word.lower=no',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=no',
#    'word[-3:]=No',
#    'word[-2:]=No',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=stir',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=stir',
#    'word[-3:]=tir',
#    'word[-2:]=ir',
#    'postag=NNP',
#    '-1:word.lower=no',
#    '-1:postag=NNP',
#    '+1:word.lower=creamy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=creamy',
#    'word[-3:]=amy',
#    'word[-2:]=my',
#    'postag=NNP',
#    '-1:word.lower=stir',
#    '-1:postag=NNP',
#    '+1:word.lower=almond',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almond',
#    'word[-3:]=ond',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=creamy',
#    '-1:postag=NNP',
#    '+1:word.lower=butter',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=butter',
#    'word[-3:]=ter',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=almond',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=classic',
#    'word[-3:]=sic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=blend',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=blend',
#    'word[-3:]=end',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=classic',
#    '-1:postag=JJ',
#    '+1:word.lower=cole',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cole',
#    'word[-3:]=ole',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=blend',
#    '-1:postag=NNP',
#    '+1:word.lower=slaw',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=slaw',
#    'word[-3:]=law',
#    'word[-2:]=aw',
#    'postag=NNP',
#    '-1:word.lower=cole',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=total',
#    'word[-3:]=tal',
#    'word[-2:]=al',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=2',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=2',
#    'word[-3:]=2',
#    'word[-2:]=2',
#    'postag=CD',
#    '-1:word.lower=total',
#    '-1:postag=JJ',
#    '+1:word.lower=with',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=with',
#    'word[-3:]=ith',
#    'word[-2:]=th',
#    'postag=IN',
#    '-1:word.lower=2',
#    '-1:postag=CD',
#    '+1:word.lower=strawberry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=strawberry',
#    'word[-3:]=rry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=with',
#    '-1:postag=IN',
#    '+1:word.lower=lowfat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lowfat',
#    'word[-3:]=fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=strawberry',
#    '-1:postag=NNP',
#    '+1:word.lower=greek',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=greek',
#    'word[-3:]=eek',
#    'word[-2:]=ek',
#    'postag=NNP',
#    '-1:word.lower=lowfat',
#    '-1:postag=NNP',
#    '+1:word.lower=strained',
#    '+1:postag=VBD'],
#   ['bias',
#    'word.lower=strained',
#    'word[-3:]=ned',
#    'word[-2:]=ed',
#    'postag=VBD',
#    '-1:word.lower=greek',
#    '-1:postag=NNP',
#    '+1:word.lower=yogurt',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=yogurt',
#    'word[-3:]=urt',
#    'word[-2:]=rt',
#    'postag=NNP',
#    '-1:word.lower=strained',
#    '-1:postag=VBD',
#    'EOS']],
#  [['bias',
#    'word.lower=unsweetened',
#    'word[-3:]=ned',
#    'word[-2:]=ed',
#    'postag=VBN',
#    'BOS',
#    '+1:word.lower=almondmilk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almondmilk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=unsweetened',
#    '-1:postag=VBN',
#    'EOS']],
#  [['bias',
#    'word.lower=lemons',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNS',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=baby',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=spinach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spinach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=unsweetened',
#    'word[-3:]=ned',
#    'word[-2:]=ed',
#    'postag=VBN',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=unsweetened',
#    '-1:postag=VBN',
#    '+1:word.lower=almond',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almond',
#    'word[-3:]=ond',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=breeze',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=breeze',
#    'word[-3:]=eze',
#    'word[-2:]=ze',
#    'postag=NNP',
#    '-1:word.lower=almond',
#    '-1:postag=NNP',
#    '+1:word.lower=almond',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almond',
#    'word[-3:]=ond',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=breeze',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=almond',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ginger',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ginger',
#    'word[-3:]=ger',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=root',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=root',
#    'word[-3:]=oot',
#    'word[-2:]=ot',
#    'postag=NNP',
#    '-1:word.lower=ginger',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=air',
#    'word[-3:]=Air',
#    'word[-2:]=ir',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chilled',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chilled',
#    'word[-3:]=led',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=air',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=chilled',
#    '-1:postag=NNP',
#    '+1:word.lower=boneless',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=boneless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=skinless',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=skinless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=boneless',
#    '-1:postag=NNP',
#    '+1:word.lower=chicken',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chicken',
#    'word[-3:]=ken',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=skinless',
#    '-1:postag=NNP',
#    '+1:word.lower=breasts',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=breasts',
#    'word[-3:]=sts',
#    'word[-2:]=ts',
#    'postag=NNS',
#    '-1:word.lower=chicken',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ezekiel',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ezekiel',
#    'word[-3:]=iel',
#    'word[-2:]=el',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=49',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=49',
#    'word[-3:]=49',
#    'word[-2:]=49',
#    'postag=CD',
#    '-1:word.lower=ezekiel',
#    '-1:postag=NNP',
#    '+1:word.lower=bread',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bread',
#    'word[-3:]=ead',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=49',
#    '-1:postag=CD',
#    '+1:word.lower=cinnamon',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cinnamon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=bread',
#    '-1:postag=NNP',
#    '+1:word.lower=raisin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raisin',
#    'word[-3:]=sin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=cinnamon',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=plain',
#    'word[-3:]=ain',
#    'word[-2:]=in',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pre',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pre',
#    'word[-3:]=Pre',
#    'word[-2:]=re',
#    'postag=NNP',
#    '-1:word.lower=plain',
#    '-1:postag=NNP',
#    '+1:word.lower=sliced',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sliced',
#    'word[-3:]=ced',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=pre',
#    '-1:postag=NNP',
#    '+1:word.lower=bagels',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bagels',
#    'word[-3:]=els',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=sliced',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=oats',
#    'word[-3:]=ats',
#    'word[-2:]=ts',
#    'postag=NNS',
#    'BOS',
#    '+1:word.lower=chocolate',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=oats',
#    '-1:postag=NNS',
#    '+1:word.lower=chewy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chewy',
#    'word[-3:]=ewy',
#    'word[-2:]=wy',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=bars',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bars',
#    'word[-3:]=ars',
#    'word[-2:]=rs',
#    'postag=NNP',
#    '-1:word.lower=chewy',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kellogg',
#    'word[-3:]=ogg',
#    'word[-2:]=gg',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=s',
#    '+1:postag=PRP'],
#   ['bias',
#    'word.lower=s',
#    'word[-3:]=s',
#    'word[-2:]=s',
#    'postag=PRP',
#    '-1:word.lower=kellogg',
#    '-1:postag=NNP',
#    '+1:word.lower=nutri',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=nutri',
#    'word[-3:]=tri',
#    'word[-2:]=ri',
#    'postag=NNP',
#    '-1:word.lower=s',
#    '-1:postag=PRP',
#    '+1:word.lower=grain',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grain',
#    'word[-3:]=ain',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=nutri',
#    '-1:postag=NNP',
#    '+1:word.lower=apple',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=apple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=grain',
#    '-1:postag=NNP',
#    '+1:word.lower=cinnamon',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cinnamon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=apple',
#    '-1:postag=NNP',
#    '+1:word.lower=cereal',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cereal',
#    'word[-3:]=eal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=cinnamon',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=nutri',
#    'word[-3:]=tri',
#    'word[-2:]=ri',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=grain',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grain',
#    'word[-3:]=ain',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=nutri',
#    '-1:postag=NNP',
#    '+1:word.lower=soft',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=soft',
#    'word[-3:]=oft',
#    'word[-2:]=ft',
#    'postag=NNP',
#    '-1:word.lower=grain',
#    '-1:postag=NNP',
#    '+1:word.lower=baked',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baked',
#    'word[-3:]=ked',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=soft',
#    '-1:postag=NNP',
#    '+1:word.lower=strawberry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=strawberry',
#    'word[-3:]=rry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=baked',
#    '-1:postag=NNP',
#    '+1:word.lower=cereal',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cereal',
#    'word[-3:]=eal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=strawberry',
#    '-1:postag=NNP',
#    '+1:word.lower=breakfast',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=breakfast',
#    'word[-3:]=ast',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=cereal',
#    '-1:postag=NNP',
#    '+1:word.lower=bars',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bars',
#    'word[-3:]=ars',
#    'word[-2:]=rs',
#    'postag=NNP',
#    '-1:word.lower=breakfast',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=kellogg',
#    'word[-3:]=ogg',
#    'word[-2:]=gg',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=s',
#    '+1:postag=PRP'],
#   ['bias',
#    'word.lower=s',
#    'word[-3:]=s',
#    'word[-2:]=s',
#    'postag=PRP',
#    '-1:word.lower=kellogg',
#    '-1:postag=NNP',
#    '+1:word.lower=nutri',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=nutri',
#    'word[-3:]=tri',
#    'word[-2:]=ri',
#    'postag=NNP',
#    '-1:word.lower=s',
#    '-1:postag=PRP',
#    '+1:word.lower=grain',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grain',
#    'word[-3:]=ain',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=nutri',
#    '-1:postag=NNP',
#    '+1:word.lower=blueberry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=blueberry',
#    'word[-3:]=rry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=grain',
#    '-1:postag=NNP',
#    '+1:word.lower=cereal',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cereal',
#    'word[-3:]=eal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=blueberry',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=bag',
#    'word[-3:]=Bag',
#    'word[-2:]=ag',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=of',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=of',
#    'word[-3:]=of',
#    'word[-2:]=of',
#    'postag=IN',
#    '-1:word.lower=bag',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=of',
#    '-1:postag=IN',
#    '+1:word.lower=bananas',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bananas',
#    'word[-3:]=nas',
#    'word[-2:]=as',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=just',
#    'word[-3:]=ust',
#    'word[-2:]=st',
#    'postag=RB',
#    'BOS',
#    '+1:word.lower=crisp',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=crisp',
#    'word[-3:]=isp',
#    'word[-2:]=sp',
#    'postag=NNP',
#    '-1:word.lower=just',
#    '-1:postag=RB',
#    '+1:word.lower=parmesan',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parmesan',
#    'word[-3:]=san',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=crisp',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=fresh',
#    'word[-3:]=esh',
#    'word[-2:]=sh',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=fruit',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fruit',
#    'word[-3:]=uit',
#    'word[-2:]=it',
#    'postag=NNP',
#    '-1:word.lower=fresh',
#    '-1:postag=NNP',
#    '+1:word.lower=salad',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salad',
#    'word[-3:]=lad',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=fruit',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=raspberries',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=raspberries',
#    'word[-3:]=ies',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=2',
#    'word[-3:]=2',
#    'word[-2:]=2',
#    'postag=CD',
#    'BOS',
#    '+1:word.lower=reduced',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=reduced',
#    'word[-3:]=ced',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=2',
#    '-1:postag=CD',
#    '+1:word.lower=fat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fat',
#    'word[-3:]=Fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=reduced',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=fat',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=matzos',
#    'word[-3:]=zos',
#    'word[-2:]=os',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=thin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=thin',
#    'word[-3:]=hin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=matzos',
#    '-1:postag=NNP',
#    '+1:word.lower=tea',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=tea',
#    'word[-3:]=Tea',
#    'word[-2:]=ea',
#    'postag=NNP',
#    '-1:word.lower=thin',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=boneless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=skinless',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=skinless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=boneless',
#    '-1:postag=NNP',
#    '+1:word.lower=chicken',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chicken',
#    'word[-3:]=ken',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=skinless',
#    '-1:postag=NNP',
#    '+1:word.lower=breast',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=breast',
#    'word[-3:]=ast',
#    'word[-2:]=st',
#    'postag=NNP',
#    '-1:word.lower=chicken',
#    '-1:postag=NNP',
#    '+1:word.lower=fillets',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=fillets',
#    'word[-3:]=ets',
#    'word[-2:]=ts',
#    'postag=NNS',
#    '-1:word.lower=breast',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mini',
#    'word[-3:]=ini',
#    'word[-2:]=ni',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=original',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=mini',
#    '-1:postag=NNP',
#    '+1:word.lower=babybel',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=babybel',
#    'word[-3:]=bel',
#    'word[-2:]=el',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=NNP',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=babybel',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=macaroni',
#    'word[-3:]=oni',
#    'word[-2:]=ni',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=and',
#    '+1:postag=CC'],
#   ['bias',
#    'word.lower=and',
#    'word[-3:]=And',
#    'word[-2:]=nd',
#    'postag=CC',
#    '-1:word.lower=macaroni',
#    '-1:postag=NNP',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=and',
#    '-1:postag=CC',
#    'EOS']],
#  [['bias',
#    'word.lower=clementines',
#    'word[-3:]=nes',
#    'word[-2:]=es',
#    'postag=NNS',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=artichokes',
#    'word[-3:]=kes',
#    'word[-2:]=es',
#    'postag=NNS',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=apricot',
#    'word[-3:]=cot',
#    'word[-2:]=ot',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=preserves',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=preserves',
#    'word[-3:]=ves',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=apricot',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=american',
#    'word[-3:]=can',
#    'word[-2:]=an',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=slices',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=slices',
#    'word[-3:]=ces',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=american',
#    '-1:postag=JJ',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=slices',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=hass',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=hass',
#    'word[-3:]=ass',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=avocado',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=avocado',
#    'word[-3:]=ado',
#    'word[-2:]=do',
#    'postag=NNP',
#    '-1:word.lower=hass',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=spaghetti',
#    'word[-3:]=tti',
#    'word[-2:]=ti',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pasta',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pasta',
#    'word[-3:]=sta',
#    'word[-2:]=ta',
#    'postag=NNP',
#    '-1:word.lower=spaghetti',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=meyer',
#    'word[-3:]=yer',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=lemon',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lemon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=meyer',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=bag',
#    'word[-3:]=Bag',
#    'word[-2:]=ag',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=of',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=of',
#    'word[-3:]=of',
#    'word[-2:]=of',
#    'postag=IN',
#    '-1:word.lower=bag',
#    '-1:postag=NNP',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=of',
#    '-1:postag=IN',
#    '+1:word.lower=lemons',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lemons',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=pineapple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=chunks',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=chunks',
#    'word[-3:]=nks',
#    'word[-2:]=ks',
#    'postag=NNS',
#    '-1:word.lower=pineapple',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=hawaiian',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=hawaiian',
#    'word[-3:]=ian',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=JJ',
#    '+1:word.lower=sweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=hawaiian',
#    '-1:postag=NNP',
#    '+1:word.lower=rolls',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=rolls',
#    'word[-3:]=lls',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=red',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=red',
#    'word[-3:]=Red',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=radish',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=radish',
#    'word[-3:]=ish',
#    'word[-2:]=sh',
#    'postag=NNP',
#    '-1:word.lower=red',
#    '-1:postag=NNP',
#    '+1:word.lower=bunch',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bunch',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=radish',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=whole',
#    'word[-3:]=ole',
#    'word[-2:]=le',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=white',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=white',
#    'word[-3:]=ite',
#    'word[-2:]=te',
#    'postag=NNP',
#    '-1:word.lower=whole',
#    '-1:postag=JJ',
#    '+1:word.lower=mushrooms',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=mushrooms',
#    'word[-3:]=oms',
#    'word[-2:]=ms',
#    'postag=NNS',
#    '-1:word.lower=white',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=spinach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spinach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=low',
#    'word[-3:]=Low',
#    'word[-2:]=ow',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=fat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fat',
#    'word[-3:]=Fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=low',
#    '-1:postag=JJ',
#    '+1:word.lower=kefir',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=kefir',
#    'word[-3:]=fir',
#    'word[-2:]=ir',
#    'postag=NNP',
#    '-1:word.lower=fat',
#    '-1:postag=NNP',
#    '+1:word.lower=cultured',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cultured',
#    'word[-3:]=red',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=kefir',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=cultured',
#    '-1:postag=NNP',
#    '+1:word.lower=smoothie',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=smoothie',
#    'word[-3:]=hie',
#    'word[-2:]=ie',
#    'postag=NNP',
#    '-1:word.lower=milk',
#    '-1:postag=NNP',
#    '+1:word.lower=lowfat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lowfat',
#    'word[-3:]=fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=smoothie',
#    '-1:postag=NNP',
#    '+1:word.lower=probiotic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=probiotic',
#    'word[-3:]=tic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=lowfat',
#    '-1:postag=NNP',
#    '+1:word.lower=blueberry',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=blueberry',
#    'word[-3:]=rry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=probiotic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=applesauce',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=applesauce',
#    'word[-3:]=uce',
#    'word[-2:]=ce',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=JJ',
#    '+1:word.lower=snack',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=snack',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=applesauce',
#    '-1:postag=NNP',
#    '+1:word.lower=go',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=go',
#    'word[-3:]=Go',
#    'word[-2:]=Go',
#    'postag=NNP',
#    '-1:word.lower=snack',
#    '-1:postag=NNP',
#    '+1:word.lower=pouches',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pouches',
#    'word[-3:]=hes',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=go',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=green',
#    'word[-3:]=een',
#    'word[-2:]=en',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=beans',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=beans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=green',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=extra',
#    'word[-3:]=tra',
#    'word[-2:]=ra',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=virgin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=virgin',
#    'word[-3:]=gin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=extra',
#    '-1:postag=NNP',
#    '+1:word.lower=olive',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=olive',
#    'word[-3:]=ive',
#    'word[-2:]=ve',
#    'postag=NNP',
#    '-1:word.lower=virgin',
#    '-1:postag=NNP',
#    '+1:word.lower=oil',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=oil',
#    'word[-3:]=Oil',
#    'word[-2:]=il',
#    'postag=NN',
#    '-1:word.lower=olive',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=french',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=baguettes',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baguettes',
#    'word[-3:]=tes',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=french',
#    '-1:postag=JJ',
#    '+1:word.lower=take',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=take',
#    'word[-3:]=ake',
#    'word[-2:]=ke',
#    'postag=NNP',
#    '-1:word.lower=baguettes',
#    '-1:postag=NNP',
#    '+1:word.lower=bake',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bake',
#    'word[-3:]=ake',
#    'word[-2:]=ke',
#    'postag=NNP',
#    '-1:word.lower=take',
#    '-1:postag=NNP',
#    '+1:word.lower=twin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=twin',
#    'word[-3:]=win',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=bake',
#    '-1:postag=NNP',
#    '+1:word.lower=pack',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pack',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=twin',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=bread',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bread',
#    'word[-3:]=ead',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=with',
#    '+1:postag=IN'],
#   ['bias',
#    'word.lower=with',
#    'word[-3:]=ith',
#    'word[-2:]=th',
#    'postag=IN',
#    '-1:word.lower=bread',
#    '-1:postag=NNP',
#    '+1:word.lower=21',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=21',
#    'word[-3:]=21',
#    'word[-2:]=21',
#    'postag=CD',
#    '-1:word.lower=with',
#    '-1:postag=IN',
#    '+1:word.lower=whole',
#    '+1:postag=JJ'],
#   ['bias',
#    'word.lower=whole',
#    'word[-3:]=ole',
#    'word[-2:]=le',
#    'postag=JJ',
#    '-1:word.lower=21',
#    '-1:postag=CD',
#    '+1:word.lower=grains',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=grains',
#    'word[-3:]=ins',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=whole',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=vanilla',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=almond',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almond',
#    'word[-3:]=ond',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=vanilla',
#    '-1:postag=NNP',
#    '+1:word.lower=breeze',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=breeze',
#    'word[-3:]=eze',
#    'word[-2:]=ze',
#    'postag=NNP',
#    '-1:word.lower=almond',
#    '-1:postag=NNP',
#    '+1:word.lower=almond',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almond',
#    'word[-3:]=ond',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=breeze',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=almond',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sharp',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sharp',
#    'word[-3:]=arp',
#    'word[-2:]=rp',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=cheddar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheddar',
#    'word[-3:]=dar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=sharp',
#    '-1:postag=NNP',
#    '+1:word.lower=sliced',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sliced',
#    'word[-3:]=ced',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=cheddar',
#    '-1:postag=NNP',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=sliced',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=fruit',
#    'word[-3:]=uit',
#    'word[-2:]=it',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=nutty',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=nutty',
#    'word[-3:]=tty',
#    'word[-2:]=ty',
#    'postag=NNP',
#    '-1:word.lower=fruit',
#    '-1:postag=NNP',
#    '+1:word.lower=almonds',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=almonds',
#    'word[-3:]=nds',
#    'word[-2:]=ds',
#    'postag=NNP',
#    '-1:word.lower=nutty',
#    '-1:postag=NNP',
#    '+1:word.lower=raisins',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=raisins',
#    'word[-3:]=ins',
#    'word[-2:]=ns',
#    'postag=NNP',
#    '-1:word.lower=almonds',
#    '-1:postag=NNP',
#    '+1:word.lower=cranberries',
#    '+1:postag=NNPS'],
#   ['bias',
#    'word.lower=cranberries',
#    'word[-3:]=ies',
#    'word[-2:]=es',
#    'postag=NNPS',
#    '-1:word.lower=raisins',
#    '-1:postag=NNP',
#    '+1:word.lower=pecans',
#    '+1:postag=NNPS'],
#   ['bias',
#    'word.lower=pecans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNPS',
#    '-1:word.lower=cranberries',
#    '-1:postag=NNPS',
#    '+1:word.lower=granola',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=granola',
#    'word[-3:]=ola',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=pecans',
#    '-1:postag=NNPS',
#    'EOS']],
#  [['bias',
#    'word.lower=banana',
#    'word[-3:]=ana',
#    'word[-2:]=na',
#    'postag=NNP',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=portabella',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=portabella',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    '+1:word.lower=mushrooms',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mushrooms',
#    'word[-3:]=oms',
#    'word[-2:]=ms',
#    'postag=NNP',
#    '-1:word.lower=portabella',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=cilantro',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cilantro',
#    'word[-3:]=tro',
#    'word[-2:]=ro',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=avocado',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=avocado',
#    'word[-3:]=ado',
#    'word[-2:]=do',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=yellow',
#    'word[-3:]=low',
#    'word[-2:]=ow',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=onions',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=onions',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=yellow',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=parsley',
#    'word[-3:]=ley',
#    'word[-2:]=ey',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=italian',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=italian',
#    'word[-3:]=ian',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=parsley',
#    '-1:postag=NNP',
#    '+1:word.lower=flat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=flat',
#    'word[-3:]=lat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=italian',
#    '-1:postag=NNP',
#    '+1:word.lower=new',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=new',
#    'word[-3:]=New',
#    'word[-2:]=ew',
#    'postag=NNP',
#    '-1:word.lower=flat',
#    '-1:postag=NNP',
#    '+1:word.lower=england',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=england',
#    'word[-3:]=and',
#    'word[-2:]=nd',
#    'postag=NNP',
#    '-1:word.lower=new',
#    '-1:postag=NNP',
#    '+1:word.lower=grown',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grown',
#    'word[-3:]=own',
#    'word[-2:]=wn',
#    'postag=NNP',
#    '-1:word.lower=england',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=strawberries',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=strawberries',
#    'word[-3:]=ies',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=black',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=black',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=beans',
#    '+1:postag=NNPS'],
#   ['bias',
#    'word.lower=beans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNPS',
#    '-1:word.lower=black',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=green',
#    'word[-3:]=een',
#    'word[-2:]=en',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=beans',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=beans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=green',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=half',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=half',
#    'word[-3:]=alf',
#    'word[-2:]=lf',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=half',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=half',
#    'word[-3:]=alf',
#    'word[-2:]=lf',
#    'postag=NNP',
#    '-1:word.lower=half',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=boneless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=beef',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=beef',
#    'word[-3:]=eef',
#    'word[-2:]=ef',
#    'postag=NNP',
#    '-1:word.lower=boneless',
#    '-1:postag=NNP',
#    '+1:word.lower=sirloin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sirloin',
#    'word[-3:]=oin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=beef',
#    '-1:postag=NNP',
#    '+1:word.lower=steak',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=steak',
#    'word[-3:]=eak',
#    'word[-2:]=ak',
#    'postag=NNP',
#    '-1:word.lower=sirloin',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=butterhead',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=butterhead',
#    'word[-3:]=ead',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=boston',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=boston',
#    'word[-3:]=ton',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=butterhead',
#    '-1:postag=NNP',
#    '+1:word.lower=butter',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=butter',
#    'word[-3:]=ter',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=boston',
#    '-1:postag=NNP',
#    '+1:word.lower=bibb',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bibb',
#    'word[-3:]=ibb',
#    'word[-2:]=bb',
#    'postag=NNP',
#    '-1:word.lower=butter',
#    '-1:postag=NNP',
#    '+1:word.lower=lettuce',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lettuce',
#    'word[-3:]=uce',
#    'word[-2:]=ce',
#    'postag=NNP',
#    '-1:word.lower=bibb',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sunchoke',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sunchoke',
#    'word[-3:]=oke',
#    'word[-2:]=ke',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=teriyaki',
#    'word[-3:]=aki',
#    'word[-2:]=ki',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pineapple',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pineapple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=teriyaki',
#    '-1:postag=NNP',
#    '+1:word.lower=chicken',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chicken',
#    'word[-3:]=ken',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=pineapple',
#    '-1:postag=NNP',
#    '+1:word.lower=meatballs',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=meatballs',
#    'word[-3:]=lls',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=chicken',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=mango',
#    'word[-3:]=ngo',
#    'word[-2:]=go',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pineapple',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pineapple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=mango',
#    '-1:postag=NNP',
#    '+1:word.lower=salsa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salsa',
#    'word[-3:]=lsa',
#    'word[-2:]=sa',
#    'postag=NNP',
#    '-1:word.lower=pineapple',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=traditional',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=refried',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=refried',
#    'word[-3:]=ied',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=traditional',
#    '-1:postag=JJ',
#    '+1:word.lower=beans',
#    '+1:postag=NNPS'],
#   ['bias',
#    'word.lower=beans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNPS',
#    '-1:word.lower=refried',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=extra',
#    'word[-3:]=tra',
#    'word[-2:]=ra',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=virgin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=virgin',
#    'word[-3:]=gin',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=extra',
#    '-1:postag=NNP',
#    '+1:word.lower=olive',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=olive',
#    'word[-3:]=ive',
#    'word[-2:]=ve',
#    'postag=NNP',
#    '-1:word.lower=virgin',
#    '-1:postag=NNP',
#    '+1:word.lower=oil',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=oil',
#    'word[-3:]=Oil',
#    'word[-2:]=il',
#    'postag=NN',
#    '-1:word.lower=olive',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=french',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=vanilla',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=vanilla',
#    'word[-3:]=lla',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=french',
#    '-1:postag=JJ',
#    '+1:word.lower=coffee',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=coffee',
#    'word[-3:]=fee',
#    'word[-2:]=ee',
#    'postag=NNP',
#    '-1:word.lower=vanilla',
#    '-1:postag=NNP',
#    '+1:word.lower=creamer',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=creamer',
#    'word[-3:]=mer',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=coffee',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=2',
#    'word[-3:]=2',
#    'word[-2:]=2',
#    'postag=CD',
#    'BOS',
#    '+1:word.lower=milk',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NN',
#    '-1:word.lower=2',
#    '-1:postag=CD',
#    'EOS']],
#  [['bias',
#    'word.lower=cherubs',
#    'word[-3:]=ubs',
#    'word[-2:]=bs',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=heavenly',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=heavenly',
#    'word[-3:]=nly',
#    'word[-2:]=ly',
#    'postag=NNP',
#    '-1:word.lower=cherubs',
#    '-1:postag=NNP',
#    '+1:word.lower=salad',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salad',
#    'word[-3:]=lad',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=heavenly',
#    '-1:postag=NNP',
#    '+1:word.lower=tomatoes',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=tomatoes',
#    'word[-3:]=oes',
#    'word[-2:]=es',
#    'postag=NNP',
#    '-1:word.lower=salad',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=extra',
#    'word[-3:]=tra',
#    'word[-2:]=ra',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=creamy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=creamy',
#    'word[-3:]=amy',
#    'word[-2:]=my',
#    'postag=NNP',
#    '-1:word.lower=extra',
#    '-1:postag=NNP',
#    '+1:word.lower=dairy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dairy',
#    'word[-3:]=iry',
#    'word[-2:]=ry',
#    'postag=NNP',
#    '-1:word.lower=creamy',
#    '-1:postag=NNP',
#    '+1:word.lower=whipped',
#    '+1:postag=VBD'],
#   ['bias',
#    'word.lower=whipped',
#    'word[-3:]=ped',
#    'word[-2:]=ed',
#    'postag=VBD',
#    '-1:word.lower=dairy',
#    '-1:postag=NNP',
#    '+1:word.lower=topping',
#    '+1:postag=VBG'],
#   ['bias',
#    'word.lower=topping',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=VBG',
#    '-1:word.lower=whipped',
#    '-1:postag=VBD',
#    'EOS']],
#  [['bias',
#    'word.lower=cheddar',
#    'word[-3:]=dar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=cheddar',
#    '-1:postag=NNP',
#    '+1:word.lower=condensed',
#    '+1:postag=VBD'],
#   ['bias',
#    'word.lower=condensed',
#    'word[-3:]=sed',
#    'word[-2:]=ed',
#    'postag=VBD',
#    '-1:word.lower=cheese',
#    '-1:postag=NNP',
#    '+1:word.lower=soup',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=soup',
#    'word[-3:]=oup',
#    'word[-2:]=up',
#    'postag=NNP',
#    '-1:word.lower=condensed',
#    '-1:postag=VBD',
#    'EOS']],
#  [['bias',
#    'word.lower=all',
#    'word[-3:]=All',
#    'word[-2:]=ll',
#    'postag=DT',
#    'BOS',
#    '+1:word.lower=natural',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=natural',
#    'word[-3:]=ral',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=all',
#    '-1:postag=DT',
#    '+1:word.lower=boneless',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=boneless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=natural',
#    '-1:postag=NNP',
#    '+1:word.lower=skinless',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=skinless',
#    'word[-3:]=ess',
#    'word[-2:]=ss',
#    'postag=NNP',
#    '-1:word.lower=boneless',
#    '-1:postag=NNP',
#    '+1:word.lower=chicken',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chicken',
#    'word[-3:]=ken',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=skinless',
#    '-1:postag=NNP',
#    '+1:word.lower=breasts',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=breasts',
#    'word[-3:]=sts',
#    'word[-2:]=ts',
#    'postag=NNS',
#    '-1:word.lower=chicken',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=combination',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=pizza',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pizza',
#    'word[-3:]=zza',
#    'word[-2:]=za',
#    'postag=NNP',
#    '-1:word.lower=combination',
#    '-1:postag=NNP',
#    '+1:word.lower=rolls',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=rolls',
#    'word[-3:]=lls',
#    'word[-2:]=ls',
#    'postag=NNP',
#    '-1:word.lower=pizza',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=chunky',
#    'word[-3:]=nky',
#    'word[-2:]=ky',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=salsa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salsa',
#    'word[-3:]=lsa',
#    'word[-2:]=sa',
#    'postag=NNP',
#    '-1:word.lower=chunky',
#    '-1:postag=NNP',
#    '+1:word.lower=medium',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=medium',
#    'word[-3:]=ium',
#    'word[-2:]=um',
#    'postag=NNP',
#    '-1:word.lower=salsa',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
# ...
#    '-1:postag=NNP',
#    '+1:word.lower=pork',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pork',
#    'word[-3:]=ork',
#    'word[-2:]=rk',
#    'postag=NNP',
#    '-1:word.lower=back',
#    '-1:postag=NNP',
#    '+1:word.lower=ribs',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ribs',
#    'word[-3:]=ibs',
#    'word[-2:]=bs',
#    'postag=NNP',
#    '-1:word.lower=pork',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=frozen',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=frozen',
#    'word[-3:]=zen',
#    'word[-2:]=en',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=peas',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=peas',
#    'word[-3:]=eas',
#    'word[-2:]=as',
#    'postag=NNP',
#    '-1:word.lower=frozen',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=russet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=russet',
#    'word[-3:]=set',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=JJ',
#    '+1:word.lower=potato',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=potato',
#    'word[-3:]=ato',
#    'word[-2:]=to',
#    'postag=NNP',
#    '-1:word.lower=russet',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=yellow',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=yellow',
#    'word[-3:]=low',
#    'word[-2:]=ow',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=onion',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=onion',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=yellow',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=baby',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=spinach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spinach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=grated',
#    'word[-3:]=ted',
#    'word[-2:]=ed',
#    'postag=VBN',
#    'BOS',
#    '+1:word.lower=parmesan',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=parmesan',
#    'word[-3:]=san',
#    'word[-2:]=an',
#    'postag=NNP',
#    '-1:word.lower=grated',
#    '-1:postag=VBN',
#    'EOS']],
#  [['bias',
#    'word.lower=vegetable',
#    'word[-3:]=ble',
#    'word[-2:]=le',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=classics',
#    '+1:postag=NNPS'],
#   ['bias',
#    'word.lower=classics',
#    'word[-3:]=ics',
#    'word[-2:]=cs',
#    'postag=NNPS',
#    '-1:word.lower=vegetable',
#    '-1:postag=JJ',
#    '+1:word.lower=minestrone',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=minestrone',
#    'word[-3:]=one',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=classics',
#    '-1:postag=NNPS',
#    '+1:word.lower=soup',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=soup',
#    'word[-3:]=oup',
#    'word[-2:]=up',
#    'postag=NNP',
#    '-1:word.lower=minestrone',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=frozen',
#    'word[-3:]=zen',
#    'word[-2:]=en',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=organic',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    '-1:word.lower=frozen',
#    '-1:postag=NNP',
#    '+1:word.lower=peach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=peach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=slices',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=slices',
#    'word[-3:]=ces',
#    'word[-2:]=es',
#    'postag=NNS',
#    '-1:word.lower=peach',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=black',
#    'word[-3:]=ack',
#    'word[-2:]=ck',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=beans',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=beans',
#    'word[-3:]=ans',
#    'word[-2:]=ns',
#    'postag=NNP',
#    '-1:word.lower=black',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=large',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=large',
#    'word[-3:]=rge',
#    'word[-2:]=ge',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=grade',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=grade',
#    'word[-3:]=ade',
#    'word[-2:]=de',
#    'postag=NNP',
#    '-1:word.lower=large',
#    '-1:postag=NNP',
#    '+1:word.lower=aa',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=aa',
#    'word[-3:]=AA',
#    'word[-2:]=AA',
#    'postag=NNP',
#    '-1:word.lower=grade',
#    '-1:postag=NNP',
#    '+1:word.lower=brown',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=brown',
#    'word[-3:]=own',
#    'word[-2:]=wn',
#    'postag=NNP',
#    '-1:word.lower=aa',
#    '-1:postag=NNP',
#    '+1:word.lower=eggs',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=eggs',
#    'word[-3:]=ggs',
#    'word[-2:]=gs',
#    'postag=NNP',
#    '-1:word.lower=brown',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=chocolate',
#    'word[-3:]=ate',
#    'word[-2:]=te',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=chip',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=chip',
#    'word[-3:]=hip',
#    'word[-2:]=ip',
#    'postag=NNP',
#    '-1:word.lower=chocolate',
#    '-1:postag=NNP',
#    '+1:word.lower=granola',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=granola',
#    'word[-3:]=ola',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=chip',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=crunchy',
#    'word[-3:]=chy',
#    'word[-2:]=hy',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=oats',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=oats',
#    'word[-3:]=ats',
#    'word[-2:]=ts',
#    'postag=NNP',
#    '-1:word.lower=crunchy',
#    '-1:postag=NNP',
#    '+1:word.lower=n',
#    '+1:postag=VBP'],
#   ['bias',
#    'word.lower=n',
#    'word[-3:]=n',
#    'word[-2:]=n',
#    'postag=VBP',
#    '-1:word.lower=oats',
#    '-1:postag=NNP',
#    '+1:word.lower=honey',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=honey',
#    'word[-3:]=ney',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=n',
#    '-1:postag=VBP',
#    '+1:word.lower=granola',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=granola',
#    'word[-3:]=ola',
#    'word[-2:]=la',
#    'postag=NNP',
#    '-1:word.lower=honey',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=2',
#    'word[-3:]=2',
#    'word[-2:]=2',
#    'postag=CD',
#    'BOS',
#    '+1:word.lower=reduced',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=reduced',
#    'word[-3:]=ced',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=2',
#    '-1:postag=CD',
#    '+1:word.lower=fat',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=fat',
#    'word[-3:]=Fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    '-1:word.lower=reduced',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=fat',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=lactose',
#    'word[-3:]=ose',
#    'word[-2:]=se',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=free',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=free',
#    'word[-3:]=ree',
#    'word[-2:]=ee',
#    'postag=NNP',
#    '-1:word.lower=lactose',
#    '-1:postag=NNP',
#    '+1:word.lower=2',
#    '+1:postag=CD'],
#   ['bias',
#    'word.lower=2',
#    'word[-3:]=2',
#    'word[-2:]=2',
#    'postag=CD',
#    '-1:word.lower=free',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NN',
#    '-1:word.lower=2',
#    '-1:postag=CD',
#    'EOS']],
#  [['bias',
#    'word.lower=whole',
#    'word[-3:]=ole',
#    'word[-2:]=le',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=vitamin',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=vitamin',
#    'word[-3:]=min',
#    'word[-2:]=in',
#    'postag=NNP',
#    '-1:word.lower=whole',
#    '-1:postag=JJ',
#    '+1:word.lower=d',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=d',
#    'word[-3:]=D',
#    'word[-2:]=D',
#    'postag=NNP',
#    '-1:word.lower=vitamin',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NNP',
#    '-1:word.lower=d',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=fat',
#    'word[-3:]=Fat',
#    'word[-2:]=at',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=free',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=free',
#    'word[-3:]=ree',
#    'word[-2:]=ee',
#    'postag=NNP',
#    '-1:word.lower=fat',
#    '-1:postag=NNP',
#    '+1:word.lower=milk',
#    '+1:postag=NN'],
#   ['bias',
#    'word.lower=milk',
#    'word[-3:]=ilk',
#    'word[-2:]=lk',
#    'postag=NN',
#    '-1:word.lower=free',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=extra',
#    'word[-3:]=tra',
#    'word[-2:]=ra',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sharp',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sharp',
#    'word[-3:]=arp',
#    'word[-2:]=rp',
#    'postag=NNP',
#    '-1:word.lower=extra',
#    '-1:postag=NNP',
#    '+1:word.lower=cheddar',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheddar',
#    'word[-3:]=dar',
#    'word[-2:]=ar',
#    'postag=NNP',
#    '-1:word.lower=sharp',
#    '-1:postag=NNP',
#    '+1:word.lower=cheese',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cheese',
#    'word[-3:]=ese',
#    'word[-2:]=se',
#    'postag=NNP',
#    '-1:word.lower=cheddar',
#    '-1:postag=NNP',
#    '+1:word.lower=block',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=block',
#    'word[-3:]=ock',
#    'word[-2:]=ck',
#    'postag=NNP',
#    '-1:word.lower=cheese',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=red',
#    'word[-3:]=Red',
#    'word[-2:]=ed',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=hot',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=hot',
#    'word[-3:]=Hot',
#    'word[-2:]=ot',
#    'postag=NNP',
#    '-1:word.lower=red',
#    '-1:postag=JJ',
#    '+1:word.lower=original',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    '-1:word.lower=hot',
#    '-1:postag=NNP',
#    '+1:word.lower=cayenne',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=cayenne',
#    'word[-3:]=nne',
#    'word[-2:]=ne',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=NNP',
#    '+1:word.lower=pepper',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=pepper',
#    'word[-3:]=per',
#    'word[-2:]=er',
#    'postag=NNP',
#    '-1:word.lower=cayenne',
#    '-1:postag=NNP',
#    '+1:word.lower=sauce',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sauce',
#    'word[-3:]=uce',
#    'word[-2:]=ce',
#    'postag=NNP',
#    '-1:word.lower=pepper',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=original',
#    'word[-3:]=nal',
#    'word[-2:]=al',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=ranch',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=ranch',
#    'word[-3:]=nch',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=original',
#    '-1:postag=NNP',
#    '+1:word.lower=salad',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=salad',
#    'word[-3:]=lad',
#    'word[-2:]=ad',
#    'postag=NNP',
#    '-1:word.lower=ranch',
#    '-1:postag=NNP',
#    '+1:word.lower=dressing',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=dressing',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=salad',
#    '-1:postag=NNP',
#    '+1:word.lower=seasoning',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=seasoning',
#    'word[-3:]=ing',
#    'word[-2:]=ng',
#    'postag=NNP',
#    '-1:word.lower=dressing',
#    '-1:postag=NNP',
#    '+1:word.lower=mix',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=mix',
#    'word[-3:]=Mix',
#    'word[-2:]=ix',
#    'postag=NNP',
#    '-1:word.lower=seasoning',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=large',
#    'word[-3:]=rge',
#    'word[-2:]=ge',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=lemon',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=lemon',
#    'word[-3:]=mon',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=large',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=banana',
#    'word[-3:]=ana',
#    'word[-2:]=na',
#    'postag=NNP',
#    'BOS',
#    'EOS']],
#  [['bias',
#    'word.lower=yellow',
#    'word[-3:]=low',
#    'word[-2:]=ow',
#    'postag=JJ',
#    'BOS',
#    '+1:word.lower=onions',
#    '+1:postag=NNS'],
#   ['bias',
#    'word.lower=onions',
#    'word[-3:]=ons',
#    'word[-2:]=ns',
#    'postag=NNS',
#    '-1:word.lower=yellow',
#    '-1:postag=JJ',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=red',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=red',
#    'word[-3:]=Red',
#    'word[-2:]=ed',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    '+1:word.lower=onion',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=onion',
#    'word[-3:]=ion',
#    'word[-2:]=on',
#    'postag=NNP',
#    '-1:word.lower=red',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=golden',
#    'word[-3:]=den',
#    'word[-2:]=en',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=sweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=golden',
#    '-1:postag=NNP',
#    '+1:word.lower=potato',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=potato',
#    'word[-3:]=ato',
#    'word[-2:]=to',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=organic',
#    'word[-3:]=nic',
#    'word[-2:]=ic',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=honey',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=honey',
#    'word[-3:]=ney',
#    'word[-2:]=ey',
#    'postag=NNP',
#    '-1:word.lower=organic',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=super',
#    'word[-3:]=per',
#    'word[-2:]=er',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=spinach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spinach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=super',
#    '-1:postag=NNP',
#    '+1:word.lower=baby',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    '-1:word.lower=spinach',
#    '-1:postag=NNP',
#    '+1:word.lower=spinach',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=spinach',
#    'word[-3:]=ach',
#    'word[-2:]=ch',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    '+1:word.lower=baby',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    '-1:word.lower=spinach',
#    '-1:postag=NNP',
#    '+1:word.lower=bok',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=bok',
#    'word[-3:]=Bok',
#    'word[-2:]=ok',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    '+1:word.lower=choy',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=choy',
#    'word[-3:]=hoy',
#    'word[-2:]=oy',
#    'postag=NNP',
#    '-1:word.lower=bok',
#    '-1:postag=NNP',
#    '+1:word.lower=sweet',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=sweet',
#    'word[-3:]=eet',
#    'word[-2:]=et',
#    'postag=NNP',
#    '-1:word.lower=choy',
#    '-1:postag=NNP',
#    '+1:word.lower=baby',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=baby',
#    'word[-3:]=aby',
#    'word[-2:]=by',
#    'postag=NNP',
#    '-1:word.lower=sweet',
#    '-1:postag=NNP',
#    '+1:word.lower=kale',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=kale',
#    'word[-3:]=ale',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=baby',
#    '-1:postag=NNP',
#    'EOS']],
#  [['bias',
#    'word.lower=honeycrisp',
#    'word[-3:]=isp',
#    'word[-2:]=sp',
#    'postag=NNP',
#    'BOS',
#    '+1:word.lower=apple',
#    '+1:postag=NNP'],
#   ['bias',
#    'word.lower=apple',
#    'word[-3:]=ple',
#    'word[-2:]=le',
#    'postag=NNP',
#    '-1:word.lower=honeycrisp',
#    '-1:postag=NNP',
#    'EOS']],
#  ...]

# %%
tagger = pycrfsuite.Tagger()
tagger.open('../../data/04_models/crf_instacart_products_final.model')

# %%
y_pred = [tagger.tag(xseq) for xseq in X]

# %%
len(token_sr)
# Out:
# 24890363

# %%
len(y_pred)
# Out:
# 24890363

# %% [markdown]
# ### Let's match up the tokens with their tags

# %% [markdown]
# Let's match up products with tags in a dictionary first.

# %%
def product_tagger(product_sentence_tokens, product_label_sentence):
    pre = []
    food = []
    post = []

    for word, label in zip(product_sentence_tokens, product_label_sentence):
        if label == 'pre':
            pre.append(word.lower())
        if label == 'food':
            food.append(word.lower())
        if label == 'post':
            post.append(word.lower())
    return {'pre': " ".join(pre), 'food': " ".join(food), 'post': " ".join(post)}

# %%
def token_labels_to_dict(tokens, labels, titles):
    final_dict = {}
    for token, label, title in zip(tokens, labels, titles):
        prod = product_tagger(token, label)
        final_dict[str(title).lower()] = prod
    return final_dict

# %%
final_dict = token_labels_to_dict(token_sr, y_pred, products_list)

# %%
final_dict
# Out:
# {'organic egg whites': {'pre': 'organic', 'food': 'egg whites', 'post': ''},
#  'michigan organic kale': {'pre': 'michigan organic',
#   'food': 'kale',
#   'post': ''},
#  'garlic powder': {'pre': '', 'food': 'garlic powder', 'post': ''},
#  'coconut butter': {'pre': '', 'food': 'coconut butter', 'post': ''},
#  'natural sweetener': {'pre': '', 'food': 'natural sweetener', 'post': ''},
#  'carrots': {'pre': '', 'food': 'carrots', 'post': ''},
#  'original unflavored gelatine mix': {'pre': 'original unflavored',
#   'food': 'gelatine mix',
#   'post': ''},
#  'all natural no stir creamy almond butter': {'pre': 'all',
#   'food': 'natural',
#   'post': 'no stir creamy almond butter'},
#  'classic blend cole slaw': {'pre': 'classic blend',
#   'food': 'cole slaw',
#   'post': ''},
#  'total 2% with strawberry lowfat greek strained yogurt': {'pre': 'total 2 with strawberry lowfat greek strained',
#   'food': 'yogurt',
#   'post': ''},
#  'unsweetened almondmilk': {'pre': 'unsweetened',
#   'food': 'almondmilk',
#   'post': ''},
#  'lemons': {'pre': '', 'food': 'lemons', 'post': ''},
#  'organic baby spinach': {'pre': 'organic baby',
#   'food': 'spinach',
#   'post': ''},
#  'unsweetened chocolate almond breeze almond milk': {'pre': 'unsweetened',
#   'food': 'chocolate',
#   'post': 'almond breeze almond milk'},
#  'organic ginger root': {'pre': 'organic', 'food': 'ginger', 'post': 'root'},
#  'air chilled organic boneless skinless chicken breasts': {'pre': 'air chilled organic boneless skinless',
#   'food': 'chicken',
#   'post': 'breasts'},
#  'organic ezekiel 49 bread cinnamon raisin': {'pre': 'organic ezekiel 49',
#   'food': 'bread',
#   'post': 'cinnamon raisin'},
#  'plain pre-sliced bagels': {'pre': 'plain pre sliced',
#   'food': 'bagels',
#   'post': ''},
#  'oats & chocolate chewy bars': {'pre': '',
#   'food': 'oats',
#   'post': 'chocolate chewy bars'},
#  "kellogg's nutri-grain apple cinnamon cereal": {'pre': '',
#   'food': 'kellogg',
#   'post': 's nutri grain apple cinnamon cereal'},
#  'nutri-grain soft baked strawberry cereal breakfast bars': {'pre': 'nutri grain soft baked strawberry cereal',
#   'food': 'breakfast bars',
#   'post': ''},
#  "kellogg's nutri-grain blueberry cereal": {'pre': 'kellogg s nutri grain blueberry',
#   'food': 'cereal',
#   'post': ''},
#  'bag of organic bananas': {'pre': 'bag of organic',
#   'food': 'bananas',
#   'post': ''},
#  'just crisp, parmesan': {'pre': '', 'food': 'just', 'post': 'crisp parmesan'},
#  'fresh fruit salad': {'pre': 'fresh', 'food': 'fruit salad', 'post': ''},
#  'organic raspberries': {'pre': 'organic', 'food': 'raspberries', 'post': ''},
#  '2% reduced fat milk': {'pre': '2 reduced fat', 'food': 'milk', 'post': ''},
#  'matzos, thin, tea': {'pre': 'matzos thin', 'food': 'tea', 'post': ''},
#  'boneless skinless chicken breast fillets': {'pre': 'boneless skinless',
#   'food': 'chicken',
#   'post': 'breast fillets'},
#  'mini original babybel cheese': {'pre': 'mini original babybel',
#   'food': 'cheese',
#   'post': ''},
#  'macaroni and cheese': {'pre': '', 'food': 'macaroni and cheese', 'post': ''},
#  'clementines': {'pre': '', 'food': 'clementines', 'post': ''},
#  'artichokes': {'pre': '', 'food': 'artichokes', 'post': ''},
#  'apricot preserves': {'pre': '', 'food': 'apricot preserves', 'post': ''},
#  'american slices cheese': {'pre': 'american slices',
#   'food': 'cheese',
#   'post': ''},
#  'organic hass avocado': {'pre': 'organic hass',
#   'food': 'avocado',
#   'post': ''},
#  'spaghetti pasta': {'pre': 'spaghetti', 'food': 'pasta', 'post': ''},
#  'meyer lemon': {'pre': 'meyer', 'food': 'lemon', 'post': ''},
#  'bag of organic lemons': {'pre': '',
#   'food': 'bag',
#   'post': 'of organic lemons'},
#  'pineapple chunks': {'pre': '', 'food': 'pineapple', 'post': 'chunks'},
#  'original hawaiian sweet rolls': {'pre': 'original hawaiian',
#   'food': 'sweet',
#   'post': 'rolls'},
#  'organic red radish, bunch': {'pre': 'organic red',
#   'food': 'radish',
#   'post': 'bunch'},
#  'whole white mushrooms': {'pre': 'whole white',
#   'food': 'mushrooms',
#   'post': ''},
#  'baby spinach': {'pre': 'baby', 'food': 'spinach', 'post': ''},
#  'low fat kefir cultured milk smoothie lowfat probiotic blueberry': {'pre': 'low fat',
#   'food': 'kefir',
#   'post': 'cultured milk smoothie lowfat probiotic blueberry'},
#  'natural applesauce snack & go pouches': {'pre': 'natural',
#   'food': 'applesauce',
#   'post': 'snack go pouches'},
#  'green beans': {'pre': '', 'food': 'green beans', 'post': ''},
#  'extra virgin olive oil': {'pre': 'extra virgin',
#   'food': 'olive oil',
#   'post': ''},
#  'french baguettes, take & bake, twin pack': {'pre': '',
#   'food': 'french baguettes',
#   'post': 'take bake twin pack'},
#  'organic bread with 21 whole grains': {'pre': 'organic',
#   'food': 'bread',
#   'post': 'with 21 whole grains'},
#  'vanilla almond breeze almond milk': {'pre': 'vanilla',
#   'food': 'almond',
#   'post': 'breeze almond milk'},
#  'natural sharp cheddar sliced cheese': {'pre': 'natural sharp cheddar sliced',
#   'food': 'cheese',
#   'post': ''},
#  'fruit & nutty almonds raisins cranberries pecans granola': {'pre': 'fruit nutty almonds raisins cranberries pecans',
#   'food': 'granola',
#   'post': ''},
#  'banana': {'pre': '', 'food': 'banana', 'post': ''},
#  'baby portabella mushrooms': {'pre': 'baby portabella',
#   'food': 'mushrooms',
#   'post': ''},
#  'organic cilantro': {'pre': 'organic', 'food': 'cilantro', 'post': ''},
#  'organic avocado': {'pre': 'organic', 'food': 'avocado', 'post': ''},
#  'yellow onions': {'pre': 'yellow', 'food': 'onions', 'post': ''},
#  'parsley, italian (flat), new england grown': {'pre': '',
#   'food': 'parsley',
#   'post': 'italian flat new england grown'},
#  'organic strawberries': {'pre': 'organic',
#   'food': 'strawberries',
#   'post': ''},
#  'organic black beans': {'pre': 'organic black', 'food': 'beans', 'post': ''},
#  'organic half & half': {'pre': 'organic', 'food': 'half half', 'post': ''},
#  'boneless beef sirloin steak': {'pre': 'boneless beef sirloin',
#   'food': 'steak',
#   'post': ''},
#  'organic butterhead (boston, butter, bibb) lettuce': {'pre': 'organic butterhead boston butter bibb',
#   'food': 'lettuce',
#   'post': ''},
#  'organic sunchoke': {'pre': 'organic', 'food': 'sunchoke', 'post': ''},
#  'teriyaki & pineapple chicken meatballs': {'pre': 'teriyaki pineapple',
#   'food': 'chicken',
#   'post': 'meatballs'},
#  'mango pineapple salsa': {'pre': 'mango pineapple',
#   'food': 'salsa',
#   'post': ''},
#  'traditional refried beans': {'pre': 'traditional refried',
#   'food': 'beans',
#   'post': ''},
#  'french vanilla coffee creamer': {'pre': 'french vanilla',
#   'food': 'coffee creamer',
#   'post': ''},
#  '2% milk': {'pre': '2', 'food': 'milk', 'post': ''},
#  'cherubs heavenly salad tomatoes': {'pre': 'cherubs',
#   'food': 'heavenly',
#   'post': 'salad tomatoes'},
#  'extra creamy dairy whipped topping': {'pre': 'extra creamy dairy',
#   'food': 'whipped topping',
#   'post': ''},
#  'cheddar cheese condensed soup': {'pre': 'cheddar cheese condensed',
#   'food': 'soup',
#   'post': ''},
#  'all natural boneless skinless chicken breasts': {'pre': 'all natural boneless skinless',
#   'food': 'chicken',
#   'post': 'breasts'},
#  'combination pizza rolls': {'pre': 'combination',
#   'food': 'pizza',
#   'post': 'rolls'},
#  'chunky salsa medium': {'pre': 'chunky', 'food': 'salsa', 'post': 'medium'},
#  'salsa con queso medium dip': {'pre': '',
#   'food': 'salsa',
#   'post': 'con queso medium dip'},
#  'philadelphia original cream cheese': {'pre': 'philadelphia original',
#   'food': 'cream cheese',
#   'post': ''},
#  'hampshire 100% natural sour cream': {'pre': 'hampshire 100 natural',
#   'food': 'sour cream',
#   'post': ''},
#  'organic whole milk': {'pre': 'organic whole', 'food': 'milk', 'post': ''},
#  'organic mini homestyle waffles': {'pre': 'organic mini homestyle',
#   'food': 'waffles',
#   'post': ''},
#  'naturals chicken nuggets': {'pre': 'naturals',
#   'food': 'chicken',
#   'post': 'nuggets'},
#  'unprocessed american singles colby-style cheese': {'pre': 'unprocessed american singles colby style',
#   'food': 'cheese',
#   'post': ''},
#  'organic mesa sunrise cereal': {'pre': 'organic mesa sunrise',
#   'food': 'cereal',
#   'post': ''},
#  'total greek strained yogurt': {'pre': 'total greek strained',
#   'food': 'yogurt',
#   'post': ''},
#  'corn meal pizza crust': {'pre': 'corn meal',
#   'food': 'pizza crust',
#   'post': ''},
#  'sriracha chili sauce': {'pre': 'sriracha',
#   'food': 'chili sauce',
#   'post': ''},
#  'organic broccoli florets': {'pre': 'organic',
#   'food': 'broccoli',
#   'post': 'florets'},
#  'honeycrisp apple': {'pre': 'honeycrisp', 'food': 'apple', 'post': ''},
#  'organic extra virgin olive oil': {'pre': 'organic extra virgin',
#   'food': 'olive oil',
#   'post': ''},
#  'pinto beans no salt added': {'pre': 'pinto',
#   'food': 'beans',
#   'post': 'no salt added'},
#  'red vine tomato': {'pre': 'red vine', 'food': 'tomato', 'post': ''},
#  'apricots': {'pre': '', 'food': 'apricots', 'post': ''},
#  'watermelon chunks': {'pre': '', 'food': 'watermelon', 'post': 'chunks'},
#  'organic fat free milk': {'pre': 'organic fat free',
#   'food': 'milk',
#   'post': ''},
#  'organic bosc pear': {'pre': 'organic bosc', 'food': 'pear', 'post': ''},
#  'ataulfo mango': {'pre': 'ataulfo', 'food': 'mango', 'post': ''},
#  'globe eggplant': {'pre': 'globe', 'food': 'eggplant', 'post': ''},
#  'organic unsalted butter': {'pre': 'organic unsalted',
#   'food': 'butter',
#   'post': ''},
#  'sesame oil, pure': {'pre': '', 'food': 'sesame oil', 'post': 'pure'},
#  'frozen broccoli florets': {'pre': 'frozen',
#   'food': 'broccoli',
#   'post': 'florets'},
#  'organic maple & onion baked beans': {'pre': 'organic maple onion baked',
#   'food': 'beans',
#   'post': ''},
#  'cilantro pesto': {'pre': '', 'food': 'cilantro', 'post': 'pesto'},
#  'raspberry preserves': {'pre': '', 'food': 'raspberry preserves', 'post': ''},
#  'balsamic reduction traditional balsamic': {'pre': '',
#   'food': 'balsamic',
#   'post': 'reduction traditional balsamic'},
#  'sweet corn on the cob': {'pre': 'sweet',
#   'food': 'corn',
#   'post': 'on the cob'},
#  'organic hazelnut spread': {'pre': 'organic',
#   'food': 'hazelnut',
#   'post': 'spread'},
#  'organic baby kale': {'pre': 'organic baby', 'food': 'kale', 'post': ''},
#  'low sodium bacon': {'pre': 'low sodium', 'food': 'bacon', 'post': ''},
#  'asparagus': {'pre': '', 'food': 'asparagus', 'post': ''},
#  'basil, asiago & pine nut pesto ravioli': {'pre': 'basil asiago pine nut pesto',
#   'food': 'ravioli',
#   'post': ''},
#  'organic baby carrots': {'pre': 'organic baby',
#   'food': 'carrots',
#   'post': ''},
#  'organic whole white mushrooms': {'pre': 'organic whole white',
#   'food': 'mushrooms',
#   'post': ''},
#  'mini chocolate chip waffles': {'pre': 'mini chocolate chip',
#   'food': 'waffles',
#   'post': ''},
#  'sweet red grape tomatoes': {'pre': 'sweet red grape',
#   'food': 'tomatoes',
#   'post': ''},
#  "danimals swingin' strawberry banana smoothie": {'pre': '',
#   'food': 'danimals',
#   'post': 'swingin strawberry banana smoothie'},
#  'red delicious apple': {'pre': 'red delicious', 'food': 'apple', 'post': ''},
#  'yuba tofu skin': {'pre': 'yuba', 'food': 'tofu', 'post': 'skin'},
#  'organic firm tofu': {'pre': 'organic firm', 'food': 'tofu', 'post': ''},
#  'frozen organic blueberries': {'pre': 'frozen organic',
#   'food': 'blueberries',
#   'post': ''},
#  'dairy-free cheddar style wedges': {'pre': 'dairy free',
#   'food': 'cheddar',
#   'post': 'style wedges'},
#  'butter top white bread': {'pre': 'butter top white',
#   'food': 'bread',
#   'post': ''},
#  'iceberg lettuce': {'pre': 'iceberg', 'food': 'lettuce', 'post': ''},
#  'broccoli florets': {'pre': '', 'food': 'broccoli', 'post': 'florets'},
#  'large grade aa eggs': {'pre': 'large grade aa', 'food': 'eggs', 'post': ''},
#  'provolone slices': {'pre': '', 'food': 'provolone', 'post': 'slices'},
#  'vine ripe tomatoes': {'pre': 'vine ripe', 'food': 'tomatoes', 'post': ''},
#  'boneless and skinless chicken breast': {'pre': 'boneless and skinless',
#   'food': 'chicken',
#   'post': 'breast'},
#  'deli fresh honey smoked turkey breast, 98% fat free, gluten free': {'pre': 'deli fresh honey smoked',
#   'food': 'turkey',
#   'post': 'breast 98 fat free gluten free'},
#  'presliced everything bagels': {'pre': 'presliced everything',
#   'food': 'bagels',
#   'post': ''},
#  'cream cheese': {'pre': '', 'food': 'cream cheese', 'post': ''},
#  'organic baby spinach salad': {'pre': 'organic baby',
#   'food': 'spinach',
#   'post': 'salad'},
#  'red leaf lettuce': {'pre': 'red leaf', 'food': 'lettuce', 'post': ''},
#  'potato yukon gold organic': {'pre': '',
#   'food': 'potato',
#   'post': 'yukon gold organic'},
#  'white corn': {'pre': 'white', 'food': 'corn', 'post': ''},
#  'gluten-free supergrain pasta organic corn & quinoa blend penne': {'pre': 'gluten free supergrain pasta organic corn quinoa blend',
#   'food': 'penne',
#   'post': ''},
#  'gluten and dairy free sonoma veggie burger': {'pre': 'gluten and dairy free sonoma',
#   'food': 'veggie burger',
#   'post': ''},
#  'organic three grain tempeh': {'pre': 'organic three grain',
#   'food': 'tempeh',
#   'post': ''},
#  'lime': {'pre': '', 'food': 'lime', 'post': ''},
#  'organic red onion': {'pre': 'organic red', 'food': 'onion', 'post': ''},
#  'dairy-free chive cream cheese': {'pre': 'dairy free',
#   'food': 'chive cream cheese',
#   'post': ''},
#  'healthy organic vinaigrette': {'pre': 'healthy organic',
#   'food': 'vinaigrette',
#   'post': ''},
#  'strawberry lemonade frozen pops': {'pre': '',
#   'food': 'strawberry',
#   'post': 'lemonade frozen pops'},
#  'mint chocolate cookie ice cream': {'pre': 'mint chocolate cookie',
#   'food': 'ice cream',
#   'post': ''},
#  'half baked® ice cream': {'pre': 'half baked',
#   'food': 'ice cream',
#   'post': ''},
#  'steamfresh lightly sauced broccoli with cheese sauce': {'pre': 'steamfresh lightly sauced',
#   'food': 'broccoli',
#   'post': 'with cheese sauce'},
#  'delights turkey sausage egg whites & cheese english muffin': {'pre': 'delights turkey sausage egg whites',
#   'food': 'cheese',
#   'post': 'english muffin'},
#  'ultra thin sliced provolone cheese': {'pre': 'ultra thin sliced provolone',
#   'food': 'cheese',
#   'post': ''},
#  'cheese shredded mozzarella reduced fat 2%': {'pre': '',
#   'food': 'cheese',
#   'post': 'shredded mozzarella reduced fat 2'},
#  'all whites 100% egg whites': {'pre': 'all whites 100',
#   'food': 'egg whites',
#   'post': ''},
#  'smok cured turkey bacon': {'pre': 'smok cured',
#   'food': 'turkey bacon',
#   'post': ''},
#  'shredded hash browns': {'pre': 'shredded',
#   'food': 'hash browns',
#   'post': ''},
#  'craveables four cheese pizza': {'pre': 'craveables four cheese',
#   'food': 'pizza',
#   'post': ''},
#  'natural muenster cheese': {'pre': 'natural muenster',
#   'food': 'cheese',
#   'post': ''},
#  'baby cut carrots': {'pre': 'baby cut', 'food': 'carrots', 'post': ''},
#  'organic unsweetened almond milk': {'pre': 'organic unsweetened',
#   'food': 'almond milk',
#   'post': ''},
#  'red grapefruit': {'pre': 'red', 'food': 'grapefruit', 'post': ''},
#  'boneless skinless chicken breasts': {'pre': 'boneless skinless',
#   'food': 'chicken',
#   'post': 'breasts'},
#  'berry medley': {'pre': '', 'food': 'berry', 'post': 'medley'},
#  'low fat vanilla yogurt': {'pre': 'low fat vanilla',
#   'food': 'yogurt',
#   'post': ''},
#  'lemon hummus': {'pre': 'lemon', 'food': 'hummus', 'post': ''},
#  'roasted red pepper hummus': {'pre': 'roasted red pepper',
#   'food': 'hummus',
#   'post': ''},
#  'organic low sodium vegetable broth': {'pre': 'organic low sodium',
#   'food': 'vegetable broth',
#   'post': ''},
#  'organic sour cream': {'pre': 'organic', 'food': 'sour cream', 'post': ''},
#  'green bell pepper': {'pre': 'green', 'food': 'bell pepper', 'post': ''},
#  'organic no salt added diced tomatoes': {'pre': 'organic no salt added diced',
#   'food': 'tomatoes',
#   'post': ''},
#  'no salt added black beans': {'pre': 'no salt added black',
#   'food': 'beans',
#   'post': ''},
#  'firm tofu': {'pre': 'firm', 'food': 'tofu', 'post': ''},
#  'organic eggplant': {'pre': 'organic', 'food': 'eggplant', 'post': ''},
#  'organic marinara pasta sauce': {'pre': 'organic marinara',
#   'food': 'pasta sauce',
#   'post': ''},
#  'organic bunch beets': {'pre': '', 'food': 'organic', 'post': 'bunch beets'},
#  'feta cheese crumbles': {'pre': 'feta', 'food': 'cheese', 'post': 'crumbles'},
#  'pasta joy ready organic brown rice pasta penne': {'pre': '',
#   'food': 'pasta',
#   'post': 'joy ready organic brown rice pasta penne'},
#  '3 lb clementines': {'pre': '3 lb', 'food': 'clementines', 'post': ''},
#  'organic whole strawberries': {'pre': 'organic whole',
#   'food': 'strawberries',
#   'post': ''},
#  'organic mango chunks': {'pre': 'organic', 'food': 'mango', 'post': 'chunks'},
#  'teriyaki veggie burgers': {'pre': 'teriyaki',
#   'food': 'veggie burgers',
#   'post': ''},
#  'organic tomato cluster': {'pre': 'organic',
#   'food': 'tomato',
#   'post': 'cluster'},
#  'coconut sugar pure & unrefined': {'pre': 'coconut',
#   'food': 'sugar',
#   'post': 'pure unrefined'},
#  'almond meal/flour': {'pre': 'almond meal', 'food': 'flour', 'post': ''},
#  'salted butter': {'pre': 'salted', 'food': 'butter', 'post': ''},
#  "organic d'anjou pears": {'pre': 'organic d anjou',
#   'food': 'pears',
#   'post': ''},
#  'cultured low fat buttermilk': {'pre': 'cultured low fat',
#   'food': 'buttermilk',
#   'post': ''},
#  'large lemon': {'pre': 'large', 'food': 'lemon', 'post': ''},
#  'organic strawberry fruit spread': {'pre': 'organic strawberry',
#   'food': 'fruit spread',
#   'post': ''},
#  'large greenhouse tomato': {'pre': 'large greenhouse',
#   'food': 'tomato',
#   'post': ''},
#  'original semisoft cheese': {'pre': 'original semisoft',
#   'food': 'cheese',
#   'post': ''},
#  'whole organic omega 3 milk': {'pre': 'whole organic omega 3',
#   'food': 'milk',
#   'post': ''},
#  'organic heavy whipping cream': {'pre': 'organic',
#   'food': 'heavy whipping cream',
#   'post': ''},
#  '1% lowfat milk': {'pre': '1 lowfat', 'food': 'milk', 'post': ''},
#  'organic whole milk strawberry beet berry yogurt pouch': {'pre': 'organic whole',
#   'food': 'milk',
#   'post': 'strawberry beet berry yogurt pouch'},
#  'organic black plum': {'pre': 'organic black', 'food': 'plum', 'post': ''},
#  'organic red delicious apple': {'pre': 'organic red delicious',
#   'food': 'apple',
#   'post': ''},
#  'raspberries': {'pre': '', 'food': 'raspberries', 'post': ''},
#  'baby cucumbers': {'pre': 'baby', 'food': 'cucumbers', 'post': ''},
#  'sinfully sweet campari tomatoes': {'pre': 'sinfully sweet campari',
#   'food': 'tomatoes',
#   'post': ''},
#  'mango chunks': {'pre': '', 'food': 'mango', 'post': 'chunks'},
#  'organic unsweetened soy milk beverage': {'pre': 'organic unsweetened',
#   'food': 'soy milk',
#   'post': 'beverage'},
#  'organic yellow onion': {'pre': 'organic yellow',
#   'food': 'onion',
#   'post': ''},
#  'seedless red grapes': {'pre': 'seedless red', 'food': 'grapes', 'post': ''},
#  'heirloom tomato': {'pre': 'heirloom', 'food': 'tomato', 'post': ''},
#  'organic whole grain sprouted quinoa': {'pre': 'organic whole grain sprouted',
#   'food': 'quinoa',
#   'post': ''},
#  'uncured, no sugar, hickory smoked bacon': {'pre': 'uncured no sugar hickory smoked',
#   'food': 'bacon',
#   'post': ''},
#  'organic vidalia onion': {'pre': 'organic vidalia',
#   'food': 'onion',
#   'post': ''},
#  'organic lactose free 1% lowfat milk': {'pre': 'organic lactose free 1 lowfat',
#   'food': 'milk',
#   'post': ''},
#  'lactose free grade a low fat vanilla yogurt': {'pre': 'lactose free grade a low fat vanilla',
#   'food': 'yogurt',
#   'post': ''},
#  'organic mixed vegetables': {'pre': 'organic',
#   'food': 'mixed vegetables',
#   'post': ''},
#  'cucumber kirby': {'pre': 'cucumber', 'food': 'kirby', 'post': ''},
#  'clementines, bag': {'pre': '', 'food': 'clementines', 'post': 'bag'},
#  'gluten free mushroom risotto bowl': {'pre': 'gluten free mushroom',
#   'food': 'risotto',
#   'post': 'bowl'},
#  'organic olive oil  spray': {'pre': 'organic',
#   'food': 'olive',
#   'post': 'oil spray'},
#  'baby swiss slices cheese': {'pre': 'baby swiss slices',
#   'food': 'cheese',
#   'post': ''},
#  'gourmet mochi ice cream vanilla bonbons': {'pre': 'gourmet mochi',
#   'food': 'ice cream',
#   'post': 'vanilla bonbons'},
#  'original recipe rice pudding': {'pre': 'original recipe',
#   'food': 'rice pudding',
#   'post': ''},
#  'bunny-luv organic carrots': {'pre': 'bunny luv organic',
#   'food': 'carrots',
#   'post': ''},
#  'cranberry almond chicken salad': {'pre': 'cranberry almond',
#   'food': 'chicken',
#   'post': 'salad'},
#  'organic garnet sweet potato (yam)': {'pre': 'organic garnet',
#   'food': 'sweet potato',
#   'post': 'yam'},
#  'organic fuji apple': {'pre': 'organic fuji', 'food': 'apple', 'post': ''},
#  'sliced genoa salami': {'pre': 'sliced genoa', 'food': 'salami', 'post': ''},
#  'organic 1% low fat milk': {'pre': 'organic 1 low fat',
#   'food': 'milk',
#   'post': ''},
#  'macaroni & cheese': {'pre': '', 'food': 'macaroni cheese', 'post': ''},
#  'chocolate milk 1% milkfat': {'pre': 'chocolate',
#   'food': 'milk',
#   'post': '1 milkfat'},
#  'uncured genoa salami': {'pre': 'uncured genoa',
#   'food': 'salami',
#   'post': ''},
#  'all natural seasoned waffle cut fries': {'pre': 'all natural seasoned waffle cut',
#   'food': 'fries',
#   'post': ''},
#  'unsweetened vanilla almond breeze': {'pre': 'unsweetened vanilla',
#   'food': 'almond',
#   'post': 'breeze'},
#  'pure irish butter': {'pre': 'pure irish', 'food': 'butter', 'post': ''},
#  'mozzarella light low moisture part skim string cheese': {'pre': 'mozzarella light low moisture part skim string',
#   'food': 'cheese',
#   'post': ''},
#  'white cheddar semisoft cheese': {'pre': 'white cheddar semisoft',
#   'food': 'cheese',
#   'post': ''},
#  'lowfat 2% milkfat cottage cheese': {'pre': 'lowfat 2 milkfat',
#   'food': 'cottage cheese',
#   'post': ''},
#  'black seedless grapes': {'pre': 'black seedless',
#   'food': 'grapes',
#   'post': ''},
#  'sausage biscuit': {'pre': 'sausage', 'food': 'biscuit', 'post': ''},
#  'cereal': {'pre': '', 'food': 'cereal', 'post': ''},
#  'breaded chicken breast tenders': {'pre': 'breaded',
#   'food': 'chicken',
#   'post': 'breast tenders'},
#  'honey roasted turkey': {'pre': 'honey roasted',
#   'food': 'turkey',
#   'post': ''},
#  'clover honey bear': {'pre': 'clover', 'food': 'honey', 'post': 'bear'},
#  'french onion dip': {'pre': '', 'food': 'french onion dip', 'post': ''},
#  'chicken pot pie': {'pre': '', 'food': 'chicken pot pie', 'post': ''},
#  'eggo nutri-grain blueberry waffles': {'pre': 'eggo nutri grain blueberry',
#   'food': 'waffles',
#   'post': ''},
#  'organic yams': {'pre': 'organic', 'food': 'yams', 'post': ''},
#  'flour tortillas': {'pre': 'flour', 'food': 'tortillas', 'post': ''},
#  'light sour cream': {'pre': 'light', 'food': 'sour cream', 'post': ''},
#  'simply 100® blueberry blended non-fat greek yogurt': {'pre': 'simply 100 blueberry blended non fat greek',
#   'food': 'yogurt',
#   'post': ''},
#  'simply 100 strawberry blended non-fat greek yogurt': {'pre': 'simply 100 strawberry blended non fat greek',
#   'food': 'yogurt',
#   'post': ''},
#  '90 calories low fat chocolate chunk granola bars': {'pre': '90 calories low fat chocolate chunk',
#   'food': 'granola',
#   'post': 'bars'},
#  'reduced fat sliced provolone cheese': {'pre': 'reduced fat sliced provolone',
#   'food': 'cheese',
#   'post': ''},
#  'deli select ultra thin honey ham': {'pre': 'deli select ultra thin honey',
#   'food': 'ham',
#   'post': ''},
#  "cafe steamers general tso's spicy chicken": {'pre': 'cafe steamers general tso s spicy',
#   'food': 'chicken',
#   'post': ''},
#  'chicken marsala': {'pre': '', 'food': 'chicken', 'post': 'marsala'},
#  '100% whole wheat bread': {'pre': '100 whole wheat',
#   'food': 'bread',
#   'post': ''},
#  'original': {'pre': '', 'food': 'original', 'post': ''},
#  "thick 'n creamy macaroni & cheese": {'pre': 'thick n creamy',
#   'food': 'macaroni cheese',
#   'post': ''},
#  'strawberries': {'pre': '', 'food': 'strawberries', 'post': ''},
#  'organic blueberries': {'pre': 'organic', 'food': 'blueberries', 'post': ''},
#  'beef franks': {'pre': '', 'food': 'beef franks', 'post': ''},
#  'golden pineapple': {'pre': 'golden', 'food': 'pineapple', 'post': ''},
#  'organic chicken bone broth': {'pre': 'organic chicken',
#   'food': 'bone broth',
#   'post': ''},
#  'yo baby organic whole milk banana mango yogurt': {'pre': 'yo baby organic whole milk banana mango',
#   'food': 'yogurt',
#   'post': ''},
#  'yokids squeezers organic low-fat yogurt, strawberry': {'pre': '',
#   'food': 'yokids',
#   'post': 'squeezers organic low fat yogurt strawberry'},
#  'low sodium beef broth': {'pre': 'low sodium',
#   'food': 'beef broth',
#   'post': ''},
#  'organic unrefined toasted sesame oil': {'pre': 'organic unrefined toasted',
#   'food': 'sesame oil',
#   'post': ''},
#  'gluten-free chicken nuggets': {'pre': 'gluten free',
#   'food': 'chicken',
#   'post': 'nuggets'},
#  'original barbeque sauce': {'pre': 'original',
#   'food': 'barbeque sauce',
#   'post': ''},
#  'milk, vitamin d': {'pre': '', 'food': 'milk', 'post': 'vitamin d'},
#  'organic blueberry': {'pre': 'organic', 'food': 'blueberry', 'post': ''},
#  'bananas': {'pre': '', 'food': 'bananas', 'post': ''},
#  'original pure creamy almond milk': {'pre': 'original pure creamy',
#   'food': 'almond milk',
#   'post': ''},
#  'pure granulated cane sugar': {'pre': 'pure granulated cane',
#   'food': 'sugar',
#   'post': ''},
#  'mango yoghurt': {'pre': 'mango', 'food': 'yoghurt', 'post': ''},
#  'peach yoghurt': {'pre': 'peach', 'food': 'yoghurt', 'post': ''},
#  'all natural gluten free probiotic pineapple yoghurt': {'pre': 'all natural gluten free probiotic pineapple',
#   'food': 'yoghurt',
#   'post': ''},
#  'organic fresh basil': {'pre': 'organic fresh', 'food': 'basil', 'post': ''},
#  'shredded parmesan': {'pre': 'shredded', 'food': 'parmesan', 'post': ''},
#  'french vanilla ice cream': {'pre': 'french vanilla',
#   'food': 'ice cream',
#   'post': ''},
#  'artesano style bread': {'pre': 'artesano style',
#   'food': 'bread',
#   'post': ''},
#  'milk whole': {'pre': '', 'food': 'milk', 'post': 'whole'},
#  'baby dynamic duo potatoes': {'pre': 'baby dynamic duo',
#   'food': 'potatoes',
#   'post': ''},
#  'living potted rosemary': {'pre': 'living potted',
#   'food': 'rosemary',
#   'post': ''},
#  'yellow straightneck squash': {'pre': 'yellow straightneck',
#   'food': 'squash',
#   'post': ''},
#  'acorn squash': {'pre': '', 'food': 'acorn squash', 'post': ''},
#  'apple cider vinegar': {'pre': 'apple cider', 'food': 'vinegar', 'post': ''},
#  'gala apples': {'pre': 'gala', 'food': 'apples', 'post': ''},
#  'cinnamon raisin granola': {'pre': 'cinnamon raisin',
#   'food': 'granola',
#   'post': ''},
#  'organic gala apples': {'pre': 'organic gala', 'food': 'apples', 'post': ''},
#  'sprouted multi-grain bread': {'pre': 'sprouted multi grain',
#   'food': 'bread',
#   'post': ''},
#  'organic original tofu veggie burger': {'pre': 'organic original tofu',
#   'food': 'veggie burger',
#   'post': ''},
#  'sweet baguette': {'pre': 'sweet', 'food': 'baguette', 'post': ''},
#  'organic grape tomatoes': {'pre': 'organic grape',
#   'food': 'tomatoes',
#   'post': ''},
#  'organic lemon': {'pre': 'organic', 'food': 'lemon', 'post': ''},
#  'organic traditional flour tortillas': {'pre': 'organic traditional flour',
#   'food': 'tortillas',
#   'post': ''},
#  'organic raw sharp cheddar cheese': {'pre': 'organic raw sharp cheddar',
#   'food': 'cheese',
#   'post': ''},
#  'burrata': {'pre': '', 'food': 'burrata', 'post': ''},
#  'instant french vanilla pudding & pie filling': {'pre': 'instant',
#   'food': 'french',
#   'post': 'vanilla pudding pie filling'},
#  'mixed berries wildly nutritious signature blends': {'pre': 'mixed',
#   'food': 'berries',
#   'post': 'wildly nutritious signature blends'},
#  'original whipped topping': {'pre': 'original',
#   'food': 'whipped topping',
#   'post': ''},
#  'sliced peaches': {'pre': 'sliced', 'food': 'peaches', 'post': ''},
#  'unsalted butter': {'pre': 'unsalted', 'food': 'butter', 'post': ''},
#  'semi-sweet chocolate premium baking chips': {'pre': '',
#   'food': 'semi',
#   'post': 'sweet chocolate premium baking chips'},
#  'total 2% lowfat plain greek yogurt': {'pre': 'total 2 lowfat plain greek',
#   'food': 'yogurt',
#   'post': ''},
#  'roasted mushroom pizza': {'pre': 'roasted mushroom',
#   'food': 'pizza',
#   'post': ''},
#  'italian sausage pizza': {'pre': 'italian sausage',
#   'food': 'pizza',
#   'post': ''},
#  'organic cucumber': {'pre': 'organic', 'food': 'cucumber', 'post': ''},
#  'spaghetti': {'pre': '', 'food': 'spaghetti', 'post': ''},
#  'large alfresco eggs': {'pre': 'large alfresco', 'food': 'eggs', 'post': ''},
#  'organic spinach bunch': {'pre': 'organic',
#   'food': 'spinach',
#   'post': 'bunch'},
#  'blood oranges': {'pre': 'blood', 'food': 'oranges', 'post': ''},
#  'organic 21 grain thin sliced bread': {'pre': 'organic 21 grain thin sliced',
#   'food': 'bread',
#   'post': ''},
#  'organic large green asparagus': {'pre': 'organic large green',
#   'food': 'asparagus',
#   'post': ''},
#  'organic braeburn apple': {'pre': 'organic braeburn',
#   'food': 'apple',
#   'post': ''},
#  'organic tomato paste': {'pre': 'organic',
#   'food': 'tomato paste',
#   'post': ''},
#  'organic garlic': {'pre': 'organic', 'food': 'garlic', 'post': ''},
#  'blueberries': {'pre': '', 'food': 'blueberries', 'post': ''},
#  'buttermilk biscuits': {'pre': 'buttermilk', 'food': 'biscuits', 'post': ''},
#  'coconut almond creamer blend': {'pre': '',
#   'food': 'coconut',
#   'post': 'almond creamer blend'},
#  'organic bartlett pear': {'pre': 'organic bartlett',
#   'food': 'pear',
#   'post': ''},
#  'organic large extra fancy fuji apple': {'pre': 'organic large extra fancy fuji',
#   'food': 'apple',
#   'post': ''},
#  'authentic french brioche': {'pre': 'authentic',
#   'food': 'french brioche',
#   'post': ''},
#  'marinara sauce': {'pre': '', 'food': 'marinara sauce', 'post': ''},
#  'organic original hommus': {'pre': 'organic original',
#   'food': 'hommus',
#   'post': ''},
#  'organic blackberries': {'pre': 'organic',
#   'food': 'blackberries',
#   'post': ''},
#  'organic australian style vanilla lowfat yogurt': {'pre': 'organic australian style vanilla lowfat',
#   'food': 'yogurt',
#   'post': ''},
#  'tomato sauce': {'pre': '', 'food': 'tomato sauce', 'post': ''},
#  'organic honeydew': {'pre': 'organic', 'food': 'honeydew', 'post': ''},
#  'organic green seedless grapes': {'pre': 'organic green seedless',
#   'food': 'grapes',
#   'post': ''},
#  'muffins, mini, flax, chocolate brownie': {'pre': 'muffins mini flax chocolate',
#   'food': 'brownie',
#   'post': ''},
#  'organic whole wheat bread': {'pre': 'organic whole wheat',
#   'food': 'bread',
#   'post': ''},
#  'organic shredded mild cheddar': {'pre': 'organic shredded mild',
#   'food': 'cheddar',
#   'post': ''},
#  'skim milk': {'pre': 'skim', 'food': 'milk', 'post': ''},
#  'organic diced tomatoes': {'pre': 'organic diced',
#   'food': 'tomatoes',
#   'post': ''},
#  'organic roasted turkey breast': {'pre': 'organic roasted',
#   'food': 'turkey',
#   'post': 'breast'},
#  'organic spring mix salad': {'pre': 'organic',
#   'food': 'spring',
#   'post': 'mix salad'},
#  'premium grapefruit large': {'pre': 'premium',
#   'food': 'grapefruit',
#   'post': 'large'},
#  'dairy free unsweetened coconut milk': {'pre': 'dairy free unsweetened',
#   'food': 'coconut milk',
#   'post': ''},
#  'original almondmilk': {'pre': 'original', 'food': 'almondmilk', 'post': ''},
#  'with crispy almonds cereal': {'pre': 'with crispy almonds',
#   'food': 'cereal',
#   'post': ''},
#  'organic low fat milk': {'pre': 'organic low fat',
#   'food': 'milk',
#   'post': ''},
#  'half and half cream': {'pre': '', 'food': 'half and half', 'post': 'cream'},
#  'non fat greek yogurt': {'pre': 'non fat greek',
#   'food': 'yogurt',
#   'post': ''},
#  '0% greek strained yogurt': {'pre': '0 greek strained',
#   'food': 'yogurt',
#   'post': ''},
#  'tilapia filet': {'pre': '', 'food': 'tilapia', 'post': 'filet'},
#  'organic lactose free whole milk': {'pre': 'organic lactose free whole',
#   'food': 'milk',
#   'post': ''},
#  'xl emerald white seedless grapes': {'pre': 'xl emerald white seedless',
#   'food': 'grapes',
#   'post': ''},
#  'limes': {'pre': '', 'food': 'limes', 'post': ''},
#  'jalapeno peppers': {'pre': 'jalapeno', 'food': 'peppers', 'post': ''},
#  'wild blend rice': {'pre': 'wild blend', 'food': 'rice', 'post': ''},
#  'reduced-fat soft cream cheese': {'pre': 'reduced fat soft',
#   'food': 'cream cheese',
#   'post': ''},
#  'whole grain oatmeal bread': {'pre': 'whole grain oatmeal',
#   'food': 'bread',
#   'post': ''},
#  'steamfresh selects frozen broccoli, cauliflower & carrots': {'pre': 'steamfresh selects frozen broccoli cauliflower',
#   'food': 'carrots',
#   'post': ''},
#  'steamfresh premium selects frozen whole green beans': {'pre': '',
#   'food': 'steamfresh',
#   'post': 'premium selects frozen whole green beans'},
#  'boneless skinless chicken breast': {'pre': 'boneless skinless',
#   'food': 'chicken',
#   'post': 'breast'},
#  'turkey': {'pre': '', 'food': 'turkey', 'post': ''},
#  'red bell pepper': {'pre': 'red', 'food': 'bell pepper', 'post': ''},
#  'red potatoes': {'pre': 'red', 'food': 'potatoes', 'post': ''},
#  'half and half ultra pasteurized': {'pre': '',
#   'food': 'half',
#   'post': 'and half ultra pasteurized'},
#  'smoothies, strawberries wild': {'pre': '',
#   'food': 'smoothies',
#   'post': 'strawberries wild'},
#  'organic 1% lowfat milk': {'pre': 'organic 1 lowfat',
#   'food': 'milk',
#   'post': ''},
#  'organic 2% reduced fat milk': {'pre': 'organic 2 reduced fat',
#   'food': 'milk',
#   'post': ''},
#  'soy sauce': {'pre': '', 'food': 'soy sauce', 'post': ''},
#  'all natural marinara pasta sauce': {'pre': 'all natural marinara',
#   'food': 'pasta sauce',
#   'post': ''},
#  'organic reduced fat milk': {'pre': 'organic reduced fat',
#   'food': 'milk',
#   'post': ''},
#  'roman raspberry sorbetto': {'pre': 'roman raspberry',
#   'food': 'sorbetto',
#   'post': ''},
#  'plain greek yogurt': {'pre': 'plain greek', 'food': 'yogurt', 'post': ''},
#  'maple glazed honey ham': {'pre': 'maple glazed honey',
#   'food': 'ham',
#   'post': ''},
#  'organic grade a large brown eggs': {'pre': 'organic grade a large brown',
#   'food': 'eggs',
#   'post': ''},
#  'cherry garcia ice cream': {'pre': 'cherry garcia',
#   'food': 'ice cream',
#   'post': ''},
#  'prosciutto': {'pre': '', 'food': 'prosciutto', 'post': ''},
#  'gourmet tomato medley': {'pre': 'gourmet',
#   'food': 'tomato',
#   'post': 'medley'},
#  'granny smith apples': {'pre': 'granny smith', 'food': 'apples', 'post': ''},
#  'ginger dressing': {'pre': '', 'food': 'ginger dressing', 'post': ''},
#  'blackberries': {'pre': '', 'food': 'blackberries', 'post': ''},
#  'chocolate peanut butter cup gelato': {'pre': 'chocolate',
#   'food': 'peanut butter',
#   'post': 'cup gelato'},
#  'carrot raisin flax muffins': {'pre': '',
#   'food': 'carrot',
#   'post': 'raisin flax muffins'},
#  'hass avocados': {'pre': 'hass', 'food': 'avocados', 'post': ''},
#  'organic romaine leaf': {'pre': 'organic',
#   'food': 'romaine leaf',
#   'post': ''},
#  '100% whole wheat hot dog buns': {'pre': '100 whole wheat',
#   'food': 'hot',
#   'post': 'dog buns'},
#  'organic quinoa & brown rice with garlic': {'pre': 'organic',
#   'food': 'quinoa brown rice with garlic',
#   'post': ''},
#  'organic greek whole milk blended vanilla bean yogurt': {'pre': 'organic greek whole milk blended vanilla bean',
#   'food': 'yogurt',
#   'post': ''},
#  'boneless chicken breast': {'pre': 'boneless',
#   'food': 'chicken',
#   'post': 'breast'},
#  'organic crushed fire roasted tomatoes': {'pre': 'organic crushed fire roasted',
#   'food': 'tomatoes',
#   'post': ''},
#  'fresh ginger root': {'pre': 'fresh', 'food': 'ginger', 'post': 'root'},
#  'toasted coconut almondmilk blend': {'pre': 'toasted coconut',
#   'food': 'almondmilk',
#   'post': 'blend'},
#  'forelle pears': {'pre': 'forelle', 'food': 'pears', 'post': ''},
#  'original traditional dijon mustard': {'pre': 'original traditional dijon',
#   'food': 'mustard',
#   'post': ''},
#  'baby boomer fresh creamer potatoes': {'pre': 'baby boomer fresh creamer',
#   'food': 'potatoes',
#   'post': ''},
#  'vegan buttery sticks': {'pre': 'vegan', 'food': 'buttery', 'post': 'sticks'},
#  'squeeze real mayonnaise': {'pre': 'squeeze real',
#   'food': 'mayonnaise',
#   'post': ''},
#  'organic  unsalted  butter': {'pre': 'organic unsalted',
#   'food': 'butter',
#   'post': ''},
#  'organic homogenized whole milk': {'pre': 'organic homogenized whole',
#   'food': 'milk',
#   'post': ''},
#  'olive bread': {'pre': '', 'food': 'olive bread', 'post': ''},
#  'organic low sodium chicken cooking stock': {'pre': 'organic low sodium',
#   'food': 'chicken cooking stock',
#   'post': ''},
#  'original soy creamer': {'pre': 'original',
#   'food': 'soy creamer',
#   'post': ''},
#  'liquid egg whites': {'pre': 'liquid', 'food': 'egg whites', 'post': ''},
#  'americone dream® ice cream': {'pre': 'americone dream',
#   'food': 'ice cream',
#   'post': ''},
#  'rosemary ham': {'pre': 'rosemary', 'food': 'ham', 'post': ''},
#  'organic mayonnaise': {'pre': 'organic', 'food': 'mayonnaise', 'post': ''},
#  'organic sunday bacon': {'pre': 'organic sunday',
#   'food': 'bacon',
#   'post': ''},
#  'organic beefsteak tomato': {'pre': 'organic beefsteak',
#   'food': 'tomato',
#   'post': ''},
#  'organic roma tomato': {'pre': 'organic roma', 'food': 'tomato', 'post': ''},
#  'organic plain greek whole milk yogurt': {'pre': 'organic plain greek whole milk',
#   'food': 'yogurt',
#   'post': ''},
#  'mint chip': {'pre': '', 'food': 'mint chip', 'post': ''},
#  'organic short brown sprouted rice': {'pre': 'organic',
#   'food': 'short',
#   'post': 'brown sprouted rice'},
#  'organic baby arugula': {'pre': 'organic baby',
#   'food': 'arugula',
#   'post': ''},
#  'four cheese thin crust pizza': {'pre': 'four cheese thin crust',
#   'food': 'pizza',
#   'post': ''},
#  'dark chocolate covered banana': {'pre': '',
#   'food': 'dark',
#   'post': 'chocolate covered banana'},
#  'grated parmesan cheese': {'pre': 'grated',
#   'food': 'parmesan',
#   'post': 'cheese'},
#  'imported capote capers': {'pre': 'imported capote',
#   'food': 'capers',
#   'post': ''},
#  'roasted garlic loaf': {'pre': 'roasted', 'food': 'garlic loaf', 'post': ''},
#  'seedless watermelon': {'pre': 'seedless', 'food': 'watermelon', 'post': ''},
#  'fresh sugar snap peas': {'pre': 'fresh',
#   'food': 'sugar snap peas',
#   'post': ''},
#  'grape tomatoes': {'pre': 'grape', 'food': 'tomatoes', 'post': ''},
#  'mini sweet peppers': {'pre': 'mini sweet', 'food': 'peppers', 'post': ''},
#  'organic gluten free maple buckwheat flakes': {'pre': 'organic',
#   'food': 'gluten',
#   'post': 'free maple buckwheat flakes'},
#  'organic vanilla soymilk': {'pre': 'organic vanilla',
#   'food': 'soymilk',
#   'post': ''},
#  'red peppers': {'pre': 'red', 'food': 'peppers', 'post': ''},
#  'yellow bell pepper': {'pre': 'yellow bell', 'food': 'pepper', 'post': ''},
#  'apple honeycrisp organic': {'pre': '',
#   'food': 'apple',
#   'post': 'honeycrisp organic'},
#  'orange bell pepper': {'pre': 'orange bell', 'food': 'pepper', 'post': ''},
#  'beyond beef beefy crumble': {'pre': '',
#   'food': 'beyond beef',
#   'post': 'beefy crumble'},
#  'california sourdough bread': {'pre': 'california sourdough',
#   'food': 'bread',
#   'post': ''},
#  'hummus, hope, original recipe': {'pre': '',
#   'food': 'hummus',
#   'post': 'hope original recipe'},
#  'seven grain crispy tenders': {'pre': 'seven grain crispy',
#   'food': 'tenders',
#   'post': ''},
#  'organic tomato basil pasta sauce': {'pre': 'organic tomato basil',
#   'food': 'pasta sauce',
#   'post': ''},
#  'marinara pasta sauce': {'pre': 'marinara',
#   'food': 'pasta sauce',
#   'post': ''},
#  'organic extra large grade aa brown eggs': {'pre': 'organic extra large grade aa brown',
#   'food': 'eggs',
#   'post': ''},
#  'veggie burger, quarter pound': {'pre': '',
#   'food': 'veggie burger',
#   'post': 'quarter pound'},
#  'fat free skim milk': {'pre': 'fat free skim', 'food': 'milk', 'post': ''},
#  'fresh mozzarella all-natural sliced cheese': {'pre': 'fresh mozzarella all natural sliced',
#   'food': 'cheese',
#   'post': ''},
#  'roasted pine nut hummus': {'pre': 'roasted pine nut',
#   'food': 'hummus',
#   'post': ''},
#  'whole milk': {'pre': 'whole', 'food': 'milk', 'post': ''},
#  'bag of oranges': {'pre': 'bag of', 'food': 'oranges', 'post': ''},
#  'organic yokids lemonade/blueberry variety pack yogurt squeezers tubes': {'pre': 'organic',
#   'food': 'yokids',
#   'post': 'lemonade blueberry variety pack yogurt squeezers tubes'},
#  'sour cream': {'pre': '', 'food': 'sour cream', 'post': ''},
#  'sliced baby bella mushrooms': {'pre': 'sliced baby bella',
#   'food': 'mushrooms',
#   'post': ''},
#  'organic acorn squash': {'pre': 'organic',
#   'food': 'acorn squash',
#   'post': ''},
#  'canary melon': {'pre': 'canary', 'food': 'melon', 'post': ''},
#  'organic english cucumber': {'pre': 'organic english',
#   'food': 'cucumber',
#   'post': ''},
#  'organic kiwi': {'pre': 'organic', 'food': 'kiwi', 'post': ''},
#  'fancy whole artichoke hearts': {'pre': '',
#   'food': 'fancy',
#   'post': 'whole artichoke hearts'},
#  'brussels sprouts': {'pre': '', 'food': 'brussels sprouts', 'post': ''},
#  'reduced fat milk 2%': {'pre': 'reduced fat', 'food': 'milk', 'post': '2'},
#  'premium traditional homestyle cream style corn': {'pre': 'premium traditional homestyle',
#   'food': 'cream',
#   'post': 'style corn'},
#  'organic whole kernel sweet corn no salt added': {'pre': 'organic whole kernel sweet',
#   'food': 'corn',
#   'post': 'no salt added'},
#  'mild diced green chiles': {'pre': 'mild diced green',
#   'food': 'chiles',
#   'post': ''},
#  'organic beef uncured hot dogs': {'pre': 'organic beef uncured',
#   'food': 'hot',
#   'post': 'dogs'},
#  'sunrise crunchy cinnamon cereal': {'pre': 'sunrise crunchy cinnamon',
#   'food': 'cereal',
#   'post': ''},
#  'organic vanilla almond milk': {'pre': 'organic vanilla',
#   'food': 'almond milk',
#   'post': ''},
#  'large pineapple chunks': {'pre': 'large',
#   'food': 'pineapple',
#   'post': 'chunks'},
#  'light & lean sweet & sour asian noodle pasta': {'pre': 'light lean sweet sour asian noodle',
#   'food': 'pasta',
#   'post': ''},
#  'light & lean black bean and cheese enchilada': {'pre': 'light lean black bean and',
#   'food': 'cheese',
#   'post': 'enchilada'},
#  'light and lean 3 cheese penne marinara': {'pre': '',
#   'food': 'light',
#   'post': 'and lean 3 cheese penne marinara'},
#  'cheese ravioli': {'pre': '', 'food': 'cheese', 'post': 'ravioli'},
#  'original bbq sauce': {'pre': 'original', 'food': 'bbq sauce', 'post': ''},
#  'organic milk': {'pre': 'organic', 'food': 'milk', 'post': ''},
#  'ancient grain blueberry hemp granola': {'pre': 'ancient grain blueberry hemp',
#   'food': 'granola',
#   'post': ''},
#  'bunched cilantro': {'pre': 'bunched', 'food': 'cilantro', 'post': ''},
#  'organic mint': {'pre': 'organic', 'food': 'mint', 'post': ''},
#  'mango coconut chia squeeze': {'pre': 'mango',
#   'food': 'coconut',
#   'post': 'chia squeeze'},
#  'tomatoes, crushed, organic': {'pre': '',
#   'food': 'tomatoes',
#   'post': 'crushed organic'},
#  'green seedless grapes': {'pre': 'green seedless',
#   'food': 'grapes',
#   'post': ''},
#  'red globe grapes': {'pre': 'red globe', 'food': 'grapes', 'post': ''},
#  'mini marshmallows': {'pre': 'mini', 'food': 'marshmallows', 'post': ''},
#  'dha omega 3 vitamin d milk': {'pre': 'dha omega 3 vitamin d',
#   'food': 'milk',
#   'post': ''},
#  'organic whole grain wheat english muffins': {'pre': 'organic whole grain wheat',
#   'food': 'english muffins',
#   'post': ''},
#  'lite salt': {'pre': 'lite', 'food': 'salt', 'post': ''},
#  'chopped green chiles': {'pre': 'chopped green',
#   'food': 'chiles',
#   'post': ''},
#  'turkey store lean ground turkey': {'pre': '',
#   'food': 'turkey',
#   'post': 'store lean ground turkey'},
#  'leafy green romaine lettuce': {'pre': 'leafy green romaine',
#   'food': 'lettuce',
#   'post': ''},
#  'honey mustard dressing topping & spread': {'pre': '',
#   'food': 'honey mustard',
#   'post': 'dressing topping spread'},
#  'half and half': {'pre': '', 'food': 'half and half', 'post': ''},
#  'organic strawberry smoothie': {'pre': 'organic strawberry',
#   'food': 'smoothie',
#   'post': ''},
#  'total 2% all natural greek strained yogurt with honey': {'pre': 'total 2 all natural greek strained',
#   'food': 'yogurt',
#   'post': 'with honey'},
#  'organic peeled whole baby carrots': {'pre': 'organic peeled whole baby',
#   'food': 'carrots',
#   'post': ''},
#  'garlic hummus': {'pre': 'garlic', 'food': 'hummus', 'post': ''},
#  'penne rigate #41 pasta': {'pre': '',
#   'food': 'penne',
#   'post': 'rigate 41 pasta'},
#  'smoked turkey breast slices': {'pre': 'smoked',
#   'food': 'turkey',
#   'post': 'breast slices'},
#  'atlantic salmon fillets': {'pre': '',
#   'food': 'atlantic',
#   'post': 'salmon fillets'},
#  'baby seedless cucumbers': {'pre': 'baby seedless',
#   'food': 'cucumbers',
#   'post': ''},
#  'asparation/broccolini/baby broccoli': {'pre': 'asparation broccolini baby',
#   'food': 'broccoli',
#   'post': ''},
#  'crescent rolls': {'pre': '', 'food': 'crescent rolls', 'post': ''},
#  'organic tomato sauce': {'pre': 'organic',
#   'food': 'tomato sauce',
#   'post': ''},
#  'organic whole peeled tomatoes': {'pre': 'organic whole peeled',
#   'food': 'tomatoes',
#   'post': ''},
#  'organic celery': {'pre': 'organic', 'food': 'celery', 'post': ''},
#  'organic shredded unsweetened coconut': {'pre': 'organic',
#   'food': 'shredded unsweetened coconut',
#   'post': ''},
#  'lightly breaded fish sticks': {'pre': 'lightly breaded',
#   'food': 'fish sticks',
#   'post': ''},
#  'smoked maple ham': {'pre': 'smoked maple', 'food': 'ham', 'post': ''},
#  'organic avocados': {'pre': 'organic', 'food': 'avocados', 'post': ''},
#  'wild berry smoothie': {'pre': 'wild berry', 'food': 'smoothie', 'post': ''},
#  'organic jasmine rice': {'pre': 'organic jasmine',
#   'food': 'rice',
#   'post': ''},
#  'organic toaster pastries frosted lotta chocolotta - 6 ct': {'pre': 'organic',
#   'food': 'toaster pastries',
#   'post': 'frosted lotta chocolotta 6 ct'},
#  'organic beef hot dogs': {'pre': 'organic beef',
#   'food': 'hot',
#   'post': 'dogs'},
#  'coconut aminos teriyaki sauce': {'pre': 'coconut aminos',
#   'food': 'teriyaki sauce',
#   'post': ''},
#  'organic yellow mustard': {'pre': 'organic yellow',
#   'food': 'mustard',
#   'post': ''},
#  'gluten free hamburger buns': {'pre': 'gluten free',
#   'food': 'hamburger buns',
#   'post': ''},
#  'chopped onions': {'pre': 'chopped', 'food': 'onions', 'post': ''},
#  'medium salsa organica': {'pre': 'medium',
#   'food': 'salsa',
#   'post': 'organica'},
#  'organic hass avocado bag': {'pre': 'organic hass',
#   'food': 'avocado',
#   'post': 'bag'},
#  'organic turkey bacon': {'pre': 'organic turkey',
#   'food': 'bacon',
#   'post': ''},
#  'taco seasoning mix original': {'pre': '',
#   'food': 'taco seasoning',
#   'post': 'mix original'},
#  'sweetened corn & oat cereal': {'pre': 'sweetened corn oat',
#   'food': 'cereal',
#   'post': ''},
#  'crunchy taco shells': {'pre': 'crunchy', 'food': 'taco shells', 'post': ''},
#  'french vanilla creamer': {'pre': 'french vanilla',
#   'food': 'creamer',
#   'post': ''},
#  'pure & natural sour cream': {'pre': 'pure natural',
#   'food': 'sour cream',
#   'post': ''},
#  '37% less sodium soy sauce': {'pre': '37 less sodium',
#   'food': 'soy sauce',
#   'post': ''},
#  'roma tomato': {'pre': 'roma', 'food': 'tomato', 'post': ''},
#  'delifresh combos the honey smoked turkey breast honey ham': {'pre': 'delifresh combos the honey smoked',
#   'food': 'turkey',
#   'post': 'breast honey ham'},
#  'frozen organic wild blueberries': {'pre': 'frozen organic wild',
#   'food': 'blueberries',
#   'post': ''},
#  'purity farms ghee clarified butter': {'pre': 'purity farms ghee clarified',
#   'food': 'butter',
#   'post': ''},
#  'wild sockeye salmon': {'pre': 'wild sockeye', 'food': 'salmon', 'post': ''},
#  'boneless & skinless wild alaskan sockeye salmon': {'pre': 'boneless skinless wild alaskan sockeye',
#   'food': 'salmon',
#   'post': ''},
#  'organic whole string cheese': {'pre': 'organic whole string',
#   'food': 'cheese',
#   'post': ''},
#  'organic free range large grade a brown eggs': {'pre': 'organic free range large grade a brown',
#   'food': 'eggs',
#   'post': ''},
#  'plain goat milk yogurt': {'pre': 'plain goat milk',
#   'food': 'yogurt',
#   'post': ''},
#  'hickory smoked ham': {'pre': 'hickory smoked', 'food': 'ham', 'post': ''},
#  'organic muenster cheese': {'pre': 'organic muenster',
#   'food': 'cheese',
#   'post': ''},
#  'natural chicken & maple breakfast sausage patty': {'pre': 'natural chicken maple breakfast',
#   'food': 'sausage',
#   'post': 'patty'},
#  'chicken & maple breakfast sausage': {'pre': 'chicken maple breakfast',
#   'food': 'sausage',
#   'post': ''},
#  'chocolate chip cookie dough ice cream': {'pre': 'chocolate chip cookie dough',
#   'food': 'ice cream',
#   'post': ''},
# ...
#   'food': 'mashed potatoes garlic',
#   'post': 'id 525 refrigerated sides'},
#  'organic green cabbage': {'pre': 'organic green',
#   'food': 'cabbage',
#   'post': ''},
#  'condensed golden mushroom soup': {'pre': 'condensed golden mushroom',
#   'food': 'soup',
#   'post': ''},
#  'lunchables uploaded deep dish pizza with pepperoni': {'pre': 'lunchables uploaded deep dish',
#   'food': 'pizza',
#   'post': 'with pepperoni'},
#  'garlic herb goat cheese log': {'pre': '',
#   'food': 'garlic',
#   'post': 'herb goat cheese log'},
#  'non-dairy organic chocolate hazelnut fudge frozen dessert': {'pre': '',
#   'food': 'non',
#   'post': 'dairy organic chocolate hazelnut fudge frozen dessert'},
#  'sweetleaf natural stevia sweetener packets': {'pre': 'sweetleaf natural',
#   'food': 'stevia',
#   'post': 'sweetener packets'},
#  'organic gluten free pancake & baking mix': {'pre': 'organic gluten free',
#   'food': 'pancake baking mix',
#   'post': ''},
#  'brown eggs': {'pre': 'brown', 'food': 'eggs', 'post': ''},
#  'organic ketchup': {'pre': 'organic', 'food': 'ketchup', 'post': ''},
#  'organic salted butter': {'pre': 'organic salted',
#   'food': 'butter',
#   'post': ''},
#  'organic low fat vegetable barley soup': {'pre': 'organic low fat vegetable barley',
#   'food': 'soup',
#   'post': ''},
#  'sprouted whole wheat bread': {'pre': 'sprouted whole wheat',
#   'food': 'bread',
#   'post': ''},
#  'organic old fashioned rolled oats': {'pre': 'organic old fashioned rolled',
#   'food': 'oats',
#   'post': ''},
#  'island vanilla cereal': {'pre': 'island vanilla',
#   'food': 'cereal',
#   'post': ''},
#  'fresh fussilli': {'pre': 'fresh', 'food': 'fussilli', 'post': ''},
#  'lite swiss cheese deli fresh slices': {'pre': 'lite swiss',
#   'food': 'cheese',
#   'post': 'deli fresh slices'},
#  'apples & mangoes fruit bars': {'pre': 'apples mangoes',
#   'food': 'fruit bars',
#   'post': ''},
#  'cacao sweet raw chocolate nibs': {'pre': '',
#   'food': 'cacao',
#   'post': 'sweet raw chocolate nibs'},
#  'organic acai berry smoothie packs': {'pre': 'organic acai berry',
#   'food': 'smoothie',
#   'post': 'packs'},
#  'asparagus spears': {'pre': '', 'food': 'asparagus', 'post': 'spears'},
#  'red raspberries': {'pre': 'red', 'food': 'raspberries', 'post': ''},
#  'green peas': {'pre': 'green', 'food': 'peas', 'post': ''},
#  'sweet potato fries with sea salt': {'pre': '',
#   'food': 'sweet potato fries',
#   'post': 'with sea salt'},
#  'shoestring fries': {'pre': 'shoestring', 'food': 'fries', 'post': ''},
#  'romaine lettuce': {'pre': 'romaine', 'food': 'lettuce', 'post': ''},
#  'boniato sweet potato': {'pre': 'boniato',
#   'food': 'sweet potato',
#   'post': ''},
#  'sourdough bread': {'pre': 'sourdough', 'food': 'bread', 'post': ''},
#  'bok choy': {'pre': '', 'food': 'bok choy', 'post': ''},
#  'organic cripps pink apples': {'pre': 'organic cripps pink',
#   'food': 'apples',
#   'post': ''},
#  'dairy free unsweetened vanilla coconut milk': {'pre': 'dairy free unsweetened vanilla',
#   'food': 'coconut milk',
#   'post': ''},
#  'organic yellow peaches': {'pre': 'organic yellow',
#   'food': 'peaches',
#   'post': ''},
#  'organic mixed baby kale salad': {'pre': 'organic mixed baby',
#   'food': 'kale',
#   'post': 'salad'},
#  'apricot': {'pre': '', 'food': 'apricot', 'post': ''},
#  'fresh whole white mushrooms': {'pre': 'fresh whole white',
#   'food': 'mushrooms',
#   'post': ''},
#  'chunky peanut butter': {'pre': 'chunky',
#   'food': 'peanut butter',
#   'post': ''},
#  'pico de gallo chunky salsa': {'pre': 'pico de gallo chunky',
#   'food': 'salsa',
#   'post': ''},
#  'organic flour tortillas': {'pre': 'organic flour',
#   'food': 'tortillas',
#   'post': ''},
#  'shredded mild cheddar cheese': {'pre': 'shredded mild cheddar',
#   'food': 'cheese',
#   'post': ''},
#  'organic red kale': {'pre': 'organic red', 'food': 'kale', 'post': ''},
#  'turmeric root': {'pre': '', 'food': 'turmeric root', 'post': ''},
#  'organic daikon root, bunch': {'pre': 'organic',
#   'food': 'daikon root',
#   'post': 'bunch'},
#  'organic alfalfa sprouts': {'pre': 'organic',
#   'food': 'alfalfa sprouts',
#   'post': ''},
#  'double concentrated tomato paste in tube': {'pre': 'double concentrated',
#   'food': 'tomato paste',
#   'post': 'in tube'},
#  'semi-sweet mini chocolate chips': {'pre': 'semi sweet mini',
#   'food': 'chocolate',
#   'post': 'chips'},
#  'large grapefruit': {'pre': 'large', 'food': 'grapefruit', 'post': ''},
#  'organic unsweetened vanilla almond milk': {'pre': 'organic unsweetened vanilla',
#   'food': 'almond milk',
#   'post': ''},
#  'simply stock organic vegetable unsalted stock': {'pre': 'simply stock organic vegetable unsalted',
#   'food': 'stock',
#   'post': ''},
#  'yoghurt blueberry': {'pre': '', 'food': 'yoghurt', 'post': 'blueberry'},
#  'lemon yogurt': {'pre': 'lemon', 'food': 'yogurt', 'post': ''},
#  'honey yoghurt': {'pre': 'honey', 'food': 'yoghurt', 'post': ''},
#  'coconut yoghurt': {'pre': 'coconut', 'food': 'yoghurt', 'post': ''},
#  'raspberry on the bottom non-fat greek yogurt': {'pre': '',
#   'food': 'raspberry',
#   'post': 'on the bottom non fat greek yogurt'},
#  'pure baking soda': {'pre': 'pure', 'food': 'baking soda', 'post': ''},
#  'peppermint mocha liquid coffee creamer': {'pre': 'peppermint mocha liquid coffee',
#   'food': 'creamer',
#   'post': ''},
#  'angel food white cake mix': {'pre': 'angel food white',
#   'food': 'cake mix',
#   'post': ''},
#  'salad, cobb': {'pre': '', 'food': 'salad', 'post': 'cobb'},
#  'organic leek': {'pre': 'organic', 'food': 'leek', 'post': ''},
#  'organic thyme': {'pre': 'organic', 'food': 'thyme', 'post': ''},
#  'pastry kitchens classic puff pastry': {'pre': 'pastry kitchens classic',
#   'food': 'puff pastry',
#   'post': ''},
#  'strawberry organic kefir': {'pre': 'strawberry organic',
#   'food': 'kefir',
#   'post': ''},
#  'goo berry pie probugs kefir': {'pre': 'goo berry pie probugs',
#   'food': 'kefir',
#   'post': ''},
#  'cream cheese spread': {'pre': '', 'food': 'cream cheese', 'post': 'spread'},
#  'organic sticks low moisture part skim mozzarella string cheese': {'pre': 'organic sticks low moisture part skim mozzarella string',
#   'food': 'cheese',
#   'post': ''},
#  'vanilla light & fit greek yogurt': {'pre': 'vanilla light fit greek',
#   'food': 'yogurt',
#   'post': ''},
#  'organic whole milk with dha omega-3': {'pre': 'organic whole',
#   'food': 'milk',
#   'post': 'with dha omega 3'},
#  'shredded mozzarella cheese': {'pre': 'shredded mozzarella',
#   'food': 'cheese',
#   'post': ''},
#  'family size naturally flavored whole grain oats cereal': {'pre': 'family size naturally flavored whole grain oats',
#   'food': 'cereal',
#   'post': ''},
#  'eggo blueberry waffles': {'pre': 'eggo blueberry',
#   'food': 'waffles',
#   'post': ''},
#  'muscat grape jelly': {'pre': 'muscat grape', 'food': 'jelly', 'post': ''},
#  'crunch time': {'pre': 'crunch', 'food': 'time', 'post': ''},
#  'quaker life cinnamon cereal': {'pre': 'quaker life cinnamon',
#   'food': 'cereal',
#   'post': ''},
#  'organic edamame': {'pre': 'organic', 'food': 'edamame', 'post': ''},
#  'italian dry salame': {'pre': 'italian dry', 'food': 'salame', 'post': ''},
#  'multi grain sandwich thins': {'pre': 'multi grain',
#   'food': 'sandwich thins',
#   'post': ''},
#  'cocktail style cubes  spring water ice': {'pre': 'cocktail style cubes spring water',
#   'food': 'ice',
#   'post': ''},
#  'parsnip': {'pre': '', 'food': 'parsnip', 'post': ''},
#  'fancy eggplant': {'pre': 'fancy', 'food': 'eggplant', 'post': ''},
#  'organic baby broccoli': {'pre': 'organic baby',
#   'food': 'broccoli',
#   'post': ''},
#  'organic extra large brown eggs': {'pre': 'organic extra large brown',
#   'food': 'eggs',
#   'post': ''},
#  'organic lite coconut milk': {'pre': 'organic lite',
#   'food': 'coconut milk',
#   'post': ''},
#  'reduced fat milk 100% lactose free': {'pre': 'reduced fat',
#   'food': 'milk',
#   'post': '100 lactose free'},
#  'spinach souffle': {'pre': '', 'food': 'spinach souffle', 'post': ''},
#  'natural deli slices gouda cheese': {'pre': 'natural deli slices gouda',
#   'food': 'cheese',
#   'post': ''},
#  'organic maple syrup': {'pre': 'organic', 'food': 'maple syrup', 'post': ''},
#  'gogo squeez organic apple strawberry applesauce on the go': {'pre': 'gogo squeez organic apple strawberry',
#   'food': 'applesauce',
#   'post': 'on the go'},
#  'organic low fat plain yogurt': {'pre': 'organic low fat plain',
#   'food': 'yogurt',
#   'post': ''},
#  'organic mango': {'pre': 'organic', 'food': 'mango', 'post': ''},
#  'organic navel orange': {'pre': 'organic navel',
#   'food': 'orange',
#   'post': ''},
#  'european-style cultured butter': {'pre': 'european style cultured',
#   'food': 'butter',
#   'post': ''},
#  'organic distilled white vinegar': {'pre': 'organic distilled white',
#   'food': 'vinegar',
#   'post': ''},
#  'organic greek plain lowfat yogurt': {'pre': 'organic greek plain lowfat',
#   'food': 'yogurt',
#   'post': ''},
#  'organic cheddar crazy bugs macaroni & cheese dinner': {'pre': 'organic cheddar crazy bugs',
#   'food': 'macaroni cheese',
#   'post': 'dinner'},
#  'lactose free sour cream': {'pre': 'lactose free',
#   'food': 'sour cream',
#   'post': ''},
#  'tuna ventresca, in olive oil': {'pre': 'tuna ventresca in',
#   'food': 'olive oil',
#   'post': ''},
#  'sun dried tomato pesto': {'pre': 'sun dried',
#   'food': 'tomato pesto',
#   'post': ''},
#  'organic brown rice': {'pre': 'organic brown', 'food': 'rice', 'post': ''},
#  'yokids strawberry banana/strawberry yogurt': {'pre': 'yokids strawberry banana strawberry',
#   'food': 'yogurt',
#   'post': ''},
#  'european cucumber': {'pre': 'european', 'food': 'cucumber', 'post': ''},
#  'organic balance milk protein shake dark chocolate': {'pre': 'organic balance',
#   'food': 'milk',
#   'post': 'protein shake dark chocolate'},
#  'organic snipped green beans': {'pre': 'organic snipped',
#   'food': 'green beans',
#   'post': ''},
#  'organic yobaby vanilla yogurt': {'pre': 'organic yobaby vanilla',
#   'food': 'yogurt',
#   'post': ''},
#  'sweet italian chicken sausage': {'pre': 'sweet italian chicken',
#   'food': 'sausage',
#   'post': ''},
#  'white cooking wine': {'pre': 'white', 'food': 'cooking wine', 'post': ''},
#  'crushed tomatoes': {'pre': 'crushed', 'food': 'tomatoes', 'post': ''},
#  'heavy cream': {'pre': '', 'food': 'heavy cream', 'post': ''},
#  'total 2% lowfat greek yogurt with honey': {'pre': 'total 2 lowfat greek',
#   'food': 'yogurt',
#   'post': 'with honey'},
#  'quick-rise yeast for bread machines': {'pre': 'quick rise',
#   'food': 'yeast',
#   'post': 'for bread machines'},
#  'dry rubbed thick sliced pork bacon': {'pre': 'dry rubbed thick sliced',
#   'food': 'pork bacon',
#   'post': ''},
#  'cake mix, yellow': {'pre': '', 'food': 'cake mix', 'post': 'yellow'},
#  'organic homestyle waffles': {'pre': 'organic homestyle',
#   'food': 'waffles',
#   'post': ''},
#  'strawberry fig bars': {'pre': 'strawberry', 'food': 'fig', 'post': 'bars'},
#  'organic kale greens': {'pre': 'organic', 'food': 'kale', 'post': 'greens'},
#  'english seedless cucumber': {'pre': 'english seedless',
#   'food': 'cucumber',
#   'post': ''},
#  'sushi nori, pacific, organic': {'pre': '',
#   'food': 'sushi',
#   'post': 'nori pacific organic'},
#  'organic low sodium chicken broth': {'pre': 'organic low sodium',
#   'food': 'chicken broth',
#   'post': ''},
#  'unsweetened almond milk': {'pre': 'unsweetened',
#   'food': 'almond milk',
#   'post': ''},
#  'gluten free old fashioned rolled oats': {'pre': 'gluten free old fashioned rolled',
#   'food': 'oats',
#   'post': ''},
#  'organic extra firm tofu': {'pre': 'organic extra firm',
#   'food': 'tofu',
#   'post': ''},
#  'creamy almond butter': {'pre': 'creamy',
#   'food': 'almond butter',
#   'post': ''},
#  'organic short grain brown rice': {'pre': 'organic',
#   'food': 'short',
#   'post': 'grain brown rice'},
#  'medium navel orange': {'pre': 'medium navel', 'food': 'orange', 'post': ''},
#  'total 0% greek yogurt': {'pre': 'total 0 greek',
#   'food': 'yogurt',
#   'post': ''},
#  'pumpkin fig ancient grain granola': {'pre': 'pumpkin fig ancient grain',
#   'food': 'granola',
#   'post': ''},
#  'organic creamy tomato soup': {'pre': 'organic creamy tomato',
#   'food': 'soup',
#   'post': ''},
#  'steel cut irish oatmeal': {'pre': 'steel cut irish',
#   'food': 'oatmeal',
#   'post': ''},
#  'light mayonnaise': {'pre': 'light', 'food': 'mayonnaise', 'post': ''},
#  'bag of large lemons': {'pre': 'bag of large', 'food': 'lemons', 'post': ''},
#  'organic small curd cottage cheese': {'pre': 'organic small curd',
#   'food': 'cottage cheese',
#   'post': ''},
#  'chicken tenders': {'pre': '', 'food': 'chicken tenders', 'post': ''},
#  'hot mexican-style chili powder': {'pre': '',
#   'food': 'hot',
#   'post': 'mexican style chili powder'},
#  'pop-tarts unfrosted strawberry': {'pre': 'pop tarts unfrosted',
#   'food': 'strawberry',
#   'post': ''},
#  'natural medium cheddar cheese': {'pre': 'natural medium cheddar',
#   'food': 'cheese',
#   'post': ''},
#  'porcini & truffle ravioli in egg pasta': {'pre': 'porcini truffle ravioli in egg',
#   'food': 'pasta',
#   'post': ''},
#  'organic reduced fat 2% milk': {'pre': 'organic reduced fat 2',
#   'food': 'milk',
#   'post': ''},
#  '2% reduced fat organic milk': {'pre': '2 reduced fat organic',
#   'food': 'milk',
#   'post': ''},
#  'whole grains health nut bread': {'pre': 'whole grains health nut',
#   'food': 'bread',
#   'post': ''},
#  'bartlett pears': {'pre': 'bartlett', 'food': 'pears', 'post': ''},
#  'fresh & fruity arbequina extra virgin olive oil': {'pre': 'fresh fruity arbequina extra virgin',
#   'food': 'olive oil',
#   'post': ''},
#  'country white bread': {'pre': 'country white', 'food': 'bread', 'post': ''},
#  'vegetable oil': {'pre': 'vegetable', 'food': 'oil', 'post': ''},
#  'feta crumbled traditional cheese': {'pre': 'feta crumbled traditional',
#   'food': 'cheese',
#   'post': ''},
#  'jasmine ready rice': {'pre': 'jasmine ready', 'food': 'rice', 'post': ''},
#  'iodized salt & pepper': {'pre': '',
#   'food': 'iodized',
#   'post': 'salt pepper'},
#  'masa harina golden corn flour': {'pre': 'masa harina golden corn',
#   'food': 'flour',
#   'post': ''},
#  'spanish style yellow rice': {'pre': 'spanish style yellow',
#   'food': 'rice',
#   'post': ''},
#  'red mango': {'pre': 'red', 'food': 'mango', 'post': ''},
#  'grape-nuts cereal': {'pre': 'grape nuts', 'food': 'cereal', 'post': ''},
#  'turkey pepperoni slices': {'pre': '',
#   'food': 'turkey',
#   'post': 'pepperoni slices'},
#  'premium sweet petites carrots': {'pre': 'premium sweet petites',
#   'food': 'carrots',
#   'post': ''},
#  'original rice pilaf mix': {'pre': 'original',
#   'food': 'rice pilaf',
#   'post': 'mix'},
#  'iodized salt': {'pre': 'iodized', 'food': 'salt', 'post': ''},
#  'corn maize tortillas': {'pre': 'corn maize',
#   'food': 'tortillas',
#   'post': ''},
#  'chocolate ice cream': {'pre': 'chocolate', 'food': 'ice cream', 'post': ''},
#  'genuine brewed rice vinegar': {'pre': 'genuine brewed',
#   'food': 'rice vinegar',
#   'post': ''},
#  'pork chorizo': {'pre': '', 'food': 'pork chorizo', 'post': ''},
#  'organic air chilled whole chicken': {'pre': 'organic air chilled whole',
#   'food': 'chicken',
#   'post': ''},
#  'organic banana': {'pre': 'organic', 'food': 'banana', 'post': ''},
#  'grass fed ground beef': {'pre': 'grass fed ground',
#   'food': 'beef',
#   'post': ''},
#  'fancy lump white, crab meat': {'pre': 'fancy lump white',
#   'food': 'crab meat',
#   'post': ''},
#  'claw crab meat': {'pre': 'claw', 'food': 'crab meat', 'post': ''},
#  'yukon gold potatoes 5lb bag': {'pre': 'yukon gold',
#   'food': 'potatoes',
#   'post': '5lb bag'},
#  'honeycrisp apples': {'pre': 'honeycrisp', 'food': 'apples', 'post': ''},
#  'organic multigrain bread': {'pre': 'organic multigrain',
#   'food': 'bread',
#   'post': ''},
#  'key limes': {'pre': 'key', 'food': 'limes', 'post': ''},
#  'frozen peaches': {'pre': 'frozen', 'food': 'peaches', 'post': ''},
#  'whole strawberries': {'pre': 'whole', 'food': 'strawberries', 'post': ''},
#  'cara cara navel orange': {'pre': 'cara cara navel',
#   'food': 'orange',
#   'post': ''},
#  'tortillas, corn, organic': {'pre': '',
#   'food': 'tortillas',
#   'post': 'corn organic'},
#  'organic cream of chicken condensed soup': {'pre': 'organic cream of chicken condensed',
#   'food': 'soup',
#   'post': ''},
#  'just mayo': {'pre': 'just', 'food': 'mayo', 'post': ''},
#  ...}

# %% [markdown]
# Let's make a new list of foods that we can replace the old list with.

# %%
def food_label_finder(token_list, label_list):
    pre = []
    food = []
    post = []

    for word, label in zip(token_list, label_list):
        if label == 'pre':
            pre.append(word.lower())
        if label == 'food':
            food.append(word.lower())
        if label == 'post':
            post.append(word.lower())
    return " ".join(food)

# %%
prod_list_new = []
for token, label in zip(token_sr, y_pred):
    prod_list_new.append(food_label_finder(token, label))

# %%
prod_list_new
# Out:
# ['egg whites',
#  'kale',
#  'garlic powder',
#  'coconut butter',
#  'natural sweetener',
#  'carrots',
#  'gelatine mix',
#  'natural',
#  'cole slaw',
#  'yogurt',
#  'almondmilk',
#  'lemons',
#  'spinach',
#  'chocolate',
#  'ginger',
#  'chicken',
#  'bread',
#  'bagels',
#  'oats',
#  'kellogg',
#  'breakfast bars',
#  'cereal',
#  'bananas',
#  'just',
#  'fruit salad',
#  'raspberries',
#  'milk',
#  'tea',
#  'chicken',
#  'cheese',
#  'macaroni and cheese',
#  'clementines',
#  'artichokes',
#  'apricot preserves',
#  'cheese',
#  'avocado',
#  'pasta',
#  'lemon',
#  'lemons',
#  'pineapple',
#  'sweet',
#  'radish',
#  'mushrooms',
#  'spinach',
#  'kefir',
#  'applesauce',
#  'green beans',
#  'olive oil',
#  'french baguettes',
#  'bread',
#  'almond',
#  'cheese',
#  'granola',
#  'banana',
#  'mushrooms',
#  'cilantro',
#  'avocado',
#  'onions',
#  'parsley',
#  'strawberries',
#  'beans',
#  'green beans',
#  'half half',
#  'steak',
#  'lettuce',
#  'sunchoke',
#  'chicken',
#  'salsa',
#  'beans',
#  'olive oil',
#  'coffee creamer',
#  'milk',
#  'heavenly',
#  'whipped topping',
#  'soup',
#  'chicken',
#  'pizza',
#  'salsa',
#  'salsa',
#  'cream cheese',
#  'sour cream',
#  'milk',
#  'waffles',
#  'chicken',
#  'cheese',
#  'cereal',
#  'yogurt',
#  'pizza crust',
#  'chili sauce',
#  'broccoli',
#  'apple',
#  'olive oil',
#  'beans',
#  'tomato',
#  'apricots',
#  'watermelon',
#  'milk',
#  'pear',
#  'raspberries',
#  'mango',
#  'eggplant',
#  'butter',
#  'sesame oil',
#  'broccoli',
#  'beans',
#  'cilantro',
#  'raspberry preserves',
#  'balsamic',
#  'corn',
#  'hazelnut',
#  'kale',
#  'bacon',
#  'asparagus',
#  'avocado',
#  'ravioli',
#  'carrots',
#  'almondmilk',
#  'mushrooms',
#  'waffles',
#  'tomatoes',
#  'danimals',
#  'banana',
#  'apple',
#  'tofu',
#  'tofu',
#  'blueberries',
#  'cheddar',
#  'milk',
#  'bread',
#  'banana',
#  'lettuce',
#  'broccoli',
#  'eggs',
#  'provolone',
#  'tomatoes',
#  'chicken',
#  'turkey',
#  'bagels',
#  'cream cheese',
#  'asparagus',
#  'spinach',
#  'lettuce',
#  'potato',
#  'corn',
#  'avocado',
#  'penne',
#  'veggie burger',
#  'tempeh',
#  'lime',
#  'onion',
#  'chive cream cheese',
#  'vinaigrette',
#  'strawberry',
#  'ice cream',
#  'ice cream',
#  'broccoli',
#  'cheese',
#  'cheese',
#  'cheese',
#  'egg whites',
#  'turkey bacon',
#  'hash browns',
#  'pizza',
#  'macaroni and cheese',
#  'cheese',
#  'carrots',
#  'almond milk',
#  'banana',
#  'grapefruit',
#  'chicken',
#  'egg whites',
#  'spinach',
#  'berry',
#  'avocado',
#  'bananas',
#  'yogurt',
#  'hummus',
#  'hummus',
#  'vegetable broth',
#  'avocado',
#  'carrots',
#  'sour cream',
#  'bell pepper',
#  'tomatoes',
#  'beans',
#  'tofu',
#  'eggplant',
#  'pasta sauce',
#  'kale',
#  'organic',
#  'cheese',
#  'pasta',
#  'clementines',
#  'strawberries',
#  'mango',
#  'veggie burgers',
#  'tomato',
#  'sugar',
#  'flour',
#  'butter',
#  'cream cheese',
#  'chicken',
#  'pears',
#  'buttermilk',
#  'lemon',
#  'fruit spread',
#  'tomato',
#  'cheese',
#  'milk',
#  'heavy whipping cream',
#  'avocado',
#  'milk',
#  'milk',
#  'plum',
#  'apple',
#  'raspberries',
#  'bananas',
#  'cucumbers',
#  'tomatoes',
#  'mango',
#  'soy milk',
#  'onion',
#  'spinach',
#  'cilantro',
#  'grapes',
#  'tomato',
#  'quinoa',
#  'bacon',
#  'onion',
#  'milk',
#  'yogurt',
#  'bananas',
#  'broccoli',
#  'bread',
#  'mixed vegetables',
#  'kirby',
#  'grapes',
#  'clementines',
#  'risotto',
#  'olive',
#  'cheese',
#  'ice cream',
#  'rice pudding',
#  'carrots',
#  'chicken',
#  'sweet potato',
#  'onions',
#  'apple',
#  'spinach',
#  'salami',
#  'milk',
#  'macaroni cheese',
#  'milk',
#  'salami',
#  'fries',
#  'almond',
#  'butter',
#  'bananas',
#  'cheese',
#  'cheese',
#  'cottage cheese',
#  'grapes',
#  'biscuit',
#  'cereal',
#  'chicken',
#  'turkey',
#  'honey',
#  'french onion dip',
#  'chicken pot pie',
#  'waffles',
#  'bagels',
#  'yams',
#  'tortillas',
#  'sour cream',
#  'yogurt',
#  'yogurt',
#  'granola',
#  'cheese',
#  'ham',
#  'chicken',
#  'chicken',
#  'bread',
#  'original',
#  'macaroni cheese',
#  'strawberries',
#  'blueberries',
#  'raspberries',
#  'beef franks',
#  'pineapple',
#  'bone broth',
#  'yogurt',
#  'yokids',
#  'beef broth',
#  'sesame oil',
#  'chicken',
#  'barbeque sauce',
#  'milk',
#  'blueberry',
#  'bananas',
#  'almond milk',
#  'sugar',
#  'yoghurt',
#  'yoghurt',
#  'yoghurt',
#  'basil',
#  'parmesan',
#  'ice cream',
#  'bread',
#  'milk',
#  'potatoes',
#  'rosemary',
#  'squash',
#  'acorn squash',
#  'olive oil',
#  'vinegar',
#  'banana',
#  'apples',
#  'kirby',
#  'granola',
#  'banana',
#  'apples',
#  'avocado',
#  'bread',
#  'veggie burger',
#  'baguette',
#  'tomatoes',
#  'lemon',
#  'yogurt',
#  'tortillas',
#  'blueberries',
#  'cheese',
#  'lemon',
#  'burrata',
#  'french',
#  'banana',
#  'berries',
#  'whipped topping',
#  'cream cheese',
#  'peaches',
#  'butter',
#  'semi',
#  'yogurt',
#  'lemon',
#  'raspberries',
#  'bananas',
#  'pizza',
#  'pizza',
#  'cucumber',
#  'onion',
#  'spaghetti',
#  'eggs',
#  'spinach',
#  'oranges',
#  'bread',
#  'lettuce',
#  'tomato',
#  'asparagus',
#  'apple',
#  'tomato paste',
#  'parmesan',
#  'garlic',
#  'eggs',
#  'blueberries',
#  'biscuits',
#  'avocado',
#  'spinach',
#  'coconut',
#  'spinach',
#  'strawberries',
#  'pear',
#  'apple',
#  'avocado',
#  'french brioche',
#  'marinara sauce',
#  'hommus',
#  'pears',
#  'bananas',
#  'blackberries',
#  'carrots',
#  'yogurt',
#  'tomato sauce',
#  'milk',
#  'bananas',
#  'apples',
#  'raspberries',
#  'honeydew',
#  'grapes',
#  'brownie',
#  'bread',
#  'cheddar',
#  'milk',
#  'onion',
#  'tomatoes',
#  'carrots',
#  'turkey',
#  'spring',
#  'carrots',
#  'grapefruit',
#  'blueberries',
#  'coconut milk',
#  'almondmilk',
#  'cereal',
#  'milk',
#  'half and half',
#  'yogurt',
#  'yogurt',
#  'clementines',
#  'tilapia',
#  'milk',
#  'grapes',
#  'limes',
#  'avocado',
#  'beans',
#  'peppers',
#  'rice',
#  'cream cheese',
#  'garlic powder',
#  'bread',
#  'carrots',
#  'steamfresh',
#  'chicken',
#  'turkey',
#  'bell pepper',
#  'potatoes',
#  'half',
#  'smoothies',
#  'milk',
#  'milk',
#  'soy sauce',
#  'pasta sauce',
#  'milk',
#  'sorbetto',
#  'bananas',
#  'yogurt',
#  'ham',
#  'eggs',
#  'ice cream',
#  'prosciutto',
#  'tomato',
#  'apples',
#  'ginger dressing',
#  'yogurt',
#  'blackberries',
#  'milk',
#  'peanut butter',
#  'carrot',
#  'avocados',
#  'romaine leaf',
#  'hot',
#  'quinoa brown rice with garlic',
#  'yogurt',
#  'chicken',
#  'tilapia',
#  'avocado',
#  'tomatoes',
#  'lemon',
#  'ginger',
#  'cilantro',
#  'limes',
#  'apple',
#  'almondmilk',
#  'pears',
#  'mustard',
#  'potatoes',
#  'buttery',
#  'banana',
#  'mayonnaise',
#  'butter',
#  'milk',
#  'carrots',
#  'olive bread',
#  'spinach',
#  'ginger',
#  'bone broth',
#  'chicken cooking stock',
#  'soy creamer',
#  'egg whites',
#  'ice cream',
#  'ham',
#  'mayonnaise',
#  'bacon',
#  'tomato',
#  'tomato',
#  'yogurt',
#  'mint chip',
#  'short',
#  'blueberries',
#  'arugula',
#  'avocados',
#  'tomatoes',
#  'pizza',
#  'dark',
#  'parmesan',
#  'hummus',
#  'capers',
#  'garlic loaf',
#  'watermelon',
#  'sugar snap peas',
#  'tomatoes',
#  'peppers',
#  'gluten',
#  'soymilk',
#  'peppers',
#  'pepper',
#  'apple',
#  'tomato',
#  'lemon',
#  'pepper',
#  'beyond beef',
#  'onion',
#  'cucumber',
#  'bread',
#  'hummus',
#  'tenders',
#  'pasta sauce',
#  'pasta sauce',
#  'eggs',
#  'veggie burger',
#  'milk',
#  'cheese',
#  'hummus',
#  'strawberries',
#  'milk',
#  'oranges',
#  'yokids',
#  'milk',
#  'banana',
#  'sour cream',
#  'pepper',
#  'blackberries',
#  'spinach',
#  'mushrooms',
#  'almondmilk',
#  'avocado',
#  'acorn squash',
#  'melon',
#  'cucumber',
#  'strawberries',
#  'kiwi',
#  'fancy',
#  'brussels sprouts',
#  'milk',
#  'cream',
#  'corn',
#  'chiles',
#  'hot',
#  'strawberries',
#  'apples',
#  'bananas',
#  'cereal',
#  'almond milk',
#  'pineapple',
#  'pasta',
#  'cheese',
#  'light',
#  'raspberries',
#  'cheese',
#  'onions',
#  'bbq sauce',
#  'milk',
#  'granola',
#  'cilantro',
#  'mint',
#  'coconut',
#  'tomatoes',
#  'strawberries',
#  'grapes',
#  'grapes',
#  'marshmallows',
#  'milk',
#  'english muffins',
#  'strawberries',
#  'salt',
#  'chiles',
#  'turkey',
#  'lettuce',
#  'honey mustard',
#  'arugula',
#  'half and half',
#  'lemon',
#  'smoothie',
#  'yogurt',
#  'banana',
#  'strawberries',
#  'carrots',
#  'hummus',
#  'penne',
#  'avocado',
#  'yogurt',
#  'turkey',
#  'eggs',
#  'cheese',
#  'mango',
#  'atlantic',
#  'kirby',
#  'cucumbers',
#  'broccoli',
#  'lettuce',
#  'carrots',
#  'lemon',
#  'artichokes',
#  'mango',
#  'carrots',
#  'crescent rolls',
#  'tomatoes',
#  'tomato sauce',
#  'tomatoes',
#  'celery',
#  'shredded unsweetened coconut',
#  'fish sticks',
#  'ham',
#  'avocados',
#  'spinach',
#  'smoothie',
#  'rice',
#  'toaster pastries',
#  'hot',
#  'teriyaki sauce',
#  'biscuits',
#  'almond milk',
#  'mustard',
#  'hamburger buns',
#  'tomato',
#  'onions',
#  'salsa',
#  'avocado',
#  'kiwi',
#  'strawberries',
#  'banana',
#  'blackberries',
#  'half half',
#  'bacon',
#  'taco seasoning',
#  'cereal',
#  'taco shells',
#  'milk',
#  'creamer',
#  'sour cream',
#  'soy sauce',
#  'apples',
#  'bananas',
#  'tomato',
#  'turkey',
#  'eggs',
#  'blueberries',
#  'butter',
#  'salmon',
#  'salmon',
#  'cheese',
#  'eggs',
#  'kiwi',
#  'yogurt',
#  'strawberries',
#  'ham',
#  'avocado',
#  'cheese',
#  'kirby',
#  'sausage',
#  'sausage',
#  'yokids',
#  'ice cream',
#  'yogurt',
#  'ice cream',
#  'macaroni cheese',
#  'breakfast burrito',
#  'yogurt',
#  'yokids',
#  'ham',
#  'peanut butter',
#  'soup',
#  'fruit bars',
#  'everything',
#  'hazelnut spread',
#  'vinegar',
#  'yogurt',
#  'bread',
#  'hot',
#  'sausages',
#  'cream cheese',
#  'soy sauce',
#  'vidalia',
#  'cucumbers',
#  'carrot',
#  'almondmilk',
#  'arugula',
#  'anchovies',
#  'fusilli',
#  'lemon',
#  'tomato',
#  'cherry',
#  'raspberries',
#  'romaine',
#  'cauliflower',
#  'avocados',
#  'salsa',
#  'kale',
#  'pasta',
#  'turkey',
#  'yogurt',
#  'blackberries',
#  'watermelon',
#  'ice cream',
#  'bananas',
#  'macaroni cheese',
#  'yokids',
#  'grapes',
#  'apple',
#  'appleapple',
#  'milk',
#  'milk',
#  'eggs',
#  'milk',
#  'eggs',
#  'pepperoni',
#  'sausage',
#  'sausage',
#  'cookie dough',
#  'hamburger buns',
#  'cheese',
#  'almond',
#  'ice cream',
#  'peppers',
#  'macaroni cheese',
#  'rice',
#  'pasta',
#  'biscuit',
#  'bell pepper',
#  'pasta',
#  'rice',
#  'hashed browns',
#  'potatoes',
#  'pasta',
#  'vodka sauce pasta sauce',
#  'pasta sauce',
#  'chilies',
#  'onions',
#  'french fried',
#  'peppers',
#  'mustard',
#  'chard',
#  'cucumber',
#  'milk',
#  'peanut butter',
#  'milk',
#  'ketchup',
#  'cheese',
#  'watermelon',
#  'dressing',
#  'butter',
#  'strawberries',
#  'cheese',
#  'soup',
#  'soup',
#  'soup',
#  'mixed vegetables',
#  'light',
#  'donuts',
#  'turkey',
#  'lemon',
#  'almond milk',
#  'beef',
#  'cotija',
#  'radish',
#  'banana',
#  'lettuce',
#  'tomato',
#  'peppers',
#  'strawberries',
#  'turkey',
#  'chicken',
#  'kirby',
#  'eggs',
#  'almond milk',
#  'bread',
#  'spinach',
#  'nectarine',
#  'potato',
#  'cheese',
#  'yogurt',
#  'ranch',
#  'eggs',
#  'cheese',
#  'sugar',
#  'pizza',
#  'chicken',
#  'pizza',
#  'milk',
#  'asian',
#  'soy milk',
#  'marinara sauce',
#  'frozen',
#  'rice',
#  'eggs',
#  'cauliflower',
#  'turkey',
#  'butter',
#  'heavy whipping cream',
#  'sour cream',
#  'hot sauce',
#  'cream cheese',
#  'cereal',
#  'spinach',
#  'pizza sauce',
#  'english muffins',
#  'cheese',
#  'cucumbers',
#  'bell peppers',
#  'grapes',
#  'asparagus',
#  'pizza dough',
#  'tomato sauce',
#  'tomato paste',
#  'tomato sauce',
#  'onion',
#  'mozzarella',
#  'olive oil',
#  'olives',
#  'berry',
#  'blackberries',
#  'apple',
#  'broccoli',
#  'spinach',
#  'carrots',
#  'cheese',
#  'cottage cheese',
#  'edamame',
#  'cauliflower',
#  'yogurt',
#  'egg whites',
#  'asparagus',
#  'green beans',
#  'peppers',
#  'sugar',
#  'yoghurt',
#  'carrots',
#  'mushrooms',
#  'broccoli',
#  'cheese',
#  'yogurt',
#  'burger',
#  'scallopini',
#  'apple',
#  'blackberries',
#  'squash',
#  'light',
#  'ravioli',
#  'apples',
#  'green beans',
#  'brussels sprouts',
#  'rotini',
#  'kale',
#  'pie crusts',
#  'horseradish',
#  'radish',
#  'broccoli',
#  'parsley',
#  'bread',
#  'cheese',
#  'hummus',
#  'eggs',
#  'turkey',
#  'bananas',
#  'half half',
#  'carrots',
#  'small',
#  'cheese',
#  'macaroni cheese',
#  'pasta sauce',
#  'mozzarella',
#  'blueberries',
#  'orzo',
#  'beans',
#  'beans',
#  'quinoa cluster',
#  'waffles',
#  'pie',
#  'veggie burger',
#  'chicken',
#  'milk',
#  'yogurt',
#  'yogurt',
#  'chicken',
#  'avocado',
#  'granola',
#  'strawberries',
#  'blueberries',
#  'chili',
#  'cinnamon',
#  'creamer',
#  'bread',
#  'sausage',
#  'waffles',
#  'hot',
#  'salami',
#  'peppers',
#  'bananas',
#  'carrots',
#  'kale',
#  'penne',
#  'rice',
#  'dill',
#  'bananas',
#  'smoothie',
#  'cucumbers',
#  'beef',
#  'tomato',
#  'grapefruit',
#  'arugula',
#  'tilapia',
#  'milk',
#  'hommus',
#  'cheese',
#  'tuna',
#  'banana',
#  'cashew milk',
#  'radish',
#  'yogurt',
#  'apple',
#  'tomato sauce',
#  'garlic',
#  'onion',
#  'coconut milk',
#  'lemon',
#  'garlic',
#  'cilantro',
#  'parsley',
#  'dill',
#  'zucchini',
#  'potato',
#  'onion',
#  'kale',
#  'kale',
#  'tomatoes',
#  'radish',
#  'yogurt',
#  'saffron',
#  'beans',
#  'oil',
#  'paper',
#  'bread',
#  'bread',
#  'cereal',
#  'peanut butter',
#  '',
#  'almond milk',
#  'almond milk',
#  'hummus',
#  'seitan',
#  'seitan',
#  'vegan',
#  'sweet potato',
#  'rice drink',
#  'carrots',
#  'milk',
#  'marinara sauce',
#  'waffles',
#  'cheese',
#  'yogurt',
#  'bagels',
#  'peas',
#  'cucumbers',
#  'yogurt',
#  'ice cream',
#  'seaweed',
#  'ice cream',
#  'spinach',
#  'spinach half',
#  'pickles',
#  'avocado',
#  'eggs',
#  'cream cheese',
#  'onion',
#  'apple sauce',
#  'pork',
#  'peas',
#  'potato',
#  'onion',
#  'spinach',
#  'parmesan',
#  'soup',
#  '',
#  'beans',
#  'eggs',
#  'granola',
#  'honey granola',
#  'milk',
#  'milk',
#  'milk',
#  'milk',
#  'cheese',
#  'cayenne pepper sauce',
#  'ranch',
#  'lemon',
#  'banana',
#  'onions',
#  'onion',
#  'sweet potato',
#  'honey',
#  'kale',
#  'apple',
#  ...]

# %%
baskets['new_prod_list'] = prod_list_new

# %%
len(baskets)
# Out:
# 24890363

# %%
baskets.to_csv('../../data/05_model_output/baskets_newprodlist_2.csv', index=False)
