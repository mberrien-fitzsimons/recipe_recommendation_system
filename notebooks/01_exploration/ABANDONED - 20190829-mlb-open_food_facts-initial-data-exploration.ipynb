# %% [markdown]
# # Open Food Facts Initial Data Exploration

# %%
import bson

# %%
a = bson.dumps({"A":[1,2,3,4,5,"6", u"7", {"C":u"DS"}]})
b = bson.loads(a)
b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-68680737871c> in <module>
# ----> 1 a = bson.dumps({"A":[1,2,3,4,5,"6", u"7", {"C":u"DS"}]})
#       2 b = bson.loads(a)
#       3 b
#
# AttributeError: module 'bson' has no attribute 'dumps'

# %%
with open('../../data/01_raw/open_nutrition_database_dump/off/products.bson','rb') as f:
    data = bson.loads(f.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-45bfdee09411> in <module>
#       1 with open('../../data/01_raw/open_nutrition_database_dump/off/products.bson','rb') as f:
# ----> 2     data = bson.loads(f.read())
#
# AttributeError: module 'bson' has no attribute 'loads'

# %%
bson_file = open('../../data/01_raw/open_nutrition_database_dump/off/products.bson', 'rb')

b = bson.loads(bson_file.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-20da9de002a7> in <module>
#       1 bson_file = open('../../data/01_raw/open_nutrition_database_dump/off/products.bson', 'rb')
#       2
# ----> 3 b = bson.loads(bson_file.read())
#
# AttributeError: module 'bson' has no attribute 'loads'

# %%
help(bson)
# Out:
# Help on package bson:
#
# NAME
#     bson - BSON (Binary JSON) encoding and decoding.
#
# DESCRIPTION
#     The mapping from Python types to BSON types is as follows:
#
#     =======================================  =============  ===================
#     Python Type                              BSON Type      Supported Direction
#     =======================================  =============  ===================
#     None                                     null           both
#     bool                                     boolean        both
#     int [#int]_                              int32 / int64  py -> bson
#     long                                     int64          py -> bson
#     `bson.int64.Int64`                       int64          both
#     float                                    number (real)  both
#     string                                   string         py -> bson
#     unicode                                  string         both
# ...

# %%
bson.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8fdc5019ecc8> in <module>
# ----> 1 bson.dumps('../../data/01_raw/open_nutrition_database_dump/off/products.bson')
#
# AttributeError: module 'bson' has no attribute 'dumps'
