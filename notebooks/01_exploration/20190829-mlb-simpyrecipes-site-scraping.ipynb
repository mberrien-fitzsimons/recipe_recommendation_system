# %% [markdown]
# # Data Scraping - Simply Recipes

# %% [markdown]
# Source: https://www.simplyrecipes.com/

# %%
import pandas as pd
import scrapy
import re
import time  

from scrapy.linkextractors import LinkExtractor
from scrapy import Selector

from selenium import webdriver    #open webdriver for specific browser
from selenium.webdriver.common.keys import Keys   # for necessary browser action
from selenium.webdriver.common.by import By    # For selecting html code

# %%
pd.set_option('display.max_columns', 500)

# %%
main_url_list = ['https://www.simplyrecipes.com/recipes/main-ingredient/pork/', 
            'https://www.simplyrecipes.com/recipes/ingredient/chicken/', 
            'https://www.simplyrecipes.com/category/eat-your-food/',
            'https://www.simplyrecipes.com/recipes/type/quick/',
            'https://www.simplyrecipes.com/recipes/ingredient/beef/', 
            'https://www.simplyrecipes.com/recipes/main-ingredient/pork/', 
            'https://www.simplyrecipes.com/recipes/ingredient/fish_and_seafood/', 
            'https://www.simplyrecipes.com/recipes/ingredient/pasta/', 
            'https://www.simplyrecipes.com/recipes/type/budget/', 
            'https://www.simplyrecipes.com/recipes/type/baking/',
            'https://www.simplyrecipes.com/recipes/course/dessert/', 
            'https://www.simplyrecipes.com/recipes/diet/allergy-friendly/',
            'https://www.simplyrecipes.com/recipes/diet/dairy-free/', 
            'https://www.simplyrecipes.com/recipes/diet/gluten-free/', 
            'https://www.simplyrecipes.com/recipes/diet/low_carb/', 
            'https://www.simplyrecipes.com/recipes/diet/paleo/', 
            'https://www.simplyrecipes.com/recipes/diet/vegan/', 
            'https://www.simplyrecipes.com/recipes/diet/vegetarian/', 
            'https://www.simplyrecipes.com/recipes/ingredient/egg/', 
            'https://www.simplyrecipes.com/recipes/ingredient/rice/', 
            'https://www.simplyrecipes.com/recipes/ingredient/vegetable/']

# %% [markdown]
# ## Let's pull our recipes

# %%
url = "https://www.google.com/"
browser = webdriver.Chrome('/usr/local/bin/chromedriver')
browser.get(url) #navigate to the page

# %%
url = "https://www.simplyrecipes.com/"
browser = webdriver.Chrome('/usr/local/bin/chromedriver')
browser.get(url) #navigate to the page

links_done = []
for url in main_url_list: 
    browser.get(url)
    for pg_num in range(1, 11):
        page = 'page/{}/'.format(pg_num)
        next_page = url+"{}".format(page)

        try:
            browser.get(next_page)
        except:
            break

        time.sleep(5)

        sel = Selector(text = browser.page_source)

        time.sleep(5)

        all_links = sel.xpath('//*[@id="content"]/ul//li/a').extract()

        for links in all_links:
            links_done.append(re.search('a href=\"(.*)\" title=\"', links).group(1))

links_df = pd.DataFrame(links_done)
links_df.rename(columns={0:'links'}, inplace=True)

# %%
links_list_complete = links_df['links']

# %%
count = 1
title = []
prep_time = []
cook_time = []
recipe_yield = []
tags = []
ingredients = []
entire_card = []

for link in links_list_complete: 
    
    print(str(count) + ' out of ' + str(998))
    browser.get(link)
    
    time.sleep(3)
    
    sel = Selector(text = browser.page_source)
        
    title.append(sel.xpath("//h1[@class='entry-title']/text()").extract())
    prep_time.append(sel.xpath("//div[@class='recipe-meta']/ul/li[1]//text()").extract())
    cook_time.append(sel.xpath("//div[@class='recipe-meta']/ul/li[2]//text()").extract())
    recipe_yield.append(sel.xpath("//div[@class='recipe-meta']/ul/li[3]//text()").extract())
    tags.append(sel.xpath("//div[@class='category-bar']//text()").extract())
    ingredients.append(sel.xpath("//div[@class='entry-details recipe-ingredients']//text()").extract())
    entire_card.append(sel.xpath("//div[@id='sr-recipe-callout']//text()").extract())

    count = count + 1
# Out:
# 1 out of 998
# 2 out of 998
# 3 out of 998
# 4 out of 998
# 5 out of 998
# 6 out of 998
# 7 out of 998
# 8 out of 998
# 9 out of 998
# 10 out of 998
# 11 out of 998
# 12 out of 998
# 13 out of 998
# 14 out of 998
# 15 out of 998
# 16 out of 998
# 17 out of 998
# 18 out of 998
# 19 out of 998
# 20 out of 998
# 21 out of 998
# 22 out of 998
# 23 out of 998
# 24 out of 998
# 25 out of 998
# 26 out of 998
# 27 out of 998
# 28 out of 998
# 29 out of 998
# 30 out of 998
# 31 out of 998
# 32 out of 998
# 33 out of 998
# 34 out of 998
# 35 out of 998
# 36 out of 998
# 37 out of 998
# 38 out of 998
# 39 out of 998
# 40 out of 998
# 41 out of 998
# 42 out of 998
# 43 out of 998
# 44 out of 998
# 45 out of 998
# 46 out of 998
# 47 out of 998
# 48 out of 998
# 49 out of 998
# 50 out of 998
# 51 out of 998
# 52 out of 998
# 53 out of 998
# 54 out of 998
# 55 out of 998
# 56 out of 998
# 57 out of 998
# 58 out of 998
# 59 out of 998
# 60 out of 998
# 61 out of 998
# 62 out of 998
# 63 out of 998
# 64 out of 998
# 65 out of 998
# 66 out of 998
# 67 out of 998
# 68 out of 998
# 69 out of 998
# 70 out of 998
# 71 out of 998
# 72 out of 998
# 73 out of 998
# 74 out of 998
# 75 out of 998
# 76 out of 998
# 77 out of 998
# 78 out of 998
# 79 out of 998
# 80 out of 998
# 81 out of 998
# 82 out of 998
# 83 out of 998
# 84 out of 998
# 85 out of 998
# 86 out of 998
# 87 out of 998
# 88 out of 998
# 89 out of 998
# 90 out of 998
# 91 out of 998
# 92 out of 998
# 93 out of 998
# 94 out of 998
# 95 out of 998
# 96 out of 998
# 97 out of 998
# 98 out of 998
# 99 out of 998
# 100 out of 998
# 101 out of 998
# 102 out of 998
# 103 out of 998
# 104 out of 998
# 105 out of 998
# 106 out of 998
# 107 out of 998
# 108 out of 998
# 109 out of 998
# 110 out of 998
# 111 out of 998
# 112 out of 998
# 113 out of 998
# 114 out of 998
# 115 out of 998
# 116 out of 998
# 117 out of 998
# 118 out of 998
# 119 out of 998
# 120 out of 998
# 121 out of 998
# 122 out of 998
# 123 out of 998
# 124 out of 998
# 125 out of 998
# 126 out of 998
# 127 out of 998
# 128 out of 998
# 129 out of 998
# 130 out of 998
# 131 out of 998
# 132 out of 998
# 133 out of 998
# 134 out of 998
# 135 out of 998
# 136 out of 998
# 137 out of 998
# 138 out of 998
# 139 out of 998
# 140 out of 998
# 141 out of 998
# 142 out of 998
# 143 out of 998
# 144 out of 998
# 145 out of 998
# 146 out of 998
# 147 out of 998
# 148 out of 998
# 149 out of 998
# 150 out of 998
# 151 out of 998
# 152 out of 998
# 153 out of 998
# 154 out of 998
# 155 out of 998
# 156 out of 998
# 157 out of 998
# 158 out of 998
# 159 out of 998
# 160 out of 998
# 161 out of 998
# 162 out of 998
# 163 out of 998
# 164 out of 998
# 165 out of 998
# 166 out of 998
# 167 out of 998
# 168 out of 998
# 169 out of 998
# 170 out of 998
# 171 out of 998
# 172 out of 998
# 173 out of 998
# 174 out of 998
# 175 out of 998
# 176 out of 998
# 177 out of 998
# 178 out of 998
# 179 out of 998
# 180 out of 998
# 181 out of 998
# 182 out of 998
# 183 out of 998
# 184 out of 998
# 185 out of 998
# 186 out of 998
# 187 out of 998
# 188 out of 998
# 189 out of 998
# 190 out of 998
# 191 out of 998
# 192 out of 998
# 193 out of 998
# 194 out of 998
# 195 out of 998
# 196 out of 998
# 197 out of 998
# 198 out of 998
# 199 out of 998
# 200 out of 998
# 201 out of 998
# 202 out of 998
# 203 out of 998
# 204 out of 998
# 205 out of 998
# 206 out of 998
# 207 out of 998
# 208 out of 998
# 209 out of 998
# 210 out of 998
# 211 out of 998
# 212 out of 998
# 213 out of 998
# 214 out of 998
# 215 out of 998
# 216 out of 998
# 217 out of 998
# 218 out of 998
# 219 out of 998
# 220 out of 998
# 221 out of 998
# 222 out of 998
# 223 out of 998
# 224 out of 998
# 225 out of 998
# 226 out of 998
# 227 out of 998
# 228 out of 998
# 229 out of 998
# 230 out of 998
# 231 out of 998
# 232 out of 998
# 233 out of 998
# 234 out of 998
# 235 out of 998
# 236 out of 998
# 237 out of 998
# 238 out of 998
# 239 out of 998
# 240 out of 998
# 241 out of 998
# 242 out of 998
# 243 out of 998
# 244 out of 998
# 245 out of 998
# 246 out of 998
# 247 out of 998
# 248 out of 998
# 249 out of 998
# 250 out of 998
# 251 out of 998
# 252 out of 998
# 253 out of 998
# 254 out of 998
# 255 out of 998
# 256 out of 998
# 257 out of 998
# 258 out of 998
# 259 out of 998
# 260 out of 998
# 261 out of 998
# 262 out of 998
# 263 out of 998
# 264 out of 998
# 265 out of 998
# 266 out of 998
# 267 out of 998
# 268 out of 998
# 269 out of 998
# 270 out of 998
# 271 out of 998
# 272 out of 998
# 273 out of 998
# 274 out of 998
# 275 out of 998
# 276 out of 998
# 277 out of 998
# 278 out of 998
# 279 out of 998
# 280 out of 998
# 281 out of 998
# 282 out of 998
# 283 out of 998
# 284 out of 998
# 285 out of 998
# 286 out of 998
# 287 out of 998
# 288 out of 998
# 289 out of 998
# 290 out of 998
# 291 out of 998
# 292 out of 998
# 293 out of 998
# 294 out of 998
# 295 out of 998
# 296 out of 998
# 297 out of 998
# 298 out of 998
# 299 out of 998
# 300 out of 998
# 301 out of 998
# 302 out of 998
# 303 out of 998
# 304 out of 998
# 305 out of 998
# 306 out of 998
# 307 out of 998
# 308 out of 998
# 309 out of 998
# 310 out of 998
# 311 out of 998
# 312 out of 998
# 313 out of 998
# 314 out of 998
# 315 out of 998
# 316 out of 998
# 317 out of 998
# 318 out of 998
# 319 out of 998
# 320 out of 998
# 321 out of 998
# 322 out of 998
# 323 out of 998
# 324 out of 998
# 325 out of 998
# 326 out of 998
# 327 out of 998
# 328 out of 998
# 329 out of 998
# 330 out of 998
# 331 out of 998
# 332 out of 998
# 333 out of 998
# 334 out of 998
# 335 out of 998
# 336 out of 998
# 337 out of 998
# 338 out of 998
# 339 out of 998
# 340 out of 998
# 341 out of 998
# 342 out of 998
# 343 out of 998
# 344 out of 998
# 345 out of 998
# 346 out of 998
# 347 out of 998
# 348 out of 998
# 349 out of 998
# 350 out of 998
# 351 out of 998
# 352 out of 998
# 353 out of 998
# 354 out of 998
# 355 out of 998
# 356 out of 998
# 357 out of 998
# 358 out of 998
# 359 out of 998
# 360 out of 998
# 361 out of 998
# 362 out of 998
# 363 out of 998
# 364 out of 998
# 365 out of 998
# 366 out of 998
# 367 out of 998
# 368 out of 998
# 369 out of 998
# 370 out of 998
# 371 out of 998
# 372 out of 998
# 373 out of 998
# 374 out of 998
# 375 out of 998
# 376 out of 998
# 377 out of 998
# 378 out of 998
# 379 out of 998
# 380 out of 998
# 381 out of 998
# 382 out of 998
# 383 out of 998
# 384 out of 998
# 385 out of 998
# 386 out of 998
# 387 out of 998
# 388 out of 998
# 389 out of 998
# 390 out of 998
# 391 out of 998
# 392 out of 998
# 393 out of 998
# 394 out of 998
# 395 out of 998
# 396 out of 998
# 397 out of 998
# 398 out of 998
# 399 out of 998
# 400 out of 998
# 401 out of 998
# 402 out of 998
# 403 out of 998
# 404 out of 998
# 405 out of 998
# 406 out of 998
# 407 out of 998
# 408 out of 998
# 409 out of 998
# 410 out of 998
# 411 out of 998
# 412 out of 998
# 413 out of 998
# 414 out of 998
# 415 out of 998
# 416 out of 998
# 417 out of 998
# 418 out of 998
# 419 out of 998
# 420 out of 998
# 421 out of 998
# 422 out of 998
# 423 out of 998
# 424 out of 998
# 425 out of 998
# 426 out of 998
# 427 out of 998
# 428 out of 998
# 429 out of 998
# 430 out of 998
# 431 out of 998
# 432 out of 998
# 433 out of 998
# 434 out of 998
# 435 out of 998
# 436 out of 998
# 437 out of 998
# 438 out of 998
# 439 out of 998
# 440 out of 998
# 441 out of 998
# 442 out of 998
# 443 out of 998
# 444 out of 998
# 445 out of 998
# 446 out of 998
# 447 out of 998
# 448 out of 998
# 449 out of 998
# 450 out of 998
# 451 out of 998
# 452 out of 998
# 453 out of 998
# 454 out of 998
# 455 out of 998
# 456 out of 998
# 457 out of 998
# 458 out of 998
# 459 out of 998
# 460 out of 998
# 461 out of 998
# 462 out of 998
# 463 out of 998
# 464 out of 998
# 465 out of 998
# 466 out of 998
# 467 out of 998
# 468 out of 998
# 469 out of 998
# 470 out of 998
# 471 out of 998
# 472 out of 998
# 473 out of 998
# 474 out of 998
# 475 out of 998
# 476 out of 998
# 477 out of 998
# 478 out of 998
# 479 out of 998
# 480 out of 998
# 481 out of 998
# 482 out of 998
# 483 out of 998
# 484 out of 998
# 485 out of 998
# 486 out of 998
# 487 out of 998
# 488 out of 998
# 489 out of 998
# 490 out of 998
# 491 out of 998
# 492 out of 998
# 493 out of 998
# 494 out of 998
# 495 out of 998
# 496 out of 998
# 497 out of 998
# 498 out of 998
# 499 out of 998
# 500 out of 998
# 501 out of 998
# 502 out of 998
# 503 out of 998
# 504 out of 998
# 505 out of 998
# 506 out of 998
# 507 out of 998
# 508 out of 998
# 509 out of 998
# 510 out of 998
# 511 out of 998
# 512 out of 998
# 513 out of 998
# 514 out of 998
# 515 out of 998
# 516 out of 998
# 517 out of 998
# 518 out of 998
# 519 out of 998
# 520 out of 998
# 521 out of 998
# 522 out of 998
# 523 out of 998
# 524 out of 998
# 525 out of 998
# 526 out of 998
# 527 out of 998
# 528 out of 998
# 529 out of 998
# 530 out of 998
# 531 out of 998
# 532 out of 998
# 533 out of 998
# 534 out of 998
# 535 out of 998
# 536 out of 998
# 537 out of 998
# 538 out of 998
# 539 out of 998
# 540 out of 998
# 541 out of 998
# 542 out of 998
# 543 out of 998
# 544 out of 998
# 545 out of 998
# 546 out of 998
# 547 out of 998
# 548 out of 998
# 549 out of 998
# 550 out of 998
# 551 out of 998
# 552 out of 998
# 553 out of 998
# 554 out of 998
# 555 out of 998
# 556 out of 998
# 557 out of 998
# 558 out of 998
# 559 out of 998
# 560 out of 998
# 561 out of 998
# 562 out of 998
# 563 out of 998
# 564 out of 998
# 565 out of 998
# 566 out of 998
# 567 out of 998
# 568 out of 998
# 569 out of 998
# 570 out of 998
# 571 out of 998
# 572 out of 998
# 573 out of 998
# 574 out of 998
# 575 out of 998
# 576 out of 998
# 577 out of 998
# 578 out of 998
# 579 out of 998
# 580 out of 998
# 581 out of 998
# 582 out of 998
# 583 out of 998
# 584 out of 998
# 585 out of 998
# 586 out of 998
# 587 out of 998
# 588 out of 998
# 589 out of 998
# 590 out of 998
# 591 out of 998
# 592 out of 998
# 593 out of 998
# 594 out of 998
# 595 out of 998
# 596 out of 998
# 597 out of 998
# 598 out of 998
# 599 out of 998
# 600 out of 998
# 601 out of 998
# 602 out of 998
# 603 out of 998
# 604 out of 998
# 605 out of 998
# 606 out of 998
# 607 out of 998
# 608 out of 998
# 609 out of 998
# 610 out of 998
# 611 out of 998
# 612 out of 998
# 613 out of 998
# 614 out of 998
# 615 out of 998
# 616 out of 998
# 617 out of 998
# 618 out of 998
# 619 out of 998
# 620 out of 998
# 621 out of 998
# 622 out of 998
# 623 out of 998
# 624 out of 998
# 625 out of 998
# 626 out of 998
# 627 out of 998
# 628 out of 998
# 629 out of 998
# 630 out of 998
# 631 out of 998
# 632 out of 998
# 633 out of 998
# 634 out of 998
# 635 out of 998
# 636 out of 998
# 637 out of 998
# 638 out of 998
# 639 out of 998
# 640 out of 998
# 641 out of 998
# 642 out of 998
# 643 out of 998
# 644 out of 998
# 645 out of 998
# 646 out of 998
# 647 out of 998
# 648 out of 998
# 649 out of 998
# 650 out of 998
# 651 out of 998
# 652 out of 998
# 653 out of 998
# 654 out of 998
# 655 out of 998
# 656 out of 998
# 657 out of 998
# 658 out of 998
# 659 out of 998
# 660 out of 998
# 661 out of 998
# 662 out of 998
# 663 out of 998
# 664 out of 998
# 665 out of 998
# 666 out of 998
# 667 out of 998
# 668 out of 998
# 669 out of 998
# 670 out of 998
# 671 out of 998
# 672 out of 998
# 673 out of 998
# 674 out of 998
# 675 out of 998
# 676 out of 998
# 677 out of 998
# 678 out of 998
# 679 out of 998
# 680 out of 998
# 681 out of 998
# 682 out of 998
# 683 out of 998
# 684 out of 998
# 685 out of 998
# 686 out of 998
# 687 out of 998
# 688 out of 998
# 689 out of 998
# 690 out of 998
# 691 out of 998
# 692 out of 998
# 693 out of 998
# 694 out of 998
# 695 out of 998
# 696 out of 998
# 697 out of 998
# 698 out of 998
# 699 out of 998
# 700 out of 998
# 701 out of 998
# 702 out of 998
# 703 out of 998
# 704 out of 998
# 705 out of 998
# 706 out of 998
# 707 out of 998
# 708 out of 998
# 709 out of 998
# 710 out of 998
# 711 out of 998
# 712 out of 998
# 713 out of 998
# 714 out of 998
# 715 out of 998
# 716 out of 998
# 717 out of 998
# 718 out of 998
# 719 out of 998
# 720 out of 998
# 721 out of 998
# 722 out of 998
# 723 out of 998
# 724 out of 998
# 725 out of 998
# 726 out of 998
# 727 out of 998
# 728 out of 998
# 729 out of 998
# 730 out of 998
# 731 out of 998
# 732 out of 998
# 733 out of 998
# 734 out of 998
# 735 out of 998
# 736 out of 998
# 737 out of 998
# 738 out of 998
# 739 out of 998
# 740 out of 998
# 741 out of 998
# 742 out of 998
# 743 out of 998
# 744 out of 998
# 745 out of 998
# 746 out of 998
# 747 out of 998
# 748 out of 998
# 749 out of 998
# 750 out of 998
# 751 out of 998
# 752 out of 998
# 753 out of 998
# 754 out of 998
# 755 out of 998
# 756 out of 998
# 757 out of 998
# 758 out of 998
# 759 out of 998
# 760 out of 998
# 761 out of 998
# 762 out of 998
# 763 out of 998
# 764 out of 998
# 765 out of 998
# 766 out of 998
# 767 out of 998
# 768 out of 998
# 769 out of 998
# 770 out of 998
# 771 out of 998
# 772 out of 998
# 773 out of 998
# 774 out of 998
# 775 out of 998
# 776 out of 998
# 777 out of 998
# 778 out of 998
# 779 out of 998
# 780 out of 998
# 781 out of 998
# 782 out of 998
# 783 out of 998
# 784 out of 998
# 785 out of 998
# 786 out of 998
# 787 out of 998
# 788 out of 998
# 789 out of 998
# 790 out of 998
# 791 out of 998
# 792 out of 998
# 793 out of 998
# 794 out of 998
# 795 out of 998
# 796 out of 998
# 797 out of 998
# 798 out of 998
# 799 out of 998
# 800 out of 998
# 801 out of 998
# 802 out of 998
# 803 out of 998
# 804 out of 998
# 805 out of 998
# 806 out of 998
# 807 out of 998
# 808 out of 998
# 809 out of 998
# 810 out of 998
# 811 out of 998
# 812 out of 998
# 813 out of 998
# 814 out of 998
# 815 out of 998
# 816 out of 998
# 817 out of 998
# 818 out of 998
# 819 out of 998
# 820 out of 998
# 821 out of 998
# 822 out of 998
# 823 out of 998
# 824 out of 998
# 825 out of 998
# 826 out of 998
# 827 out of 998
# 828 out of 998
# 829 out of 998
# 830 out of 998
# 831 out of 998
# 832 out of 998
# 833 out of 998
# 834 out of 998
# 835 out of 998
# 836 out of 998
# 837 out of 998
# 838 out of 998
# 839 out of 998
# 840 out of 998
# 841 out of 998
# 842 out of 998
# 843 out of 998
# 844 out of 998
# 845 out of 998
# 846 out of 998
# 847 out of 998
# 848 out of 998
# 849 out of 998
# 850 out of 998
# 851 out of 998
# 852 out of 998
# 853 out of 998
# 854 out of 998
# 855 out of 998
# 856 out of 998
# 857 out of 998
# 858 out of 998
# 859 out of 998
# 860 out of 998
# 861 out of 998
# 862 out of 998
# 863 out of 998
# 864 out of 998
# 865 out of 998
# 866 out of 998
# 867 out of 998
# 868 out of 998
# 869 out of 998
# 870 out of 998
# 871 out of 998
# 872 out of 998
# 873 out of 998
# 874 out of 998
# 875 out of 998
# 876 out of 998
# 877 out of 998
# 878 out of 998
# 879 out of 998
# 880 out of 998
# 881 out of 998
# 882 out of 998
# 883 out of 998
# 884 out of 998
# 885 out of 998
# 886 out of 998
# 887 out of 998
# 888 out of 998
# 889 out of 998
# 890 out of 998
# 891 out of 998
# 892 out of 998
# 893 out of 998
# 894 out of 998
# 895 out of 998
# 896 out of 998
# 897 out of 998
# 898 out of 998
# 899 out of 998
# 900 out of 998
# 901 out of 998
# 902 out of 998
# 903 out of 998
# 904 out of 998
# 905 out of 998
# 906 out of 998
# 907 out of 998
# 908 out of 998
# 909 out of 998
# 910 out of 998
# 911 out of 998
# 912 out of 998
# 913 out of 998
# 914 out of 998
# 915 out of 998
# 916 out of 998
# 917 out of 998
# 918 out of 998
# 919 out of 998
# 920 out of 998
# 921 out of 998
# 922 out of 998
# 923 out of 998
# 924 out of 998
# 925 out of 998
# 926 out of 998
# 927 out of 998
# 928 out of 998
# 929 out of 998
# 930 out of 998
# 931 out of 998
# 932 out of 998
# 933 out of 998
# 934 out of 998
# 935 out of 998
# 936 out of 998
# 937 out of 998
# 938 out of 998
# 939 out of 998
# 940 out of 998
# 941 out of 998
# 942 out of 998
# 943 out of 998
# 944 out of 998
# 945 out of 998
# 946 out of 998
# 947 out of 998
# 948 out of 998
# 949 out of 998
# 950 out of 998
# 951 out of 998
# 952 out of 998
# 953 out of 998
# 954 out of 998
# 955 out of 998
# 956 out of 998
# 957 out of 998
# 958 out of 998
# 959 out of 998
# 960 out of 998
# 961 out of 998
# 962 out of 998
# 963 out of 998
# 964 out of 998
# 965 out of 998
# 966 out of 998
# 967 out of 998
# 968 out of 998
# 969 out of 998
# 970 out of 998
# 971 out of 998
# 972 out of 998
# 973 out of 998
# 974 out of 998
# 975 out of 998
# 976 out of 998
# 977 out of 998
# 978 out of 998
# 979 out of 998
# 980 out of 998
# 981 out of 998
# 982 out of 998
# 983 out of 998
# 984 out of 998
# 985 out of 998
# 986 out of 998
# 987 out of 998
# 988 out of 998
# 989 out of 998
# 990 out of 998
# 991 out of 998
# 992 out of 998
# 993 out of 998
# 994 out of 998
# 995 out of 998
# 996 out of 998
# 997 out of 998
# 998 out of 998
# 999 out of 998
# 1000 out of 998

# %% [markdown]
# ### Let's save everything to a CSV

# %%
d = {'title':title,'prep_time':prep_time, 'cook_time':cook_time, 'recipe_yield':recipe_yield, 'tags':tags, 'ingredients':ingredients, 'entire_card':entire_card}
df_sr =  pd.DataFrame(d)
links = list(links_list_complete)
df_sr['recipe_links'] = links

# %%
df_sr.to_csv('../../data/01_raw/simply_recipes.csv')

# %% [markdown]
# ## Let's make a function

# %%
def scrape_simplyrecipes_data():   
    # List of main URLs to scrape (collected by hand from simplyrecipes.com)
    main_url_list = ['https://www.simplyrecipes.com/recipes/main-ingredient/pork/', 
                'https://www.simplyrecipes.com/recipes/ingredient/chicken/', 
                'https://www.simplyrecipes.com/category/eat-your-food/',
                'https://www.simplyrecipes.com/recipes/type/quick/',
                'https://www.simplyrecipes.com/recipes/ingredient/beef/', 
                'https://www.simplyrecipes.com/recipes/main-ingredient/pork/', 
                'https://www.simplyrecipes.com/recipes/ingredient/fish_and_seafood/', 
                'https://www.simplyrecipes.com/recipes/ingredient/pasta/', 
                'https://www.simplyrecipes.com/recipes/type/budget/', 
                'https://www.simplyrecipes.com/recipes/type/baking/',
                'https://www.simplyrecipes.com/recipes/course/dessert/', 
                'https://www.simplyrecipes.com/recipes/diet/allergy-friendly/',
                'https://www.simplyrecipes.com/recipes/diet/dairy-free/', 
                'https://www.simplyrecipes.com/recipes/diet/gluten-free/', 
                'https://www.simplyrecipes.com/recipes/diet/low_carb/', 
                'https://www.simplyrecipes.com/recipes/diet/paleo/', 
                'https://www.simplyrecipes.com/recipes/diet/vegan/', 
                'https://www.simplyrecipes.com/recipes/diet/vegetarian/', 
                'https://www.simplyrecipes.com/recipes/ingredient/egg/', 
                'https://www.simplyrecipes.com/recipes/ingredient/rice/', 
                'https://www.simplyrecipes.com/recipes/ingredient/vegetable/']

    url = "https://www.simplyrecipes.com/"
    browser = webdriver.Chrome('/usr/local/bin/chromedriver')
    browser.get(url) #navigate to the page

    links_done = []
    for url in main_url_list: 
        browser.get(url)
        for pg_num in range(1, 11):
            page = 'page/{}/'.format(pg_num)
            next_page = url+"{}".format(page)

            try:
                browser.get(next_page)
            except:
                break

            time.sleep(5)

            sel = Selector(text = browser.page_source)

            time.sleep(5)

            all_links = sel.xpath('//*[@id="content"]/ul//li/a').extract()

            for links in all_links:
                links_done.append(re.search('a href=\"(.*)\" title=\"', links).group(1))

    links_df = pd.DataFrame(links_done)
    links_df.rename(columns={0:'links'}, inplace=True)

    links_list_complete = links_df['links']

    title = []
    prep_time = []
    cook_time = []
    recipe_yield = []
    tags = []
    ingredients = []
    entire_card = []
    byline = []
    link_food = []

    count = 1
    for link in links_list_complete: 

        print(str(count) + ' out of ' + str(998))
        browser.get(link)

        time.sleep(3)

        sel = Selector(text = browser.page_source)

        title.append(sel.xpath("//h1[@class='entry-title']/text()").extract())
        prep_time.append(sel.xpath("//div[@class='recipe-meta']/ul/li[1]//text()").extract())
        cook_time.append(sel.xpath("//div[@class='recipe-meta']/ul/li[2]//text()").extract())
        recipe_yield.append(sel.xpath("//div[@class='recipe-meta']/ul/li[3]//text()").extract())
        tags.append(sel.xpath("//div[@class='category-bar']//text()").extract())
        ingredients.append(sel.xpath("//div[@class='entry-details recipe-ingredients']//text()").extract())
        entire_card.append(sel.xpath("//div[@id='sr-recipe-callout']//text()").extract())
        byline.append(sel.xpath("//span[@class='entry-byline']//text()").extract())
    #     link_food.append(sel.xpath("//div[@id='sr-recipe-callout']//text()").extract())

        exec("df{} = pd.DataFrame(zip(title, prep_time, cook_time, recipe_yield, tags, ingredients, entire_card, byline), columns =['title', 'prep_time', 'cook_time', 'recipe_yield', 'tags', 'ingredients', 'entire_card', 'byline'])".format(count))
        exec("df{}.to_csv('../../data/01_raw/simply_recipes/simply_recipes_{}.csv')".format(count, count))

        count = count + 1
